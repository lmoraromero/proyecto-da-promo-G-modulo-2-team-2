# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION 

#cortos del  año 2021: 25024 45354

execution_number = 1 #la primera vez que tiro pongo 1, la segunda pongo un 2, la 3..
initial_counter = 10001 #desde donde empiezo la tirada. Indice de inicio. 
incremental = 1000 #el numero de pelis que quiero sacar. PARA PELIS PONER 1000 Y PARA CORTOS PONER 3000.

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    # driver.maximize_window()
    if accept_cookies:
        sleep(2)
        # Aceptar las cookies PAG IMDB
        driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
        print("cookies accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
        
            try:
                nombre = elemento.find_element("css selector", "span").text
                    
                if nombre == "Dirección":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                    except:
                        directors = "DESCONOCIDO"
                    

                elif nombre == "Guión":
                    
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                    except:
                        scripters = "DESCONOCIDO"
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("union_peliculas.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt30396355...
# url loaded
# Getting attributes for tt30396355
# Getting cast for tt30396355
# time to obtain tt30396355 with position 10001 was 1 seconds
# getting url with title/tt30790147...
# url loaded
# Getting attributes for tt30790147
# Getting cast for tt30790147
# time to obtain tt30790147 with position 10002 was 1 seconds
# getting url with title/tt30826481...
# url loaded
# Getting attributes for tt30826481
# Getting cast for tt30826481
# time to obtain tt30826481 with position 10003 was 1 seconds
# getting url with title/tt30850344...
# url loaded
# Getting attributes for tt30850344
# Getting cast for tt30850344
# time to obtain tt30850344 with position 10004 was 1 seconds
# getting url with title/tt0138992...
# url loaded
# Getting attributes for tt0138992
# Getting cast for tt0138992
# time to obtain tt0138992 with position 10005 was 2 seconds
# getting url with title/tt0168721...
# url loaded
# Getting attributes for tt0168721
# Getting cast for tt0168721
# time to obtain tt0168721 with position 10006 was 2 seconds
# getting url with title/tt0180283...
# url loaded
# Getting attributes for tt0180283
# Getting cast for tt0180283
# time to obtain tt0180283 with position 10007 was 3 seconds
# getting url with title/tt0367683...
# url loaded
# Getting attributes for tt0367683
# Getting cast for tt0367683
# time to obtain tt0367683 with position 10008 was 1 seconds
# getting url with title/tt0369072...
# url loaded
# Getting attributes for tt0369072
# Getting cast for tt0369072
# time to obtain tt0369072 with position 10009 was 2 seconds
# getting url with title/tt0381658...
# url loaded
# Getting attributes for tt0381658
# Getting cast for tt0381658
# time to obtain tt0381658 with position 10010 was 2 seconds
# getting url with title/tt0400931...
# url loaded
# Getting attributes for tt0400931
# Getting cast for tt0400931
# time to obtain tt0400931 with position 10011 was 2 seconds
# getting url with title/tt0417175...
# url loaded
# Getting attributes for tt0417175
# Getting cast for tt0417175
# time to obtain tt0417175 with position 10012 was 2 seconds
# getting url with title/tt0419137...
# url loaded
# Getting attributes for tt0419137
# Getting cast for tt0419137
# time to obtain tt0419137 with position 10013 was 2 seconds
# getting url with title/tt0449081...
# url loaded
# Getting attributes for tt0449081
# Getting cast for tt0449081
# time to obtain tt0449081 with position 10014 was 3 seconds
# getting url with title/tt0457447...
# url loaded
# Getting attributes for tt0457447
# Getting cast for tt0457447
# time to obtain tt0457447 with position 10015 was 2 seconds
# getting url with title/tt0462382...
# url loaded
# Getting attributes for tt0462382
# Getting cast for tt0462382
# time to obtain tt0462382 with position 10016 was 3 seconds
# getting url with title/tt0466878...
# url loaded
# Getting attributes for tt0466878
# Getting cast for tt0466878
# time to obtain tt0466878 with position 10017 was 2 seconds
# getting url with title/tt0472223...
# url loaded
# Getting attributes for tt0472223
# Getting cast for tt0472223
# time to obtain tt0472223 with position 10018 was 3 seconds
# getting url with title/tt0479630...
# url loaded
# Getting attributes for tt0479630
# Getting cast for tt0479630
# time to obtain tt0479630 with position 10019 was 2 seconds
# getting url with title/tt0481810...
# url loaded
# Getting attributes for tt0481810
# Getting cast for tt0481810
# time to obtain tt0481810 with position 10020 was 2 seconds
# getting url with title/tt0485506...
# url loaded
# Getting attributes for tt0485506
# Getting cast for tt0485506
# time to obtain tt0485506 with position 10021 was 2 seconds
# getting url with title/tt0486039...
# url loaded
# Getting attributes for tt0486039
# Getting cast for tt0486039
# time to obtain tt0486039 with position 10022 was 4 seconds
# getting url with title/tt0488052...
# url loaded
# Getting attributes for tt0488052
# Getting cast for tt0488052
# time to obtain tt0488052 with position 10023 was 2 seconds
# getting url with title/tt0488769...
# url loaded
# Getting attributes for tt0488769
# Getting cast for tt0488769
# time to obtain tt0488769 with position 10024 was 2 seconds
# getting url with title/tt0490908...
# url loaded
# Getting attributes for tt0490908
# Getting cast for tt0490908
# time to obtain tt0490908 with position 10025 was 2 seconds
# getting url with title/tt0492981...
# url loaded
# Getting attributes for tt0492981
# Getting cast for tt0492981
# time to obtain tt0492981 with position 10026 was 1 seconds
# getting url with title/tt0492984...
# url loaded
# Getting attributes for tt0492984
# Getting cast for tt0492984
# time to obtain tt0492984 with position 10027 was 2 seconds
# getting url with title/tt0492961...
# url loaded
# Getting attributes for tt0492961
# Getting cast for tt0492961
# time to obtain tt0492961 with position 10028 was 2 seconds
# getting url with title/tt0493467...
# url loaded
# Getting attributes for tt0493467
# Getting cast for tt0493467
# time to obtain tt0493467 with position 10029 was 2 seconds
# getting url with title/tt0492974...
# url loaded
# Getting attributes for tt0492974
# Getting cast for tt0492974
# time to obtain tt0492974 with position 10030 was 2 seconds
# getting url with title/tt0493019...
# url loaded
# Getting attributes for tt0493019
# Getting cast for tt0493019
# time to obtain tt0493019 with position 10031 was 2 seconds
# getting url with title/tt0493444...
# url loaded
# Getting attributes for tt0493444
# Getting cast for tt0493444
# time to obtain tt0493444 with position 10032 was 2 seconds
# getting url with title/tt0492978...
# url loaded
# Getting attributes for tt0492978
# Getting cast for tt0492978
# time to obtain tt0492978 with position 10033 was 1 seconds
# getting url with title/tt0492940...
# url loaded
# Getting attributes for tt0492940
# Getting cast for tt0492940
# time to obtain tt0492940 with position 10034 was 3 seconds
# getting url with title/tt0493055...
# url loaded
# Getting attributes for tt0493055
# Getting cast for tt0493055
# time to obtain tt0493055 with position 10035 was 1 seconds
# getting url with title/tt0493457...
# url loaded
# Getting attributes for tt0493457
# Getting cast for tt0493457
# time to obtain tt0493457 with position 10036 was 2 seconds
# getting url with title/tt0492999...
# url loaded
# Getting attributes for tt0492999
# Getting cast for tt0492999
# time to obtain tt0492999 with position 10037 was 2 seconds
# getting url with title/tt0493392...
# url loaded
# Getting attributes for tt0493392
# Getting cast for tt0493392
# time to obtain tt0493392 with position 10038 was 3 seconds
# getting url with title/tt0493017...
# url loaded
# Getting attributes for tt0493017
# Getting cast for tt0493017
# time to obtain tt0493017 with position 10039 was 2 seconds
# getting url with title/tt0493413...
# url loaded
# Getting attributes for tt0493413
# Getting cast for tt0493413
# time to obtain tt0493413 with position 10040 was 1 seconds
# getting url with title/tt0492986...
# url loaded
# Getting attributes for tt0492986
# Getting cast for tt0492986
# time to obtain tt0492986 with position 10041 was 3 seconds
# getting url with title/tt0492621...
# url loaded
# Getting attributes for tt0492621
# Getting cast for tt0492621
# time to obtain tt0492621 with position 10042 was 4 seconds
# getting url with title/tt0495341...
# url loaded
# Getting attributes for tt0495341
# Getting cast for tt0495341
# time to obtain tt0495341 with position 10043 was 2 seconds
# getting url with title/tt0493036...
# url loaded
# Getting attributes for tt0493036
# Getting cast for tt0493036
# time to obtain tt0493036 with position 10044 was 4 seconds
# getting url with title/tt0496349...
# url loaded
# Getting attributes for tt0496349
# Getting cast for tt0496349
# time to obtain tt0496349 with position 10045 was 5 seconds
# getting url with title/tt0496609...
# url loaded
# Getting attributes for tt0496609
# Getting cast for tt0496609
# time to obtain tt0496609 with position 10046 was 3 seconds
# getting url with title/tt0497493...
# url loaded
# Getting attributes for tt0497493
# Getting cast for tt0497493
# time to obtain tt0497493 with position 10047 was 2 seconds
# getting url with title/tt0497918...
# url loaded
# Getting attributes for tt0497918
# Getting cast for tt0497918
# time to obtain tt0497918 with position 10048 was 2 seconds
# getting url with title/tt0498338...
# url loaded
# Getting attributes for tt0498338
# Getting cast for tt0498338
# time to obtain tt0498338 with position 10049 was 2 seconds
# getting url with title/tt0498912...
# url loaded
# Getting attributes for tt0498912
# Getting cast for tt0498912
# time to obtain tt0498912 with position 10050 was 3 seconds
# getting url with title/tt0498497...
# url loaded
# Getting attributes for tt0498497
# Getting cast for tt0498497
# time to obtain tt0498497 with position 10051 was 2 seconds
# getting url with title/tt0499441...
# url loaded
# Getting attributes for tt0499441
# Getting cast for tt0499441
# time to obtain tt0499441 with position 10052 was 3 seconds
# getting url with title/tt0499564...
# url loaded
# Getting attributes for tt0499564
# Getting cast for tt0499564
# time to obtain tt0499564 with position 10053 was 4 seconds
# getting url with title/tt0756656...
# url loaded
# Getting attributes for tt0756656
# Getting cast for tt0756656
# time to obtain tt0756656 with position 10054 was 3 seconds
# getting url with title/tt0756643...
# url loaded
# Getting attributes for tt0756643
# Getting cast for tt0756643
# time to obtain tt0756643 with position 10055 was 4 seconds
# getting url with title/tt0756663...
# url loaded
# Getting attributes for tt0756663
# Getting cast for tt0756663
# time to obtain tt0756663 with position 10056 was 5 seconds
# getting url with title/tt0756628...
# url loaded
# Getting attributes for tt0756628
# Getting cast for tt0756628
# time to obtain tt0756628 with position 10057 was 2 seconds
# getting url with title/tt0757287...
# url loaded
# Getting attributes for tt0757287
# Getting cast for tt0757287
# time to obtain tt0757287 with position 10058 was 5 seconds
# getting url with title/tt0756708...
# url loaded
# Getting attributes for tt0756708
# Getting cast for tt0756708
# time to obtain tt0756708 with position 10059 was 5 seconds
# getting url with title/tt0756638...
# url loaded
# Getting attributes for tt0756638
# Getting cast for tt0756638
# time to obtain tt0756638 with position 10060 was 3 seconds
# getting url with title/tt0756713...
# url loaded
# Getting attributes for tt0756713
# Getting cast for tt0756713
# time to obtain tt0756713 with position 10061 was 6 seconds
# getting url with title/tt0757349...
# url loaded
# Getting attributes for tt0757349
# Getting cast for tt0757349
# time to obtain tt0757349 with position 10062 was 4 seconds
# getting url with title/tt0756642...
# url loaded
# Getting attributes for tt0756642
# Getting cast for tt0756642
# time to obtain tt0756642 with position 10063 was 3 seconds
# getting url with title/tt0757234...
# url loaded
# Getting attributes for tt0757234
# Getting cast for tt0757234
# time to obtain tt0757234 with position 10064 was 3 seconds
# getting url with title/tt0757375...
# url loaded
# Getting attributes for tt0757375
# Getting cast for tt0757375
# time to obtain tt0757375 with position 10065 was 4 seconds
# getting url with title/tt0756627...
# url loaded
# Getting attributes for tt0756627
# Getting cast for tt0756627
# time to obtain tt0756627 with position 10066 was 6 seconds
# getting url with title/tt0758041...
# url loaded
# Getting attributes for tt0758041
# Getting cast for tt0758041
# time to obtain tt0758041 with position 10067 was 6 seconds
# getting url with title/tt0756651...
# url loaded
# Getting attributes for tt0756651
# Getting cast for tt0756651
# time to obtain tt0756651 with position 10068 was 4 seconds
# getting url with title/tt0760495...
# url loaded
# Getting attributes for tt0760495
# Getting cast for tt0760495
# time to obtain tt0760495 with position 10069 was 4 seconds
# getting url with title/tt0763312...
# url loaded
# Getting attributes for tt0763312
# Getting cast for tt0763312
# time to obtain tt0763312 with position 10070 was 3 seconds
# getting url with title/tt0765016...
# url loaded
# Getting attributes for tt0765016
# Getting cast for tt0765016
# time to obtain tt0765016 with position 10071 was 3 seconds
# getting url with title/tt0764642...
# url loaded
# Getting attributes for tt0764642
# Getting cast for tt0764642
# time to obtain tt0764642 with position 10072 was 7 seconds
# getting url with title/tt0764645...
# url loaded
# Getting attributes for tt0764645
# Getting cast for tt0764645
# time to obtain tt0764645 with position 10073 was 3 seconds
# getting url with title/tt0765115...
# url loaded
# Getting attributes for tt0765115
# Getting cast for tt0765115
# time to obtain tt0765115 with position 10074 was 4 seconds
# getting url with title/tt0765133...
# url loaded
# Getting attributes for tt0765133
# Getting cast for tt0765133
# time to obtain tt0765133 with position 10075 was 3 seconds
# getting url with title/tt0766212...
# url loaded
# Getting attributes for tt0766212
# Getting cast for tt0766212
# time to obtain tt0766212 with position 10076 was 3 seconds
# getting url with title/tt0766217...
# url loaded
# Getting attributes for tt0766217
# Getting cast for tt0766217
# time to obtain tt0766217 with position 10077 was 3 seconds
# getting url with title/tt0766218...
# url loaded
# Getting attributes for tt0766218
# Getting cast for tt0766218
# time to obtain tt0766218 with position 10078 was 4 seconds
# getting url with title/tt0766222...
# url loaded
# Getting attributes for tt0766222
# Getting cast for tt0766222
# time to obtain tt0766222 with position 10079 was 8 seconds
# getting url with title/tt0768174...
# url loaded
# Getting attributes for tt0768174
# Getting cast for tt0768174
# time to obtain tt0768174 with position 10080 was 4 seconds
# getting url with title/tt0768793...
# url loaded
# Getting attributes for tt0768793
# Getting cast for tt0768793
# time to obtain tt0768793 with position 10081 was 4 seconds
# getting url with title/tt0768810...
# url loaded
# Getting attributes for tt0768810
# Getting cast for tt0768810
# time to obtain tt0768810 with position 10082 was 7 seconds
# getting url with title/tt0768213...
# url loaded
# Getting attributes for tt0768213
# Getting cast for tt0768213
# time to obtain tt0768213 with position 10083 was 4 seconds
# getting url with title/tt0770817...
# url loaded
# Getting attributes for tt0770817
# Getting cast for tt0770817
# time to obtain tt0770817 with position 10084 was 7 seconds
# getting url with title/tt0772253...
# url loaded
# Getting attributes for tt0772253
# Getting cast for tt0772253
# time to obtain tt0772253 with position 10085 was 3 seconds
# getting url with title/tt0774033...
# url loaded
# Getting attributes for tt0774033
# Getting cast for tt0774033
# time to obtain tt0774033 with position 10086 was 3 seconds
# getting url with title/tt0774041...
# url loaded
# Getting attributes for tt0774041
# Getting cast for tt0774041
# time to obtain tt0774041 with position 10087 was 3 seconds
# getting url with title/tt0772234...
# url loaded
# Getting attributes for tt0772234
# Getting cast for tt0772234
# time to obtain tt0772234 with position 10088 was 7 seconds
# getting url with title/tt0772218...
# url loaded
# Getting attributes for tt0772218
# Getting cast for tt0772218
# time to obtain tt0772218 with position 10089 was 3 seconds
# getting url with title/tt0774754...
# url loaded
# Getting attributes for tt0774754
# Getting cast for tt0774754
# time to obtain tt0774754 with position 10090 was 4 seconds
# getting url with title/tt0774046...
# url loaded
# Getting attributes for tt0774046
# Getting cast for tt0774046
# time to obtain tt0774046 with position 10091 was 6 seconds
# getting url with title/tt0773756...
# url loaded
# Getting attributes for tt0773756
# Getting cast for tt0773756
# time to obtain tt0773756 with position 10092 was 10 seconds
# getting url with title/tt0774123...
# url loaded
# Getting attributes for tt0774123
# Getting cast for tt0774123
# time to obtain tt0774123 with position 10093 was 7 seconds
# getting url with title/tt0774704...
# url loaded
# Getting attributes for tt0774704
# Getting cast for tt0774704
# time to obtain tt0774704 with position 10094 was 4 seconds
# getting url with title/tt0774052...
# url loaded
# Getting attributes for tt0774052
# Getting cast for tt0774052
# time to obtain tt0774052 with position 10095 was 5 seconds
# getting url with title/tt0776758...
# url loaded
# Getting attributes for tt0776758
# Getting cast for tt0776758
# time to obtain tt0776758 with position 10096 was 5 seconds
# getting url with title/tt0775504...
# url loaded
# Getting attributes for tt0775504
# Getting cast for tt0775504
# time to obtain tt0775504 with position 10097 was 6 seconds
# getting url with title/tt0775527...
# url loaded
# Getting attributes for tt0775527
# Getting cast for tt0775527
# time to obtain tt0775527 with position 10098 was 4 seconds
# getting url with title/tt0776799...
# url loaded
# Getting attributes for tt0776799
# Getting cast for tt0776799
# time to obtain tt0776799 with position 10099 was 3 seconds
# getting url with title/tt0778912...
# url loaded
# Getting attributes for tt0778912
# Getting cast for tt0778912
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0778912 with position 10100 was 17 seconds
# getting url with title/tt0778903...
# url loaded
# Getting attributes for tt0778903
# Getting cast for tt0778903
# time to obtain tt0778903 with position 10101 was 18 seconds
# getting url with title/tt0776779...
# url loaded
# Getting attributes for tt0776779
# Getting cast for tt0776779
# time to obtain tt0776779 with position 10102 was 1 seconds
# getting url with title/tt0779274...
# url loaded
# Getting attributes for tt0779274
# Getting cast for tt0779274
# time to obtain tt0779274 with position 10103 was 3 seconds
# getting url with title/tt0776764...
# url loaded
# Getting attributes for tt0776764
# Getting cast for tt0776764
# time to obtain tt0776764 with position 10104 was 2 seconds
# getting url with title/tt0776797...
# url loaded
# Getting attributes for tt0776797
# Getting cast for tt0776797
# time to obtain tt0776797 with position 10105 was 2 seconds
# getting url with title/tt0779265...
# url loaded
# Getting attributes for tt0779265
# Getting cast for tt0779265
# time to obtain tt0779265 with position 10106 was 2 seconds
# getting url with title/tt0778680...
# url loaded
# Getting attributes for tt0778680
# Getting cast for tt0778680
# time to obtain tt0778680 with position 10107 was 2 seconds
# getting url with title/tt0779270...
# url loaded
# Getting attributes for tt0779270
# Getting cast for tt0779270
# time to obtain tt0779270 with position 10108 was 3 seconds
# getting url with title/tt0780525...
# url loaded
# Getting attributes for tt0780525
# Getting cast for tt0780525
# time to obtain tt0780525 with position 10109 was 2 seconds
# getting url with title/tt0779763...
# url loaded
# Getting attributes for tt0779763
# Getting cast for tt0779763
# time to obtain tt0779763 with position 10110 was 3 seconds
# getting url with title/tt0779273...
# url loaded
# Getting attributes for tt0779273
# Getting cast for tt0779273
# time to obtain tt0779273 with position 10111 was 4 seconds
# getting url with title/tt0779286...
# url loaded
# Getting attributes for tt0779286
# Getting cast for tt0779286
# time to obtain tt0779286 with position 10112 was 2 seconds
# getting url with title/tt0781451...
# url loaded
# Getting attributes for tt0781451
# Getting cast for tt0781451
# time to obtain tt0781451 with position 10113 was 2 seconds
# getting url with title/tt0781387...
# url loaded
# Getting attributes for tt0781387
# Getting cast for tt0781387
# time to obtain tt0781387 with position 10114 was 3 seconds
# getting url with title/tt0778753...
# url loaded
# Getting attributes for tt0778753
# Getting cast for tt0778753
# time to obtain tt0778753 with position 10115 was 2 seconds
# getting url with title/tt0779275...
# url loaded
# Getting attributes for tt0779275
# Getting cast for tt0779275
# time to obtain tt0779275 with position 10116 was 2 seconds
# getting url with title/tt0782145...
# url loaded
# Getting attributes for tt0782145
# Getting cast for tt0782145
# time to obtain tt0782145 with position 10117 was 3 seconds
# getting url with title/tt0782131...
# url loaded
# Getting attributes for tt0782131
# Getting cast for tt0782131
# time to obtain tt0782131 with position 10118 was 2 seconds
# getting url with title/tt0782862...
# url loaded
# Getting attributes for tt0782862
# Getting cast for tt0782862
# time to obtain tt0782862 with position 10119 was 5 seconds
# getting url with title/tt0782701...
# url loaded
# Getting attributes for tt0782701
# Getting cast for tt0782701
# time to obtain tt0782701 with position 10120 was 2 seconds
# getting url with title/tt0783587...
# url loaded
# Getting attributes for tt0783587
# Getting cast for tt0783587
# time to obtain tt0783587 with position 10121 was 3 seconds
# getting url with title/tt0783728...
# url loaded
# Getting attributes for tt0783728
# Getting cast for tt0783728
# time to obtain tt0783728 with position 10122 was 3 seconds
# getting url with title/tt0783670...
# url loaded
# Getting attributes for tt0783670
# Getting cast for tt0783670
# time to obtain tt0783670 with position 10123 was 2 seconds
# getting url with title/tt0784144...
# url loaded
# Getting attributes for tt0784144
# Getting cast for tt0784144
# time to obtain tt0784144 with position 10124 was 3 seconds
# getting url with title/tt0783741...
# url loaded
# Getting attributes for tt0783741
# Getting cast for tt0783741
# time to obtain tt0783741 with position 10125 was 2 seconds
# getting url with title/tt0784158...
# url loaded
# Getting attributes for tt0784158
# Getting cast for tt0784158
# time to obtain tt0784158 with position 10126 was 3 seconds
# getting url with title/tt0784153...
# url loaded
# Getting attributes for tt0784153
# Getting cast for tt0784153
# time to obtain tt0784153 with position 10127 was 2 seconds
# getting url with title/tt0783732...
# url loaded
# Getting attributes for tt0783732
# Getting cast for tt0783732
# time to obtain tt0783732 with position 10128 was 3 seconds
# getting url with title/tt0785033...
# url loaded
# Getting attributes for tt0785033
# Getting cast for tt0785033
# time to obtain tt0785033 with position 10129 was 3 seconds
# getting url with title/tt0783849...
# url loaded
# Getting attributes for tt0783849
# Getting cast for tt0783849
# time to obtain tt0783849 with position 10130 was 3 seconds
# getting url with title/tt0784833...
# url loaded
# Getting attributes for tt0784833
# Getting cast for tt0784833
# time to obtain tt0784833 with position 10131 was 5 seconds
# getting url with title/tt0786925...
# url loaded
# Getting attributes for tt0786925
# Getting cast for tt0786925
# time to obtain tt0786925 with position 10132 was 3 seconds
# getting url with title/tt0787473...
# url loaded
# Getting attributes for tt0787473
# Getting cast for tt0787473
# time to obtain tt0787473 with position 10133 was 3 seconds
# getting url with title/tt0788148...
# url loaded
# Getting attributes for tt0788148
# Getting cast for tt0788148
# time to obtain tt0788148 with position 10134 was 3 seconds
# getting url with title/tt0787032...
# url loaded
# Getting attributes for tt0787032
# Getting cast for tt0787032
# time to obtain tt0787032 with position 10135 was 2 seconds
# getting url with title/tt0788225...
# url loaded
# Getting attributes for tt0788225
# Getting cast for tt0788225
# time to obtain tt0788225 with position 10136 was 3 seconds
# getting url with title/tt0790664...
# url loaded
# Getting attributes for tt0790664
# Getting cast for tt0790664
# time to obtain tt0790664 with position 10137 was 3 seconds
# getting url with title/tt0788097...
# url loaded
# Getting attributes for tt0788097
# Getting cast for tt0788097
# time to obtain tt0788097 with position 10138 was 3 seconds
# getting url with title/tt0790774...
# url loaded
# Getting attributes for tt0790774
# Getting cast for tt0790774
# time to obtain tt0790774 with position 10139 was 4 seconds
# getting url with title/tt0789772...
# url loaded
# Getting attributes for tt0789772
# Getting cast for tt0789772
# time to obtain tt0789772 with position 10140 was 5 seconds
# getting url with title/tt0789788...
# url loaded
# Getting attributes for tt0789788
# Getting cast for tt0789788
# time to obtain tt0789788 with position 10141 was 2 seconds
# getting url with title/tt0789791...
# url loaded
# Getting attributes for tt0789791
# Getting cast for tt0789791
# time to obtain tt0789791 with position 10142 was 5 seconds
# getting url with title/tt0790466...
# url loaded
# Getting attributes for tt0790466
# Getting cast for tt0790466
# time to obtain tt0790466 with position 10143 was 3 seconds
# getting url with title/tt0791127...
# url loaded
# Getting attributes for tt0791127
# Getting cast for tt0791127
# time to obtain tt0791127 with position 10144 was 2 seconds
# getting url with title/tt0791243...
# url loaded
# Getting attributes for tt0791243
# Getting cast for tt0791243
# time to obtain tt0791243 with position 10145 was 3 seconds
# getting url with title/tt0791129...
# url loaded
# Getting attributes for tt0791129
# Getting cast for tt0791129
# time to obtain tt0791129 with position 10146 was 3 seconds
# getting url with title/tt0791195...
# url loaded
# Getting attributes for tt0791195
# Getting cast for tt0791195
# time to obtain tt0791195 with position 10147 was 4 seconds
# getting url with title/tt0791248...
# url loaded
# Getting attributes for tt0791248
# Getting cast for tt0791248
# time to obtain tt0791248 with position 10148 was 3 seconds
# getting url with title/tt0791212...
# url loaded
# Getting attributes for tt0791212
# Getting cast for tt0791212
# time to obtain tt0791212 with position 10149 was 2 seconds
# getting url with title/tt0791623...
# url loaded
# Getting attributes for tt0791623
# Getting cast for tt0791623
# time to obtain tt0791623 with position 10150 was 3 seconds
# getting url with title/tt0791237...
# url loaded
# Getting attributes for tt0791237
# Getting cast for tt0791237
# time to obtain tt0791237 with position 10151 was 15 seconds
# getting url with title/tt0791628...
# url loaded
# Getting attributes for tt0791628
# Getting cast for tt0791628
# time to obtain tt0791628 with position 10152 was 5 seconds
# getting url with title/tt0791130...
# url loaded
# Getting attributes for tt0791130
# Getting cast for tt0791130
# time to obtain tt0791130 with position 10153 was 3 seconds
# getting url with title/tt0791290...
# url loaded
# Getting attributes for tt0791290
# Getting cast for tt0791290
# time to obtain tt0791290 with position 10154 was 3 seconds
# getting url with title/tt0791109...
# url loaded
# Getting attributes for tt0791109
# Getting cast for tt0791109
# time to obtain tt0791109 with position 10155 was 4 seconds
# getting url with title/tt0791650...
# url loaded
# Getting attributes for tt0791650
# Getting cast for tt0791650
# time to obtain tt0791650 with position 10156 was 4 seconds
# getting url with title/tt0791084...
# url loaded
# Getting attributes for tt0791084
# Getting cast for tt0791084
# time to obtain tt0791084 with position 10157 was 4 seconds
# getting url with title/tt0791226...
# url loaded
# Getting attributes for tt0791226
# Getting cast for tt0791226
# time to obtain tt0791226 with position 10158 was 3 seconds
# getting url with title/tt0791173...
# url loaded
# Getting attributes for tt0791173
# Getting cast for tt0791173
# time to obtain tt0791173 with position 10159 was 3 seconds
# getting url with title/tt0791156...
# url loaded
# Getting attributes for tt0791156
# Getting cast for tt0791156
# time to obtain tt0791156 with position 10160 was 4 seconds
# getting url with title/tt0793434...
# url loaded
# Getting attributes for tt0793434
# Getting cast for tt0793434
# time to obtain tt0793434 with position 10161 was 3 seconds
# getting url with title/tt0793544...
# url loaded
# Getting attributes for tt0793544
# Getting cast for tt0793544
# time to obtain tt0793544 with position 10162 was 6 seconds
# getting url with title/tt0793402...
# url loaded
# Getting attributes for tt0793402
# Getting cast for tt0793402
# time to obtain tt0793402 with position 10163 was 2 seconds
# getting url with title/tt0793404...
# url loaded
# Getting attributes for tt0793404
# Getting cast for tt0793404
# time to obtain tt0793404 with position 10164 was 3 seconds
# getting url with title/tt0794292...
# url loaded
# Getting attributes for tt0794292
# Getting cast for tt0794292
# time to obtain tt0794292 with position 10165 was 3 seconds
# getting url with title/tt0795415...
# url loaded
# Getting attributes for tt0795415
# Getting cast for tt0795415
# time to obtain tt0795415 with position 10166 was 4 seconds
# getting url with title/tt0796208...
# url loaded
# Getting attributes for tt0796208
# Getting cast for tt0796208
# time to obtain tt0796208 with position 10167 was 4 seconds
# getting url with title/tt0796234...
# url loaded
# Getting attributes for tt0796234
# Getting cast for tt0796234
# time to obtain tt0796234 with position 10168 was 2 seconds
# getting url with title/tt0796359...
# url loaded
# Getting attributes for tt0796359
# Getting cast for tt0796359
# time to obtain tt0796359 with position 10169 was 3 seconds
# getting url with title/tt0795485...
# url loaded
# Getting attributes for tt0795485
# Getting cast for tt0795485
# time to obtain tt0795485 with position 10170 was 6 seconds
# getting url with title/tt0796225...
# url loaded
# Getting attributes for tt0796225
# Getting cast for tt0796225
# time to obtain tt0796225 with position 10171 was 7 seconds
# getting url with title/tt0795437...
# url loaded
# Getting attributes for tt0795437
# Getting cast for tt0795437
# time to obtain tt0795437 with position 10172 was 3 seconds
# getting url with title/tt0796837...
# url loaded
# Getting attributes for tt0796837
# Getting cast for tt0796837
# time to obtain tt0796837 with position 10173 was 4 seconds
# getting url with title/tt0796910...
# url loaded
# Getting attributes for tt0796910
# Getting cast for tt0796910
# time to obtain tt0796910 with position 10174 was 3 seconds
# getting url with title/tt0797030...
# url loaded
# Getting attributes for tt0797030
# Getting cast for tt0797030
# time to obtain tt0797030 with position 10175 was 3 seconds
# getting url with title/tt0796928...
# url loaded
# Getting attributes for tt0796928
# Getting cast for tt0796928
# time to obtain tt0796928 with position 10176 was 3 seconds
# getting url with title/tt0796822...
# url loaded
# Getting attributes for tt0796822
# Getting cast for tt0796822
# time to obtain tt0796822 with position 10177 was 7 seconds
# getting url with title/tt0796601...
# url loaded
# Getting attributes for tt0796601
# Getting cast for tt0796601
# time to obtain tt0796601 with position 10178 was 3 seconds
# getting url with title/tt0796606...
# url loaded
# Getting attributes for tt0796606
# Getting cast for tt0796606
# time to obtain tt0796606 with position 10179 was 2 seconds
# getting url with title/tt0796599...
# url loaded
# Getting attributes for tt0796599
# Getting cast for tt0796599
# time to obtain tt0796599 with position 10180 was 3 seconds
# getting url with title/tt0796834...
# url loaded
# Getting attributes for tt0796834
# Getting cast for tt0796834
# time to obtain tt0796834 with position 10181 was 4 seconds
# getting url with title/tt0798793...
# url loaded
# Getting attributes for tt0798793
# Getting cast for tt0798793
# time to obtain tt0798793 with position 10182 was 3 seconds
# getting url with title/tt0798794...
# url loaded
# Getting attributes for tt0798794
# Getting cast for tt0798794
# time to obtain tt0798794 with position 10183 was 5 seconds
# getting url with title/tt0798900...
# url loaded
# Getting attributes for tt0798900
# Getting cast for tt0798900
# time to obtain tt0798900 with position 10184 was 3 seconds
# getting url with title/tt0798790...
# url loaded
# Getting attributes for tt0798790
# Getting cast for tt0798790
# time to obtain tt0798790 with position 10185 was 8 seconds
# getting url with title/tt0800262...
# url loaded
# Getting attributes for tt0800262
# Getting cast for tt0800262
# time to obtain tt0800262 with position 10186 was 7 seconds
# getting url with title/tt0799961...
# url loaded
# Getting attributes for tt0799961
# Getting cast for tt0799961
# time to obtain tt0799961 with position 10187 was 3 seconds
# getting url with title/tt0800120...
# url loaded
# Getting attributes for tt0800120
# Getting cast for tt0800120
# time to obtain tt0800120 with position 10188 was 5 seconds
# getting url with title/tt0800112...
# url loaded
# Getting attributes for tt0800112
# Getting cast for tt0800112
# time to obtain tt0800112 with position 10189 was 5 seconds
# getting url with title/tt0800189...
# url loaded
# Getting attributes for tt0800189
# Getting cast for tt0800189
# time to obtain tt0800189 with position 10190 was 3 seconds
# getting url with title/tt0799955...
# url loaded
# Getting attributes for tt0799955
# Getting cast for tt0799955
# time to obtain tt0799955 with position 10191 was 3 seconds
# getting url with title/tt0800274...
# url loaded
# Getting attributes for tt0800274
# Getting cast for tt0800274
# time to obtain tt0800274 with position 10192 was 4 seconds
# getting url with title/tt0800152...
# url loaded
# Getting attributes for tt0800152
# Getting cast for tt0800152
# time to obtain tt0800152 with position 10193 was 5 seconds
# getting url with title/tt0800013...
# url loaded
# Getting attributes for tt0800013
# Getting cast for tt0800013
# time to obtain tt0800013 with position 10194 was 5 seconds
# getting url with title/tt0800350...
# url loaded
# Getting attributes for tt0800350
# Getting cast for tt0800350
# time to obtain tt0800350 with position 10195 was 5 seconds
# getting url with title/tt0799980...
# url loaded
# Getting attributes for tt0799980
# Getting cast for tt0799980
# time to obtain tt0799980 with position 10196 was 9 seconds
# getting url with title/tt0800008...
# url loaded
# Getting attributes for tt0800008
# error obtaining name for id tt0800008
# Getting cast for tt0800008
# time to obtain tt0800008 with position 10197 was 60 seconds
# getting url with title/tt0800169...
# url loaded
# Getting attributes for tt0800169
# Getting cast for tt0800169
# time to obtain tt0800169 with position 10198 was 6 seconds
# getting url with title/tt0800235...
# url loaded
# Getting attributes for tt0800235
# Getting cast for tt0800235
# time to obtain tt0800235 with position 10199 was 18 seconds
# getting url with title/tt0800213...
# url loaded
# Getting attributes for tt0800213
# Getting cast for tt0800213
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0800213 with position 10200 was 17 seconds
# getting url with title/tt0800198...
# url loaded
# Getting attributes for tt0800198
# Getting cast for tt0800198
# time to obtain tt0800198 with position 10201 was 1 seconds
# getting url with title/tt0799837...
# url loaded
# Getting attributes for tt0799837
# Getting cast for tt0799837
# time to obtain tt0799837 with position 10202 was 1 seconds
# getting url with title/tt0800225...
# url loaded
# Getting attributes for tt0800225
# Getting cast for tt0800225
# time to obtain tt0800225 with position 10203 was 2 seconds
# getting url with title/tt0800072...
# url loaded
# Getting attributes for tt0800072
# Getting cast for tt0800072
# time to obtain tt0800072 with position 10204 was 2 seconds
# getting url with title/tt0800033...
# url loaded
# Getting attributes for tt0800033
# Getting cast for tt0800033
# time to obtain tt0800033 with position 10205 was 2 seconds
# getting url with title/tt0799986...
# url loaded
# Getting attributes for tt0799986
# Getting cast for tt0799986
# time to obtain tt0799986 with position 10206 was 2 seconds
# getting url with title/tt0800245...
# url loaded
# Getting attributes for tt0800245
# Getting cast for tt0800245
# time to obtain tt0800245 with position 10207 was 2 seconds
# getting url with title/tt0800173...
# url loaded
# Getting attributes for tt0800173
# Getting cast for tt0800173
# time to obtain tt0800173 with position 10208 was 2 seconds
# getting url with title/tt0801341...
# url loaded
# Getting attributes for tt0801341
# Getting cast for tt0801341
# time to obtain tt0801341 with position 10209 was 1 seconds
# getting url with title/tt0800961...
# url loaded
# Getting attributes for tt0800961
# Getting cast for tt0800961
# time to obtain tt0800961 with position 10210 was 1 seconds
# getting url with title/tt0800980...
# url loaded
# Getting attributes for tt0800980
# Getting cast for tt0800980
# time to obtain tt0800980 with position 10211 was 1 seconds
# getting url with title/tt0800042...
# url loaded
# Getting attributes for tt0800042
# Getting cast for tt0800042
# time to obtain tt0800042 with position 10212 was 1 seconds
# getting url with title/tt0800227...
# url loaded
# Getting attributes for tt0800227
# Getting cast for tt0800227
# time to obtain tt0800227 with position 10213 was 2 seconds
# getting url with title/tt0800958...
# url loaded
# Getting attributes for tt0800958
# Getting cast for tt0800958
# time to obtain tt0800958 with position 10214 was 1 seconds
# getting url with title/tt0801832...
# url loaded
# Getting attributes for tt0801832
# Getting cast for tt0801832
# time to obtain tt0801832 with position 10215 was 1 seconds
# getting url with title/tt0801843...
# url loaded
# Getting attributes for tt0801843
# Getting cast for tt0801843
# time to obtain tt0801843 with position 10216 was 1 seconds
# getting url with title/tt0801012...
# url loaded
# Getting attributes for tt0801012
# Getting cast for tt0801012
# time to obtain tt0801012 with position 10217 was 2 seconds
# getting url with title/tt0801516...
# url loaded
# Getting attributes for tt0801516
# Getting cast for tt0801516
# time to obtain tt0801516 with position 10218 was 1 seconds
# getting url with title/tt0800964...
# url loaded
# Getting attributes for tt0800964
# Getting cast for tt0800964
# time to obtain tt0800964 with position 10219 was 1 seconds
# getting url with title/tt0801332...
# url loaded
# Getting attributes for tt0801332
# Getting cast for tt0801332
# time to obtain tt0801332 with position 10220 was 1 seconds
# getting url with title/tt0800966...
# url loaded
# Getting attributes for tt0800966
# Getting cast for tt0800966
# time to obtain tt0800966 with position 10221 was 2 seconds
# getting url with title/tt0801821...
# url loaded
# Getting attributes for tt0801821
# Getting cast for tt0801821
# time to obtain tt0801821 with position 10222 was 2 seconds
# getting url with title/tt0801841...
# url loaded
# Getting attributes for tt0801841
# Getting cast for tt0801841
# time to obtain tt0801841 with position 10223 was 2 seconds
# getting url with title/tt0801828...
# url loaded
# Getting attributes for tt0801828
# Getting cast for tt0801828
# time to obtain tt0801828 with position 10224 was 2 seconds
# getting url with title/tt0804261...
# url loaded
# Getting attributes for tt0804261
# Getting cast for tt0804261
# time to obtain tt0804261 with position 10225 was 2 seconds
# getting url with title/tt0804254...
# url loaded
# Getting attributes for tt0804254
# Getting cast for tt0804254
# time to obtain tt0804254 with position 10226 was 1 seconds
# getting url with title/tt0805503...
# url loaded
# Getting attributes for tt0805503
# Getting cast for tt0805503
# time to obtain tt0805503 with position 10227 was 2 seconds
# getting url with title/tt0805586...
# url loaded
# Getting attributes for tt0805586
# Getting cast for tt0805586
# time to obtain tt0805586 with position 10228 was 2 seconds
# getting url with title/tt0802996...
# url loaded
# Getting attributes for tt0802996
# Getting cast for tt0802996
# time to obtain tt0802996 with position 10229 was 2 seconds
# getting url with title/tt0803024...
# url loaded
# Getting attributes for tt0803024
# Getting cast for tt0803024
# time to obtain tt0803024 with position 10230 was 1 seconds
# getting url with title/tt0803042...
# url loaded
# Getting attributes for tt0803042
# Getting cast for tt0803042
# time to obtain tt0803042 with position 10231 was 1 seconds
# getting url with title/tt0806153...
# url loaded
# Getting attributes for tt0806153
# Getting cast for tt0806153
# time to obtain tt0806153 with position 10232 was 1 seconds
# getting url with title/tt0806155...
# url loaded
# Getting attributes for tt0806155
# Getting cast for tt0806155
# time to obtain tt0806155 with position 10233 was 1 seconds
# getting url with title/tt0806168...
# url loaded
# Getting attributes for tt0806168
# Getting cast for tt0806168
# time to obtain tt0806168 with position 10234 was 2 seconds
# getting url with title/tt0806125...
# url loaded
# Getting attributes for tt0806125
# Getting cast for tt0806125
# time to obtain tt0806125 with position 10235 was 1 seconds
# getting url with title/tt0806135...
# url loaded
# Getting attributes for tt0806135
# Getting cast for tt0806135
# time to obtain tt0806135 with position 10236 was 2 seconds
# getting url with title/tt0806071...
# url loaded
# Getting attributes for tt0806071
# Getting cast for tt0806071
# time to obtain tt0806071 with position 10237 was 1 seconds
# getting url with title/tt0804305...
# url loaded
# Getting attributes for tt0804305
# Getting cast for tt0804305
# time to obtain tt0804305 with position 10238 was 2 seconds
# getting url with title/tt0806183...
# url loaded
# Getting attributes for tt0806183
# Getting cast for tt0806183
# time to obtain tt0806183 with position 10239 was 1 seconds
# getting url with title/tt0806192...
# url loaded
# Getting attributes for tt0806192
# Getting cast for tt0806192
# time to obtain tt0806192 with position 10240 was 2 seconds
# getting url with title/tt0804549...
# url loaded
# Getting attributes for tt0804549
# error obtaining name for id tt0804549
# Getting cast for tt0804549
# time to obtain tt0804549 with position 10241 was 60 seconds
# getting url with title/tt0805507...
# url loaded
# Getting attributes for tt0805507
# Getting cast for tt0805507
# time to obtain tt0805507 with position 10242 was 2 seconds
# getting url with title/tt0806001...
# url loaded
# Getting attributes for tt0806001
# Getting cast for tt0806001
# time to obtain tt0806001 with position 10243 was 1 seconds
# getting url with title/tt0806069...
# url loaded
# Getting attributes for tt0806069
# Getting cast for tt0806069
# time to obtain tt0806069 with position 10244 was 1 seconds
# getting url with title/tt0806115...
# url loaded
# Getting attributes for tt0806115
# Getting cast for tt0806115
# time to obtain tt0806115 with position 10245 was 1 seconds
# getting url with title/tt0805504...
# url loaded
# Getting attributes for tt0805504
# Getting cast for tt0805504
# time to obtain tt0805504 with position 10246 was 1 seconds
# getting url with title/tt0806054...
# url loaded
# Getting attributes for tt0806054
# Getting cast for tt0806054
# time to obtain tt0806054 with position 10247 was 2 seconds
# getting url with title/tt0805518...
# url loaded
# Getting attributes for tt0805518
# Getting cast for tt0805518
# time to obtain tt0805518 with position 10248 was 2 seconds
# getting url with title/tt0805615...
# url loaded
# Getting attributes for tt0805615
# Getting cast for tt0805615
# time to obtain tt0805615 with position 10249 was 1 seconds
# getting url with title/tt0806052...
# url loaded
# Getting attributes for tt0806052
# Getting cast for tt0806052
# time to obtain tt0806052 with position 10250 was 2 seconds
# getting url with title/tt0806086...
# url loaded
# Getting attributes for tt0806086
# Getting cast for tt0806086
# time to obtain tt0806086 with position 10251 was 1 seconds
# getting url with title/tt0805532...
# url loaded
# Getting attributes for tt0805532
# Getting cast for tt0805532
# time to obtain tt0805532 with position 10252 was 2 seconds
# getting url with title/tt0805699...
# url loaded
# Getting attributes for tt0805699
# Getting cast for tt0805699
# time to obtain tt0805699 with position 10253 was 2 seconds
# getting url with title/tt0805480...
# url loaded
# Getting attributes for tt0805480
# Getting cast for tt0805480
# time to obtain tt0805480 with position 10254 was 2 seconds
# getting url with title/tt0805636...
# url loaded
# Getting attributes for tt0805636
# Getting cast for tt0805636
# time to obtain tt0805636 with position 10255 was 1 seconds
# getting url with title/tt0805329...
# url loaded
# Getting attributes for tt0805329
# Getting cast for tt0805329
# time to obtain tt0805329 with position 10256 was 3 seconds
# getting url with title/tt0805502...
# url loaded
# Getting attributes for tt0805502
# Getting cast for tt0805502
# time to obtain tt0805502 with position 10257 was 2 seconds
# getting url with title/tt0805563...
# url loaded
# Getting attributes for tt0805563
# Getting cast for tt0805563
# time to obtain tt0805563 with position 10258 was 1 seconds
# getting url with title/tt0805630...
# url loaded
# Getting attributes for tt0805630
# Getting cast for tt0805630
# time to obtain tt0805630 with position 10259 was 2 seconds
# getting url with title/tt0805612...
# url loaded
# Getting attributes for tt0805612
# Getting cast for tt0805612
# time to obtain tt0805612 with position 10260 was 1 seconds
# getting url with title/tt0805477...
# url loaded
# Getting attributes for tt0805477
# Getting cast for tt0805477
# time to obtain tt0805477 with position 10261 was 1 seconds
# getting url with title/tt0805508...
# url loaded
# Getting attributes for tt0805508
# Getting cast for tt0805508
# time to obtain tt0805508 with position 10262 was 1 seconds
# getting url with title/tt0805539...
# url loaded
# Getting attributes for tt0805539
# Getting cast for tt0805539
# time to obtain tt0805539 with position 10263 was 2 seconds
# getting url with title/tt0807717...
# url loaded
# Getting attributes for tt0807717
# Getting cast for tt0807717
# time to obtain tt0807717 with position 10264 was 3 seconds
# getting url with title/tt0807855...
# url loaded
# Getting attributes for tt0807855
# Getting cast for tt0807855
# time to obtain tt0807855 with position 10265 was 2 seconds
# getting url with title/tt0808188...
# url loaded
# Getting attributes for tt0808188
# Getting cast for tt0808188
# time to obtain tt0808188 with position 10266 was 2 seconds
# getting url with title/tt0808424...
# url loaded
# Getting attributes for tt0808424
# Getting cast for tt0808424
# time to obtain tt0808424 with position 10267 was 2 seconds
# getting url with title/tt0808451...
# url loaded
# Getting attributes for tt0808451
# Getting cast for tt0808451
# time to obtain tt0808451 with position 10268 was 2 seconds
# getting url with title/tt0809423...
# url loaded
# Getting attributes for tt0809423
# Getting cast for tt0809423
# time to obtain tt0809423 with position 10269 was 2 seconds
# getting url with title/tt0808268...
# url loaded
# Getting attributes for tt0808268
# Getting cast for tt0808268
# time to obtain tt0808268 with position 10270 was 2 seconds
# getting url with title/tt0808920...
# url loaded
# Getting attributes for tt0808920
# Getting cast for tt0808920
# time to obtain tt0808920 with position 10271 was 1 seconds
# getting url with title/tt0807842...
# url loaded
# Getting attributes for tt0807842
# Getting cast for tt0807842
# time to obtain tt0807842 with position 10272 was 2 seconds
# getting url with title/tt0807722...
# url loaded
# Getting attributes for tt0807722
# Getting cast for tt0807722
# time to obtain tt0807722 with position 10273 was 2 seconds
# getting url with title/tt0808257...
# url loaded
# Getting attributes for tt0808257
# Getting cast for tt0808257
# time to obtain tt0808257 with position 10274 was 1 seconds
# getting url with title/tt0808918...
# url loaded
# Getting attributes for tt0808918
# Getting cast for tt0808918
# time to obtain tt0808918 with position 10275 was 2 seconds
# getting url with title/tt0808316...
# url loaded
# Getting attributes for tt0808316
# Getting cast for tt0808316
# time to obtain tt0808316 with position 10276 was 2 seconds
# getting url with title/tt0809452...
# url loaded
# Getting attributes for tt0809452
# Getting cast for tt0809452
# time to obtain tt0809452 with position 10277 was 2 seconds
# getting url with title/tt0807942...
# url loaded
# Getting attributes for tt0807942
# Getting cast for tt0807942
# time to obtain tt0807942 with position 10278 was 2 seconds
# getting url with title/tt0808922...
# url loaded
# Getting attributes for tt0808922
# Getting cast for tt0808922
# time to obtain tt0808922 with position 10279 was 2 seconds
# getting url with title/tt0808251...
# url loaded
# Getting attributes for tt0808251
# Getting cast for tt0808251
# time to obtain tt0808251 with position 10280 was 2 seconds
# getting url with title/tt0808343...
# url loaded
# Getting attributes for tt0808343
# Getting cast for tt0808343
# time to obtain tt0808343 with position 10281 was 1 seconds
# getting url with title/tt0808256...
# url loaded
# Getting attributes for tt0808256
# Getting cast for tt0808256
# time to obtain tt0808256 with position 10282 was 2 seconds
# getting url with title/tt0808901...
# url loaded
# Getting attributes for tt0808901
# Getting cast for tt0808901
# time to obtain tt0808901 with position 10283 was 4 seconds
# getting url with title/tt0808215...
# url loaded
# Getting attributes for tt0808215
# Getting cast for tt0808215
# time to obtain tt0808215 with position 10284 was 1 seconds
# getting url with title/tt0807843...
# url loaded
# Getting attributes for tt0807843
# Getting cast for tt0807843
# time to obtain tt0807843 with position 10285 was 1 seconds
# getting url with title/tt0808143...
# url loaded
# Getting attributes for tt0808143
# Getting cast for tt0808143
# time to obtain tt0808143 with position 10286 was 2 seconds
# getting url with title/tt0809468...
# url loaded
# Getting attributes for tt0809468
# Getting cast for tt0809468
# time to obtain tt0809468 with position 10287 was 1 seconds
# getting url with title/tt0808349...
# url loaded
# ...
# Getting attributes for tt0870126
# Getting cast for tt0870126
# time to obtain tt0870126 with position 10905 was 1 seconds
# getting url with title/tt0869941...
# url loaded
# Getting attributes for tt0869941
# Getting cast for tt0869941
# time to obtain tt0869941 with position 10906 was 2 seconds
# getting url with title/tt0869125...
# url loaded
# Getting attributes for tt0869125
# Getting cast for tt0869125
# time to obtain tt0869125 with position 10907 was 1 seconds
# getting url with title/tt0870990...
# url loaded
# Getting attributes for tt0870990
# Getting cast for tt0870990
# time to obtain tt0870990 with position 10908 was 1 seconds
# getting url with title/tt0871008...
# url loaded
# Getting attributes for tt0871008
# Getting cast for tt0871008
# time to obtain tt0871008 with position 10909 was 1 seconds
# getting url with title/tt0871013...
# url loaded
# Getting attributes for tt0871013
# Getting cast for tt0871013
# time to obtain tt0871013 with position 10910 was 1 seconds
# getting url with title/tt0870942...
# url loaded
# Getting attributes for tt0870942
# Getting cast for tt0870942
# time to obtain tt0870942 with position 10911 was 2 seconds
# getting url with title/tt0871003...
# url loaded
# Getting attributes for tt0871003
# Getting cast for tt0871003
# time to obtain tt0871003 with position 10912 was 2 seconds
# getting url with title/tt0871433...
# url loaded
# Getting attributes for tt0871433
# Getting cast for tt0871433
# time to obtain tt0871433 with position 10913 was 1 seconds
# getting url with title/tt0871861...
# url loaded
# Getting attributes for tt0871861
# Getting cast for tt0871861
# time to obtain tt0871861 with position 10914 was 2 seconds
# getting url with title/tt0872201...
# url loaded
# Getting attributes for tt0872201
# Getting cast for tt0872201
# time to obtain tt0872201 with position 10915 was 2 seconds
# getting url with title/tt0872280...
# url loaded
# Getting attributes for tt0872280
# Getting cast for tt0872280
# time to obtain tt0872280 with position 10916 was 1 seconds
# getting url with title/tt0872189...
# url loaded
# Getting attributes for tt0872189
# Getting cast for tt0872189
# time to obtain tt0872189 with position 10917 was 1 seconds
# getting url with title/tt0872210...
# url loaded
# Getting attributes for tt0872210
# Getting cast for tt0872210
# time to obtain tt0872210 with position 10918 was 1 seconds
# getting url with title/tt0871849...
# url loaded
# Getting attributes for tt0871849
# Getting cast for tt0871849
# time to obtain tt0871849 with position 10919 was 3 seconds
# getting url with title/tt0872199...
# url loaded
# Getting attributes for tt0872199
# Getting cast for tt0872199
# time to obtain tt0872199 with position 10920 was 1 seconds
# getting url with title/tt0872222...
# url loaded
# Getting attributes for tt0872222
# Getting cast for tt0872222
# time to obtain tt0872222 with position 10921 was 1 seconds
# getting url with title/tt0872341...
# url loaded
# Getting attributes for tt0872341
# Getting cast for tt0872341
# time to obtain tt0872341 with position 10922 was 2 seconds
# getting url with title/tt0871434...
# url loaded
# Getting attributes for tt0871434
# Getting cast for tt0871434
# time to obtain tt0871434 with position 10923 was 2 seconds
# getting url with title/tt0871876...
# url loaded
# Getting attributes for tt0871876
# Getting cast for tt0871876
# time to obtain tt0871876 with position 10924 was 1 seconds
# getting url with title/tt0871904...
# url loaded
# Getting attributes for tt0871904
# Getting cast for tt0871904
# time to obtain tt0871904 with position 10925 was 1 seconds
# getting url with title/tt0872200...
# url loaded
# Getting attributes for tt0872200
# Getting cast for tt0872200
# time to obtain tt0872200 with position 10926 was 2 seconds
# getting url with title/tt0872284...
# url loaded
# Getting attributes for tt0872284
# Getting cast for tt0872284
# time to obtain tt0872284 with position 10927 was 1 seconds
# getting url with title/tt0872333...
# url loaded
# Getting attributes for tt0872333
# Getting cast for tt0872333
# time to obtain tt0872333 with position 10928 was 2 seconds
# getting url with title/tt0872242...
# url loaded
# Getting attributes for tt0872242
# Getting cast for tt0872242
# time to obtain tt0872242 with position 10929 was 1 seconds
# getting url with title/tt0872234...
# url loaded
# Getting attributes for tt0872234
# Getting cast for tt0872234
# time to obtain tt0872234 with position 10930 was 2 seconds
# getting url with title/tt0872260...
# url loaded
# Getting attributes for tt0872260
# Getting cast for tt0872260
# time to obtain tt0872260 with position 10931 was 2 seconds
# getting url with title/tt0872262...
# url loaded
# Getting attributes for tt0872262
# Getting cast for tt0872262
# time to obtain tt0872262 with position 10932 was 2 seconds
# getting url with title/tt0874905...
# url loaded
# Getting attributes for tt0874905
# Getting cast for tt0874905
# time to obtain tt0874905 with position 10933 was 2 seconds
# getting url with title/tt0872294...
# url loaded
# Getting attributes for tt0872294
# Getting cast for tt0872294
# time to obtain tt0872294 with position 10934 was 2 seconds
# getting url with title/tt0875145...
# url loaded
# Getting attributes for tt0875145
# Getting cast for tt0875145
# time to obtain tt0875145 with position 10935 was 2 seconds
# getting url with title/tt0875136...
# url loaded
# Getting attributes for tt0875136
# Getting cast for tt0875136
# time to obtain tt0875136 with position 10936 was 2 seconds
# getting url with title/tt0874259...
# url loaded
# Getting attributes for tt0874259
# Getting cast for tt0874259
# time to obtain tt0874259 with position 10937 was 3 seconds
# getting url with title/tt0874861...
# url loaded
# Getting attributes for tt0874861
# Getting cast for tt0874861
# time to obtain tt0874861 with position 10938 was 2 seconds
# getting url with title/tt0875126...
# url loaded
# Getting attributes for tt0875126
# Getting cast for tt0875126
# time to obtain tt0875126 with position 10939 was 2 seconds
# getting url with title/tt0874328...
# url loaded
# Getting attributes for tt0874328
# Getting cast for tt0874328
# time to obtain tt0874328 with position 10940 was 1 seconds
# getting url with title/tt0874952...
# url loaded
# Getting attributes for tt0874952
# Getting cast for tt0874952
# time to obtain tt0874952 with position 10941 was 2 seconds
# getting url with title/tt0875144...
# url loaded
# Getting attributes for tt0875144
# Getting cast for tt0875144
# time to obtain tt0875144 with position 10942 was 2 seconds
# getting url with title/tt0874945...
# url loaded
# Getting attributes for tt0874945
# Getting cast for tt0874945
# time to obtain tt0874945 with position 10943 was 1 seconds
# getting url with title/tt0874316...
# url loaded
# Getting attributes for tt0874316
# Getting cast for tt0874316
# time to obtain tt0874316 with position 10944 was 1 seconds
# getting url with title/tt0875118...
# url loaded
# Getting attributes for tt0875118
# Getting cast for tt0875118
# time to obtain tt0875118 with position 10945 was 2 seconds
# getting url with title/tt0875114...
# url loaded
# Getting attributes for tt0875114
# Getting cast for tt0875114
# time to obtain tt0875114 with position 10946 was 2 seconds
# getting url with title/tt0875133...
# url loaded
# Getting attributes for tt0875133
# Getting cast for tt0875133
# time to obtain tt0875133 with position 10947 was 2 seconds
# getting url with title/tt0876276...
# url loaded
# Getting attributes for tt0876276
# Getting cast for tt0876276
# time to obtain tt0876276 with position 10948 was 1 seconds
# getting url with title/tt0875048...
# url loaded
# Getting attributes for tt0875048
# Getting cast for tt0875048
# time to obtain tt0875048 with position 10949 was 1 seconds
# getting url with title/tt0876131...
# url loaded
# Getting attributes for tt0876131
# Getting cast for tt0876131
# time to obtain tt0876131 with position 10950 was 2 seconds
# getting url with title/tt0876119...
# url loaded
# Getting attributes for tt0876119
# Getting cast for tt0876119
# time to obtain tt0876119 with position 10951 was 2 seconds
# getting url with title/tt0876094...
# url loaded
# Getting attributes for tt0876094
# Getting cast for tt0876094
# time to obtain tt0876094 with position 10952 was 2 seconds
# getting url with title/tt0874875...
# url loaded
# Getting attributes for tt0874875
# Getting cast for tt0874875
# time to obtain tt0874875 with position 10953 was 2 seconds
# getting url with title/tt0876098...
# url loaded
# Getting attributes for tt0876098
# Getting cast for tt0876098
# time to obtain tt0876098 with position 10954 was 2 seconds
# getting url with title/tt0876230...
# url loaded
# Getting attributes for tt0876230
# Getting cast for tt0876230
# time to obtain tt0876230 with position 10955 was 2 seconds
# getting url with title/tt0876151...
# url loaded
# Getting attributes for tt0876151
# error obtaining name for id tt0876151
# Getting cast for tt0876151
# time to obtain tt0876151 with position 10956 was 60 seconds
# getting url with title/tt0876122...
# url loaded
# Getting attributes for tt0876122
# Getting cast for tt0876122
# time to obtain tt0876122 with position 10957 was 1 seconds
# getting url with title/tt0876285...
# url loaded
# Getting attributes for tt0876285
# Getting cast for tt0876285
# time to obtain tt0876285 with position 10958 was 1 seconds
# getting url with title/tt0876107...
# url loaded
# Getting attributes for tt0876107
# Getting cast for tt0876107
# time to obtain tt0876107 with position 10959 was 2 seconds
# getting url with title/tt0876280...
# url loaded
# Getting attributes for tt0876280
# Getting cast for tt0876280
# time to obtain tt0876280 with position 10960 was 1 seconds
# getting url with title/tt0876433...
# url loaded
# Getting attributes for tt0876433
# Getting cast for tt0876433
# time to obtain tt0876433 with position 10961 was 1 seconds
# getting url with title/tt0875582...
# url loaded
# Getting attributes for tt0875582
# Getting cast for tt0875582
# time to obtain tt0875582 with position 10962 was 1 seconds
# getting url with title/tt0875600...
# url loaded
# Getting attributes for tt0875600
# Getting cast for tt0875600
# time to obtain tt0875600 with position 10963 was 1 seconds
# getting url with title/tt0875606...
# url loaded
# Getting attributes for tt0875606
# Getting cast for tt0875606
# time to obtain tt0875606 with position 10964 was 2 seconds
# getting url with title/tt0875614...
# url loaded
# Getting attributes for tt0875614
# Getting cast for tt0875614
# time to obtain tt0875614 with position 10965 was 2 seconds
# getting url with title/tt0875631...
# url loaded
# Getting attributes for tt0875631
# Getting cast for tt0875631
# time to obtain tt0875631 with position 10966 was 2 seconds
# getting url with title/tt0876534...
# url loaded
# Getting attributes for tt0876534
# Getting cast for tt0876534
# time to obtain tt0876534 with position 10967 was 2 seconds
# getting url with title/tt0875597...
# url loaded
# Getting attributes for tt0875597
# Getting cast for tt0875597
# time to obtain tt0875597 with position 10968 was 1 seconds
# getting url with title/tt0875591...
# url loaded
# Getting attributes for tt0875591
# Getting cast for tt0875591
# time to obtain tt0875591 with position 10969 was 2 seconds
# getting url with title/tt0875594...
# url loaded
# Getting attributes for tt0875594
# Getting cast for tt0875594
# time to obtain tt0875594 with position 10970 was 1 seconds
# getting url with title/tt0875620...
# url loaded
# Getting attributes for tt0875620
# Getting cast for tt0875620
# time to obtain tt0875620 with position 10971 was 2 seconds
# getting url with title/tt0875588...
# url loaded
# Getting attributes for tt0875588
# Getting cast for tt0875588
# time to obtain tt0875588 with position 10972 was 1 seconds
# getting url with title/tt0875592...
# url loaded
# Getting attributes for tt0875592
# Getting cast for tt0875592
# time to obtain tt0875592 with position 10973 was 2 seconds
# getting url with title/tt0875604...
# url loaded
# Getting attributes for tt0875604
# Getting cast for tt0875604
# time to obtain tt0875604 with position 10974 was 1 seconds
# getting url with title/tt0877499...
# url loaded
# Getting attributes for tt0877499
# Getting cast for tt0877499
# time to obtain tt0877499 with position 10975 was 2 seconds
# getting url with title/tt0877333...
# url loaded
# Getting attributes for tt0877333
# Getting cast for tt0877333
# time to obtain tt0877333 with position 10976 was 1 seconds
# getting url with title/tt0877518...
# url loaded
# Getting attributes for tt0877518
# Getting cast for tt0877518
# time to obtain tt0877518 with position 10977 was 2 seconds
# getting url with title/tt0878118...
# url loaded
# Getting attributes for tt0878118
# Getting cast for tt0878118
# time to obtain tt0878118 with position 10978 was 1 seconds
# getting url with title/tt0878125...
# url loaded
# Getting attributes for tt0878125
# Getting cast for tt0878125
# time to obtain tt0878125 with position 10979 was 1 seconds
# getting url with title/tt0878139...
# url loaded
# Getting attributes for tt0878139
# Getting cast for tt0878139
# time to obtain tt0878139 with position 10980 was 3 seconds
# getting url with title/tt0878687...
# url loaded
# Getting attributes for tt0878687
# Getting cast for tt0878687
# time to obtain tt0878687 with position 10981 was 2 seconds
# getting url with title/tt0877514...
# url loaded
# Getting attributes for tt0877514
# Getting cast for tt0877514
# time to obtain tt0877514 with position 10982 was 2 seconds
# getting url with title/tt0878661...
# url loaded
# Getting attributes for tt0878661
# Getting cast for tt0878661
# time to obtain tt0878661 with position 10983 was 1 seconds
# getting url with title/tt0878141...
# url loaded
# Getting attributes for tt0878141
# Getting cast for tt0878141
# time to obtain tt0878141 with position 10984 was 1 seconds
# getting url with title/tt0877713...
# url loaded
# Getting attributes for tt0877713
# Getting cast for tt0877713
# time to obtain tt0877713 with position 10985 was 1 seconds
# getting url with title/tt0877357...
# url loaded
# Getting attributes for tt0877357
# Getting cast for tt0877357
# time to obtain tt0877357 with position 10986 was 3 seconds
# getting url with title/tt0877501...
# url loaded
# Getting attributes for tt0877501
# Getting cast for tt0877501
# time to obtain tt0877501 with position 10987 was 1 seconds
# getting url with title/tt0878708...
# url loaded
# Getting attributes for tt0878708
# Getting cast for tt0878708
# time to obtain tt0878708 with position 10988 was 1 seconds
# getting url with title/tt0877342...
# url loaded
# Getting attributes for tt0877342
# Getting cast for tt0877342
# time to obtain tt0877342 with position 10989 was 2 seconds
# getting url with title/tt0878143...
# url loaded
# Getting attributes for tt0878143
# Getting cast for tt0878143
# time to obtain tt0878143 with position 10990 was 2 seconds
# getting url with title/tt0877356...
# url loaded
# Getting attributes for tt0877356
# Getting cast for tt0877356
# time to obtain tt0877356 with position 10991 was 1 seconds
# getting url with title/tt0877486...
# url loaded
# Getting attributes for tt0877486
# Getting cast for tt0877486
# time to obtain tt0877486 with position 10992 was 1 seconds
# getting url with title/tt0877533...
# url loaded
# Getting attributes for tt0877533
# Getting cast for tt0877533
# time to obtain tt0877533 with position 10993 was 3 seconds
# getting url with title/tt0879258...
# url loaded
# Getting attributes for tt0879258
# Getting cast for tt0879258
# time to obtain tt0879258 with position 10994 was 1 seconds
# getting url with title/tt0878670...
# url loaded
# Getting attributes for tt0878670
# Getting cast for tt0878670
# time to obtain tt0878670 with position 10995 was 1 seconds
# getting url with title/tt0878802...
# url loaded
# Getting attributes for tt0878802
# Getting cast for tt0878802
# time to obtain tt0878802 with position 10996 was 2 seconds
# getting url with title/tt0879237...
# url loaded
# Getting attributes for tt0879237
# Getting cast for tt0879237
# time to obtain tt0879237 with position 10997 was 2 seconds
# getting url with title/tt0878718...
# url loaded
# Getting attributes for tt0878718
# Getting cast for tt0878718
# time to obtain tt0878718 with position 10998 was 2 seconds
# getting url with title/tt0879251...
# url loaded
# Getting attributes for tt0879251
# Getting cast for tt0879251
# time to obtain tt0879251 with position 10999 was 2 seconds
# getting url with title/tt0878826...
# url loaded
# Getting attributes for tt0878826
# Getting cast for tt0878826
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0878826 with position 11000 was 16 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    4.334
# dtype: float64
