# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 1
initial_counter = 12662
incremental = 2338

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers":
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("union_peliculas.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt1874394...
# url loaded
# Getting attributes for tt1874394
# Getting cast for tt1874394
# time to obtain tt1874394 with position 12662 was 12 seconds
# getting url with title/tt1883282...
# url loaded
# Getting attributes for tt1883282
# Getting cast for tt1883282
# time to obtain tt1883282 with position 12663 was 2 seconds
# getting url with title/tt1883317...
# url loaded
# Getting attributes for tt1883317
# Getting cast for tt1883317
# time to obtain tt1883317 with position 12664 was 2 seconds
# getting url with title/tt1884330...
# url loaded
# Getting attributes for tt1884330
# Getting cast for tt1884330
# time to obtain tt1884330 with position 12665 was 2 seconds
# getting url with title/tt1885412...
# url loaded
# Getting attributes for tt1885412
# Getting cast for tt1885412
# time to obtain tt1885412 with position 12666 was 2 seconds
# getting url with title/tt1886706...
# url loaded
# Getting attributes for tt1886706
# Getting cast for tt1886706
# time to obtain tt1886706 with position 12667 was 2 seconds
# getting url with title/tt1887895...
# url loaded
# Getting attributes for tt1887895
# Getting cast for tt1887895
# time to obtain tt1887895 with position 12668 was 2 seconds
# getting url with title/tt1891797...
# url loaded
# Getting attributes for tt1891797
# Getting cast for tt1891797
# time to obtain tt1891797 with position 12669 was 2 seconds
# getting url with title/tt1890435...
# url loaded
# Getting attributes for tt1890435
# Getting cast for tt1890435
# time to obtain tt1890435 with position 12670 was 1 seconds
# getting url with title/tt1890388...
# url loaded
# Getting attributes for tt1890388
# Getting cast for tt1890388
# time to obtain tt1890388 with position 12671 was 3 seconds
# getting url with title/tt1890401...
# url loaded
# Getting attributes for tt1890401
# Getting cast for tt1890401
# time to obtain tt1890401 with position 12672 was 2 seconds
# getting url with title/tt1896800...
# url loaded
# Getting attributes for tt1896800
# Getting cast for tt1896800
# time to obtain tt1896800 with position 12673 was 4 seconds
# getting url with title/tt1899119...
# url loaded
# Getting attributes for tt1899119
# Getting cast for tt1899119
# time to obtain tt1899119 with position 12674 was 2 seconds
# getting url with title/tt1899273...
# url loaded
# Getting attributes for tt1899273
# Getting cast for tt1899273
# time to obtain tt1899273 with position 12675 was 2 seconds
# getting url with title/tt1907638...
# url loaded
# Getting attributes for tt1907638
# Getting cast for tt1907638
# time to obtain tt1907638 with position 12676 was 2 seconds
# getting url with title/tt1909343...
# url loaded
# Getting attributes for tt1909343
# Getting cast for tt1909343
# time to obtain tt1909343 with position 12677 was 2 seconds
# getting url with title/tt1912427...
# url loaded
# Getting attributes for tt1912427
# Getting cast for tt1912427
# time to obtain tt1912427 with position 12678 was 1 seconds
# getting url with title/tt1915605...
# url loaded
# Getting attributes for tt1915605
# Getting cast for tt1915605
# time to obtain tt1915605 with position 12679 was 2 seconds
# getting url with title/tt1914349...
# url loaded
# Getting attributes for tt1914349
# Getting cast for tt1914349
# time to obtain tt1914349 with position 12680 was 1 seconds
# getting url with title/tt1915540...
# url loaded
# Getting attributes for tt1915540
# Getting cast for tt1915540
# time to obtain tt1915540 with position 12681 was 3 seconds
# getting url with title/tt1916737...
# url loaded
# Getting attributes for tt1916737
# Getting cast for tt1916737
# time to obtain tt1916737 with position 12682 was 2 seconds
# getting url with title/tt1922761...
# url loaded
# Getting attributes for tt1922761
# Getting cast for tt1922761
# time to obtain tt1922761 with position 12683 was 1 seconds
# getting url with title/tt1922558...
# url loaded
# Getting attributes for tt1922558
# Getting cast for tt1922558
# time to obtain tt1922558 with position 12684 was 2 seconds
# getting url with title/tt1927154...
# url loaded
# Getting attributes for tt1927154
# Getting cast for tt1927154
# time to obtain tt1927154 with position 12685 was 3 seconds
# getting url with title/tt1929169...
# url loaded
# Getting attributes for tt1929169
# Getting cast for tt1929169
# time to obtain tt1929169 with position 12686 was 1 seconds
# getting url with title/tt1928152...
# url loaded
# Getting attributes for tt1928152
# Getting cast for tt1928152
# time to obtain tt1928152 with position 12687 was 1 seconds
# getting url with title/tt1929421...
# url loaded
# Getting attributes for tt1929421
# Getting cast for tt1929421
# time to obtain tt1929421 with position 12688 was 1 seconds
# getting url with title/tt1930479...
# url loaded
# Getting attributes for tt1930479
# Getting cast for tt1930479
# time to obtain tt1930479 with position 12689 was 2 seconds
# getting url with title/tt1930306...
# url loaded
# Getting attributes for tt1930306
# Getting cast for tt1930306
# time to obtain tt1930306 with position 12690 was 2 seconds
# getting url with title/tt1929333...
# url loaded
# Getting attributes for tt1929333
# Getting cast for tt1929333
# time to obtain tt1929333 with position 12691 was 2 seconds
# getting url with title/tt1930492...
# url loaded
# Getting attributes for tt1930492
# Getting cast for tt1930492
# time to obtain tt1930492 with position 12692 was 2 seconds
# getting url with title/tt1929375...
# url loaded
# Getting attributes for tt1929375
# Getting cast for tt1929375
# time to obtain tt1929375 with position 12693 was 2 seconds
# getting url with title/tt1934217...
# url loaded
# Getting attributes for tt1934217
# Getting cast for tt1934217
# time to obtain tt1934217 with position 12694 was 2 seconds
# getting url with title/tt1934235...
# url loaded
# Getting attributes for tt1934235
# Getting cast for tt1934235
# time to obtain tt1934235 with position 12695 was 3 seconds
# getting url with title/tt1942863...
# url loaded
# Getting attributes for tt1942863
# Getting cast for tt1942863
# time to obtain tt1942863 with position 12696 was 1 seconds
# getting url with title/tt1943049...
# url loaded
# Getting attributes for tt1943049
# Getting cast for tt1943049
# time to obtain tt1943049 with position 12697 was 2 seconds
# getting url with title/tt1946216...
# url loaded
# Getting attributes for tt1946216
# Getting cast for tt1946216
# time to obtain tt1946216 with position 12698 was 2 seconds
# getting url with title/tt1946399...
# url loaded
# Getting attributes for tt1946399
# Getting cast for tt1946399
# time to obtain tt1946399 with position 12699 was 2 seconds
# getting url with title/tt1949239...
# url loaded
# Getting attributes for tt1949239
# Getting cast for tt1949239
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt1949239 with position 12700 was 15 seconds
# getting url with title/tt1949584...
# url loaded
# Getting attributes for tt1949584
# Getting cast for tt1949584
# time to obtain tt1949584 with position 12701 was 2 seconds
# getting url with title/tt1956596...
# url loaded
# Getting attributes for tt1956596
# Getting cast for tt1956596
# time to obtain tt1956596 with position 12702 was 3 seconds
# getting url with title/tt1954420...
# url loaded
# Getting attributes for tt1954420
# Getting cast for tt1954420
# time to obtain tt1954420 with position 12703 was 1 seconds
# getting url with title/tt1957915...
# url loaded
# Getting attributes for tt1957915
# Getting cast for tt1957915
# time to obtain tt1957915 with position 12704 was 2 seconds
# getting url with title/tt1959424...
# url loaded
# Getting attributes for tt1959424
# Getting cast for tt1959424
# time to obtain tt1959424 with position 12705 was 1 seconds
# getting url with title/tt1959355...
# url loaded
# Getting attributes for tt1959355
# Getting cast for tt1959355
# time to obtain tt1959355 with position 12706 was 2 seconds
# getting url with title/tt1961578...
# url loaded
# Getting attributes for tt1961578
# Getting cast for tt1961578
# time to obtain tt1961578 with position 12707 was 1 seconds
# getting url with title/tt1966650...
# url loaded
# Getting attributes for tt1966650
# Getting cast for tt1966650
# time to obtain tt1966650 with position 12708 was 1 seconds
# getting url with title/tt1965261...
# url loaded
# Getting attributes for tt1965261
# Getting cast for tt1965261
# time to obtain tt1965261 with position 12709 was 1 seconds
# getting url with title/tt1964754...
# url loaded
# Getting attributes for tt1964754
# Getting cast for tt1964754
# time to obtain tt1964754 with position 12710 was 2 seconds
# getting url with title/tt1971423...
# url loaded
# Getting attributes for tt1971423
# Getting cast for tt1971423
# time to obtain tt1971423 with position 12711 was 2 seconds
# getting url with title/tt1972619...
# url loaded
# Getting attributes for tt1972619
# Getting cast for tt1972619
# time to obtain tt1972619 with position 12712 was 1 seconds
# getting url with title/tt1976572...
# url loaded
# Getting attributes for tt1976572
# Getting cast for tt1976572
# time to obtain tt1976572 with position 12713 was 2 seconds
# getting url with title/tt1976605...
# url loaded
# Getting attributes for tt1976605
# Getting cast for tt1976605
# time to obtain tt1976605 with position 12714 was 2 seconds
# getting url with title/tt1977991...
# url loaded
# Getting attributes for tt1977991
# Getting cast for tt1977991
# time to obtain tt1977991 with position 12715 was 3 seconds
# getting url with title/tt1977803...
# url loaded
# Getting attributes for tt1977803
# Getting cast for tt1977803
# time to obtain tt1977803 with position 12716 was 3 seconds
# getting url with title/tt1978515...
# url loaded
# Getting attributes for tt1978515
# Getting cast for tt1978515
# time to obtain tt1978515 with position 12717 was 2 seconds
# getting url with title/tt1981715...
# url loaded
# Getting attributes for tt1981715
# Getting cast for tt1981715
# time to obtain tt1981715 with position 12718 was 2 seconds
# getting url with title/tt1982650...
# url loaded
# Getting attributes for tt1982650
# Getting cast for tt1982650
# time to obtain tt1982650 with position 12719 was 3 seconds
# getting url with title/tt1984146...
# url loaded
# Getting attributes for tt1984146
# Getting cast for tt1984146
# time to obtain tt1984146 with position 12720 was 3 seconds
# getting url with title/tt1985278...
# url loaded
# Getting attributes for tt1985278
# Getting cast for tt1985278
# time to obtain tt1985278 with position 12721 was 3 seconds
# getting url with title/tt1985992...
# url loaded
# Getting attributes for tt1985992
# Getting cast for tt1985992
# time to obtain tt1985992 with position 12722 was 2 seconds
# getting url with title/tt1987524...
# url loaded
# Getting attributes for tt1987524
# Getting cast for tt1987524
# time to obtain tt1987524 with position 12723 was 4 seconds
# getting url with title/tt1995407...
# url loaded
# Getting attributes for tt1995407
# Getting cast for tt1995407
# time to obtain tt1995407 with position 12724 was 4 seconds
# getting url with title/tt1995322...
# url loaded
# Getting attributes for tt1995322
# Getting cast for tt1995322
# time to obtain tt1995322 with position 12725 was 4 seconds
# getting url with title/tt1997335...
# url loaded
# Getting attributes for tt1997335
# Getting cast for tt1997335
# time to obtain tt1997335 with position 12726 was 2 seconds
# getting url with title/tt1997546...
# url loaded
# Getting attributes for tt1997546
# Getting cast for tt1997546
# time to obtain tt1997546 with position 12727 was 4 seconds
# getting url with title/tt1995349...
# url loaded
# Getting attributes for tt1995349
# Getting cast for tt1995349
# time to obtain tt1995349 with position 12728 was 2 seconds
# getting url with title/tt1997468...
# url loaded
# Getting attributes for tt1997468
# Getting cast for tt1997468
# time to obtain tt1997468 with position 12729 was 2 seconds
# getting url with title/tt1997467...
# url loaded
# Getting attributes for tt1997467
# Getting cast for tt1997467
# time to obtain tt1997467 with position 12730 was 2 seconds
# getting url with title/tt1997366...
# url loaded
# Getting attributes for tt1997366
# Getting cast for tt1997366
# time to obtain tt1997366 with position 12731 was 2 seconds
# getting url with title/tt2009518...
# url loaded
# Getting attributes for tt2009518
# Getting cast for tt2009518
# time to obtain tt2009518 with position 12732 was 3 seconds
# getting url with title/tt2009566...
# url loaded
# Getting attributes for tt2009566
# Getting cast for tt2009566
# time to obtain tt2009566 with position 12733 was 3 seconds
# getting url with title/tt2015360...
# url loaded
# Getting attributes for tt2015360
# Getting cast for tt2015360
# time to obtain tt2015360 with position 12734 was 3 seconds
# getting url with title/tt2015309...
# url loaded
# Getting attributes for tt2015309
# Getting cast for tt2015309
# time to obtain tt2015309 with position 12735 was 3 seconds
# getting url with title/tt2014301...
# url loaded
# Getting attributes for tt2014301
# Getting cast for tt2014301
# time to obtain tt2014301 with position 12736 was 3 seconds
# getting url with title/tt2017005...
# url loaded
# Getting attributes for tt2017005
# Getting cast for tt2017005
# time to obtain tt2017005 with position 12737 was 2 seconds
# getting url with title/tt2024383...
# url loaded
# Getting attributes for tt2024383
# Getting cast for tt2024383
# time to obtain tt2024383 with position 12738 was 3 seconds
# getting url with title/tt2034795...
# url loaded
# Getting attributes for tt2034795
# Getting cast for tt2034795
# time to obtain tt2034795 with position 12739 was 3 seconds
# getting url with title/tt2035633...
# url loaded
# Getting attributes for tt2035633
# Getting cast for tt2035633
# time to obtain tt2035633 with position 12740 was 2 seconds
# getting url with title/tt2040448...
# url loaded
# Getting attributes for tt2040448
# Getting cast for tt2040448
# time to obtain tt2040448 with position 12741 was 4 seconds
# getting url with title/tt2055723...
# url loaded
# Getting attributes for tt2055723
# Getting cast for tt2055723
# time to obtain tt2055723 with position 12742 was 3 seconds
# getting url with title/tt2059262...
# url loaded
# Getting attributes for tt2059262
# Getting cast for tt2059262
# time to obtain tt2059262 with position 12743 was 3 seconds
# getting url with title/tt2058581...
# url loaded
# Getting attributes for tt2058581
# Getting cast for tt2058581
# time to obtain tt2058581 with position 12744 was 3 seconds
# getting url with title/tt2061677...
# url loaded
# Getting attributes for tt2061677
# Getting cast for tt2061677
# time to obtain tt2061677 with position 12745 was 2 seconds
# getting url with title/tt2064915...
# url loaded
# Getting attributes for tt2064915
# Getting cast for tt2064915
# time to obtain tt2064915 with position 12746 was 3 seconds
# getting url with title/tt2065866...
# url loaded
# Getting attributes for tt2065866
# Getting cast for tt2065866
# time to obtain tt2065866 with position 12747 was 2 seconds
# getting url with title/tt2066918...
# url loaded
# Getting attributes for tt2066918
# Getting cast for tt2066918
# time to obtain tt2066918 with position 12748 was 2 seconds
# getting url with title/tt2070716...
# url loaded
# Getting attributes for tt2070716
# Getting cast for tt2070716
# time to obtain tt2070716 with position 12749 was 3 seconds
# getting url with title/tt2069963...
# url loaded
# Getting attributes for tt2069963
# Getting cast for tt2069963
# time to obtain tt2069963 with position 12750 was 3 seconds
# getting url with title/tt2072886...
# url loaded
# Getting attributes for tt2072886
# Getting cast for tt2072886
# time to obtain tt2072886 with position 12751 was 3 seconds
# getting url with title/tt2073562...
# url loaded
# Getting attributes for tt2073562
# Getting cast for tt2073562
# time to obtain tt2073562 with position 12752 was 3 seconds
# getting url with title/tt2076861...
# url loaded
# Getting attributes for tt2076861
# Getting cast for tt2076861
# time to obtain tt2076861 with position 12753 was 6 seconds
# getting url with title/tt2078663...
# url loaded
# Getting attributes for tt2078663
# Getting cast for tt2078663
# time to obtain tt2078663 with position 12754 was 3 seconds
# getting url with title/tt2083930...
# url loaded
# Getting attributes for tt2083930
# Getting cast for tt2083930
# time to obtain tt2083930 with position 12755 was 3 seconds
# getting url with title/tt2087943...
# url loaded
# Getting attributes for tt2087943
# Getting cast for tt2087943
# time to obtain tt2087943 with position 12756 was 2 seconds
# getting url with title/tt2088032...
# url loaded
# Getting attributes for tt2088032
# Getting cast for tt2088032
# time to obtain tt2088032 with position 12757 was 3 seconds
# getting url with title/tt2088028...
# url loaded
# Getting attributes for tt2088028
# Getting cast for tt2088028
# time to obtain tt2088028 with position 12758 was 2 seconds
# getting url with title/tt2093282...
# url loaded
# Getting attributes for tt2093282
# Getting cast for tt2093282
# time to obtain tt2093282 with position 12759 was 2 seconds
# getting url with title/tt2094847...
# url loaded
# Getting attributes for tt2094847
# Getting cast for tt2094847
# time to obtain tt2094847 with position 12760 was 4 seconds
# getting url with title/tt2097210...
# url loaded
# Getting attributes for tt2097210
# Getting cast for tt2097210
# time to obtain tt2097210 with position 12761 was 4 seconds
# getting url with title/tt2094793...
# url loaded
# Getting attributes for tt2094793
# Getting cast for tt2094793
# time to obtain tt2094793 with position 12762 was 1 seconds
# getting url with title/tt2098800...
# url loaded
# Getting attributes for tt2098800
# Getting cast for tt2098800
# time to obtain tt2098800 with position 12763 was 4 seconds
# getting url with title/tt2100398...
# url loaded
# Getting attributes for tt2100398
# Getting cast for tt2100398
# time to obtain tt2100398 with position 12764 was 4 seconds
# getting url with title/tt2102418...
# url loaded
# Getting attributes for tt2102418
# Getting cast for tt2102418
# time to obtain tt2102418 with position 12765 was 4 seconds
# getting url with title/tt2103138...
# url loaded
# Getting attributes for tt2103138
# Getting cast for tt2103138
# time to obtain tt2103138 with position 12766 was 3 seconds
# getting url with title/tt2105015...
# url loaded
# Getting attributes for tt2105015
# Getting cast for tt2105015
# time to obtain tt2105015 with position 12767 was 2 seconds
# getting url with title/tt2106640...
# url loaded
# Getting attributes for tt2106640
# Getting cast for tt2106640
# time to obtain tt2106640 with position 12768 was 5 seconds
# getting url with title/tt2107807...
# url loaded
# Getting attributes for tt2107807
# Getting cast for tt2107807
# time to obtain tt2107807 with position 12769 was 4 seconds
# getting url with title/tt2106661...
# url loaded
# Getting attributes for tt2106661
# Getting cast for tt2106661
# time to obtain tt2106661 with position 12770 was 3 seconds
# getting url with title/tt2106380...
# url loaded
# Getting attributes for tt2106380
# Getting cast for tt2106380
# time to obtain tt2106380 with position 12771 was 6 seconds
# getting url with title/tt2111395...
# url loaded
# Getting attributes for tt2111395
# Getting cast for tt2111395
# time to obtain tt2111395 with position 12772 was 3 seconds
# getting url with title/tt2111259...
# url loaded
# Getting attributes for tt2111259
# Getting cast for tt2111259
# time to obtain tt2111259 with position 12773 was 4 seconds
# getting url with title/tt2114507...
# url loaded
# Getting attributes for tt2114507
# Getting cast for tt2114507
# time to obtain tt2114507 with position 12774 was 4 seconds
# getting url with title/tt2119522...
# url loaded
# Getting attributes for tt2119522
# Getting cast for tt2119522
# time to obtain tt2119522 with position 12775 was 4 seconds
# getting url with title/tt2122345...
# url loaded
# Getting attributes for tt2122345
# Getting cast for tt2122345
# time to obtain tt2122345 with position 12776 was 3 seconds
# getting url with title/tt2122376...
# url loaded
# Getting attributes for tt2122376
# Getting cast for tt2122376
# time to obtain tt2122376 with position 12777 was 3 seconds
# getting url with title/tt2124017...
# url loaded
# Getting attributes for tt2124017
# Getting cast for tt2124017
# time to obtain tt2124017 with position 12778 was 3 seconds
# getting url with title/tt2123304...
# url loaded
# Getting attributes for tt2123304
# Getting cast for tt2123304
# time to obtain tt2123304 with position 12779 was 5 seconds
# getting url with title/tt2125507...
# url loaded
# Getting attributes for tt2125507
# Getting cast for tt2125507
# time to obtain tt2125507 with position 12780 was 4 seconds
# getting url with title/tt2128485...
# url loaded
# Getting attributes for tt2128485
# error obtaining name for id tt2128485
# Getting cast for tt2128485
# time to obtain tt2128485 with position 12781 was 60 seconds
# getting url with title/tt2131549...
# url loaded
# Getting attributes for tt2131549
# Getting cast for tt2131549
# time to obtain tt2131549 with position 12782 was 3 seconds
# getting url with title/tt2130024...
# url loaded
# Getting attributes for tt2130024
# Getting cast for tt2130024
# time to obtain tt2130024 with position 12783 was 4 seconds
# getting url with title/tt2137100...
# url loaded
# Getting attributes for tt2137100
# Getting cast for tt2137100
# time to obtain tt2137100 with position 12784 was 10 seconds
# getting url with title/tt2137287...
# url loaded
# Getting attributes for tt2137287
# Getting cast for tt2137287
# time to obtain tt2137287 with position 12785 was 4 seconds
# getting url with title/tt2137358...
# url loaded
# Getting attributes for tt2137358
# Getting cast for tt2137358
# time to obtain tt2137358 with position 12786 was 4 seconds
# getting url with title/tt2137988...
# url loaded
# Getting attributes for tt2137988
# Getting cast for tt2137988
# time to obtain tt2137988 with position 12787 was 6 seconds
# getting url with title/tt2140059...
# url loaded
# Getting attributes for tt2140059
# Getting cast for tt2140059
# time to obtain tt2140059 with position 12788 was 3 seconds
# getting url with title/tt2141643...
# url loaded
# Getting attributes for tt2141643
# Getting cast for tt2141643
# time to obtain tt2141643 with position 12789 was 3 seconds
# getting url with title/tt2147270...
# url loaded
# Getting attributes for tt2147270
# Getting cast for tt2147270
# time to obtain tt2147270 with position 12790 was 3 seconds
# getting url with title/tt2150106...
# url loaded
# Getting attributes for tt2150106
# Getting cast for tt2150106
# time to obtain tt2150106 with position 12791 was 3 seconds
# getting url with title/tt2152845...
# url loaded
# Getting attributes for tt2152845
# Getting cast for tt2152845
# time to obtain tt2152845 with position 12792 was 9 seconds
# getting url with title/tt2153014...
# url loaded
# Getting attributes for tt2153014
# Getting cast for tt2153014
# time to obtain tt2153014 with position 12793 was 4 seconds
# getting url with title/tt2152709...
# url loaded
# Getting attributes for tt2152709
# Getting cast for tt2152709
# time to obtain tt2152709 with position 12794 was 5 seconds
# getting url with title/tt2155239...
# url loaded
# Getting attributes for tt2155239
# Getting cast for tt2155239
# time to obtain tt2155239 with position 12795 was 4 seconds
# getting url with title/tt2153624...
# url loaded
# Getting attributes for tt2153624
# Getting cast for tt2153624
# time to obtain tt2153624 with position 12796 was 4 seconds
# getting url with title/tt2155401...
# url loaded
# Getting attributes for tt2155401
# Getting cast for tt2155401
# time to obtain tt2155401 with position 12797 was 2 seconds
# getting url with title/tt2160287...
# url loaded
# Getting attributes for tt2160287
# Getting cast for tt2160287
# time to obtain tt2160287 with position 12798 was 4 seconds
# getting url with title/tt2158417...
# url loaded
# Getting attributes for tt2158417
# Getting cast for tt2158417
# time to obtain tt2158417 with position 12799 was 3 seconds
# getting url with title/tt2161160...
# url loaded
# Getting attributes for tt2161160
# Getting cast for tt2161160
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt2161160 with position 12800 was 19 seconds
# getting url with title/tt2162680...
# url loaded
# Getting attributes for tt2162680
# Getting cast for tt2162680
# time to obtain tt2162680 with position 12801 was 1 seconds
# getting url with title/tt2162731...
# url loaded
# Getting attributes for tt2162731
# Getting cast for tt2162731
# time to obtain tt2162731 with position 12802 was 1 seconds
# getting url with title/tt2166283...
# url loaded
# Getting attributes for tt2166283
# Getting cast for tt2166283
# time to obtain tt2166283 with position 12803 was 2 seconds
# getting url with title/tt2166630...
# url loaded
# Getting attributes for tt2166630
# Getting cast for tt2166630
# time to obtain tt2166630 with position 12804 was 1 seconds
# getting url with title/tt2180218...
# url loaded
# Getting attributes for tt2180218
# Getting cast for tt2180218
# time to obtain tt2180218 with position 12805 was 1 seconds
# getting url with title/tt2182137...
# url loaded
# Getting attributes for tt2182137
# Getting cast for tt2182137
# time to obtain tt2182137 with position 12806 was 2 seconds
# getting url with title/tt2188649...
# url loaded
# Getting attributes for tt2188649
# Getting cast for tt2188649
# time to obtain tt2188649 with position 12807 was 2 seconds
# getting url with title/tt2190227...
# url loaded
# Getting attributes for tt2190227
# Getting cast for tt2190227
# time to obtain tt2190227 with position 12808 was 1 seconds
# getting url with title/tt2193217...
# url loaded
# Getting attributes for tt2193217
# Getting cast for tt2193217
# time to obtain tt2193217 with position 12809 was 2 seconds
# getting url with title/tt2197961...
# url loaded
# Getting attributes for tt2197961
# Getting cast for tt2197961
# time to obtain tt2197961 with position 12810 was 3 seconds
# getting url with title/tt2203040...
# url loaded
# Getting attributes for tt2203040
# Getting cast for tt2203040
# time to obtain tt2203040 with position 12811 was 2 seconds
# getting url with title/tt2210510...
# url loaded
# Getting attributes for tt2210510
# Getting cast for tt2210510
# time to obtain tt2210510 with position 12812 was 1 seconds
# getting url with title/tt2210382...
# url loaded
# Getting attributes for tt2210382
# Getting cast for tt2210382
# time to obtain tt2210382 with position 12813 was 2 seconds
# getting url with title/tt2219480...
# url loaded
# Getting attributes for tt2219480
# Getting cast for tt2219480
# time to obtain tt2219480 with position 12814 was 1 seconds
# getting url with title/tt2223602...
# url loaded
# Getting attributes for tt2223602
# Getting cast for tt2223602
# time to obtain tt2223602 with position 12815 was 2 seconds
# getting url with title/tt2224015...
# url loaded
# Getting attributes for tt2224015
# Getting cast for tt2224015
# time to obtain tt2224015 with position 12816 was 2 seconds
# getting url with title/tt2222174...
# url loaded
# Getting attributes for tt2222174
# Getting cast for tt2222174
# time to obtain tt2222174 with position 12817 was 3 seconds
# getting url with title/tt2234285...
# url loaded
# Getting attributes for tt2234285
# Getting cast for tt2234285
# time to obtain tt2234285 with position 12818 was 2 seconds
# getting url with title/tt2243166...
# url loaded
# Getting attributes for tt2243166
# Getting cast for tt2243166
# time to obtain tt2243166 with position 12819 was 3 seconds
# getting url with title/tt2245908...
# url loaded
# Getting attributes for tt2245908
# Getting cast for tt2245908
# time to obtain tt2245908 with position 12820 was 2 seconds
# getting url with title/tt2251668...
# url loaded
# Getting attributes for tt2251668
# Getting cast for tt2251668
# time to obtain tt2251668 with position 12821 was 2 seconds
# getting url with title/tt2254180...
# url loaded
# Getting attributes for tt2254180
# Getting cast for tt2254180
# time to obtain tt2254180 with position 12822 was 3 seconds
# getting url with title/tt2258257...
# url loaded
# Getting attributes for tt2258257
# Getting cast for tt2258257
# time to obtain tt2258257 with position 12823 was 2 seconds
# getting url with title/tt2256841...
# url loaded
# Getting attributes for tt2256841
# Getting cast for tt2256841
# time to obtain tt2256841 with position 12824 was 2 seconds
# getting url with title/tt2260266...
# url loaded
# Getting attributes for tt2260266
# Getting cast for tt2260266
# time to obtain tt2260266 with position 12825 was 2 seconds
# getting url with title/tt2265303...
# url loaded
# Getting attributes for tt2265303
# Getting cast for tt2265303
# time to obtain tt2265303 with position 12826 was 2 seconds
# getting url with title/tt2269840...
# url loaded
# Getting attributes for tt2269840
# Getting cast for tt2269840
# time to obtain tt2269840 with position 12827 was 2 seconds
# getting url with title/tt2282905...
# url loaded
# Getting attributes for tt2282905
# error obtaining name for id tt2282905
# Getting cast for tt2282905
# time to obtain tt2282905 with position 12828 was 60 seconds
# getting url with title/tt2288157...
# url loaded
# Getting attributes for tt2288157
# Getting cast for tt2288157
# time to obtain tt2288157 with position 12829 was 12 seconds
# getting url with title/tt2288502...
# url loaded
# Getting attributes for tt2288502
# Getting cast for tt2288502
# time to obtain tt2288502 with position 12830 was 2 seconds
# getting url with title/tt2288258...
# url loaded
# Getting attributes for tt2288258
# Getting cast for tt2288258
# time to obtain tt2288258 with position 12831 was 2 seconds
# getting url with title/tt2290669...
# url loaded
# Getting attributes for tt2290669
# Getting cast for tt2290669
# time to obtain tt2290669 with position 12832 was 1 seconds
# getting url with title/tt2291562...
# url loaded
# Getting attributes for tt2291562
# Getting cast for tt2291562
# time to obtain tt2291562 with position 12833 was 3 seconds
# getting url with title/tt2296770...
# url loaded
# Getting attributes for tt2296770
# Getting cast for tt2296770
# time to obtain tt2296770 with position 12834 was 2 seconds
# getting url with title/tt2298447...
# url loaded
# Getting attributes for tt2298447
# Getting cast for tt2298447
# time to obtain tt2298447 with position 12835 was 2 seconds
# getting url with title/tt2298354...
# url loaded
# Getting attributes for tt2298354
# Getting cast for tt2298354
# time to obtain tt2298354 with position 12836 was 1 seconds
# getting url with title/tt2302541...
# url loaded
# Getting attributes for tt2302541
# Getting cast for tt2302541
# time to obtain tt2302541 with position 12837 was 2 seconds
# getting url with title/tt2308655...
# url loaded
# Getting attributes for tt2308655
# Getting cast for tt2308655
# time to obtain tt2308655 with position 12838 was 1 seconds
# getting url with title/tt2319658...
# url loaded
# Getting attributes for tt2319658
# Getting cast for tt2319658
# time to obtain tt2319658 with position 12839 was 2 seconds
# getting url with title/tt2319773...
# url loaded
# Getting attributes for tt2319773
# Getting cast for tt2319773
# time to obtain tt2319773 with position 12840 was 1 seconds
# getting url with title/tt2320024...
# url loaded
# Getting attributes for tt2320024
# Getting cast for tt2320024
# time to obtain tt2320024 with position 12841 was 1 seconds
# getting url with title/tt2323661...
# url loaded
# Getting attributes for tt2323661
# Getting cast for tt2323661
# time to obtain tt2323661 with position 12842 was 2 seconds
# getting url with title/tt2323591...
# url loaded
# Getting attributes for tt2323591
# Getting cast for tt2323591
# time to obtain tt2323591 with position 12843 was 1 seconds
# getting url with title/tt2325605...
# url loaded
# Getting attributes for tt2325605
# Getting cast for tt2325605
# time to obtain tt2325605 with position 12844 was 1 seconds
# getting url with title/tt2328507...
# url loaded
# Getting attributes for tt2328507
# Getting cast for tt2328507
# time to obtain tt2328507 with position 12845 was 2 seconds
# getting url with title/tt2330070...
# url loaded
# Getting attributes for tt2330070
# Getting cast for tt2330070
# time to obtain tt2330070 with position 12846 was 2 seconds
# getting url with title/tt2336483...
# url loaded
# Getting attributes for tt2336483
# Getting cast for tt2336483
# time to obtain tt2336483 with position 12847 was 1 seconds
# getting url with title/tt2341004...
# url loaded
# Getting attributes for tt2341004
# Getting cast for tt2341004
# time to obtain tt2341004 with position 12848 was 1 seconds
# getting url with title/tt2340854...
# url loaded
# Getting attributes for tt2340854
# Getting cast for tt2340854
# time to obtain tt2340854 with position 12849 was 2 seconds
# getting url with title/tt2341856...
# url loaded
# Getting attributes for tt2341856
# Getting cast for tt2341856
# time to obtain tt2341856 with position 12850 was 5 seconds
# getting url with title/tt2342632...
# url loaded
# Getting attributes for tt2342632
# Getting cast for tt2342632
# time to obtain tt2342632 with position 12851 was 3 seconds
# getting url with title/tt2342968...
# url loaded
# Getting attributes for tt2342968
# Getting cast for tt2342968
# time to obtain tt2342968 with position 12852 was 3 seconds
# getting url with title/tt2342185...
# url loaded
# Getting attributes for tt2342185
# Getting cast for tt2342185
# time to obtain tt2342185 with position 12853 was 4 seconds
# getting url with title/tt2345002...
# url loaded
# Getting attributes for tt2345002
# Getting cast for tt2345002
# time to obtain tt2345002 with position 12854 was 2 seconds
# getting url with title/tt2345519...
# url loaded
# Getting attributes for tt2345519
# Getting cast for tt2345519
# time to obtain tt2345519 with position 12855 was 4 seconds
# getting url with title/tt2347146...
# url loaded
# Getting attributes for tt2347146
# Getting cast for tt2347146
# time to obtain tt2347146 with position 12856 was 3 seconds
# getting url with title/tt2350670...
# url loaded
# Getting attributes for tt2350670
# Getting cast for tt2350670
# time to obtain tt2350670 with position 12857 was 3 seconds
# getting url with title/tt2356152...
# url loaded
# Getting attributes for tt2356152
# Getting cast for tt2356152
# time to obtain tt2356152 with position 12858 was 4 seconds
# getting url with title/tt2357804...
# url loaded
# Getting attributes for tt2357804
# Getting cast for tt2357804
# time to obtain tt2357804 with position 12859 was 4 seconds
# getting url with title/tt2357269...
# url loaded
# Getting attributes for tt2357269
# Getting cast for tt2357269
# time to obtain tt2357269 with position 12860 was 3 seconds
# getting url with title/tt2362566...
# url loaded
# Getting attributes for tt2362566
# Getting cast for tt2362566
# time to obtain tt2362566 with position 12861 was 4 seconds
# getting url with title/tt2367668...
# url loaded
# Getting attributes for tt2367668
# Getting cast for tt2367668
# time to obtain tt2367668 with position 12862 was 4 seconds
# getting url with title/tt2368805...
# url loaded
# Getting attributes for tt2368805
# Getting cast for tt2368805
# time to obtain tt2368805 with position 12863 was 3 seconds
# getting url with title/tt2369357...
# url loaded
# Getting attributes for tt2369357
# Getting cast for tt2369357
# time to obtain tt2369357 with position 12864 was 2 seconds
# getting url with title/tt2382882...
# url loaded
# Getting attributes for tt2382882
# Getting cast for tt2382882
# time to obtain tt2382882 with position 12865 was 3 seconds
# getting url with title/tt2384714...
# url loaded
# Getting attributes for tt2384714
# Getting cast for tt2384714
# time to obtain tt2384714 with position 12866 was 3 seconds
# getting url with title/tt2403917...
# url loaded
# Getting attributes for tt2403917
# Getting cast for tt2403917
# time to obtain tt2403917 with position 12867 was 3 seconds
# getting url with title/tt2403951...
# url loaded
# Getting attributes for tt2403951
# Getting cast for tt2403951
# time to obtain tt2403951 with position 12868 was 4 seconds
# getting url with title/tt2406870...
# url loaded
# Getting attributes for tt2406870
# Getting cast for tt2406870
# time to obtain tt2406870 with position 12869 was 3 seconds
# getting url with title/tt2406904...
# url loaded
# Getting attributes for tt2406904
# Getting cast for tt2406904
# time to obtain tt2406904 with position 12870 was 3 seconds
# getting url with title/tt2405798...
# url loaded
# Getting attributes for tt2405798
# Getting cast for tt2405798
# time to obtain tt2405798 with position 12871 was 4 seconds
# getting url with title/tt2408712...
# url loaded
# Getting attributes for tt2408712
# Getting cast for tt2408712
# time to obtain tt2408712 with position 12872 was 3 seconds
# getting url with title/tt2422380...
# url loaded
# Getting attributes for tt2422380
# Getting cast for tt2422380
# time to obtain tt2422380 with position 12873 was 4 seconds
# getting url with title/tt2428366...
# url loaded
# Getting attributes for tt2428366
# Getting cast for tt2428366
# time to obtain tt2428366 with position 12874 was 3 seconds
# getting url with title/tt2436872...
# url loaded
# Getting attributes for tt2436872
# Getting cast for tt2436872
# time to obtain tt2436872 with position 12875 was 3 seconds
# getting url with title/tt2441800...
# url loaded
# Getting attributes for tt2441800
# Getting cast for tt2441800
# time to obtain tt2441800 with position 12876 was 4 seconds
# getting url with title/tt2440912...
# url loaded
# Getting attributes for tt2440912
# Getting cast for tt2440912
# time to obtain tt2440912 with position 12877 was 3 seconds
# getting url with title/tt2450142...
# url loaded
# Getting attributes for tt2450142
# Getting cast for tt2450142
# time to obtain tt2450142 with position 12878 was 4 seconds
# getting url with title/tt2451696...
# url loaded
# Getting attributes for tt2451696
# Getting cast for tt2451696
# time to obtain tt2451696 with position 12879 was 3 seconds
# getting url with title/tt2463416...
# url loaded
# Getting attributes for tt2463416
# Getting cast for tt2463416
# time to obtain tt2463416 with position 12880 was 6 seconds
# getting url with title/tt2466914...
# url loaded
# Getting attributes for tt2466914
# Getting cast for tt2466914
# time to obtain tt2466914 with position 12881 was 4 seconds
# getting url with title/tt2468052...
# url loaded
# Getting attributes for tt2468052
# Getting cast for tt2468052
# time to obtain tt2468052 with position 12882 was 3 seconds
# getting url with title/tt2468210...
# url loaded
# Getting attributes for tt2468210
# Getting cast for tt2468210
# time to obtain tt2468210 with position 12883 was 2 seconds
# getting url with title/tt2473934...
# url loaded
# Getting attributes for tt2473934
# Getting cast for tt2473934
# time to obtain tt2473934 with position 12884 was 3 seconds
# getting url with title/tt2483130...
# url loaded
# Getting attributes for tt2483130
# Getting cast for tt2483130
# time to obtain tt2483130 with position 12885 was 3 seconds
# getting url with title/tt2478824...
# url loaded
# Getting attributes for tt2478824
# Getting cast for tt2478824
# time to obtain tt2478824 with position 12886 was 6 seconds
# getting url with title/tt2479512...
# url loaded
# Getting attributes for tt2479512
# Getting cast for tt2479512
# time to obtain tt2479512 with position 12887 was 4 seconds
# getting url with title/tt2495446...
# url loaded
# Getting attributes for tt2495446
# Getting cast for tt2495446
# time to obtain tt2495446 with position 12888 was 4 seconds
# getting url with title/tt2498460...
# url loaded
# Getting attributes for tt2498460
# Getting cast for tt2498460
# time to obtain tt2498460 with position 12889 was 3 seconds
# getting url with title/tt2498496...
# url loaded
# Getting attributes for tt2498496
# Getting cast for tt2498496
# time to obtain tt2498496 with position 12890 was 2 seconds
# getting url with title/tt2502910...
# url loaded
# Getting attributes for tt2502910
# Getting cast for tt2502910
# time to obtain tt2502910 with position 12891 was 3 seconds
# getting url with title/tt2528620...
# url loaded
# Getting attributes for tt2528620
# Getting cast for tt2528620
# time to obtain tt2528620 with position 12892 was 3 seconds
# getting url with title/tt2529200...
# url loaded
# Getting attributes for tt2529200
# Getting cast for tt2529200
# time to obtain tt2529200 with position 12893 was 4 seconds
# getting url with title/tt2555798...
# url loaded
# Getting attributes for tt2555798
# Getting cast for tt2555798
# time to obtain tt2555798 with position 12894 was 3 seconds
# getting url with title/tt2559370...
# url loaded
# Getting attributes for tt2559370
# Getting cast for tt2559370
# time to obtain tt2559370 with position 12895 was 4 seconds
# getting url with title/tt2569496...
# url loaded
# Getting attributes for tt2569496
# Getting cast for tt2569496
# time to obtain tt2569496 with position 12896 was 4 seconds
# getting url with title/tt2569636...
# url loaded
# Getting attributes for tt2569636
# Getting cast for tt2569636
# time to obtain tt2569636 with position 12897 was 6 seconds
# getting url with title/tt2570426...
# url loaded
# Getting attributes for tt2570426
# Getting cast for tt2570426
# time to obtain tt2570426 with position 12898 was 4 seconds
# getting url with title/tt2576550...
# url loaded
# Getting attributes for tt2576550
# Getting cast for tt2576550
# time to obtain tt2576550 with position 12899 was 3 seconds
# getting url with title/tt2585326...
# url loaded
# Getting attributes for tt2585326
# Getting cast for tt2585326
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt2585326 with position 12900 was 16 seconds
# getting url with title/tt2586420...
# url loaded
# Getting attributes for tt2586420
# Getting cast for tt2586420
# time to obtain tt2586420 with position 12901 was 2 seconds
# getting url with title/tt2618896...
# url loaded
# Getting attributes for tt2618896
# Getting cast for tt2618896
# time to obtain tt2618896 with position 12902 was 1 seconds
# getting url with title/tt2631636...
# url loaded
# Getting attributes for tt2631636
# Getting cast for tt2631636
# time to obtain tt2631636 with position 12903 was 2 seconds
# getting url with title/tt2631604...
# url loaded
# Getting attributes for tt2631604
# Getting cast for tt2631604
# time to obtain tt2631604 with position 12904 was 1 seconds
# getting url with title/tt2638438...
# url loaded
# Getting attributes for tt2638438
# Getting cast for tt2638438
# time to obtain tt2638438 with position 12905 was 1 seconds
# getting url with title/tt2641922...
# url loaded
# Getting attributes for tt2641922
# Getting cast for tt2641922
# time to obtain tt2641922 with position 12906 was 3 seconds
# getting url with title/tt2651262...
# url loaded
# Getting attributes for tt2651262
# Getting cast for tt2651262
# time to obtain tt2651262 with position 12907 was 2 seconds
# getting url with title/tt2654054...
# url loaded
# Getting attributes for tt2654054
# Getting cast for tt2654054
# time to obtain tt2654054 with position 12908 was 2 seconds
# getting url with title/tt2659948...
# url loaded
# Getting attributes for tt2659948
# Getting cast for tt2659948
# time to obtain tt2659948 with position 12909 was 2 seconds
# getting url with title/tt2672646...
# url loaded
# Getting attributes for tt2672646
# Getting cast for tt2672646
# time to obtain tt2672646 with position 12910 was 3 seconds
# getting url with title/tt2679404...
# url loaded
# Getting attributes for tt2679404
# Getting cast for tt2679404
# time to obtain tt2679404 with position 12911 was 5 seconds
# getting url with title/tt2701418...
# url loaded
# Getting attributes for tt2701418
# Getting cast for tt2701418
# time to obtain tt2701418 with position 12912 was 2 seconds
# getting url with title/tt2709702...
# url loaded
# Getting attributes for tt2709702
# Getting cast for tt2709702
# time to obtain tt2709702 with position 12913 was 2 seconds
# getting url with title/tt2717550...
# url loaded
# Getting attributes for tt2717550
# Getting cast for tt2717550
# time to obtain tt2717550 with position 12914 was 3 seconds
# getting url with title/tt2718114...
# url loaded
# Getting attributes for tt2718114
# Getting cast for tt2718114
# time to obtain tt2718114 with position 12915 was 2 seconds
# getting url with title/tt2719638...
# url loaded
# Getting attributes for tt2719638
# Getting cast for tt2719638
# time to obtain tt2719638 with position 12916 was 2 seconds
# getting url with title/tt2736340...
# url loaded
# Getting attributes for tt2736340
# Getting cast for tt2736340
# time to obtain tt2736340 with position 12917 was 3 seconds
# getting url with title/tt2736090...
# url loaded
# Getting attributes for tt2736090
# Getting cast for tt2736090
# time to obtain tt2736090 with position 12918 was 2 seconds
# getting url with title/tt2738904...
# url loaded
# Getting attributes for tt2738904
# Getting cast for tt2738904
# time to obtain tt2738904 with position 12919 was 3 seconds
# getting url with title/tt2767476...
# url loaded
# Getting attributes for tt2767476
# Getting cast for tt2767476
# time to obtain tt2767476 with position 12920 was 2 seconds
# getting url with title/tt2786658...
# url loaded
# Getting attributes for tt2786658
# Getting cast for tt2786658
# time to obtain tt2786658 with position 12921 was 2 seconds
# getting url with title/tt2793230...
# url loaded
# Getting attributes for tt2793230
# Getting cast for tt2793230
# time to obtain tt2793230 with position 12922 was 3 seconds
# getting url with title/tt2795206...
# url loaded
# Getting attributes for tt2795206
# Getting cast for tt2795206
# time to obtain tt2795206 with position 12923 was 3 seconds
# getting url with title/tt2794928...
# url loaded
# Getting attributes for tt2794928
# Getting cast for tt2794928
# time to obtain tt2794928 with position 12924 was 4 seconds
# getting url with title/tt2795594...
# url loaded
# Getting attributes for tt2795594
# Getting cast for tt2795594
# time to obtain tt2795594 with position 12925 was 4 seconds
# getting url with title/tt2799242...
# url loaded
# Getting attributes for tt2799242
# Getting cast for tt2799242
# time to obtain tt2799242 with position 12926 was 4 seconds
# getting url with title/tt2808662...
# url loaded
# Getting attributes for tt2808662
# Getting cast for tt2808662
# time to obtain tt2808662 with position 12927 was 3 seconds
# getting url with title/tt2829184...
# url loaded
# Getting attributes for tt2829184
# error obtaining name for id tt2829184
# Getting cast for tt2829184
# time to obtain tt2829184 with position 12928 was 61 seconds
# getting url with title/tt2830164...
# url loaded
# Getting attributes for tt2830164
# Getting cast for tt2830164
# time to obtain tt2830164 with position 12929 was 2 seconds
# getting url with title/tt2827944...
# url loaded
# Getting attributes for tt2827944
# Getting cast for tt2827944
# time to obtain tt2827944 with position 12930 was 2 seconds
# getting url with title/tt2846636...
# url loaded
# Getting attributes for tt2846636
# Getting cast for tt2846636
# time to obtain tt2846636 with position 12931 was 2 seconds
# getting url with title/tt2858738...
# url loaded
# Getting attributes for tt2858738
# Getting cast for tt2858738
# time to obtain tt2858738 with position 12932 was 2 seconds
# getting url with title/tt2872758...
# url loaded
# Getting attributes for tt2872758
# Getting cast for tt2872758
# time to obtain tt2872758 with position 12933 was 2 seconds
# getting url with title/tt2878526...
# url loaded
# Getting attributes for tt2878526
# Getting cast for tt2878526
# time to obtain tt2878526 with position 12934 was 2 seconds
# getting url with title/tt2891578...
# url loaded
# Getting attributes for tt2891578
# Getting cast for tt2891578
# time to obtain tt2891578 with position 12935 was 2 seconds
# getting url with title/tt2891064...
# url loaded
# Getting attributes for tt2891064
# Getting cast for tt2891064
# time to obtain tt2891064 with position 12936 was 3 seconds
# getting url with title/tt2903322...
# url loaded
# Getting attributes for tt2903322
# Getting cast for tt2903322
# time to obtain tt2903322 with position 12937 was 3 seconds
# getting url with title/tt2909032...
# url loaded
# Getting attributes for tt2909032
# Getting cast for tt2909032
# time to obtain tt2909032 with position 12938 was 2 seconds
# getting url with title/tt2920176...
# url loaded
# Getting attributes for tt2920176
# Getting cast for tt2920176
# time to obtain tt2920176 with position 12939 was 3 seconds
# getting url with title/tt2936464...
# url loaded
# Getting attributes for tt2936464
# Getting cast for tt2936464
# time to obtain tt2936464 with position 12940 was 3 seconds
# getting url with title/tt2937762...
# url loaded
# Getting attributes for tt2937762
# Getting cast for tt2937762
# time to obtain tt2937762 with position 12941 was 3 seconds
# getting url with title/tt2942756...
# url loaded
# Getting attributes for tt2942756
# Getting cast for tt2942756
# time to obtain tt2942756 with position 12942 was 3 seconds
# getting url with title/tt2975648...
# url loaded
# Getting attributes for tt2975648
# Getting cast for tt2975648
# time to obtain tt2975648 with position 12943 was 3 seconds
# getting url with title/tt2976100...
# url loaded
# Getting attributes for tt2976100
# Getting cast for tt2976100
# time to obtain tt2976100 with position 12944 was 3 seconds
# getting url with title/tt2979946...
# url loaded
# Getting attributes for tt2979946
# Getting cast for tt2979946
# time to obtain tt2979946 with position 12945 was 4 seconds
# getting url with title/tt2981422...
# url loaded
# Getting attributes for tt2981422
# Getting cast for tt2981422
# time to obtain tt2981422 with position 12946 was 3 seconds
# getting url with title/tt2987758...
# url loaded
# Getting attributes for tt2987758
# Getting cast for tt2987758
# time to obtain tt2987758 with position 12947 was 5 seconds
# getting url with title/tt2994014...
# url loaded
# Getting attributes for tt2994014
# Getting cast for tt2994014
# ...
# url loaded
# Getting attributes for tt0386734
# Getting cast for tt0386734
# time to obtain tt0386734 with position 14520 was 1 seconds
# getting url with title/tt0386845...
# url loaded
# Getting attributes for tt0386845
# Getting cast for tt0386845
# time to obtain tt0386845 with position 14521 was 2 seconds
# getting url with title/tt0386456...
# url loaded
# Getting attributes for tt0386456
# Getting cast for tt0386456
# time to obtain tt0386456 with position 14522 was 2 seconds
# getting url with title/tt0387468...
# url loaded
# Getting attributes for tt0387468
# Getting cast for tt0387468
# time to obtain tt0387468 with position 14523 was 1 seconds
# getting url with title/tt0387420...
# url loaded
# Getting attributes for tt0387420
# Getting cast for tt0387420
# time to obtain tt0387420 with position 14524 was 1 seconds
# getting url with title/tt0388674...
# url loaded
# Getting attributes for tt0388674
# Getting cast for tt0388674
# time to obtain tt0388674 with position 14525 was 3 seconds
# getting url with title/tt0391259...
# url loaded
# Getting attributes for tt0391259
# Getting cast for tt0391259
# time to obtain tt0391259 with position 14526 was 2 seconds
# getting url with title/tt0390493...
# url loaded
# Getting attributes for tt0390493
# Getting cast for tt0390493
# time to obtain tt0390493 with position 14527 was 1 seconds
# getting url with title/tt0391381...
# url loaded
# Getting attributes for tt0391381
# Getting cast for tt0391381
# time to obtain tt0391381 with position 14528 was 1 seconds
# getting url with title/tt0391444...
# url loaded
# Getting attributes for tt0391444
# Getting cast for tt0391444
# time to obtain tt0391444 with position 14529 was 1 seconds
# getting url with title/tt0392607...
# url loaded
# Getting attributes for tt0392607
# Getting cast for tt0392607
# time to obtain tt0392607 with position 14530 was 1 seconds
# getting url with title/tt0392806...
# url loaded
# Getting attributes for tt0392806
# Getting cast for tt0392806
# time to obtain tt0392806 with position 14531 was 1 seconds
# getting url with title/tt0396142...
# url loaded
# Getting attributes for tt0396142
# Getting cast for tt0396142
# time to obtain tt0396142 with position 14532 was 2 seconds
# getting url with title/tt0393556...
# url loaded
# Getting attributes for tt0393556
# Getting cast for tt0393556
# time to obtain tt0393556 with position 14533 was 2 seconds
# getting url with title/tt0398066...
# url loaded
# Getting attributes for tt0398066
# Getting cast for tt0398066
# time to obtain tt0398066 with position 14534 was 2 seconds
# getting url with title/tt0396178...
# url loaded
# Getting attributes for tt0396178
# Getting cast for tt0396178
# time to obtain tt0396178 with position 14535 was 1 seconds
# getting url with title/tt0396811...
# url loaded
# Getting attributes for tt0396811
# Getting cast for tt0396811
# time to obtain tt0396811 with position 14536 was 2 seconds
# getting url with title/tt0396858...
# url loaded
# Getting attributes for tt0396858
# Getting cast for tt0396858
# time to obtain tt0396858 with position 14537 was 2 seconds
# getting url with title/tt0398901...
# url loaded
# Getting attributes for tt0398901
# Getting cast for tt0398901
# time to obtain tt0398901 with position 14538 was 3 seconds
# getting url with title/tt0399353...
# url loaded
# Getting attributes for tt0399353
# Getting cast for tt0399353
# time to obtain tt0399353 with position 14539 was 3 seconds
# getting url with title/tt0399101...
# url loaded
# Getting attributes for tt0399101
# Getting cast for tt0399101
# time to obtain tt0399101 with position 14540 was 2 seconds
# getting url with title/tt0398863...
# url loaded
# Getting attributes for tt0398863
# Getting cast for tt0398863
# time to obtain tt0398863 with position 14541 was 1 seconds
# getting url with title/tt0399183...
# url loaded
# Getting attributes for tt0399183
# Getting cast for tt0399183
# time to obtain tt0399183 with position 14542 was 1 seconds
# getting url with title/tt0399175...
# url loaded
# Getting attributes for tt0399175
# Getting cast for tt0399175
# time to obtain tt0399175 with position 14543 was 2 seconds
# getting url with title/tt0399563...
# url loaded
# Getting attributes for tt0399563
# Getting cast for tt0399563
# time to obtain tt0399563 with position 14544 was 1 seconds
# getting url with title/tt0400744...
# url loaded
# Getting attributes for tt0400744
# Getting cast for tt0400744
# time to obtain tt0400744 with position 14545 was 1 seconds
# getting url with title/tt0400692...
# url loaded
# Getting attributes for tt0400692
# Getting cast for tt0400692
# time to obtain tt0400692 with position 14546 was 3 seconds
# getting url with title/tt0402928...
# url loaded
# Getting attributes for tt0402928
# Getting cast for tt0402928
# time to obtain tt0402928 with position 14547 was 3 seconds
# getting url with title/tt0404561...
# url loaded
# Getting attributes for tt0404561
# Getting cast for tt0404561
# time to obtain tt0404561 with position 14548 was 2 seconds
# getting url with title/tt0404484...
# url loaded
# Getting attributes for tt0404484
# Getting cast for tt0404484
# time to obtain tt0404484 with position 14549 was 2 seconds
# getting url with title/tt0403591...
# url loaded
# Getting attributes for tt0403591
# Getting cast for tt0403591
# time to obtain tt0403591 with position 14550 was 3 seconds
# getting url with title/tt0404037...
# url loaded
# Getting attributes for tt0404037
# Getting cast for tt0404037
# time to obtain tt0404037 with position 14551 was 2 seconds
# getting url with title/tt0406145...
# url loaded
# Getting attributes for tt0406145
# Getting cast for tt0406145
# time to obtain tt0406145 with position 14552 was 3 seconds
# getting url with title/tt0404921...
# url loaded
# Getting attributes for tt0404921
# Getting cast for tt0404921
# time to obtain tt0404921 with position 14553 was 6 seconds
# getting url with title/tt0405256...
# url loaded
# Getting attributes for tt0405256
# Getting cast for tt0405256
# time to obtain tt0405256 with position 14554 was 3 seconds
# getting url with title/tt0404904...
# url loaded
# Getting attributes for tt0404904
# Getting cast for tt0404904
# time to obtain tt0404904 with position 14555 was 4 seconds
# getting url with title/tt0405310...
# url loaded
# Getting attributes for tt0405310
# Getting cast for tt0405310
# time to obtain tt0405310 with position 14556 was 3 seconds
# getting url with title/tt0405905...
# url loaded
# Getting attributes for tt0405905
# Getting cast for tt0405905
# time to obtain tt0405905 with position 14557 was 2 seconds
# getting url with title/tt0406784...
# url loaded
# Getting attributes for tt0406784
# Getting cast for tt0406784
# time to obtain tt0406784 with position 14558 was 5 seconds
# getting url with title/tt0407506...
# url loaded
# Getting attributes for tt0407506
# Getting cast for tt0407506
# time to obtain tt0407506 with position 14559 was 5 seconds
# getting url with title/tt0407656...
# url loaded
# Getting attributes for tt0407656
# Getting cast for tt0407656
# time to obtain tt0407656 with position 14560 was 4 seconds
# getting url with title/tt0408020...
# url loaded
# Getting attributes for tt0408020
# Getting cast for tt0408020
# time to obtain tt0408020 with position 14561 was 3 seconds
# getting url with title/tt0408907...
# url loaded
# Getting attributes for tt0408907
# Getting cast for tt0408907
# time to obtain tt0408907 with position 14562 was 2 seconds
# getting url with title/tt0408617...
# url loaded
# Getting attributes for tt0408617
# Getting cast for tt0408617
# time to obtain tt0408617 with position 14563 was 2 seconds
# getting url with title/tt0409198...
# url loaded
# Getting attributes for tt0409198
# Getting cast for tt0409198
# time to obtain tt0409198 with position 14564 was 3 seconds
# getting url with title/tt0408670...
# url loaded
# Getting attributes for tt0408670
# Getting cast for tt0408670
# time to obtain tt0408670 with position 14565 was 3 seconds
# getting url with title/tt0410051...
# url loaded
# Getting attributes for tt0410051
# Getting cast for tt0410051
# time to obtain tt0410051 with position 14566 was 6 seconds
# getting url with title/tt0412017...
# url loaded
# Getting attributes for tt0412017
# Getting cast for tt0412017
# time to obtain tt0412017 with position 14567 was 4 seconds
# getting url with title/tt0410800...
# url loaded
# Getting attributes for tt0410800
# Getting cast for tt0410800
# time to obtain tt0410800 with position 14568 was 2 seconds
# getting url with title/tt0412081...
# url loaded
# Getting attributes for tt0412081
# Getting cast for tt0412081
# time to obtain tt0412081 with position 14569 was 5 seconds
# getting url with title/tt0415321...
# url loaded
# Getting attributes for tt0415321
# Getting cast for tt0415321
# time to obtain tt0415321 with position 14570 was 4 seconds
# getting url with title/tt0414529...
# url loaded
# Getting attributes for tt0414529
# Getting cast for tt0414529
# time to obtain tt0414529 with position 14571 was 3 seconds
# getting url with title/tt0415269...
# url loaded
# Getting attributes for tt0415269
# Getting cast for tt0415269
# time to obtain tt0415269 with position 14572 was 4 seconds
# getting url with title/tt0416075...
# url loaded
# Getting attributes for tt0416075
# Getting cast for tt0416075
# time to obtain tt0416075 with position 14573 was 5 seconds
# getting url with title/tt0416850...
# url loaded
# Getting attributes for tt0416850
# Getting cast for tt0416850
# time to obtain tt0416850 with position 14574 was 5 seconds
# getting url with title/tt0417890...
# url loaded
# Getting attributes for tt0417890
# Getting cast for tt0417890
# time to obtain tt0417890 with position 14575 was 5 seconds
# getting url with title/tt0421185...
# url loaded
# Getting attributes for tt0421185
# Getting cast for tt0421185
# time to obtain tt0421185 with position 14576 was 4 seconds
# getting url with title/tt0421047...
# url loaded
# Getting attributes for tt0421047
# Getting cast for tt0421047
# time to obtain tt0421047 with position 14577 was 3 seconds
# getting url with title/tt0423053...
# url loaded
# Getting attributes for tt0423053
# Getting cast for tt0423053
# time to obtain tt0423053 with position 14578 was 2 seconds
# getting url with title/tt0425026...
# url loaded
# Getting attributes for tt0425026
# Getting cast for tt0425026
# time to obtain tt0425026 with position 14579 was 7 seconds
# getting url with title/tt0426325...
# url loaded
# Getting attributes for tt0426325
# Getting cast for tt0426325
# time to obtain tt0426325 with position 14580 was 6 seconds
# getting url with title/tt0426021...
# url loaded
# Getting attributes for tt0426021
# Getting cast for tt0426021
# time to obtain tt0426021 with position 14581 was 4 seconds
# getting url with title/tt0426837...
# url loaded
# Getting attributes for tt0426837
# Getting cast for tt0426837
# time to obtain tt0426837 with position 14582 was 5 seconds
# getting url with title/tt0426833...
# url loaded
# Getting attributes for tt0426833
# Getting cast for tt0426833
# time to obtain tt0426833 with position 14583 was 3 seconds
# getting url with title/tt0426474...
# url loaded
# Getting attributes for tt0426474
# Getting cast for tt0426474
# time to obtain tt0426474 with position 14584 was 4 seconds
# getting url with title/tt0427260...
# url loaded
# Getting attributes for tt0427260
# Getting cast for tt0427260
# time to obtain tt0427260 with position 14585 was 4 seconds
# getting url with title/tt0426946...
# url loaded
# Getting attributes for tt0426946
# Getting cast for tt0426946
# time to obtain tt0426946 with position 14586 was 4 seconds
# getting url with title/tt0427445...
# url loaded
# Getting attributes for tt0427445
# Getting cast for tt0427445
# time to obtain tt0427445 with position 14587 was 4 seconds
# getting url with title/tt0427917...
# url loaded
# Getting attributes for tt0427917
# Getting cast for tt0427917
# time to obtain tt0427917 with position 14588 was 3 seconds
# getting url with title/tt0430558...
# url loaded
# Getting attributes for tt0430558
# Getting cast for tt0430558
# time to obtain tt0430558 with position 14589 was 4 seconds
# getting url with title/tt0430398...
# url loaded
# Getting attributes for tt0430398
# Getting cast for tt0430398
# time to obtain tt0430398 with position 14590 was 6 seconds
# getting url with title/tt0430942...
# url loaded
# Getting attributes for tt0430942
# Getting cast for tt0430942
# time to obtain tt0430942 with position 14591 was 4 seconds
# getting url with title/tt0433518...
# url loaded
# Getting attributes for tt0433518
# Getting cast for tt0433518
# time to obtain tt0433518 with position 14592 was 7 seconds
# getting url with title/tt0434359...
# url loaded
# Getting attributes for tt0434359
# Getting cast for tt0434359
# time to obtain tt0434359 with position 14593 was 5 seconds
# getting url with title/tt0434195...
# url loaded
# Getting attributes for tt0434195
# Getting cast for tt0434195
# time to obtain tt0434195 with position 14594 was 6 seconds
# getting url with title/tt0433584...
# url loaded
# Getting attributes for tt0433584
# Getting cast for tt0433584
# time to obtain tt0433584 with position 14595 was 4 seconds
# getting url with title/tt0436630...
# url loaded
# Getting attributes for tt0436630
# Getting cast for tt0436630
# time to obtain tt0436630 with position 14596 was 3 seconds
# getting url with title/tt0436518...
# url loaded
# Getting attributes for tt0436518
# Getting cast for tt0436518
# time to obtain tt0436518 with position 14597 was 3 seconds
# getting url with title/tt0437493...
# url loaded
# Getting attributes for tt0437493
# Getting cast for tt0437493
# time to obtain tt0437493 with position 14598 was 4 seconds
# getting url with title/tt0439594...
# url loaded
# Getting attributes for tt0439594
# Getting cast for tt0439594
# time to obtain tt0439594 with position 14599 was 4 seconds
# getting url with title/tt0440185...
# url loaded
# Getting attributes for tt0440185
# Getting cast for tt0440185
# Saving checkpoint...
# getting url with ...
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[21], line 71
#      69     driver.close()
#      70     driver = webdriver.Firefox(options)
# ---> 71     driver = get_url(driver, "", True)
#      73 counter += 1
#      74 end_time = datetime.now()
#
# Cell In[15], line 6, in get_url(driver, path, accept_cookies)
#       3 url = f"https://www.imdb.com/{path}"
#       5 print(f"getting url with {path}...")
# ----> 6 driver.get(url)
#       7 print("url loaded")
#       8 driver.maximize_window()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: Browsing context has been discarded
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:191:5
# NoSuchWindowError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:662:5
# assert.that/<@chrome://remote/content/shared/webdriver/Assert.sys.mjs:485:13
# assert.open@chrome://remote/content/shared/webdriver/Assert.sys.mjs:147:4
# GeckoDriver.prototype.navigateTo@chrome://remote/content/marionette/driver.sys.mjs:816:39
# despatch@chrome://remote/content/marionette/server.sys.mjs:318:40
# execute@chrome://remote/content/marionette/server.sys.mjs:289:16
# onPacket/<@chrome://remote/content/marionette/server.sys.mjs:262:20
# onPacket@chrome://remote/content/marionette/server.sys.mjs:263:9
# _onJSONObjectReady/<@chrome://remote/content/marionette/transport.sys.mjs:494:20

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    3.974
# dtype: float64
