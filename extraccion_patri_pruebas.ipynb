# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 5
initial_counter = 28301
incremental = 10000

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers" or nombre == "Writer": 
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("union_peliculas.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt0804556...
# url loaded
# Getting attributes for tt0804556
# Getting cast for tt0804556
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0804556 with position 21400 was 13 seconds
# getting url with title/tt0803097...
# url loaded
# Getting attributes for tt0803097
# Getting cast for tt0803097
# time to obtain tt0803097 with position 21401 was 3 seconds
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# getting url with title/tt0804238...
# Error getting tt0804238
# Fatal error
# Getting attributes for tt0804238
# Getting cast for tt0804238
# time to obtain tt0804238 with position 21402 was 3710 seconds
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# getting url with title/tt0805588...
# Error getting tt0805588
# Fatal error
# Getting attributes for tt0805588
# Getting cast for tt0805588
# time to obtain tt0805588 with position 21403 was 3734 seconds
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# getting url with title/tt0802964...
# Error getting tt0802964
# Fatal error
# Getting attributes for tt0802964
# Getting cast for tt0802964
# time to obtain tt0802964 with position 21404 was 3723 seconds
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# getting url with title/tt0805573...
# Error getting tt0805573
# Fatal error
# Getting attributes for tt0805573
# Getting cast for tt0805573
# time to obtain tt0805573 with position 21405 was 3718 seconds
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# getting url with title/tt0805334...
# Error getting tt0805334
# Fatal error
# Getting attributes for tt0805334
# Getting cast for tt0805334
# time to obtain tt0805334 with position 21406 was 3737 seconds
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# getting url with title/tt0805499...
# Error getting tt0805499
# Fatal error
# Getting attributes for tt0805499
# Getting cast for tt0805499
# time to obtain tt0805499 with position 21407 was 3733 seconds
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# getting url with title/tt0802997...
# Error getting tt0802997
# Fatal error
# Getting attributes for tt0802997
# Getting cast for tt0802997
# time to obtain tt0802997 with position 21408 was 3747 seconds
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# getting url with title/tt0802979...
# Error getting tt0802979
# Fatal error
# Getting attributes for tt0802979
# Getting cast for tt0802979
# time to obtain tt0802979 with position 21409 was 3717 seconds
# getting url with title/tt0806148...
# Error getting tt0806148
# getting url with title/tt0806148...
# url loaded
# Getting attributes for tt0806148
# error obtaining name for id tt0806148
# Getting cast for tt0806148
# time to obtain tt0806148 with position 21410 was 414 seconds
# getting url with title/tt0806170...
# url loaded
# Getting attributes for tt0806170
# Getting cast for tt0806170
# time to obtain tt0806170 with position 21411 was 5 seconds
# getting url with title/tt0806126...
# url loaded
# Getting attributes for tt0806126
# Getting cast for tt0806126
# time to obtain tt0806126 with position 21412 was 142 seconds
# getting url with title/tt0806251...
# url loaded
# Getting attributes for tt0806251
# Getting cast for tt0806251
# time to obtain tt0806251 with position 21413 was 3 seconds
# getting url with title/tt0805518...
# url loaded
# Getting attributes for tt0805518
# Getting cast for tt0805518
# time to obtain tt0805518 with position 21414 was 2 seconds
# getting url with title/tt0805479...
# url loaded
# Getting attributes for tt0805479
# Getting cast for tt0805479
# time to obtain tt0805479 with position 21415 was 2 seconds
# getting url with title/tt0805699...
# url loaded
# Getting attributes for tt0805699
# Getting cast for tt0805699
# time to obtain tt0805699 with position 21416 was 2 seconds
# getting url with title/tt0805322...
# url loaded
# Getting attributes for tt0805322
# Getting cast for tt0805322
# time to obtain tt0805322 with position 21417 was 3 seconds
# getting url with title/tt0805493...
# url loaded
# Getting attributes for tt0805493
# Getting cast for tt0805493
# time to obtain tt0805493 with position 21418 was 2 seconds
# getting url with title/tt0806948...
# url loaded
# Getting attributes for tt0806948
# Getting cast for tt0806948
# time to obtain tt0806948 with position 21419 was 2 seconds
# getting url with title/tt0808305...
# url loaded
# Getting attributes for tt0808305
# Getting cast for tt0808305
# time to obtain tt0808305 with position 21420 was 2 seconds
# getting url with title/tt0807940...
# url loaded
# Getting attributes for tt0807940
# Getting cast for tt0807940
# time to obtain tt0807940 with position 21421 was 2 seconds
# getting url with title/tt0808188...
# url loaded
# Getting attributes for tt0808188
# Getting cast for tt0808188
# time to obtain tt0808188 with position 21422 was 2 seconds
# getting url with title/tt0808469...
# url loaded
# Getting attributes for tt0808469
# Getting cast for tt0808469
# time to obtain tt0808469 with position 21423 was 3 seconds
# getting url with title/tt0808443...
# url loaded
# Getting attributes for tt0808443
# Getting cast for tt0808443
# time to obtain tt0808443 with position 21424 was 1 seconds
# getting url with title/tt0808271...
# url loaded
# Getting attributes for tt0808271
# Getting cast for tt0808271
# time to obtain tt0808271 with position 21425 was 2 seconds
# getting url with title/tt0807722...
# url loaded
# Getting attributes for tt0807722
# Getting cast for tt0807722
# time to obtain tt0807722 with position 21426 was 2 seconds
# getting url with title/tt0808304...
# url loaded
# Getting attributes for tt0808304
# Getting cast for tt0808304
# time to obtain tt0808304 with position 21427 was 2 seconds
# getting url with title/tt0808395...
# url loaded
# Getting attributes for tt0808395
# Getting cast for tt0808395
# time to obtain tt0808395 with position 21428 was 2 seconds
# getting url with title/tt0807848...
# url loaded
# Getting attributes for tt0807848
# Getting cast for tt0807848
# time to obtain tt0807848 with position 21429 was 2 seconds
# getting url with title/tt0808401...
# url loaded
# Getting attributes for tt0808401
# Getting cast for tt0808401
# time to obtain tt0808401 with position 21430 was 2 seconds
# getting url with title/tt0807856...
# url loaded
# Getting attributes for tt0807856
# Getting cast for tt0807856
# time to obtain tt0807856 with position 21431 was 2 seconds
# getting url with title/tt0808912...
# url loaded
# Getting attributes for tt0808912
# Getting cast for tt0808912
# time to obtain tt0808912 with position 21432 was 2 seconds
# getting url with title/tt0810820...
# url loaded
# Getting attributes for tt0810820
# Getting cast for tt0810820
# time to obtain tt0810820 with position 21433 was 3 seconds
# getting url with title/tt0808464...
# url loaded
# Getting attributes for tt0808464
# Getting cast for tt0808464
# time to obtain tt0808464 with position 21434 was 2 seconds
# getting url with title/tt0808275...
# url loaded
# Getting attributes for tt0808275
# Getting cast for tt0808275
# time to obtain tt0808275 with position 21435 was 2 seconds
# getting url with title/tt0808191...
# url loaded
# Getting attributes for tt0808191
# Getting cast for tt0808191
# time to obtain tt0808191 with position 21436 was 2 seconds
# getting url with title/tt0808890...
# url loaded
# Getting attributes for tt0808890
# Getting cast for tt0808890
# time to obtain tt0808890 with position 21437 was 2 seconds
# getting url with title/tt0808501...
# url loaded
# Getting attributes for tt0808501
# Getting cast for tt0808501
# time to obtain tt0808501 with position 21438 was 2 seconds
# getting url with title/tt0810427...
# url loaded
# Getting attributes for tt0810427
# Getting cast for tt0810427
# time to obtain tt0810427 with position 21439 was 2 seconds
# getting url with title/tt0808876...
# url loaded
# Getting attributes for tt0808876
# Getting cast for tt0808876
# time to obtain tt0808876 with position 21440 was 2 seconds
# getting url with title/tt0810835...
# url loaded
# Getting attributes for tt0810835
# Getting cast for tt0810835
# time to obtain tt0810835 with position 21441 was 3 seconds
# getting url with title/tt0808366...
# url loaded
# Getting attributes for tt0808366
# Getting cast for tt0808366
# time to obtain tt0808366 with position 21442 was 3 seconds
# getting url with title/tt0810848...
# url loaded
# Getting attributes for tt0810848
# Getting cast for tt0810848
# time to obtain tt0810848 with position 21443 was 3 seconds
# getting url with title/tt0810006...
# url loaded
# Getting attributes for tt0810006
# Getting cast for tt0810006
# time to obtain tt0810006 with position 21444 was 2 seconds
# getting url with title/tt0810040...
# url loaded
# Getting attributes for tt0810040
# Getting cast for tt0810040
# time to obtain tt0810040 with position 21445 was 2 seconds
# getting url with title/tt0810379...
# url loaded
# Getting attributes for tt0810379
# Getting cast for tt0810379
# time to obtain tt0810379 with position 21446 was 2 seconds
# getting url with title/tt0810079...
# url loaded
# Getting attributes for tt0810079
# Getting cast for tt0810079
# time to obtain tt0810079 with position 21447 was 3 seconds
# getting url with title/tt0809934...
# url loaded
# Getting attributes for tt0809934
# Getting cast for tt0809934
# time to obtain tt0809934 with position 21448 was 3 seconds
# getting url with title/tt0810933...
# url loaded
# Getting attributes for tt0810933
# Getting cast for tt0810933
# time to obtain tt0810933 with position 21449 was 2 seconds
# getting url with title/tt0810899...
# url loaded
# Getting attributes for tt0810899
# Getting cast for tt0810899
# time to obtain tt0810899 with position 21450 was 2 seconds
# getting url with title/tt0811100...
# url loaded
# Getting attributes for tt0811100
# Getting cast for tt0811100
# time to obtain tt0811100 with position 21451 was 3 seconds
# getting url with title/tt0811603...
# url loaded
# Getting attributes for tt0811603
# Getting cast for tt0811603
# time to obtain tt0811603 with position 21452 was 2 seconds
# getting url with title/tt0810858...
# url loaded
# Getting attributes for tt0810858
# Getting cast for tt0810858
# time to obtain tt0810858 with position 21453 was 2 seconds
# getting url with title/tt0810447...
# url loaded
# Getting attributes for tt0810447
# Getting cast for tt0810447
# time to obtain tt0810447 with position 21454 was 2 seconds
# getting url with title/tt0811070...
# url loaded
# Getting attributes for tt0811070
# Getting cast for tt0811070
# time to obtain tt0811070 with position 21455 was 2 seconds
# getting url with title/tt0810830...
# url loaded
# Getting attributes for tt0810830
# Getting cast for tt0810830
# time to obtain tt0810830 with position 21456 was 2 seconds
# getting url with title/tt0810418...
# url loaded
# Getting attributes for tt0810418
# Getting cast for tt0810418
# time to obtain tt0810418 with position 21457 was 2 seconds
# getting url with title/tt0810950...
# url loaded
# Getting attributes for tt0810950
# Getting cast for tt0810950
# time to obtain tt0810950 with position 21458 was 2 seconds
# getting url with title/tt0810881...
# url loaded
# Getting attributes for tt0810881
# Getting cast for tt0810881
# time to obtain tt0810881 with position 21459 was 2 seconds
# getting url with title/tt0810987...
# url loaded
# Getting attributes for tt0810987
# Getting cast for tt0810987
# time to obtain tt0810987 with position 21460 was 2 seconds
# getting url with title/tt0812387...
# url loaded
# Getting attributes for tt0812387
# Getting cast for tt0812387
# time to obtain tt0812387 with position 21461 was 3 seconds
# getting url with title/tt0811148...
# url loaded
# Getting attributes for tt0811148
# Getting cast for tt0811148
# time to obtain tt0811148 with position 21462 was 2 seconds
# getting url with title/tt0814167...
# url loaded
# Getting attributes for tt0814167
# Getting cast for tt0814167
# time to obtain tt0814167 with position 21463 was 2 seconds
# getting url with title/tt0814307...
# url loaded
# Getting attributes for tt0814307
# Getting cast for tt0814307
# time to obtain tt0814307 with position 21464 was 2 seconds
# getting url with title/tt0814405...
# url loaded
# Getting attributes for tt0814405
# Getting cast for tt0814405
# time to obtain tt0814405 with position 21465 was 3 seconds
# getting url with title/tt0814323...
# url loaded
# Getting attributes for tt0814323
# Getting cast for tt0814323
# time to obtain tt0814323 with position 21466 was 2 seconds
# getting url with title/tt0814301...
# url loaded
# Getting attributes for tt0814301
# Getting cast for tt0814301
# time to obtain tt0814301 with position 21467 was 2 seconds
# getting url with title/tt0814021...
# url loaded
# Getting attributes for tt0814021
# Getting cast for tt0814021
# time to obtain tt0814021 with position 21468 was 3 seconds
# getting url with title/tt0814300...
# url loaded
# Getting attributes for tt0814300
# Getting cast for tt0814300
# time to obtain tt0814300 with position 21469 was 2 seconds
# getting url with title/tt0813416...
# url loaded
# Getting attributes for tt0813416
# Getting cast for tt0813416
# time to obtain tt0813416 with position 21470 was 3 seconds
# getting url with title/tt0813409...
# url loaded
# Getting attributes for tt0813409
# Getting cast for tt0813409
# time to obtain tt0813409 with position 21471 was 3 seconds
# getting url with title/tt0814251...
# url loaded
# Getting attributes for tt0814251
# Getting cast for tt0814251
# time to obtain tt0814251 with position 21472 was 2 seconds
# getting url with title/tt0814066...
# url loaded
# Getting attributes for tt0814066
# Getting cast for tt0814066
# time to obtain tt0814066 with position 21473 was 2 seconds
# getting url with title/tt0814268...
# url loaded
# Getting attributes for tt0814268
# Getting cast for tt0814268
# time to obtain tt0814268 with position 21474 was 2 seconds
# getting url with title/tt0814347...
# url loaded
# Getting attributes for tt0814347
# Getting cast for tt0814347
# time to obtain tt0814347 with position 21475 was 2 seconds
# getting url with title/tt0814141...
# url loaded
# Getting attributes for tt0814141
# Getting cast for tt0814141
# time to obtain tt0814141 with position 21476 was 2 seconds
# getting url with title/tt0814049...
# url loaded
# Getting attributes for tt0814049
# Getting cast for tt0814049
# time to obtain tt0814049 with position 21477 was 2 seconds
# getting url with title/tt0815089...
# url loaded
# Getting attributes for tt0815089
# Getting cast for tt0815089
# time to obtain tt0815089 with position 21478 was 2 seconds
# getting url with title/tt0814110...
# url loaded
# Getting attributes for tt0814110
# Getting cast for tt0814110
# time to obtain tt0814110 with position 21479 was 2 seconds
# getting url with title/tt0814177...
# url loaded
# Getting attributes for tt0814177
# Getting cast for tt0814177
# time to obtain tt0814177 with position 21480 was 2 seconds
# getting url with title/tt0814270...
# url loaded
# Getting attributes for tt0814270
# Getting cast for tt0814270
# time to obtain tt0814270 with position 21481 was 2 seconds
# getting url with title/tt0814043...
# url loaded
# Getting attributes for tt0814043
# Getting cast for tt0814043
# time to obtain tt0814043 with position 21482 was 2 seconds
# getting url with title/tt0814358...
# url loaded
# Getting attributes for tt0814358
# Getting cast for tt0814358
# time to obtain tt0814358 with position 21483 was 2 seconds
# getting url with title/tt0815195...
# url loaded
# Getting attributes for tt0815195
# Getting cast for tt0815195
# time to obtain tt0815195 with position 21484 was 2 seconds
# getting url with title/tt0815164...
# url loaded
# Getting attributes for tt0815164
# Getting cast for tt0815164
# time to obtain tt0815164 with position 21485 was 2 seconds
# getting url with title/tt0815675...
# url loaded
# Getting attributes for tt0815675
# Getting cast for tt0815675
# time to obtain tt0815675 with position 21486 was 2 seconds
# getting url with title/tt0816263...
# url loaded
# Getting attributes for tt0816263
# Getting cast for tt0816263
# time to obtain tt0816263 with position 21487 was 3 seconds
# getting url with title/tt0816508...
# url loaded
# Getting attributes for tt0816508
# Getting cast for tt0816508
# time to obtain tt0816508 with position 21488 was 3 seconds
# getting url with title/tt0816083...
# url loaded
# Getting attributes for tt0816083
# Getting cast for tt0816083
# time to obtain tt0816083 with position 21489 was 3 seconds
# getting url with title/tt0816469...
# url loaded
# Getting attributes for tt0816469
# Getting cast for tt0816469
# time to obtain tt0816469 with position 21490 was 2 seconds
# getting url with title/tt0816477...
# url loaded
# Getting attributes for tt0816477
# error obtaining name for id tt0816477
# Getting cast for tt0816477
# time to obtain tt0816477 with position 21491 was 60 seconds
# getting url with title/tt0816444...
# url loaded
# Getting attributes for tt0816444
# Getting cast for tt0816444
# time to obtain tt0816444 with position 21492 was 2 seconds
# getting url with title/tt0814179...
# url loaded
# Getting attributes for tt0814179
# Getting cast for tt0814179
# time to obtain tt0814179 with position 21493 was 3 seconds
# getting url with title/tt0816087...
# url loaded
# Getting attributes for tt0816087
# Getting cast for tt0816087
# time to obtain tt0816087 with position 21494 was 3 seconds
# getting url with title/tt0815231...
# url loaded
# Getting attributes for tt0815231
# Getting cast for tt0815231
# time to obtain tt0815231 with position 21495 was 2 seconds
# getting url with title/tt0816535...
# url loaded
# Getting attributes for tt0816535
# Getting cast for tt0816535
# time to obtain tt0816535 with position 21496 was 2 seconds
# getting url with title/tt0816578...
# url loaded
# Getting attributes for tt0816578
# Getting cast for tt0816578
# time to obtain tt0816578 with position 21497 was 2 seconds
# getting url with title/tt0816194...
# url loaded
# Getting attributes for tt0816194
# Getting cast for tt0816194
# time to obtain tt0816194 with position 21498 was 2 seconds
# getting url with title/tt0815691...
# url loaded
# Getting attributes for tt0815691
# Getting cast for tt0815691
# time to obtain tt0815691 with position 21499 was 3 seconds
# getting url with title/tt0816186...
# url loaded
# Getting attributes for tt0816186
# Getting cast for tt0816186
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0816186 with position 21500 was 13 seconds
# getting url with title/tt0816471...
# url loaded
# Getting attributes for tt0816471
# Getting cast for tt0816471
# time to obtain tt0816471 with position 21501 was 1 seconds
# getting url with title/tt0816480...
# url loaded
# Getting attributes for tt0816480
# Getting cast for tt0816480
# time to obtain tt0816480 with position 21502 was 2 seconds
# getting url with title/tt0816688...
# url loaded
# Getting attributes for tt0816688
# Getting cast for tt0816688
# time to obtain tt0816688 with position 21503 was 2 seconds
# getting url with title/tt0816426...
# url loaded
# Getting attributes for tt0816426
# Getting cast for tt0816426
# time to obtain tt0816426 with position 21504 was 2 seconds
# getting url with title/tt0816558...
# url loaded
# Getting attributes for tt0816558
# Getting cast for tt0816558
# time to obtain tt0816558 with position 21505 was 2 seconds
# getting url with title/tt0816614...
# url loaded
# Getting attributes for tt0816614
# Getting cast for tt0816614
# time to obtain tt0816614 with position 21506 was 2 seconds
# getting url with title/tt0817506...
# url loaded
# Getting attributes for tt0817506
# Getting cast for tt0817506
# time to obtain tt0817506 with position 21507 was 2 seconds
# getting url with title/tt0818760...
# url loaded
# Getting attributes for tt0818760
# Getting cast for tt0818760
# time to obtain tt0818760 with position 21508 was 2 seconds
# getting url with title/tt0818109...
# url loaded
# Getting attributes for tt0818109
# Getting cast for tt0818109
# time to obtain tt0818109 with position 21509 was 3 seconds
# getting url with title/tt0818579...
# url loaded
# Getting attributes for tt0818579
# Getting cast for tt0818579
# time to obtain tt0818579 with position 21510 was 3 seconds
# getting url with title/tt0819751...
# url loaded
# Getting attributes for tt0819751
# Getting cast for tt0819751
# time to obtain tt0819751 with position 21511 was 2 seconds
# getting url with title/tt0819872...
# url loaded
# Getting attributes for tt0819872
# Getting cast for tt0819872
# time to obtain tt0819872 with position 21512 was 3 seconds
# getting url with title/tt0818136...
# url loaded
# Getting attributes for tt0818136
# Getting cast for tt0818136
# time to obtain tt0818136 with position 21513 was 2 seconds
# getting url with title/tt0817952...
# url loaded
# Getting attributes for tt0817952
# Getting cast for tt0817952
# time to obtain tt0817952 with position 21514 was 1 seconds
# getting url with title/tt0819703...
# url loaded
# Getting attributes for tt0819703
# Getting cast for tt0819703
# time to obtain tt0819703 with position 21515 was 4 seconds
# getting url with title/tt0818472...
# url loaded
# Getting attributes for tt0818472
# Getting cast for tt0818472
# time to obtain tt0818472 with position 21516 was 2 seconds
# getting url with title/tt0818740...
# url loaded
# Getting attributes for tt0818740
# Getting cast for tt0818740
# time to obtain tt0818740 with position 21517 was 2 seconds
# getting url with title/tt0819652...
# url loaded
# Getting attributes for tt0819652
# Getting cast for tt0819652
# time to obtain tt0819652 with position 21518 was 2 seconds
# getting url with title/tt0818260...
# url loaded
# Getting attributes for tt0818260
# Getting cast for tt0818260
# time to obtain tt0818260 with position 21519 was 5 seconds
# getting url with title/tt0818749...
# url loaded
# Getting attributes for tt0818749
# Getting cast for tt0818749
# time to obtain tt0818749 with position 21520 was 3 seconds
# getting url with title/tt0819612...
# url loaded
# Getting attributes for tt0819612
# Getting cast for tt0819612
# time to obtain tt0819612 with position 21521 was 4 seconds
# getting url with title/tt0819789...
# url loaded
# Getting attributes for tt0819789
# Getting cast for tt0819789
# time to obtain tt0819789 with position 21522 was 2 seconds
# getting url with title/tt0819131...
# url loaded
# Getting attributes for tt0819131
# Getting cast for tt0819131
# time to obtain tt0819131 with position 21523 was 3 seconds
# getting url with title/tt0819615...
# url loaded
# Getting attributes for tt0819615
# Getting cast for tt0819615
# time to obtain tt0819615 with position 21524 was 2 seconds
# getting url with title/tt0817534...
# url loaded
# Getting attributes for tt0817534
# Getting cast for tt0817534
# time to obtain tt0817534 with position 21525 was 2 seconds
# getting url with title/tt0818107...
# url loaded
# Getting attributes for tt0818107
# Getting cast for tt0818107
# time to obtain tt0818107 with position 21526 was 4 seconds
# getting url with title/tt0820016...
# url loaded
# Getting attributes for tt0820016
# Getting cast for tt0820016
# time to obtain tt0820016 with position 21527 was 4 seconds
# getting url with title/tt0819647...
# url loaded
# Getting attributes for tt0819647
# Getting cast for tt0819647
# time to obtain tt0819647 with position 21528 was 5 seconds
# getting url with title/tt0819909...
# url loaded
# Getting attributes for tt0819909
# Getting cast for tt0819909
# time to obtain tt0819909 with position 21529 was 4 seconds
# getting url with title/tt0820475...
# url loaded
# Getting attributes for tt0820475
# Getting cast for tt0820475
# time to obtain tt0820475 with position 21530 was 4 seconds
# getting url with title/tt0818473...
# url loaded
# Getting attributes for tt0818473
# Getting cast for tt0818473
# time to obtain tt0818473 with position 21531 was 3 seconds
# getting url with title/tt0818913...
# url loaded
# Getting attributes for tt0818913
# Getting cast for tt0818913
# time to obtain tt0818913 with position 21532 was 5 seconds
# getting url with title/tt0818263...
# url loaded
# Getting attributes for tt0818263
# Getting cast for tt0818263
# time to obtain tt0818263 with position 21533 was 4 seconds
# getting url with title/tt0818814...
# url loaded
# Getting attributes for tt0818814
# Getting cast for tt0818814
# time to obtain tt0818814 with position 21534 was 3 seconds
# getting url with title/tt0817897...
# url loaded
# Getting attributes for tt0817897
# Getting cast for tt0817897
# time to obtain tt0817897 with position 21535 was 3 seconds
# getting url with title/tt0818588...
# url loaded
# Getting attributes for tt0818588
# Getting cast for tt0818588
# time to obtain tt0818588 with position 21536 was 3 seconds
# getting url with title/tt0818633...
# url loaded
# Getting attributes for tt0818633
# Getting cast for tt0818633
# time to obtain tt0818633 with position 21537 was 3 seconds
# getting url with title/tt0818823...
# url loaded
# Getting attributes for tt0818823
# Getting cast for tt0818823
# time to obtain tt0818823 with position 21538 was 6 seconds
# getting url with title/tt0818747...
# url loaded
# Getting attributes for tt0818747
# Getting cast for tt0818747
# time to obtain tt0818747 with position 21539 was 3 seconds
# getting url with title/tt0818118...
# url loaded
# Getting attributes for tt0818118
# Getting cast for tt0818118
# time to obtain tt0818118 with position 21540 was 4 seconds
# getting url with title/tt0819689...
# url loaded
# Getting attributes for tt0819689
# Getting cast for tt0819689
# time to obtain tt0819689 with position 21541 was 3 seconds
# getting url with title/tt0818130...
# url loaded
# Getting attributes for tt0818130
# Getting cast for tt0818130
# time to obtain tt0818130 with position 21542 was 7 seconds
# getting url with title/tt0819133...
# url loaded
# Getting attributes for tt0819133
# Getting cast for tt0819133
# time to obtain tt0819133 with position 21543 was 3 seconds
# getting url with title/tt0818772...
# url loaded
# Getting attributes for tt0818772
# Getting cast for tt0818772
# time to obtain tt0818772 with position 21544 was 3 seconds
# getting url with title/tt0819873...
# url loaded
# Getting attributes for tt0819873
# Getting cast for tt0819873
# time to obtain tt0819873 with position 21545 was 4 seconds
# getting url with title/tt0819801...
# url loaded
# Getting attributes for tt0819801
# Getting cast for tt0819801
# time to obtain tt0819801 with position 21546 was 1 seconds
# getting url with title/tt0819737...
# url loaded
# Getting attributes for tt0819737
# Getting cast for tt0819737
# time to obtain tt0819737 with position 21547 was 3 seconds
# getting url with title/tt0819911...
# url loaded
# Getting attributes for tt0819911
# Getting cast for tt0819911
# time to obtain tt0819911 with position 21548 was 7 seconds
# getting url with title/tt0820478...
# url loaded
# Getting attributes for tt0820478
# Getting cast for tt0820478
# time to obtain tt0820478 with position 21549 was 4 seconds
# getting url with title/tt0821023...
# url loaded
# Getting attributes for tt0821023
# Getting cast for tt0821023
# time to obtain tt0821023 with position 21550 was 3 seconds
# getting url with title/tt0820898...
# url loaded
# Getting attributes for tt0820898
# Getting cast for tt0820898
# time to obtain tt0820898 with position 21551 was 4 seconds
# getting url with title/tt0820170...
# url loaded
# Getting attributes for tt0820170
# Getting cast for tt0820170
# time to obtain tt0820170 with position 21552 was 5 seconds
# getting url with title/tt0820168...
# url loaded
# Getting attributes for tt0820168
# Getting cast for tt0820168
# time to obtain tt0820168 with position 21553 was 4 seconds
# getting url with title/tt0820050...
# url loaded
# Getting attributes for tt0820050
# Getting cast for tt0820050
# time to obtain tt0820050 with position 21554 was 4 seconds
# getting url with title/tt0820485...
# url loaded
# Getting attributes for tt0820485
# Getting cast for tt0820485
# time to obtain tt0820485 with position 21555 was 6 seconds
# getting url with title/tt0821559...
# url loaded
# Getting attributes for tt0821559
# Getting cast for tt0821559
# time to obtain tt0821559 with position 21556 was 3 seconds
# getting url with title/tt0820909...
# url loaded
# Getting attributes for tt0820909
# Getting cast for tt0820909
# time to obtain tt0820909 with position 21557 was 5 seconds
# getting url with title/tt0821042...
# url loaded
# Getting attributes for tt0821042
# Getting cast for tt0821042
# time to obtain tt0821042 with position 21558 was 4 seconds
# getting url with title/tt0820971...
# url loaded
# Getting attributes for tt0820971
# Getting cast for tt0820971
# time to obtain tt0820971 with position 21559 was 8 seconds
# getting url with title/tt0821953...
# url loaded
# Getting attributes for tt0821953
# Getting cast for tt0821953
# time to obtain tt0821953 with position 21560 was 4 seconds
# getting url with title/tt0824315...
# url loaded
# Getting attributes for tt0824315
# Getting cast for tt0824315
# time to obtain tt0824315 with position 21561 was 4 seconds
# getting url with title/tt0823625...
# url loaded
# Getting attributes for tt0823625
# Getting cast for tt0823625
# time to obtain tt0823625 with position 21562 was 4 seconds
# getting url with title/tt0825470...
# url loaded
# Getting attributes for tt0825470
# Getting cast for tt0825470
# time to obtain tt0825470 with position 21563 was 4 seconds
# getting url with title/tt0825459...
# url loaded
# Getting attributes for tt0825459
# Getting cast for tt0825459
# time to obtain tt0825459 with position 21564 was 7 seconds
# getting url with title/tt0824301...
# url loaded
# Getting attributes for tt0824301
# Getting cast for tt0824301
# time to obtain tt0824301 with position 21565 was 5 seconds
# getting url with title/tt0825455...
# url loaded
# Getting attributes for tt0825455
# Getting cast for tt0825455
# time to obtain tt0825455 with position 21566 was 9 seconds
# getting url with title/tt0823196...
# url loaded
# Getting attributes for tt0823196
# Getting cast for tt0823196
# time to obtain tt0823196 with position 21567 was 6 seconds
# getting url with title/tt0824341...
# url loaded
# Getting attributes for tt0824341
# Getting cast for tt0824341
# time to obtain tt0824341 with position 21568 was 7 seconds
# getting url with title/tt0822395...
# url loaded
# Getting attributes for tt0822395
# Getting cast for tt0822395
# time to obtain tt0822395 with position 21569 was 3 seconds
# getting url with title/tt0823631...
# url loaded
# Getting attributes for tt0823631
# Getting cast for tt0823631
# time to obtain tt0823631 with position 21570 was 4 seconds
# getting url with title/tt0824670...
# url loaded
# Getting attributes for tt0824670
# Getting cast for tt0824670
# time to obtain tt0824670 with position 21571 was 3 seconds
# getting url with title/tt0823615...
# url loaded
# Getting attributes for tt0823615
# Getting cast for tt0823615
# time to obtain tt0823615 with position 21572 was 5 seconds
# getting url with title/tt0823183...
# url loaded
# Getting attributes for tt0823183
# Getting cast for tt0823183
# time to obtain tt0823183 with position 21573 was 8 seconds
# getting url with title/tt0823521...
# url loaded
# Getting attributes for tt0823521
# Getting cast for tt0823521
# time to obtain tt0823521 with position 21574 was 5 seconds
# getting url with title/tt0824409...
# url loaded
# Getting attributes for tt0824409
# Getting cast for tt0824409
# time to obtain tt0824409 with position 21575 was 5 seconds
# getting url with title/tt0824321...
# url loaded
# Getting attributes for tt0824321
# Getting cast for tt0824321
# time to obtain tt0824321 with position 21576 was 4 seconds
# getting url with title/tt0824419...
# url loaded
# Getting attributes for tt0824419
# Getting cast for tt0824419
# time to obtain tt0824419 with position 21577 was 5 seconds
# getting url with title/tt0824372...
# url loaded
# Getting attributes for tt0824372
# Getting cast for tt0824372
# time to obtain tt0824372 with position 21578 was 4 seconds
# getting url with title/tt0824387...
# url loaded
# Getting attributes for tt0824387
# Getting cast for tt0824387
# time to obtain tt0824387 with position 21579 was 4 seconds
# getting url with title/tt0823665...
# url loaded
# Getting attributes for tt0823665
# Getting cast for tt0823665
# time to obtain tt0823665 with position 21580 was 8 seconds
# getting url with title/tt0823622...
# url loaded
# Getting attributes for tt0823622
# Getting cast for tt0823622
# time to obtain tt0823622 with position 21581 was 11 seconds
# getting url with title/tt0823653...
# url loaded
# Getting attributes for tt0823653
# Getting cast for tt0823653
# time to obtain tt0823653 with position 21582 was 8 seconds
# getting url with title/tt0823642...
# url loaded
# Getting attributes for tt0823642
# Getting cast for tt0823642
# time to obtain tt0823642 with position 21583 was 7 seconds
# getting url with title/tt0824410...
# url loaded
# Getting attributes for tt0824410
# Getting cast for tt0824410
# time to obtain tt0824410 with position 21584 was 5 seconds
# getting url with title/tt0824765...
# url loaded
# Getting attributes for tt0824765
# Getting cast for tt0824765
# time to obtain tt0824765 with position 21585 was 8 seconds
# getting url with title/tt0823683...
# url loaded
# Getting attributes for tt0823683
# Getting cast for tt0823683
# time to obtain tt0823683 with position 21586 was 4 seconds
# getting url with title/tt0824753...
# url loaded
# Getting attributes for tt0824753
# Getting cast for tt0824753
# time to obtain tt0824753 with position 21587 was 6 seconds
# getting url with title/tt0825683...
# url loaded
# Getting attributes for tt0825683
# Getting cast for tt0825683
# time to obtain tt0825683 with position 21588 was 10 seconds
# getting url with title/tt0825472...
# url loaded
# Getting attributes for tt0825472
# Getting cast for tt0825472
# time to obtain tt0825472 with position 21589 was 6 seconds
# getting url with title/tt0825668...
# url loaded
# Getting attributes for tt0825668
# Getting cast for tt0825668
# time to obtain tt0825668 with position 21590 was 5 seconds
# getting url with title/tt0825670...
# url loaded
# Getting attributes for tt0825670
# Getting cast for tt0825670
# time to obtain tt0825670 with position 21591 was 4 seconds
# getting url with title/tt0824396...
# url loaded
# Getting attributes for tt0824396
# Getting cast for tt0824396
# time to obtain tt0824396 with position 21592 was 12 seconds
# getting url with title/tt0824764...
# url loaded
# Getting attributes for tt0824764
# Getting cast for tt0824764
# time to obtain tt0824764 with position 21593 was 9 seconds
# getting url with title/tt0825476...
# url loaded
# Getting attributes for tt0825476
# Getting cast for tt0825476
# time to obtain tt0825476 with position 21594 was 7 seconds
# getting url with title/tt0825461...
# url loaded
# Getting attributes for tt0825461
# Getting cast for tt0825461
# time to obtain tt0825461 with position 21595 was 11 seconds
# getting url with title/tt0825242...
# url loaded
# Getting attributes for tt0825242
# Getting cast for tt0825242
# time to obtain tt0825242 with position 21596 was 10 seconds
# getting url with title/tt0826174...
# url loaded
# Getting attributes for tt0826174
# Getting cast for tt0826174
# time to obtain tt0826174 with position 21597 was 4 seconds
# getting url with title/tt0826826...
# url loaded
# Getting attributes for tt0826826
# Getting cast for tt0826826
# time to obtain tt0826826 with position 21598 was 9 seconds
# getting url with title/tt0826739...
# url loaded
# Getting attributes for tt0826739
# Getting cast for tt0826739
# time to obtain tt0826739 with position 21599 was 6 seconds
# getting url with title/tt0826809...
# url loaded
# Getting attributes for tt0826809
# Getting cast for tt0826809
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0826809 with position 21600 was 29 seconds
# getting url with title/tt0826747...
# url loaded
# Getting attributes for tt0826747
# Getting cast for tt0826747
# time to obtain tt0826747 with position 21601 was 1 seconds
# getting url with title/tt0826770...
# url loaded
# Getting attributes for tt0826770
# Getting cast for tt0826770
# time to obtain tt0826770 with position 21602 was 2 seconds
# getting url with title/tt0827194...
# url loaded
# Getting attributes for tt0827194
# Getting cast for tt0827194
# time to obtain tt0827194 with position 21603 was 1 seconds
# getting url with title/tt0827217...
# url loaded
# Getting attributes for tt0827217
# Getting cast for tt0827217
# time to obtain tt0827217 with position 21604 was 3 seconds
# getting url with title/tt0826786...
# url loaded
# Getting attributes for tt0826786
# Getting cast for tt0826786
# time to obtain tt0826786 with position 21605 was 2 seconds
# getting url with title/tt0827772...
# url loaded
# Getting attributes for tt0827772
# Getting cast for tt0827772
# time to obtain tt0827772 with position 21606 was 2 seconds
# getting url with title/tt0827496...
# url loaded
# Getting attributes for tt0827496
# Getting cast for tt0827496
# time to obtain tt0827496 with position 21607 was 1 seconds
# getting url with title/tt0827785...
# url loaded
# Getting attributes for tt0827785
# Getting cast for tt0827785
# time to obtain tt0827785 with position 21608 was 2 seconds
# getting url with title/tt0827718...
# url loaded
# Getting attributes for tt0827718
# Getting cast for tt0827718
# time to obtain tt0827718 with position 21609 was 3 seconds
# getting url with title/tt0828143...
# url loaded
# Getting attributes for tt0828143
# Getting cast for tt0828143
# time to obtain tt0828143 with position 21610 was 1 seconds
# getting url with title/tt0828142...
# url loaded
# Getting attributes for tt0828142
# Getting cast for tt0828142
# time to obtain tt0828142 with position 21611 was 3 seconds
# getting url with title/tt0828155...
# url loaded
# Getting attributes for tt0828155
# Getting cast for tt0828155
# time to obtain tt0828155 with position 21612 was 2 seconds
# getting url with title/tt0829428...
# url loaded
# Getting attributes for tt0829428
# Getting cast for tt0829428
# time to obtain tt0829428 with position 21613 was 1 seconds
# getting url with title/tt0830543...
# url loaded
# Getting attributes for tt0830543
# Getting cast for tt0830543
# time to obtain tt0830543 with position 21614 was 2 seconds
# getting url with title/tt0828589...
# url loaded
# Getting attributes for tt0828589
# Getting cast for tt0828589
# time to obtain tt0828589 with position 21615 was 1 seconds
# getting url with title/tt0829116...
# url loaded
# Getting attributes for tt0829116
# Getting cast for tt0829116
# time to obtain tt0829116 with position 21616 was 2 seconds
# getting url with title/tt0829416...
# url loaded
# Getting attributes for tt0829416
# Getting cast for tt0829416
# time to obtain tt0829416 with position 21617 was 2 seconds
# getting url with title/tt0830212...
# url loaded
# Getting attributes for tt0830212
# Getting cast for tt0830212
# time to obtain tt0830212 with position 21618 was 1 seconds
# getting url with title/tt0831282...
# url loaded
# Getting attributes for tt0831282
# Getting cast for tt0831282
# time to obtain tt0831282 with position 21619 was 2 seconds
# getting url with title/tt0831342...
# url loaded
# Getting attributes for tt0831342
# Getting cast for tt0831342
# time to obtain tt0831342 with position 21620 was 2 seconds
# getting url with title/tt0832294...
# url loaded
# Getting attributes for tt0832294
# Getting cast for tt0832294
# time to obtain tt0832294 with position 21621 was 1 seconds
# getting url with title/tt0832331...
# url loaded
# Getting attributes for tt0832331
# Getting cast for tt0832331
# time to obtain tt0832331 with position 21622 was 2 seconds
# getting url with title/tt0832496...
# url loaded
# Getting attributes for tt0832496
# Getting cast for tt0832496
# time to obtain tt0832496 with position 21623 was 2 seconds
# getting url with title/tt0831329...
# url loaded
# Getting attributes for tt0831329
# Getting cast for tt0831329
# time to obtain tt0831329 with position 21624 was 2 seconds
# getting url with title/tt0831337...
# url loaded
# Getting attributes for tt0831337
# Getting cast for tt0831337
# time to obtain tt0831337 with position 21625 was 2 seconds
# getting url with title/tt0832501...
# url loaded
# Getting attributes for tt0832501
# Getting cast for tt0832501
# time to obtain tt0832501 with position 21626 was 3 seconds
# getting url with title/tt0832314...
# url loaded
# Getting attributes for tt0832314
# Getting cast for tt0832314
# time to obtain tt0832314 with position 21627 was 2 seconds
# getting url with title/tt0832291...
# url loaded
# Getting attributes for tt0832291
# Getting cast for tt0832291
# time to obtain tt0832291 with position 21628 was 2 seconds
# getting url with title/tt0832492...
# url loaded
# Getting attributes for tt0832492
# Getting cast for tt0832492
# time to obtain tt0832492 with position 21629 was 2 seconds
# getting url with title/tt0832322...
# url loaded
# Getting attributes for tt0832322
# Getting cast for tt0832322
# time to obtain tt0832322 with position 21630 was 2 seconds
# getting url with title/tt0832299...
# url loaded
# Getting attributes for tt0832299
# Getting cast for tt0832299
# time to obtain tt0832299 with position 21631 was 2 seconds
# getting url with title/tt0832301...
# url loaded
# Getting attributes for tt0832301
# Getting cast for tt0832301
# time to obtain tt0832301 with position 21632 was 2 seconds
# getting url with title/tt0832452...
# url loaded
# Getting attributes for tt0832452
# Getting cast for tt0832452
# time to obtain tt0832452 with position 21633 was 1 seconds
# getting url with title/tt0832223...
# url loaded
# Getting attributes for tt0832223
# Getting cast for tt0832223
# time to obtain tt0832223 with position 21634 was 1 seconds
# getting url with title/tt0832269...
# url loaded
# Getting attributes for tt0832269
# Getting cast for tt0832269
# time to obtain tt0832269 with position 21635 was 2 seconds
# getting url with title/tt0831921...
# url loaded
# Getting attributes for tt0831921
# Getting cast for tt0831921
# time to obtain tt0831921 with position 21636 was 1 seconds
# getting url with title/tt0831870...
# url loaded
# Getting attributes for tt0831870
# Getting cast for tt0831870
# time to obtain tt0831870 with position 21637 was 1 seconds
# getting url with title/tt0832482...
# url loaded
# Getting attributes for tt0832482
# Getting cast for tt0832482
# time to obtain tt0832482 with position 21638 was 1 seconds
# getting url with title/tt0832863...
# url loaded
# Getting attributes for tt0832863
# Getting cast for tt0832863
# time to obtain tt0832863 with position 21639 was 1 seconds
# getting url with title/tt0832436...
# url loaded
# Getting attributes for tt0832436
# Getting cast for tt0832436
# time to obtain tt0832436 with position 21640 was 1 seconds
# getting url with title/tt0833599...
# url loaded
# Getting attributes for tt0833599
# Getting cast for tt0833599
# time to obtain tt0833599 with position 21641 was 2 seconds
# getting url with title/tt0831864...
# url loaded
# Getting attributes for tt0831864
# Getting cast for tt0831864
# time to obtain tt0831864 with position 21642 was 1 seconds
# getting url with title/tt0833593...
# url loaded
# Getting attributes for tt0833593
# Getting cast for tt0833593
# time to obtain tt0833593 with position 21643 was 2 seconds
# getting url with title/tt0833602...
# url loaded
# Getting attributes for tt0833602
# Getting cast for tt0833602
# time to obtain tt0833602 with position 21644 was 1 seconds
# getting url with title/tt0832356...
# url loaded
# Getting attributes for tt0832356
# Getting cast for tt0832356
# time to obtain tt0832356 with position 21645 was 1 seconds
# getting url with title/tt0833971...
# url loaded
# Getting attributes for tt0833971
# Getting cast for tt0833971
# time to obtain tt0833971 with position 21646 was 2 seconds
# getting url with title/tt0833958...
# url loaded
# Getting attributes for tt0833958
# Getting cast for tt0833958
# time to obtain tt0833958 with position 21647 was 1 seconds
# getting url with title/tt0833959...
# url loaded
# Getting attributes for tt0833959
# Getting cast for tt0833959
# time to obtain tt0833959 with position 21648 was 2 seconds
# getting url with title/tt0835049...
# url loaded
# Getting attributes for tt0835049
# Getting cast for tt0835049
# time to obtain tt0835049 with position 21649 was 2 seconds
# getting url with title/tt0834957...
# url loaded
# Getting attributes for tt0834957
# Getting cast for tt0834957
# time to obtain tt0834957 with position 21650 was 3 seconds
# getting url with title/tt0835477...
# url loaded
# Getting attributes for tt0835477
# Getting cast for tt0835477
# time to obtain tt0835477 with position 21651 was 3 seconds
# getting url with title/tt0835019...
# url loaded
# Getting attributes for tt0835019
# Getting cast for tt0835019
# time to obtain tt0835019 with position 21652 was 3 seconds
# getting url with title/tt0835056...
# url loaded
# Getting attributes for tt0835056
# ...
# url loaded
# Getting attributes for tt14316624
# Getting cast for tt14316624
# time to obtain tt14316624 with position 28306 was 2 seconds
# getting url with title/tt14316764...
# url loaded
# Getting attributes for tt14316764
# Getting cast for tt14316764
# time to obtain tt14316764 with position 28307 was 2 seconds
# getting url with title/tt14316946...
# url loaded
# Getting attributes for tt14316946
# Getting cast for tt14316946
# time to obtain tt14316946 with position 28308 was 1 seconds
# getting url with title/tt14317676...
# url loaded
# Getting attributes for tt14317676
# Getting cast for tt14317676
# time to obtain tt14317676 with position 28309 was 2 seconds
# getting url with title/tt14321742...
# url loaded
# Getting attributes for tt14321742
# Getting cast for tt14321742
# time to obtain tt14321742 with position 28310 was 1 seconds
# getting url with title/tt14318910...
# url loaded
# Getting attributes for tt14318910
# Getting cast for tt14318910
# time to obtain tt14318910 with position 28311 was 1 seconds
# getting url with title/tt14322004...
# url loaded
# Getting attributes for tt14322004
# Getting cast for tt14322004
# time to obtain tt14322004 with position 28312 was 1 seconds
# getting url with title/tt14317466...
# url loaded
# Getting attributes for tt14317466
# Getting cast for tt14317466
# time to obtain tt14317466 with position 28313 was 2 seconds
# getting url with title/tt14319342...
# url loaded
# Getting attributes for tt14319342
# Getting cast for tt14319342
# time to obtain tt14319342 with position 28314 was 1 seconds
# getting url with title/tt14321794...
# url loaded
# Getting attributes for tt14321794
# Getting cast for tt14321794
# time to obtain tt14321794 with position 28315 was 2 seconds
# getting url with title/tt14319940...
# url loaded
# Getting attributes for tt14319940
# Getting cast for tt14319940
# time to obtain tt14319940 with position 28316 was 2 seconds
# getting url with title/tt14319780...
# url loaded
# Getting attributes for tt14319780
# Getting cast for tt14319780
# time to obtain tt14319780 with position 28317 was 2 seconds
# getting url with title/tt14320226...
# url loaded
# Getting attributes for tt14320226
# Getting cast for tt14320226
# time to obtain tt14320226 with position 28318 was 1 seconds
# getting url with title/tt14317054...
# url loaded
# Getting attributes for tt14317054
# Getting cast for tt14317054
# time to obtain tt14317054 with position 28319 was 1 seconds
# getting url with title/tt14317016...
# url loaded
# Getting attributes for tt14317016
# Getting cast for tt14317016
# time to obtain tt14317016 with position 28320 was 1 seconds
# getting url with title/tt14317420...
# url loaded
# Getting attributes for tt14317420
# Getting cast for tt14317420
# time to obtain tt14317420 with position 28321 was 2 seconds
# getting url with title/tt14317492...
# url loaded
# Getting attributes for tt14317492
# Getting cast for tt14317492
# time to obtain tt14317492 with position 28322 was 1 seconds
# getting url with title/tt14318982...
# url loaded
# Getting attributes for tt14318982
# Getting cast for tt14318982
# time to obtain tt14318982 with position 28323 was 1 seconds
# getting url with title/tt14318200...
# url loaded
# Getting attributes for tt14318200
# Getting cast for tt14318200
# time to obtain tt14318200 with position 28324 was 1 seconds
# getting url with title/tt14318494...
# url loaded
# Getting attributes for tt14318494
# Getting cast for tt14318494
# time to obtain tt14318494 with position 28325 was 3 seconds
# getting url with title/tt14321904...
# url loaded
# Getting attributes for tt14321904
# Getting cast for tt14321904
# time to obtain tt14321904 with position 28326 was 1 seconds
# getting url with title/tt14320442...
# url loaded
# Getting attributes for tt14320442
# Getting cast for tt14320442
# time to obtain tt14320442 with position 28327 was 1 seconds
# getting url with title/tt14322378...
# url loaded
# Getting attributes for tt14322378
# Getting cast for tt14322378
# time to obtain tt14322378 with position 28328 was 2 seconds
# getting url with title/tt14324692...
# url loaded
# Getting attributes for tt14324692
# Getting cast for tt14324692
# time to obtain tt14324692 with position 28329 was 2 seconds
# getting url with title/tt14324582...
# url loaded
# Getting attributes for tt14324582
# Getting cast for tt14324582
# time to obtain tt14324582 with position 28330 was 1 seconds
# getting url with title/tt14323268...
# url loaded
# Getting attributes for tt14323268
# Getting cast for tt14323268
# time to obtain tt14323268 with position 28331 was 1 seconds
# getting url with title/tt14325206...
# url loaded
# Getting attributes for tt14325206
# Getting cast for tt14325206
# time to obtain tt14325206 with position 28332 was 1 seconds
# getting url with title/tt14323156...
# url loaded
# Getting attributes for tt14323156
# Getting cast for tt14323156
# time to obtain tt14323156 with position 28333 was 1 seconds
# getting url with title/tt14325270...
# url loaded
# Getting attributes for tt14325270
# Getting cast for tt14325270
# time to obtain tt14325270 with position 28334 was 2 seconds
# getting url with title/tt14324572...
# url loaded
# Getting attributes for tt14324572
# Getting cast for tt14324572
# time to obtain tt14324572 with position 28335 was 2 seconds
# getting url with title/tt14325308...
# url loaded
# Getting attributes for tt14325308
# Getting cast for tt14325308
# time to obtain tt14325308 with position 28336 was 2 seconds
# getting url with title/tt14325148...
# url loaded
# Getting attributes for tt14325148
# Getting cast for tt14325148
# time to obtain tt14325148 with position 28337 was 1 seconds
# getting url with title/tt14325456...
# url loaded
# Getting attributes for tt14325456
# Getting cast for tt14325456
# time to obtain tt14325456 with position 28338 was 1 seconds
# getting url with title/tt14325220...
# url loaded
# Getting attributes for tt14325220
# Getting cast for tt14325220
# time to obtain tt14325220 with position 28339 was 1 seconds
# getting url with title/tt14324814...
# url loaded
# Getting attributes for tt14324814
# Getting cast for tt14324814
# time to obtain tt14324814 with position 28340 was 1 seconds
# getting url with title/tt14325728...
# url loaded
# Getting attributes for tt14325728
# Getting cast for tt14325728
# time to obtain tt14325728 with position 28341 was 1 seconds
# getting url with title/tt14330240...
# url loaded
# Getting attributes for tt14330240
# Getting cast for tt14330240
# time to obtain tt14330240 with position 28342 was 2 seconds
# getting url with title/tt14326736...
# url loaded
# Getting attributes for tt14326736
# Getting cast for tt14326736
# time to obtain tt14326736 with position 28343 was 2 seconds
# getting url with title/tt14330108...
# url loaded
# Getting attributes for tt14330108
# Getting cast for tt14330108
# time to obtain tt14330108 with position 28344 was 1 seconds
# getting url with title/tt14330106...
# url loaded
# Getting attributes for tt14330106
# Getting cast for tt14330106
# time to obtain tt14330106 with position 28345 was 1 seconds
# getting url with title/tt14325792...
# url loaded
# Getting attributes for tt14325792
# Getting cast for tt14325792
# time to obtain tt14325792 with position 28346 was 1 seconds
# getting url with title/tt14323168...
# url loaded
# Getting attributes for tt14323168
# Getting cast for tt14323168
# time to obtain tt14323168 with position 28347 was 1 seconds
# getting url with title/tt14327694...
# url loaded
# Getting attributes for tt14327694
# Getting cast for tt14327694
# time to obtain tt14327694 with position 28348 was 1 seconds
# getting url with title/tt14328182...
# url loaded
# Getting attributes for tt14328182
# Getting cast for tt14328182
# time to obtain tt14328182 with position 28349 was 1 seconds
# getting url with title/tt14329346...
# url loaded
# Getting attributes for tt14329346
# Getting cast for tt14329346
# time to obtain tt14329346 with position 28350 was 2 seconds
# getting url with title/tt14324708...
# url loaded
# Getting attributes for tt14324708
# Getting cast for tt14324708
# time to obtain tt14324708 with position 28351 was 2 seconds
# getting url with title/tt14329004...
# url loaded
# Getting attributes for tt14329004
# Getting cast for tt14329004
# time to obtain tt14329004 with position 28352 was 2 seconds
# getting url with title/tt14329104...
# url loaded
# Getting attributes for tt14329104
# Getting cast for tt14329104
# time to obtain tt14329104 with position 28353 was 1 seconds
# getting url with title/tt14325956...
# url loaded
# Getting attributes for tt14325956
# Getting cast for tt14325956
# time to obtain tt14325956 with position 28354 was 1 seconds
# getting url with title/tt14329476...
# url loaded
# Getting attributes for tt14329476
# Getting cast for tt14329476
# time to obtain tt14329476 with position 28355 was 4 seconds
# getting url with title/tt14330774...
# url loaded
# Getting attributes for tt14330774
# Getting cast for tt14330774
# time to obtain tt14330774 with position 28356 was 1 seconds
# getting url with title/tt14330540...
# url loaded
# Getting attributes for tt14330540
# Getting cast for tt14330540
# time to obtain tt14330540 with position 28357 was 2 seconds
# getting url with title/tt14328948...
# url loaded
# Getting attributes for tt14328948
# Getting cast for tt14328948
# time to obtain tt14328948 with position 28358 was 2 seconds
# getting url with title/tt14331130...
# url loaded
# Getting attributes for tt14331130
# Getting cast for tt14331130
# time to obtain tt14331130 with position 28359 was 1 seconds
# getting url with title/tt14332716...
# url loaded
# Getting attributes for tt14332716
# Getting cast for tt14332716
# time to obtain tt14332716 with position 28360 was 1 seconds
# getting url with title/tt14332484...
# url loaded
# Getting attributes for tt14332484
# Getting cast for tt14332484
# time to obtain tt14332484 with position 28361 was 2 seconds
# getting url with title/tt14331074...
# url loaded
# Getting attributes for tt14331074
# Getting cast for tt14331074
# time to obtain tt14331074 with position 28362 was 1 seconds
# getting url with title/tt14331582...
# url loaded
# Getting attributes for tt14331582
# Getting cast for tt14331582
# time to obtain tt14331582 with position 28363 was 1 seconds
# getting url with title/tt14332428...
# url loaded
# Getting attributes for tt14332428
# Getting cast for tt14332428
# time to obtain tt14332428 with position 28364 was 2 seconds
# getting url with title/tt14332086...
# url loaded
# Getting attributes for tt14332086
# Getting cast for tt14332086
# time to obtain tt14332086 with position 28365 was 2 seconds
# getting url with title/tt14331942...
# url loaded
# Getting attributes for tt14331942
# Getting cast for tt14331942
# time to obtain tt14331942 with position 28366 was 2 seconds
# getting url with title/tt14333084...
# url loaded
# Getting attributes for tt14333084
# Getting cast for tt14333084
# time to obtain tt14333084 with position 28367 was 1 seconds
# getting url with title/tt14332624...
# url loaded
# Getting attributes for tt14332624
# Getting cast for tt14332624
# time to obtain tt14332624 with position 28368 was 1 seconds
# getting url with title/tt14332638...
# url loaded
# Getting attributes for tt14332638
# Getting cast for tt14332638
# time to obtain tt14332638 with position 28369 was 1 seconds
# getting url with title/tt14332646...
# url loaded
# Getting attributes for tt14332646
# Getting cast for tt14332646
# time to obtain tt14332646 with position 28370 was 2 seconds
# getting url with title/tt14336388...
# url loaded
# Getting attributes for tt14336388
# Getting cast for tt14336388
# time to obtain tt14336388 with position 28371 was 1 seconds
# getting url with title/tt14336738...
# url loaded
# Getting attributes for tt14336738
# Getting cast for tt14336738
# time to obtain tt14336738 with position 28372 was 2 seconds
# getting url with title/tt14336430...
# url loaded
# Getting attributes for tt14336430
# Getting cast for tt14336430
# time to obtain tt14336430 with position 28373 was 1 seconds
# getting url with title/tt14335992...
# url loaded
# Getting attributes for tt14335992
# Getting cast for tt14335992
# time to obtain tt14335992 with position 28374 was 1 seconds
# getting url with title/tt14337230...
# url loaded
# Getting attributes for tt14337230
# Getting cast for tt14337230
# time to obtain tt14337230 with position 28375 was 3 seconds
# getting url with title/tt14336112...
# url loaded
# Getting attributes for tt14336112
# Getting cast for tt14336112
# time to obtain tt14336112 with position 28376 was 2 seconds
# getting url with title/tt14337802...
# url loaded
# Getting attributes for tt14337802
# Getting cast for tt14337802
# time to obtain tt14337802 with position 28377 was 2 seconds
# getting url with title/tt14336546...
# url loaded
# Getting attributes for tt14336546
# Getting cast for tt14336546
# time to obtain tt14336546 with position 28378 was 2 seconds
# getting url with title/tt14337562...
# url loaded
# Getting attributes for tt14337562
# Getting cast for tt14337562
# time to obtain tt14337562 with position 28379 was 2 seconds
# getting url with title/tt14336700...
# url loaded
# Getting attributes for tt14336700
# Getting cast for tt14336700
# time to obtain tt14336700 with position 28380 was 1 seconds
# getting url with title/tt14337398...
# url loaded
# Getting attributes for tt14337398
# Getting cast for tt14337398
# time to obtain tt14337398 with position 28381 was 2 seconds
# getting url with title/tt14336444...
# url loaded
# Getting attributes for tt14336444
# Getting cast for tt14336444
# time to obtain tt14336444 with position 28382 was 2 seconds
# getting url with title/tt14338328...
# url loaded
# Getting attributes for tt14338328
# Getting cast for tt14338328
# time to obtain tt14338328 with position 28383 was 1 seconds
# getting url with title/tt14338396...
# url loaded
# Getting attributes for tt14338396
# Getting cast for tt14338396
# time to obtain tt14338396 with position 28384 was 2 seconds
# getting url with title/tt14338990...
# url loaded
# Getting attributes for tt14338990
# Getting cast for tt14338990
# time to obtain tt14338990 with position 28385 was 2 seconds
# getting url with title/tt14339012...
# url loaded
# Getting attributes for tt14339012
# Getting cast for tt14339012
# time to obtain tt14339012 with position 28386 was 1 seconds
# getting url with title/tt14338806...
# url loaded
# Getting attributes for tt14338806
# error obtaining name for id tt14338806
# Getting cast for tt14338806
# time to obtain tt14338806 with position 28387 was 2 seconds
# getting url with title/tt14337960...
# url loaded
# Getting attributes for tt14337960
# Getting cast for tt14337960
# time to obtain tt14337960 with position 28388 was 1 seconds
# getting url with title/tt14338702...
# url loaded
# Getting attributes for tt14338702
# Getting cast for tt14338702
# time to obtain tt14338702 with position 28389 was 2 seconds
# getting url with title/tt14338846...
# url loaded
# Getting attributes for tt14338846
# Getting cast for tt14338846
# time to obtain tt14338846 with position 28390 was 2 seconds
# getting url with title/tt14338912...
# url loaded
# Getting attributes for tt14338912
# Getting cast for tt14338912
# time to obtain tt14338912 with position 28391 was 1 seconds
# getting url with title/tt14342784...
# url loaded
# Getting attributes for tt14342784
# Getting cast for tt14342784
# time to obtain tt14342784 with position 28392 was 2 seconds
# getting url with title/tt14343100...
# url loaded
# Getting attributes for tt14343100
# Getting cast for tt14343100
# time to obtain tt14343100 with position 28393 was 2 seconds
# getting url with title/tt14343196...
# url loaded
# Getting attributes for tt14343196
# Getting cast for tt14343196
# time to obtain tt14343196 with position 28394 was 2 seconds
# getting url with title/tt14346400...
# url loaded
# Getting attributes for tt14346400
# Getting cast for tt14346400
# time to obtain tt14346400 with position 28395 was 1 seconds
# getting url with title/tt14344742...
# url loaded
# Getting attributes for tt14344742
# Getting cast for tt14344742
# time to obtain tt14344742 with position 28396 was 1 seconds
# getting url with title/tt14344642...
# url loaded
# Getting attributes for tt14344642
# Getting cast for tt14344642
# time to obtain tt14344642 with position 28397 was 1 seconds
# getting url with title/tt14344280...
# url loaded
# Getting attributes for tt14344280
# Getting cast for tt14344280
# time to obtain tt14344280 with position 28398 was 3 seconds
# getting url with title/tt14344690...
# url loaded
# Getting attributes for tt14344690
# Getting cast for tt14344690
# time to obtain tt14344690 with position 28399 was 3 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    3.974
# dtype: float64
