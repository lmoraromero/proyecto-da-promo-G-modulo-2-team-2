# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 6
initial_counter = 38301
incremental = 10000

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers" or nombre == "Writer": 
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("union_peliculas.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_rebe_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_rebe_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt12379026...
# url loaded
# Getting attributes for tt12379026
# Getting cast for tt12379026
# time to obtain tt12379026 with position 38301 was 1 seconds
# getting url with title/tt12391614...
# url loaded
# Getting attributes for tt12391614
# Getting cast for tt12391614
# time to obtain tt12391614 with position 38302 was 1 seconds
# getting url with title/tt12392790...
# url loaded
# Getting attributes for tt12392790
# Getting cast for tt12392790
# time to obtain tt12392790 with position 38303 was 2 seconds
# getting url with title/tt12403738...
# url loaded
# Getting attributes for tt12403738
# Getting cast for tt12403738
# time to obtain tt12403738 with position 38304 was 2 seconds
# getting url with title/tt12421546...
# url loaded
# Getting attributes for tt12421546
# Getting cast for tt12421546
# time to obtain tt12421546 with position 38305 was 3 seconds
# getting url with title/tt12422850...
# url loaded
# Getting attributes for tt12422850
# Getting cast for tt12422850
# time to obtain tt12422850 with position 38306 was 2 seconds
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# getting url with title/tt12427612...
# Error getting tt12427612
# Fatal error
# Getting attributes for tt12427612
# Getting cast for tt12427612
# time to obtain tt12427612 with position 38307 was 3710 seconds
# getting url with title/tt12435324...
# Error getting tt12435324
# getting url with title/tt12435324...
# Error getting tt12435324
# getting url with title/tt12435324...
# Error getting tt12435324
# getting url with title/tt12435324...
# Error getting tt12435324
# getting url with title/tt12435324...
# url loaded
# Getting attributes for tt12435324
# error obtaining name for id tt12435324
# Getting cast for tt12435324
# time to obtain tt12435324 with position 38308 was 1271 seconds
# getting url with title/tt12464390...
# url loaded
# Getting attributes for tt12464390
# Getting cast for tt12464390
# time to obtain tt12464390 with position 38309 was 2 seconds
# getting url with title/tt12472926...
# url loaded
# Getting attributes for tt12472926
# error obtaining name for id tt12472926
# Getting cast for tt12472926
# time to obtain tt12472926 with position 38310 was 3 seconds
# getting url with title/tt12478328...
# url loaded
# Getting attributes for tt12478328
# Getting cast for tt12478328
# time to obtain tt12478328 with position 38311 was 2 seconds
# getting url with title/tt12503440...
# url loaded
# Getting attributes for tt12503440
# error obtaining name for id tt12503440
# Getting cast for tt12503440
# time to obtain tt12503440 with position 38312 was 60 seconds
# getting url with title/tt12503500...
# url loaded
# Getting attributes for tt12503500
# Getting cast for tt12503500
# time to obtain tt12503500 with position 38313 was 1 seconds
# getting url with title/tt12503476...
# url loaded
# Getting attributes for tt12503476
# Getting cast for tt12503476
# time to obtain tt12503476 with position 38314 was 1 seconds
# getting url with title/tt12503480...
# url loaded
# Getting attributes for tt12503480
# Getting cast for tt12503480
# time to obtain tt12503480 with position 38315 was 1 seconds
# getting url with title/tt12503490...
# url loaded
# Getting attributes for tt12503490
# Getting cast for tt12503490
# time to obtain tt12503490 with position 38316 was 1 seconds
# getting url with title/tt12506786...
# url loaded
# Getting attributes for tt12506786
# Getting cast for tt12506786
# time to obtain tt12506786 with position 38317 was 2 seconds
# getting url with title/tt12524394...
# url loaded
# Getting attributes for tt12524394
# Getting cast for tt12524394
# time to obtain tt12524394 with position 38318 was 1 seconds
# getting url with title/tt12530202...
# url loaded
# Getting attributes for tt12530202
# Getting cast for tt12530202
# time to obtain tt12530202 with position 38319 was 2 seconds
# getting url with title/tt12530328...
# url loaded
# Getting attributes for tt12530328
# Getting cast for tt12530328
# time to obtain tt12530328 with position 38320 was 1 seconds
# getting url with title/tt12539084...
# url loaded
# Getting attributes for tt12539084
# Getting cast for tt12539084
# time to obtain tt12539084 with position 38321 was 2 seconds
# getting url with title/tt12540886...
# url loaded
# Getting attributes for tt12540886
# Getting cast for tt12540886
# time to obtain tt12540886 with position 38322 was 1 seconds
# getting url with title/tt12544268...
# url loaded
# Getting attributes for tt12544268
# Getting cast for tt12544268
# time to obtain tt12544268 with position 38323 was 2 seconds
# getting url with title/tt12544068...
# url loaded
# Getting attributes for tt12544068
# Getting cast for tt12544068
# time to obtain tt12544068 with position 38324 was 1 seconds
# getting url with title/tt12595760...
# url loaded
# Getting attributes for tt12595760
# Getting cast for tt12595760
# time to obtain tt12595760 with position 38325 was 2 seconds
# getting url with title/tt12598032...
# url loaded
# Getting attributes for tt12598032
# Getting cast for tt12598032
# time to obtain tt12598032 with position 38326 was 2 seconds
# getting url with title/tt12605986...
# url loaded
# Getting attributes for tt12605986
# Getting cast for tt12605986
# time to obtain tt12605986 with position 38327 was 3 seconds
# getting url with title/tt12605454...
# url loaded
# Getting attributes for tt12605454
# Getting cast for tt12605454
# time to obtain tt12605454 with position 38328 was 3 seconds
# getting url with title/tt12606054...
# url loaded
# Getting attributes for tt12606054
# Getting cast for tt12606054
# time to obtain tt12606054 with position 38329 was 2 seconds
# getting url with title/tt12619824...
# url loaded
# Getting attributes for tt12619824
# error obtaining name for id tt12619824
# Getting cast for tt12619824
# time to obtain tt12619824 with position 38330 was 60 seconds
# getting url with title/tt12622514...
# url loaded
# Getting attributes for tt12622514
# Getting cast for tt12622514
# time to obtain tt12622514 with position 38331 was 2 seconds
# getting url with title/tt12632230...
# url loaded
# Getting attributes for tt12632230
# Getting cast for tt12632230
# time to obtain tt12632230 with position 38332 was 2 seconds
# getting url with title/tt12635774...
# url loaded
# Getting attributes for tt12635774
# Getting cast for tt12635774
# time to obtain tt12635774 with position 38333 was 1 seconds
# getting url with title/tt12636762...
# url loaded
# Getting attributes for tt12636762
# Getting cast for tt12636762
# time to obtain tt12636762 with position 38334 was 2 seconds
# getting url with title/tt12637484...
# url loaded
# Getting attributes for tt12637484
# Getting cast for tt12637484
# time to obtain tt12637484 with position 38335 was 2 seconds
# getting url with title/tt12641428...
# url loaded
# Getting attributes for tt12641428
# Getting cast for tt12641428
# time to obtain tt12641428 with position 38336 was 1 seconds
# getting url with title/tt12643020...
# url loaded
# Getting attributes for tt12643020
# Getting cast for tt12643020
# time to obtain tt12643020 with position 38337 was 1 seconds
# getting url with title/tt12647410...
# url loaded
# Getting attributes for tt12647410
# Getting cast for tt12647410
# time to obtain tt12647410 with position 38338 was 1 seconds
# getting url with title/tt12681318...
# url loaded
# Getting attributes for tt12681318
# Getting cast for tt12681318
# time to obtain tt12681318 with position 38339 was 2 seconds
# getting url with title/tt12695674...
# url loaded
# Getting attributes for tt12695674
# Getting cast for tt12695674
# time to obtain tt12695674 with position 38340 was 1 seconds
# getting url with title/tt12699776...
# url loaded
# Getting attributes for tt12699776
# Getting cast for tt12699776
# time to obtain tt12699776 with position 38341 was 2 seconds
# getting url with title/tt12706936...
# url loaded
# Getting attributes for tt12706936
# Getting cast for tt12706936
# time to obtain tt12706936 with position 38342 was 1 seconds
# getting url with title/tt12712776...
# url loaded
# Getting attributes for tt12712776
# Getting cast for tt12712776
# time to obtain tt12712776 with position 38343 was 2 seconds
# getting url with title/tt12715486...
# url loaded
# Getting attributes for tt12715486
# Getting cast for tt12715486
# time to obtain tt12715486 with position 38344 was 1 seconds
# getting url with title/tt12730354...
# url loaded
# Getting attributes for tt12730354
# Getting cast for tt12730354
# time to obtain tt12730354 with position 38345 was 1 seconds
# getting url with title/tt12746424...
# url loaded
# Getting attributes for tt12746424
# Getting cast for tt12746424
# time to obtain tt12746424 with position 38346 was 2 seconds
# getting url with title/tt12752546...
# url loaded
# Getting attributes for tt12752546
# Getting cast for tt12752546
# time to obtain tt12752546 with position 38347 was 2 seconds
# getting url with title/tt12762638...
# url loaded
# Getting attributes for tt12762638
# Getting cast for tt12762638
# time to obtain tt12762638 with position 38348 was 1 seconds
# getting url with title/tt12766064...
# url loaded
# Getting attributes for tt12766064
# Getting cast for tt12766064
# time to obtain tt12766064 with position 38349 was 2 seconds
# getting url with title/tt12772074...
# url loaded
# Getting attributes for tt12772074
# Getting cast for tt12772074
# time to obtain tt12772074 with position 38350 was 2 seconds
# getting url with title/tt12773182...
# url loaded
# Getting attributes for tt12773182
# Getting cast for tt12773182
# time to obtain tt12773182 with position 38351 was 2 seconds
# getting url with title/tt12780670...
# url loaded
# Getting attributes for tt12780670
# Getting cast for tt12780670
# time to obtain tt12780670 with position 38352 was 1 seconds
# getting url with title/tt12786846...
# url loaded
# Getting attributes for tt12786846
# Getting cast for tt12786846
# time to obtain tt12786846 with position 38353 was 1 seconds
# getting url with title/tt12791156...
# url loaded
# Getting attributes for tt12791156
# Getting cast for tt12791156
# time to obtain tt12791156 with position 38354 was 1 seconds
# getting url with title/tt12797058...
# url loaded
# Getting attributes for tt12797058
# Getting cast for tt12797058
# time to obtain tt12797058 with position 38355 was 1 seconds
# getting url with title/tt12797542...
# url loaded
# Getting attributes for tt12797542
# Getting cast for tt12797542
# time to obtain tt12797542 with position 38356 was 2 seconds
# getting url with title/tt12810904...
# url loaded
# Getting attributes for tt12810904
# Getting cast for tt12810904
# time to obtain tt12810904 with position 38357 was 2 seconds
# getting url with title/tt12816734...
# url loaded
# Getting attributes for tt12816734
# Getting cast for tt12816734
# time to obtain tt12816734 with position 38358 was 2 seconds
# getting url with title/tt12814406...
# url loaded
# Getting attributes for tt12814406
# Getting cast for tt12814406
# time to obtain tt12814406 with position 38359 was 1 seconds
# getting url with title/tt12826022...
# url loaded
# Getting attributes for tt12826022
# Getting cast for tt12826022
# time to obtain tt12826022 with position 38360 was 2 seconds
# getting url with title/tt12826186...
# url loaded
# Getting attributes for tt12826186
# Getting cast for tt12826186
# time to obtain tt12826186 with position 38361 was 1 seconds
# getting url with title/tt12831622...
# url loaded
# Getting attributes for tt12831622
# Getting cast for tt12831622
# time to obtain tt12831622 with position 38362 was 2 seconds
# getting url with title/tt12832108...
# url loaded
# Getting attributes for tt12832108
# Getting cast for tt12832108
# time to obtain tt12832108 with position 38363 was 3 seconds
# getting url with title/tt12842114...
# url loaded
# Getting attributes for tt12842114
# Getting cast for tt12842114
# time to obtain tt12842114 with position 38364 was 3 seconds
# getting url with title/tt12856268...
# url loaded
# Getting attributes for tt12856268
# Getting cast for tt12856268
# time to obtain tt12856268 with position 38365 was 2 seconds
# getting url with title/tt12867224...
# url loaded
# Getting attributes for tt12867224
# Getting cast for tt12867224
# time to obtain tt12867224 with position 38366 was 3 seconds
# getting url with title/tt12869086...
# url loaded
# Getting attributes for tt12869086
# Getting cast for tt12869086
# time to obtain tt12869086 with position 38367 was 3 seconds
# getting url with title/tt12870356...
# url loaded
# Getting attributes for tt12870356
# Getting cast for tt12870356
# time to obtain tt12870356 with position 38368 was 2 seconds
# getting url with title/tt12879570...
# url loaded
# Getting attributes for tt12879570
# Getting cast for tt12879570
# time to obtain tt12879570 with position 38369 was 1 seconds
# getting url with title/tt12879494...
# url loaded
# Getting attributes for tt12879494
# Getting cast for tt12879494
# time to obtain tt12879494 with position 38370 was 2 seconds
# getting url with title/tt12879594...
# url loaded
# Getting attributes for tt12879594
# Getting cast for tt12879594
# time to obtain tt12879594 with position 38371 was 2 seconds
# getting url with title/tt12881042...
# url loaded
# Getting attributes for tt12881042
# Getting cast for tt12881042
# time to obtain tt12881042 with position 38372 was 1 seconds
# getting url with title/tt12887698...
# url loaded
# Getting attributes for tt12887698
# Getting cast for tt12887698
# time to obtain tt12887698 with position 38373 was 2 seconds
# getting url with title/tt12888938...
# url loaded
# Getting attributes for tt12888938
# Getting cast for tt12888938
# time to obtain tt12888938 with position 38374 was 2 seconds
# getting url with title/tt12891542...
# url loaded
# Getting attributes for tt12891542
# Getting cast for tt12891542
# time to obtain tt12891542 with position 38375 was 3 seconds
# getting url with title/tt12899052...
# url loaded
# Getting attributes for tt12899052
# Getting cast for tt12899052
# time to obtain tt12899052 with position 38376 was 2 seconds
# getting url with title/tt12899140...
# url loaded
# Getting attributes for tt12899140
# Getting cast for tt12899140
# time to obtain tt12899140 with position 38377 was 2 seconds
# getting url with title/tt12899826...
# url loaded
# Getting attributes for tt12899826
# Getting cast for tt12899826
# time to obtain tt12899826 with position 38378 was 2 seconds
# getting url with title/tt12906718...
# url loaded
# Getting attributes for tt12906718
# Getting cast for tt12906718
# time to obtain tt12906718 with position 38379 was 1 seconds
# getting url with title/tt12907394...
# url loaded
# Getting attributes for tt12907394
# Getting cast for tt12907394
# time to obtain tt12907394 with position 38380 was 1 seconds
# getting url with title/tt12907676...
# url loaded
# Getting attributes for tt12907676
# Getting cast for tt12907676
# time to obtain tt12907676 with position 38381 was 2 seconds
# getting url with title/tt12915780...
# url loaded
# Getting attributes for tt12915780
# Getting cast for tt12915780
# time to obtain tt12915780 with position 38382 was 1 seconds
# getting url with title/tt12917710...
# url loaded
# Getting attributes for tt12917710
# Getting cast for tt12917710
# time to obtain tt12917710 with position 38383 was 2 seconds
# getting url with title/tt12934888...
# url loaded
# Getting attributes for tt12934888
# Getting cast for tt12934888
# time to obtain tt12934888 with position 38384 was 1 seconds
# getting url with title/tt12936004...
# url loaded
# Getting attributes for tt12936004
# Getting cast for tt12936004
# time to obtain tt12936004 with position 38385 was 2 seconds
# getting url with title/tt12945736...
# url loaded
# Getting attributes for tt12945736
# error obtaining name for id tt12945736
# Getting cast for tt12945736
# time to obtain tt12945736 with position 38386 was 60 seconds
# getting url with title/tt12961752...
# url loaded
# Getting attributes for tt12961752
# Getting cast for tt12961752
# time to obtain tt12961752 with position 38387 was 2 seconds
# getting url with title/tt12967422...
# url loaded
# Getting attributes for tt12967422
# Getting cast for tt12967422
# time to obtain tt12967422 with position 38388 was 2 seconds
# getting url with title/tt12967358...
# url loaded
# Getting attributes for tt12967358
# Getting cast for tt12967358
# time to obtain tt12967358 with position 38389 was 2 seconds
# getting url with title/tt12976372...
# url loaded
# Getting attributes for tt12976372
# Getting cast for tt12976372
# time to obtain tt12976372 with position 38390 was 2 seconds
# getting url with title/tt12975344...
# url loaded
# Getting attributes for tt12975344
# Getting cast for tt12975344
# time to obtain tt12975344 with position 38391 was 2 seconds
# getting url with title/tt12978240...
# url loaded
# Getting attributes for tt12978240
# Getting cast for tt12978240
# time to obtain tt12978240 with position 38392 was 1 seconds
# getting url with title/tt12978330...
# url loaded
# Getting attributes for tt12978330
# Getting cast for tt12978330
# time to obtain tt12978330 with position 38393 was 1 seconds
# getting url with title/tt12982260...
# url loaded
# Getting attributes for tt12982260
# Getting cast for tt12982260
# time to obtain tt12982260 with position 38394 was 2 seconds
# getting url with title/tt12982146...
# url loaded
# Getting attributes for tt12982146
# Getting cast for tt12982146
# time to obtain tt12982146 with position 38395 was 2 seconds
# getting url with title/tt12990144...
# url loaded
# Getting attributes for tt12990144
# Getting cast for tt12990144
# time to obtain tt12990144 with position 38396 was 1 seconds
# getting url with title/tt12999544...
# url loaded
# Getting attributes for tt12999544
# Getting cast for tt12999544
# time to obtain tt12999544 with position 38397 was 1 seconds
# getting url with title/tt13000466...
# url loaded
# Getting attributes for tt13000466
# Getting cast for tt13000466
# time to obtain tt13000466 with position 38398 was 1 seconds
# getting url with title/tt13004520...
# url loaded
# Getting attributes for tt13004520
# Getting cast for tt13004520
# time to obtain tt13004520 with position 38399 was 1 seconds
# getting url with title/tt13004468...
# url loaded
# Getting attributes for tt13004468
# Getting cast for tt13004468
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt13004468 with position 38400 was 15 seconds
# getting url with title/tt13011516...
# url loaded
# Getting attributes for tt13011516
# Getting cast for tt13011516
# time to obtain tt13011516 with position 38401 was 1 seconds
# getting url with title/tt13016870...
# url loaded
# Getting attributes for tt13016870
# Getting cast for tt13016870
# time to obtain tt13016870 with position 38402 was 1 seconds
# getting url with title/tt13016876...
# url loaded
# Getting attributes for tt13016876
# Getting cast for tt13016876
# time to obtain tt13016876 with position 38403 was 2 seconds
# getting url with title/tt13022204...
# url loaded
# Getting attributes for tt13022204
# Getting cast for tt13022204
# time to obtain tt13022204 with position 38404 was 2 seconds
# getting url with title/tt13024090...
# url loaded
# Getting attributes for tt13024090
# Getting cast for tt13024090
# time to obtain tt13024090 with position 38405 was 1 seconds
# getting url with title/tt13023070...
# url loaded
# Getting attributes for tt13023070
# Getting cast for tt13023070
# time to obtain tt13023070 with position 38406 was 1 seconds
# getting url with title/tt13026916...
# url loaded
# Getting attributes for tt13026916
# Getting cast for tt13026916
# time to obtain tt13026916 with position 38407 was 2 seconds
# getting url with title/tt13032732...
# url loaded
# Getting attributes for tt13032732
# Getting cast for tt13032732
# time to obtain tt13032732 with position 38408 was 2 seconds
# getting url with title/tt13037490...
# url loaded
# Getting attributes for tt13037490
# Getting cast for tt13037490
# time to obtain tt13037490 with position 38409 was 1 seconds
# getting url with title/tt13046144...
# url loaded
# Getting attributes for tt13046144
# Getting cast for tt13046144
# time to obtain tt13046144 with position 38410 was 1 seconds
# getting url with title/tt13050622...
# url loaded
# Getting attributes for tt13050622
# Getting cast for tt13050622
# time to obtain tt13050622 with position 38411 was 1 seconds
# getting url with title/tt13051674...
# url loaded
# Getting attributes for tt13051674
# Getting cast for tt13051674
# time to obtain tt13051674 with position 38412 was 2 seconds
# getting url with title/tt13052470...
# url loaded
# Getting attributes for tt13052470
# Getting cast for tt13052470
# time to obtain tt13052470 with position 38413 was 1 seconds
# getting url with title/tt13057332...
# url loaded
# Getting attributes for tt13057332
# Getting cast for tt13057332
# time to obtain tt13057332 with position 38414 was 1 seconds
# getting url with title/tt13055274...
# url loaded
# Getting attributes for tt13055274
# Getting cast for tt13055274
# time to obtain tt13055274 with position 38415 was 2 seconds
# getting url with title/tt13061874...
# url loaded
# Getting attributes for tt13061874
# Getting cast for tt13061874
# time to obtain tt13061874 with position 38416 was 1 seconds
# getting url with title/tt13063502...
# url loaded
# Getting attributes for tt13063502
# Getting cast for tt13063502
# time to obtain tt13063502 with position 38417 was 1 seconds
# getting url with title/tt13063720...
# url loaded
# Getting attributes for tt13063720
# Getting cast for tt13063720
# time to obtain tt13063720 with position 38418 was 1 seconds
# getting url with title/tt13059888...
# url loaded
# Getting attributes for tt13059888
# Getting cast for tt13059888
# time to obtain tt13059888 with position 38419 was 1 seconds
# getting url with title/tt13069778...
# url loaded
# Getting attributes for tt13069778
# Getting cast for tt13069778
# time to obtain tt13069778 with position 38420 was 2 seconds
# getting url with title/tt13070474...
# url loaded
# Getting attributes for tt13070474
# Getting cast for tt13070474
# time to obtain tt13070474 with position 38421 was 1 seconds
# getting url with title/tt13066972...
# url loaded
# Getting attributes for tt13066972
# Getting cast for tt13066972
# time to obtain tt13066972 with position 38422 was 1 seconds
# getting url with title/tt13071528...
# url loaded
# Getting attributes for tt13071528
# Getting cast for tt13071528
# time to obtain tt13071528 with position 38423 was 2 seconds
# getting url with title/tt13073642...
# url loaded
# Getting attributes for tt13073642
# Getting cast for tt13073642
# time to obtain tt13073642 with position 38424 was 2 seconds
# getting url with title/tt13073398...
# url loaded
# Getting attributes for tt13073398
# Getting cast for tt13073398
# time to obtain tt13073398 with position 38425 was 1 seconds
# getting url with title/tt13074260...
# url loaded
# Getting attributes for tt13074260
# Getting cast for tt13074260
# time to obtain tt13074260 with position 38426 was 2 seconds
# getting url with title/tt13074136...
# url loaded
# Getting attributes for tt13074136
# Getting cast for tt13074136
# time to obtain tt13074136 with position 38427 was 2 seconds
# getting url with title/tt13084496...
# url loaded
# Getting attributes for tt13084496
# error obtaining name for id tt13084496
# Getting cast for tt13084496
# time to obtain tt13084496 with position 38428 was 60 seconds
# getting url with title/tt13082162...
# url loaded
# Getting attributes for tt13082162
# Getting cast for tt13082162
# time to obtain tt13082162 with position 38429 was 2 seconds
# getting url with title/tt13085316...
# url loaded
# Getting attributes for tt13085316
# Getting cast for tt13085316
# time to obtain tt13085316 with position 38430 was 2 seconds
# getting url with title/tt13086098...
# url loaded
# Getting attributes for tt13086098
# Getting cast for tt13086098
# time to obtain tt13086098 with position 38431 was 1 seconds
# getting url with title/tt13089428...
# url loaded
# Getting attributes for tt13089428
# Getting cast for tt13089428
# time to obtain tt13089428 with position 38432 was 2 seconds
# getting url with title/tt13091392...
# url loaded
# Getting attributes for tt13091392
# Getting cast for tt13091392
# time to obtain tt13091392 with position 38433 was 2 seconds
# getting url with title/tt13093006...
# url loaded
# Getting attributes for tt13093006
# Getting cast for tt13093006
# time to obtain tt13093006 with position 38434 was 2 seconds
# getting url with title/tt13097366...
# url loaded
# Getting attributes for tt13097366
# Getting cast for tt13097366
# time to obtain tt13097366 with position 38435 was 2 seconds
# getting url with title/tt13099296...
# url loaded
# Getting attributes for tt13099296
# Getting cast for tt13099296
# time to obtain tt13099296 with position 38436 was 1 seconds
# getting url with title/tt13103590...
# url loaded
# Getting attributes for tt13103590
# Getting cast for tt13103590
# time to obtain tt13103590 with position 38437 was 2 seconds
# getting url with title/tt13103506...
# url loaded
# Getting attributes for tt13103506
# Getting cast for tt13103506
# time to obtain tt13103506 with position 38438 was 1 seconds
# getting url with title/tt13103608...
# url loaded
# Getting attributes for tt13103608
# Getting cast for tt13103608
# time to obtain tt13103608 with position 38439 was 2 seconds
# getting url with title/tt13103618...
# url loaded
# Getting attributes for tt13103618
# Getting cast for tt13103618
# time to obtain tt13103618 with position 38440 was 1 seconds
# getting url with title/tt13107604...
# url loaded
# Getting attributes for tt13107604
# Getting cast for tt13107604
# time to obtain tt13107604 with position 38441 was 1 seconds
# getting url with title/tt13110108...
# url loaded
# Getting attributes for tt13110108
# Getting cast for tt13110108
# time to obtain tt13110108 with position 38442 was 2 seconds
# getting url with title/tt13116622...
# url loaded
# Getting attributes for tt13116622
# Getting cast for tt13116622
# time to obtain tt13116622 with position 38443 was 1 seconds
# getting url with title/tt13119882...
# url loaded
# Getting attributes for tt13119882
# Getting cast for tt13119882
# time to obtain tt13119882 with position 38444 was 1 seconds
# getting url with title/tt13123474...
# url loaded
# Getting attributes for tt13123474
# Getting cast for tt13123474
# time to obtain tt13123474 with position 38445 was 1 seconds
# getting url with title/tt13138994...
# url loaded
# Getting attributes for tt13138994
# Getting cast for tt13138994
# time to obtain tt13138994 with position 38446 was 2 seconds
# getting url with title/tt13149414...
# url loaded
# Getting attributes for tt13149414
# Getting cast for tt13149414
# time to obtain tt13149414 with position 38447 was 1 seconds
# getting url with title/tt13154238...
# url loaded
# Getting attributes for tt13154238
# Getting cast for tt13154238
# time to obtain tt13154238 with position 38448 was 2 seconds
# getting url with title/tt13154810...
# url loaded
# Getting attributes for tt13154810
# Getting cast for tt13154810
# time to obtain tt13154810 with position 38449 was 1 seconds
# getting url with title/tt13159766...
# url loaded
# Getting attributes for tt13159766
# Getting cast for tt13159766
# time to obtain tt13159766 with position 38450 was 1 seconds
# getting url with title/tt13161366...
# url loaded
# Getting attributes for tt13161366
# Getting cast for tt13161366
# time to obtain tt13161366 with position 38451 was 1 seconds
# getting url with title/tt13163104...
# url loaded
# Getting attributes for tt13163104
# Getting cast for tt13163104
# time to obtain tt13163104 with position 38452 was 2 seconds
# getting url with title/tt13164926...
# url loaded
# Getting attributes for tt13164926
# Getting cast for tt13164926
# time to obtain tt13164926 with position 38453 was 2 seconds
# getting url with title/tt13168460...
# url loaded
# Getting attributes for tt13168460
# Getting cast for tt13168460
# time to obtain tt13168460 with position 38454 was 1 seconds
# getting url with title/tt13168186...
# url loaded
# Getting attributes for tt13168186
# Getting cast for tt13168186
# time to obtain tt13168186 with position 38455 was 1 seconds
# getting url with title/tt13173190...
# url loaded
# Getting attributes for tt13173190
# Getting cast for tt13173190
# time to obtain tt13173190 with position 38456 was 2 seconds
# getting url with title/tt13179106...
# url loaded
# Getting attributes for tt13179106
# Getting cast for tt13179106
# time to obtain tt13179106 with position 38457 was 2 seconds
# getting url with title/tt13178750...
# url loaded
# Getting attributes for tt13178750
# Getting cast for tt13178750
# time to obtain tt13178750 with position 38458 was 2 seconds
# getting url with title/tt13186046...
# url loaded
# Getting attributes for tt13186046
# Getting cast for tt13186046
# time to obtain tt13186046 with position 38459 was 1 seconds
# getting url with title/tt13188350...
# url loaded
# Getting attributes for tt13188350
# Getting cast for tt13188350
# time to obtain tt13188350 with position 38460 was 2 seconds
# getting url with title/tt13187834...
# url loaded
# Getting attributes for tt13187834
# Getting cast for tt13187834
# time to obtain tt13187834 with position 38461 was 2 seconds
# getting url with title/tt13192784...
# url loaded
# Getting attributes for tt13192784
# Getting cast for tt13192784
# time to obtain tt13192784 with position 38462 was 2 seconds
# getting url with title/tt13199070...
# url loaded
# Getting attributes for tt13199070
# Getting cast for tt13199070
# time to obtain tt13199070 with position 38463 was 1 seconds
# getting url with title/tt13203598...
# url loaded
# Getting attributes for tt13203598
# Getting cast for tt13203598
# time to obtain tt13203598 with position 38464 was 2 seconds
# getting url with title/tt13203758...
# url loaded
# Getting attributes for tt13203758
# Getting cast for tt13203758
# time to obtain tt13203758 with position 38465 was 1 seconds
# getting url with title/tt13212060...
# url loaded
# Getting attributes for tt13212060
# Getting cast for tt13212060
# time to obtain tt13212060 with position 38466 was 1 seconds
# getting url with title/tt13212798...
# url loaded
# Getting attributes for tt13212798
# Getting cast for tt13212798
# time to obtain tt13212798 with position 38467 was 2 seconds
# getting url with title/tt13212712...
# url loaded
# Getting attributes for tt13212712
# Getting cast for tt13212712
# time to obtain tt13212712 with position 38468 was 1 seconds
# getting url with title/tt13209836...
# url loaded
# Getting attributes for tt13209836
# Getting cast for tt13209836
# time to obtain tt13209836 with position 38469 was 2 seconds
# getting url with title/tt13216634...
# url loaded
# Getting attributes for tt13216634
# Getting cast for tt13216634
# time to obtain tt13216634 with position 38470 was 1 seconds
# getting url with title/tt13218816...
# url loaded
# Getting attributes for tt13218816
# Getting cast for tt13218816
# time to obtain tt13218816 with position 38471 was 1 seconds
# getting url with title/tt13218152...
# url loaded
# Getting attributes for tt13218152
# Getting cast for tt13218152
# time to obtain tt13218152 with position 38472 was 1 seconds
# getting url with title/tt13228684...
# url loaded
# Getting attributes for tt13228684
# Getting cast for tt13228684
# time to obtain tt13228684 with position 38473 was 1 seconds
# getting url with title/tt13229430...
# url loaded
# Getting attributes for tt13229430
# Getting cast for tt13229430
# time to obtain tt13229430 with position 38474 was 1 seconds
# getting url with title/tt13227258...
# url loaded
# Getting attributes for tt13227258
# Getting cast for tt13227258
# time to obtain tt13227258 with position 38475 was 1 seconds
# getting url with title/tt13225406...
# url loaded
# Getting attributes for tt13225406
# Getting cast for tt13225406
# time to obtain tt13225406 with position 38476 was 2 seconds
# getting url with title/tt13229874...
# url loaded
# Getting attributes for tt13229874
# Getting cast for tt13229874
# time to obtain tt13229874 with position 38477 was 2 seconds
# getting url with title/tt13230598...
# url loaded
# Getting attributes for tt13230598
# Getting cast for tt13230598
# time to obtain tt13230598 with position 38478 was 1 seconds
# getting url with title/tt13238916...
# url loaded
# Getting attributes for tt13238916
# Getting cast for tt13238916
# time to obtain tt13238916 with position 38479 was 1 seconds
# getting url with title/tt13242320...
# url loaded
# Getting attributes for tt13242320
# Getting cast for tt13242320
# time to obtain tt13242320 with position 38480 was 2 seconds
# getting url with title/tt13246452...
# url loaded
# Getting attributes for tt13246452
# Getting cast for tt13246452
# time to obtain tt13246452 with position 38481 was 2 seconds
# getting url with title/tt13257874...
# url loaded
# Getting attributes for tt13257874
# Getting cast for tt13257874
# time to obtain tt13257874 with position 38482 was 3 seconds
# getting url with title/tt13264608...
# url loaded
# Getting attributes for tt13264608
# Getting cast for tt13264608
# time to obtain tt13264608 with position 38483 was 3 seconds
# getting url with title/tt13260978...
# url loaded
# Getting attributes for tt13260978
# Getting cast for tt13260978
# time to obtain tt13260978 with position 38484 was 1 seconds
# getting url with title/tt13268428...
# url loaded
# Getting attributes for tt13268428
# Getting cast for tt13268428
# time to obtain tt13268428 with position 38485 was 1 seconds
# getting url with title/tt13265588...
# url loaded
# Getting attributes for tt13265588
# Getting cast for tt13265588
# time to obtain tt13265588 with position 38486 was 2 seconds
# getting url with title/tt13265782...
# url loaded
# Getting attributes for tt13265782
# Getting cast for tt13265782
# time to obtain tt13265782 with position 38487 was 2 seconds
# getting url with title/tt13268836...
# url loaded
# Getting attributes for tt13268836
# Getting cast for tt13268836
# time to obtain tt13268836 with position 38488 was 1 seconds
# getting url with title/tt13273704...
# url loaded
# Getting attributes for tt13273704
# Getting cast for tt13273704
# time to obtain tt13273704 with position 38489 was 2 seconds
# getting url with title/tt13273700...
# url loaded
# Getting attributes for tt13273700
# Getting cast for tt13273700
# time to obtain tt13273700 with position 38490 was 1 seconds
# getting url with title/tt13277426...
# url loaded
# Getting attributes for tt13277426
# Getting cast for tt13277426
# time to obtain tt13277426 with position 38491 was 1 seconds
# getting url with title/tt13280740...
# url loaded
# Getting attributes for tt13280740
# Getting cast for tt13280740
# time to obtain tt13280740 with position 38492 was 1 seconds
# getting url with title/tt13282754...
# url loaded
# Getting attributes for tt13282754
# Getting cast for tt13282754
# time to obtain tt13282754 with position 38493 was 2 seconds
# getting url with title/tt13281078...
# url loaded
# Getting attributes for tt13281078
# Getting cast for tt13281078
# time to obtain tt13281078 with position 38494 was 2 seconds
# getting url with title/tt13286026...
# url loaded
# Getting attributes for tt13286026
# Getting cast for tt13286026
# time to obtain tt13286026 with position 38495 was 1 seconds
# getting url with title/tt13286592...
# url loaded
# Getting attributes for tt13286592
# Getting cast for tt13286592
# time to obtain tt13286592 with position 38496 was 2 seconds
# getting url with title/tt13288910...
# url loaded
# Getting attributes for tt13288910
# Getting cast for tt13288910
# time to obtain tt13288910 with position 38497 was 2 seconds
# getting url with title/tt13288214...
# url loaded
# Getting attributes for tt13288214
# Getting cast for tt13288214
# time to obtain tt13288214 with position 38498 was 2 seconds
# getting url with title/tt13290952...
# url loaded
# Getting attributes for tt13290952
# Getting cast for tt13290952
# time to obtain tt13290952 with position 38499 was 2 seconds
# getting url with title/tt13293072...
# url loaded
# Getting attributes for tt13293072
# Getting cast for tt13293072
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt13293072 with position 38500 was 12 seconds
# getting url with title/tt13304590...
# url loaded
# Getting attributes for tt13304590
# Getting cast for tt13304590
# time to obtain tt13304590 with position 38501 was 1 seconds
# getting url with title/tt13303124...
# url loaded
# Getting attributes for tt13303124
# Getting cast for tt13303124
# time to obtain tt13303124 with position 38502 was 2 seconds
# getting url with title/tt13308666...
# url loaded
# Getting attributes for tt13308666
# Getting cast for tt13308666
# time to obtain tt13308666 with position 38503 was 2 seconds
# getting url with title/tt13309768...
# url loaded
# Getting attributes for tt13309768
# Getting cast for tt13309768
# time to obtain tt13309768 with position 38504 was 2 seconds
# getting url with title/tt13310992...
# url loaded
# Getting attributes for tt13310992
# Getting cast for tt13310992
# time to obtain tt13310992 with position 38505 was 2 seconds
# getting url with title/tt13309176...
# url loaded
# Getting attributes for tt13309176
# Getting cast for tt13309176
# time to obtain tt13309176 with position 38506 was 2 seconds
# getting url with title/tt13314268...
# url loaded
# Getting attributes for tt13314268
# Getting cast for tt13314268
# time to obtain tt13314268 with position 38507 was 1 seconds
# getting url with title/tt13317492...
# url loaded
# Getting attributes for tt13317492
# Getting cast for tt13317492
# time to obtain tt13317492 with position 38508 was 2 seconds
# getting url with title/tt13316222...
# url loaded
# Getting attributes for tt13316222
# Getting cast for tt13316222
# time to obtain tt13316222 with position 38509 was 2 seconds
# getting url with title/tt13316050...
# url loaded
# Getting attributes for tt13316050
# Getting cast for tt13316050
# time to obtain tt13316050 with position 38510 was 1 seconds
# getting url with title/tt13317086...
# url loaded
# Getting attributes for tt13317086
# Getting cast for tt13317086
# time to obtain tt13317086 with position 38511 was 1 seconds
# getting url with title/tt13316726...
# url loaded
# Getting attributes for tt13316726
# Getting cast for tt13316726
# time to obtain tt13316726 with position 38512 was 2 seconds
# getting url with title/tt13321082...
# url loaded
# Getting attributes for tt13321082
# Getting cast for tt13321082
# time to obtain tt13321082 with position 38513 was 1 seconds
# getting url with title/tt13325026...
# url loaded
# Getting attributes for tt13325026
# Getting cast for tt13325026
# time to obtain tt13325026 with position 38514 was 1 seconds
# getting url with title/tt13326490...
# url loaded
# Getting attributes for tt13326490
# Getting cast for tt13326490
# time to obtain tt13326490 with position 38515 was 2 seconds
# getting url with title/tt13328358...
# url loaded
# Getting attributes for tt13328358
# Getting cast for tt13328358
# time to obtain tt13328358 with position 38516 was 2 seconds
# getting url with title/tt13328120...
# url loaded
# Getting attributes for tt13328120
# Getting cast for tt13328120
# time to obtain tt13328120 with position 38517 was 1 seconds
# getting url with title/tt13328146...
# url loaded
# Getting attributes for tt13328146
# Getting cast for tt13328146
# time to obtain tt13328146 with position 38518 was 1 seconds
# getting url with title/tt13331260...
# url loaded
# Getting attributes for tt13331260
# Getting cast for tt13331260
# time to obtain tt13331260 with position 38519 was 2 seconds
# getting url with title/tt13334434...
# url loaded
# Getting attributes for tt13334434
# Getting cast for tt13334434
# time to obtain tt13334434 with position 38520 was 2 seconds
# getting url with title/tt13345406...
# url loaded
# Getting attributes for tt13345406
# Getting cast for tt13345406
# time to obtain tt13345406 with position 38521 was 1 seconds
# getting url with title/tt13344390...
# url loaded
# Getting attributes for tt13344390
# Getting cast for tt13344390
# time to obtain tt13344390 with position 38522 was 1 seconds
# getting url with title/tt13348704...
# url loaded
# Getting attributes for tt13348704
# Getting cast for tt13348704
# time to obtain tt13348704 with position 38523 was 2 seconds
# getting url with title/tt13351420...
# url loaded
# Getting attributes for tt13351420
# Getting cast for tt13351420
# time to obtain tt13351420 with position 38524 was 2 seconds
# getting url with title/tt13352226...
# url loaded
# Getting attributes for tt13352226
# Getting cast for tt13352226
# time to obtain tt13352226 with position 38525 was 1 seconds
# getting url with title/tt13356532...
# url loaded
# Getting attributes for tt13356532
# Getting cast for tt13356532
# time to obtain tt13356532 with position 38526 was 1 seconds
# getting url with title/tt13362268...
# url loaded
# Getting attributes for tt13362268
# Getting cast for tt13362268
# time to obtain tt13362268 with position 38527 was 2 seconds
# getting url with title/tt13364366...
# url loaded
# Getting attributes for tt13364366
# Getting cast for tt13364366
# time to obtain tt13364366 with position 38528 was 2 seconds
# getting url with title/tt13367598...
# url loaded
# Getting attributes for tt13367598
# Getting cast for tt13367598
# time to obtain tt13367598 with position 38529 was 3 seconds
# getting url with title/tt13368884...
# url loaded
# Getting attributes for tt13368884
# Getting cast for tt13368884
# time to obtain tt13368884 with position 38530 was 1 seconds
# getting url with title/tt13375776...
# url loaded
# Getting attributes for tt13375776
# Getting cast for tt13375776
# time to obtain tt13375776 with position 38531 was 1 seconds
# getting url with title/tt13381210...
# url loaded
# Getting attributes for tt13381210
# Getting cast for tt13381210
# time to obtain tt13381210 with position 38532 was 1 seconds
# getting url with title/tt13386028...
# url loaded
# Getting attributes for tt13386028
# Getting cast for tt13386028
# time to obtain tt13386028 with position 38533 was 2 seconds
# getting url with title/tt13392124...
# url loaded
# Getting attributes for tt13392124
# Getting cast for tt13392124
# time to obtain tt13392124 with position 38534 was 1 seconds
# getting url with title/tt13392600...
# url loaded
# Getting attributes for tt13392600
# Getting cast for tt13392600
# time to obtain tt13392600 with position 38535 was 2 seconds
# getting url with title/tt13397636...
# url loaded
# Getting attributes for tt13397636
# Getting cast for tt13397636
# time to obtain tt13397636 with position 38536 was 2 seconds
# getting url with title/tt13398324...
# url loaded
# Getting attributes for tt13398324
# Getting cast for tt13398324
# time to obtain tt13398324 with position 38537 was 1 seconds
# getting url with title/tt13404024...
# url loaded
# Getting attributes for tt13404024
# error obtaining name for id tt13404024
# Getting cast for tt13404024
# time to obtain tt13404024 with position 38538 was 1 seconds
# getting url with title/tt13403460...
# url loaded
# Getting attributes for tt13403460
# Getting cast for tt13403460
# time to obtain tt13403460 with position 38539 was 1 seconds
# getting url with title/tt13404016...
# url loaded
# Getting attributes for tt13404016
# Getting cast for tt13404016
# time to obtain tt13404016 with position 38540 was 3 seconds
# getting url with title/tt13409120...
# url loaded
# Getting attributes for tt13409120
# Getting cast for tt13409120
# time to obtain tt13409120 with position 38541 was 1 seconds
# getting url with title/tt13409246...
# url loaded
# Getting attributes for tt13409246
# Getting cast for tt13409246
# time to obtain tt13409246 with position 38542 was 1 seconds
# getting url with title/tt13410236...
# url loaded
# Getting attributes for tt13410236
# Getting cast for tt13410236
# time to obtain tt13410236 with position 38543 was 1 seconds
# getting url with title/tt13416264...
# url loaded
# Getting attributes for tt13416264
# Getting cast for tt13416264
# time to obtain tt13416264 with position 38544 was 1 seconds
# getting url with title/tt13421400...
# url loaded
# Getting attributes for tt13421400
# error obtaining name for id tt13421400
# Getting cast for tt13421400
# time to obtain tt13421400 with position 38545 was 1 seconds
# getting url with title/tt13427430...
# url loaded
# Getting attributes for tt13427430
# Getting cast for tt13427430
# time to obtain tt13427430 with position 38546 was 1 seconds
# getting url with title/tt13427770...
# url loaded
# Getting attributes for tt13427770
# Getting cast for tt13427770
# time to obtain tt13427770 with position 38547 was 2 seconds
# getting url with title/tt13428898...
# url loaded
# Getting attributes for tt13428898
# Getting cast for tt13428898
# time to obtain tt13428898 with position 38548 was 2 seconds
# getting url with title/tt13429656...
# url loaded
# Getting attributes for tt13429656
# Getting cast for tt13429656
# time to obtain tt13429656 with position 38549 was 2 seconds
# getting url with title/tt13428778...
# url loaded
# Getting attributes for tt13428778
# Getting cast for tt13428778
# time to obtain tt13428778 with position 38550 was 1 seconds
# getting url with title/tt13431006...
# url loaded
# Getting attributes for tt13431006
# Getting cast for tt13431006
# time to obtain tt13431006 with position 38551 was 3 seconds
# getting url with title/tt13432760...
# url loaded
# Getting attributes for tt13432760
# Getting cast for tt13432760
# time to obtain tt13432760 with position 38552 was 1 seconds
# getting url with title/tt13434666...
# url loaded
# Getting attributes for tt13434666
# Getting cast for tt13434666
# time to obtain tt13434666 with position 38553 was 1 seconds
# getting url with title/tt13444936...
# url loaded
# Getting attributes for tt13444936
# Getting cast for tt13444936
# time to obtain tt13444936 with position 38554 was 2 seconds
# getting url with title/tt13448420...
# url loaded
# Getting attributes for tt13448420
# Getting cast for tt13448420
# time to obtain tt13448420 with position 38555 was 2 seconds
# getting url with title/tt13449858...
# url loaded
# Getting attributes for tt13449858
# Getting cast for tt13449858
# time to obtain tt13449858 with position 38556 was 1 seconds
# getting url with title/tt13452324...
# url loaded
# Getting attributes for tt13452324
# Getting cast for tt13452324
# time to obtain tt13452324 with position 38557 was 3 seconds
# getting url with title/tt13453202...
# url loaded
# Getting attributes for tt13453202
# Getting cast for tt13453202
# time to obtain tt13453202 with position 38558 was 2 seconds
# getting url with title/tt13459424...
# url loaded
# Getting attributes for tt13459424
# Getting cast for tt13459424
# time to obtain tt13459424 with position 38559 was 2 seconds
# getting url with title/tt13459408...
# url loaded
# Getting attributes for tt13459408
# Getting cast for tt13459408
# time to obtain tt13459408 with position 38560 was 1 seconds
# getting url with title/tt13459448...
# url loaded
# Getting attributes for tt13459448
# Getting cast for tt13459448
# time to obtain tt13459448 with position 38561 was 1 seconds
# getting url with title/tt13464958...
# url loaded
# Getting attributes for tt13464958
# Getting cast for tt13464958
# time to obtain tt13464958 with position 38562 was 1 seconds
# getting url with title/tt13462314...
# url loaded
# Getting attributes for tt13462314
# Getting cast for tt13462314
# time to obtain tt13462314 with position 38563 was 1 seconds
# getting url with title/tt13464850...
# url loaded
# Getting attributes for tt13464850
# Getting cast for tt13464850
# time to obtain tt13464850 with position 38564 was 2 seconds
# getting url with title/tt13464200...
# url loaded
# Getting attributes for tt13464200
# Getting cast for tt13464200
# time to obtain tt13464200 with position 38565 was 2 seconds
# getting url with title/tt13476878...
# url loaded
# Getting attributes for tt13476878
# Getting cast for tt13476878
# time to obtain tt13476878 with position 38566 was 1 seconds
# getting url with title/tt13476844...
# url loaded
# Getting attributes for tt13476844
# Getting cast for tt13476844
# time to obtain tt13476844 with position 38567 was 1 seconds
# getting url with title/tt13486278...
# url loaded
# Getting attributes for tt13486278
# Getting cast for tt13486278
# time to obtain tt13486278 with position 38568 was 1 seconds
# getting url with title/tt13489568...
# url loaded
# Getting attributes for tt13489568
# Getting cast for tt13489568
# time to obtain tt13489568 with position 38569 was 2 seconds
# getting url with title/tt13483088...
# url loaded
# Getting attributes for tt13483088
# Getting cast for tt13483088
# time to obtain tt13483088 with position 38570 was 1 seconds
# getting url with title/tt13489406...
# url loaded
# Getting attributes for tt13489406
# Getting cast for tt13489406
# time to obtain tt13489406 with position 38571 was 1 seconds
# getting url with title/tt13490202...
# url loaded
# Getting attributes for tt13490202
# Getting cast for tt13490202
# time to obtain tt13490202 with position 38572 was 1 seconds
# getting url with title/tt13492502...
# url loaded
# Getting attributes for tt13492502
# Getting cast for tt13492502
# time to obtain tt13492502 with position 38573 was 1 seconds
# getting url with title/tt13495758...
# url loaded
# Getting attributes for tt13495758
# Getting cast for tt13495758
# ...
# getting url with title/tt19351076...
# url loaded
# Getting attributes for tt19351076
# Getting cast for tt19351076
# time to obtain tt19351076 with position 48208 was 2 seconds
# getting url with title/tt19353050...
# url loaded
# Getting attributes for tt19353050
# Getting cast for tt19353050
# time to obtain tt19353050 with position 48209 was 2 seconds
# getting url with title/tt19354256...
# url loaded
# Getting attributes for tt19354256
# Getting cast for tt19354256
# time to obtain tt19354256 with position 48210 was 4 seconds
# getting url with title/tt19355496...
# url loaded
# Getting attributes for tt19355496
# Getting cast for tt19355496
# time to obtain tt19355496 with position 48211 was 1 seconds
# getting url with title/tt19355416...
# url loaded
# Getting attributes for tt19355416
# Getting cast for tt19355416
# time to obtain tt19355416 with position 48212 was 1 seconds
# getting url with title/tt19355670...
# url loaded
# Getting attributes for tt19355670
# Getting cast for tt19355670
# time to obtain tt19355670 with position 48213 was 1 seconds
# getting url with title/tt19355884...
# url loaded
# Getting attributes for tt19355884
# Getting cast for tt19355884
# time to obtain tt19355884 with position 48214 was 1 seconds
# getting url with title/tt19356088...
# url loaded
# Getting attributes for tt19356088
# Getting cast for tt19356088
# time to obtain tt19356088 with position 48215 was 1 seconds
# getting url with title/tt19356194...
# url loaded
# Getting attributes for tt19356194
# Getting cast for tt19356194
# time to obtain tt19356194 with position 48216 was 1 seconds
# getting url with title/tt19354302...
# url loaded
# Getting attributes for tt19354302
# Getting cast for tt19354302
# time to obtain tt19354302 with position 48217 was 1 seconds
# getting url with title/tt19353940...
# url loaded
# Getting attributes for tt19353940
# Getting cast for tt19353940
# time to obtain tt19353940 with position 48218 was 1 seconds
# getting url with title/tt19355624...
# url loaded
# Getting attributes for tt19355624
# Getting cast for tt19355624
# time to obtain tt19355624 with position 48219 was 1 seconds
# getting url with title/tt19355552...
# url loaded
# Getting attributes for tt19355552
# Getting cast for tt19355552
# time to obtain tt19355552 with position 48220 was 3 seconds
# getting url with title/tt19351844...
# url loaded
# Getting attributes for tt19351844
# Getting cast for tt19351844
# time to obtain tt19351844 with position 48221 was 1 seconds
# getting url with title/tt19357604...
# url loaded
# Getting attributes for tt19357604
# Getting cast for tt19357604
# time to obtain tt19357604 with position 48222 was 1 seconds
# getting url with title/tt19357500...
# url loaded
# Getting attributes for tt19357500
# Getting cast for tt19357500
# time to obtain tt19357500 with position 48223 was 1 seconds
# getting url with title/tt19358230...
# url loaded
# Getting attributes for tt19358230
# Getting cast for tt19358230
# time to obtain tt19358230 with position 48224 was 1 seconds
# getting url with title/tt19358440...
# url loaded
# Getting attributes for tt19358440
# Getting cast for tt19358440
# time to obtain tt19358440 with position 48225 was 1 seconds
# getting url with title/tt19358820...
# url loaded
# Getting attributes for tt19358820
# Getting cast for tt19358820
# time to obtain tt19358820 with position 48226 was 2 seconds
# getting url with title/tt19358836...
# url loaded
# Getting attributes for tt19358836
# Getting cast for tt19358836
# time to obtain tt19358836 with position 48227 was 2 seconds
# getting url with title/tt19359534...
# url loaded
# Getting attributes for tt19359534
# Getting cast for tt19359534
# time to obtain tt19359534 with position 48228 was 1 seconds
# getting url with title/tt19359570...
# url loaded
# Getting attributes for tt19359570
# Getting cast for tt19359570
# time to obtain tt19359570 with position 48229 was 1 seconds
# getting url with title/tt19359578...
# url loaded
# Getting attributes for tt19359578
# Getting cast for tt19359578
# time to obtain tt19359578 with position 48230 was 2 seconds
# getting url with title/tt19361138...
# url loaded
# Getting attributes for tt19361138
# Getting cast for tt19361138
# time to obtain tt19361138 with position 48231 was 2 seconds
# getting url with title/tt19363808...
# url loaded
# Getting attributes for tt19363808
# Getting cast for tt19363808
# time to obtain tt19363808 with position 48232 was 2 seconds
# getting url with title/tt19364214...
# url loaded
# Getting attributes for tt19364214
# Getting cast for tt19364214
# time to obtain tt19364214 with position 48233 was 2 seconds
# getting url with title/tt19364500...
# url loaded
# Getting attributes for tt19364500
# Getting cast for tt19364500
# time to obtain tt19364500 with position 48234 was 1 seconds
# getting url with title/tt19364624...
# url loaded
# Getting attributes for tt19364624
# Getting cast for tt19364624
# time to obtain tt19364624 with position 48235 was 1 seconds
# getting url with title/tt19364636...
# url loaded
# Getting attributes for tt19364636
# Getting cast for tt19364636
# time to obtain tt19364636 with position 48236 was 2 seconds
# getting url with title/tt19364210...
# url loaded
# Getting attributes for tt19364210
# Getting cast for tt19364210
# time to obtain tt19364210 with position 48237 was 2 seconds
# getting url with title/tt19364860...
# url loaded
# Getting attributes for tt19364860
# Getting cast for tt19364860
# time to obtain tt19364860 with position 48238 was 1 seconds
# getting url with title/tt19365268...
# url loaded
# Getting attributes for tt19365268
# Getting cast for tt19365268
# time to obtain tt19365268 with position 48239 was 2 seconds
# getting url with title/tt19365372...
# url loaded
# Getting attributes for tt19365372
# Getting cast for tt19365372
# time to obtain tt19365372 with position 48240 was 1 seconds
# getting url with title/tt19366090...
# url loaded
# Getting attributes for tt19366090
# Getting cast for tt19366090
# time to obtain tt19366090 with position 48241 was 1 seconds
# getting url with title/tt19368308...
# url loaded
# Getting attributes for tt19368308
# Getting cast for tt19368308
# time to obtain tt19368308 with position 48242 was 1 seconds
# getting url with title/tt19368520...
# url loaded
# Getting attributes for tt19368520
# Getting cast for tt19368520
# time to obtain tt19368520 with position 48243 was 2 seconds
# getting url with title/tt19368454...
# url loaded
# Getting attributes for tt19368454
# Getting cast for tt19368454
# time to obtain tt19368454 with position 48244 was 1 seconds
# getting url with title/tt19368982...
# url loaded
# Getting attributes for tt19368982
# Getting cast for tt19368982
# time to obtain tt19368982 with position 48245 was 2 seconds
# getting url with title/tt19370376...
# url loaded
# Getting attributes for tt19370376
# Getting cast for tt19370376
# time to obtain tt19370376 with position 48246 was 2 seconds
# getting url with title/tt19370428...
# url loaded
# Getting attributes for tt19370428
# Getting cast for tt19370428
# time to obtain tt19370428 with position 48247 was 1 seconds
# getting url with title/tt19370628...
# url loaded
# Getting attributes for tt19370628
# Getting cast for tt19370628
# time to obtain tt19370628 with position 48248 was 1 seconds
# getting url with title/tt19370736...
# url loaded
# Getting attributes for tt19370736
# Getting cast for tt19370736
# time to obtain tt19370736 with position 48249 was 2 seconds
# getting url with title/tt19368378...
# url loaded
# Getting attributes for tt19368378
# Getting cast for tt19368378
# time to obtain tt19368378 with position 48250 was 2 seconds
# getting url with title/tt19370178...
# url loaded
# Getting attributes for tt19370178
# Getting cast for tt19370178
# time to obtain tt19370178 with position 48251 was 2 seconds
# getting url with title/tt19370990...
# url loaded
# Getting attributes for tt19370990
# Getting cast for tt19370990
# time to obtain tt19370990 with position 48252 was 1 seconds
# getting url with title/tt19367306...
# url loaded
# Getting attributes for tt19367306
# Getting cast for tt19367306
# time to obtain tt19367306 with position 48253 was 3 seconds
# getting url with title/tt19369416...
# url loaded
# Getting attributes for tt19369416
# Getting cast for tt19369416
# time to obtain tt19369416 with position 48254 was 2 seconds
# getting url with title/tt19371408...
# url loaded
# Getting attributes for tt19371408
# Getting cast for tt19371408
# time to obtain tt19371408 with position 48255 was 1 seconds
# getting url with title/tt19371404...
# url loaded
# Getting attributes for tt19371404
# Getting cast for tt19371404
# time to obtain tt19371404 with position 48256 was 1 seconds
# getting url with title/tt19371450...
# url loaded
# Getting attributes for tt19371450
# Getting cast for tt19371450
# time to obtain tt19371450 with position 48257 was 2 seconds
# getting url with title/tt19372288...
# url loaded
# Getting attributes for tt19372288
# Getting cast for tt19372288
# time to obtain tt19372288 with position 48258 was 2 seconds
# getting url with title/tt19372834...
# url loaded
# Getting attributes for tt19372834
# Getting cast for tt19372834
# time to obtain tt19372834 with position 48259 was 1 seconds
# getting url with title/tt19373080...
# url loaded
# Getting attributes for tt19373080
# Getting cast for tt19373080
# time to obtain tt19373080 with position 48260 was 1 seconds
# getting url with title/tt19373142...
# url loaded
# Getting attributes for tt19373142
# Getting cast for tt19373142
# time to obtain tt19373142 with position 48261 was 1 seconds
# getting url with title/tt19373176...
# url loaded
# Getting attributes for tt19373176
# Getting cast for tt19373176
# time to obtain tt19373176 with position 48262 was 2 seconds
# getting url with title/tt19373666...
# url loaded
# Getting attributes for tt19373666
# Getting cast for tt19373666
# time to obtain tt19373666 with position 48263 was 2 seconds
# getting url with title/tt19375132...
# url loaded
# Getting attributes for tt19375132
# Getting cast for tt19375132
# time to obtain tt19375132 with position 48264 was 2 seconds
# getting url with title/tt19375532...
# url loaded
# Getting attributes for tt19375532
# Getting cast for tt19375532
# time to obtain tt19375532 with position 48265 was 2 seconds
# getting url with title/tt19379262...
# url loaded
# Getting attributes for tt19379262
# Getting cast for tt19379262
# time to obtain tt19379262 with position 48266 was 1 seconds
# getting url with title/tt19380296...
# url loaded
# Getting attributes for tt19380296
# Getting cast for tt19380296
# time to obtain tt19380296 with position 48267 was 1 seconds
# getting url with title/tt19380288...
# url loaded
# Getting attributes for tt19380288
# Getting cast for tt19380288
# time to obtain tt19380288 with position 48268 was 1 seconds
# getting url with title/tt19381172...
# url loaded
# Getting attributes for tt19381172
# Getting cast for tt19381172
# time to obtain tt19381172 with position 48269 was 2 seconds
# getting url with title/tt19381192...
# url loaded
# Getting attributes for tt19381192
# Getting cast for tt19381192
# time to obtain tt19381192 with position 48270 was 2 seconds
# getting url with title/tt19381266...
# url loaded
# Getting attributes for tt19381266
# Getting cast for tt19381266
# time to obtain tt19381266 with position 48271 was 1 seconds
# getting url with title/tt19380514...
# url loaded
# Getting attributes for tt19380514
# Getting cast for tt19380514
# time to obtain tt19380514 with position 48272 was 1 seconds
# getting url with title/tt19381718...
# url loaded
# Getting attributes for tt19381718
# Getting cast for tt19381718
# time to obtain tt19381718 with position 48273 was 1 seconds
# getting url with title/tt19382164...
# url loaded
# Getting attributes for tt19382164
# Getting cast for tt19382164
# time to obtain tt19382164 with position 48274 was 1 seconds
# getting url with title/tt19382252...
# url loaded
# Getting attributes for tt19382252
# Getting cast for tt19382252
# time to obtain tt19382252 with position 48275 was 1 seconds
# getting url with title/tt19372436...
# url loaded
# Getting attributes for tt19372436
# Getting cast for tt19372436
# time to obtain tt19372436 with position 48276 was 2 seconds
# getting url with title/tt19379366...
# url loaded
# Getting attributes for tt19379366
# Getting cast for tt19379366
# time to obtain tt19379366 with position 48277 was 1 seconds
# getting url with title/tt19373576...
# url loaded
# Getting attributes for tt19373576
# Getting cast for tt19373576
# time to obtain tt19373576 with position 48278 was 5 seconds
# getting url with title/tt19371276...
# url loaded
# Getting attributes for tt19371276
# Getting cast for tt19371276
# time to obtain tt19371276 with position 48279 was 3 seconds
# getting url with title/tt19382402...
# url loaded
# Getting attributes for tt19382402
# error obtaining name for id tt19382402
# Getting cast for tt19382402
# time to obtain tt19382402 with position 48280 was 1 seconds
# getting url with title/tt19382686...
# url loaded
# Getting attributes for tt19382686
# Getting cast for tt19382686
# time to obtain tt19382686 with position 48281 was 1 seconds
# getting url with title/tt19383068...
# url loaded
# Getting attributes for tt19383068
# Getting cast for tt19383068
# time to obtain tt19383068 with position 48282 was 2 seconds
# getting url with title/tt19383092...
# url loaded
# Getting attributes for tt19383092
# Getting cast for tt19383092
# time to obtain tt19383092 with position 48283 was 2 seconds
# getting url with title/tt19383062...
# url loaded
# Getting attributes for tt19383062
# Getting cast for tt19383062
# time to obtain tt19383062 with position 48284 was 1 seconds
# getting url with title/tt19383086...
# url loaded
# Getting attributes for tt19383086
# Getting cast for tt19383086
# time to obtain tt19383086 with position 48285 was 1 seconds
# getting url with title/tt19383074...
# url loaded
# Getting attributes for tt19383074
# Getting cast for tt19383074
# time to obtain tt19383074 with position 48286 was 1 seconds
# getting url with title/tt19383282...
# url loaded
# Getting attributes for tt19383282
# Getting cast for tt19383282
# time to obtain tt19383282 with position 48287 was 1 seconds
# getting url with title/tt19383368...
# url loaded
# Getting attributes for tt19383368
# Getting cast for tt19383368
# time to obtain tt19383368 with position 48288 was 2 seconds
# getting url with title/tt19383726...
# url loaded
# Getting attributes for tt19383726
# Getting cast for tt19383726
# time to obtain tt19383726 with position 48289 was 2 seconds
# getting url with title/tt19383732...
# url loaded
# Getting attributes for tt19383732
# Getting cast for tt19383732
# time to obtain tt19383732 with position 48290 was 2 seconds
# getting url with title/tt19385152...
# url loaded
# Getting attributes for tt19385152
# Getting cast for tt19385152
# time to obtain tt19385152 with position 48291 was 2 seconds
# getting url with title/tt19385526...
# url loaded
# Getting attributes for tt19385526
# error obtaining name for id tt19385526
# Getting cast for tt19385526
# time to obtain tt19385526 with position 48292 was 60 seconds
# getting url with title/tt19386618...
# url loaded
# Getting attributes for tt19386618
# Getting cast for tt19386618
# time to obtain tt19386618 with position 48293 was 2 seconds
# getting url with title/tt19386966...
# url loaded
# Getting attributes for tt19386966
# Getting cast for tt19386966
# time to obtain tt19386966 with position 48294 was 1 seconds
# getting url with title/tt19387338...
# url loaded
# Getting attributes for tt19387338
# Getting cast for tt19387338
# time to obtain tt19387338 with position 48295 was 2 seconds
# getting url with title/tt19387384...
# url loaded
# Getting attributes for tt19387384
# Getting cast for tt19387384
# time to obtain tt19387384 with position 48296 was 1 seconds
# getting url with title/tt19387552...
# url loaded
# Getting attributes for tt19387552
# Getting cast for tt19387552
# time to obtain tt19387552 with position 48297 was 1 seconds
# getting url with title/tt19387590...
# url loaded
# Getting attributes for tt19387590
# Getting cast for tt19387590
# time to obtain tt19387590 with position 48298 was 2 seconds
# getting url with title/tt19387660...
# url loaded
# Getting attributes for tt19387660
# Getting cast for tt19387660
# time to obtain tt19387660 with position 48299 was 1 seconds
# getting url with title/tt19387704...
# url loaded
# Getting attributes for tt19387704
# Getting cast for tt19387704
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt19387704 with position 48300 was 15 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    3.974
# dtype: float64
