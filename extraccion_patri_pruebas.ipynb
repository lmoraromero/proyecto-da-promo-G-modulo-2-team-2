# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 3
initial_counter = 18500
incremental = 3000

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers" or nombre == "Writer": 
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("union_peliculas.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/rebe_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/rebe_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt0851207...
# url loaded
# Getting attributes for tt0851207
# Getting cast for tt0851207
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt0851207 with position 18500 was 11 seconds
# getting url with title/tt0853262...
# url loaded
# Getting attributes for tt0853262
# Getting cast for tt0853262
# time to obtain tt0853262 with position 18501 was 1 seconds
# getting url with title/tt0854158...
# url loaded
# Getting attributes for tt0854158
# Getting cast for tt0854158
# time to obtain tt0854158 with position 18502 was 1 seconds
# getting url with title/tt0853232...
# url loaded
# Getting attributes for tt0853232
# Getting cast for tt0853232
# time to obtain tt0853232 with position 18503 was 1 seconds
# getting url with title/tt0854126...
# url loaded
# Getting attributes for tt0854126
# Getting cast for tt0854126
# time to obtain tt0854126 with position 18504 was 2 seconds
# getting url with title/tt0857314...
# url loaded
# Getting attributes for tt0857314
# Getting cast for tt0857314
# time to obtain tt0857314 with position 18505 was 2 seconds
# getting url with title/tt0861697...
# url loaded
# Getting attributes for tt0861697
# Getting cast for tt0861697
# time to obtain tt0861697 with position 18506 was 2 seconds
# getting url with title/tt0861737...
# url loaded
# Getting attributes for tt0861737
# Getting cast for tt0861737
# time to obtain tt0861737 with position 18507 was 2 seconds
# getting url with title/tt0864337...
# url loaded
# Getting attributes for tt0864337
# Getting cast for tt0864337
# time to obtain tt0864337 with position 18508 was 2 seconds
# getting url with title/tt0869028...
# url loaded
# Getting attributes for tt0869028
# Getting cast for tt0869028
# time to obtain tt0869028 with position 18509 was 1 seconds
# getting url with title/tt0870017...
# url loaded
# Getting attributes for tt0870017
# Getting cast for tt0870017
# time to obtain tt0870017 with position 18510 was 2 seconds
# getting url with title/tt0874291...
# url loaded
# Getting attributes for tt0874291
# Getting cast for tt0874291
# time to obtain tt0874291 with position 18511 was 2 seconds
# getting url with title/tt0877483...
# url loaded
# Getting attributes for tt0877483
# Getting cast for tt0877483
# time to obtain tt0877483 with position 18512 was 1 seconds
# getting url with title/tt0879798...
# url loaded
# Getting attributes for tt0879798
# Getting cast for tt0879798
# time to obtain tt0879798 with position 18513 was 1 seconds
# getting url with title/tt0880452...
# url loaded
# Getting attributes for tt0880452
# Getting cast for tt0880452
# time to obtain tt0880452 with position 18514 was 2 seconds
# getting url with title/tt0886536...
# url loaded
# Getting attributes for tt0886536
# Getting cast for tt0886536
# time to obtain tt0886536 with position 18515 was 1 seconds
# getting url with title/tt0889167...
# url loaded
# Getting attributes for tt0889167
# Getting cast for tt0889167
# time to obtain tt0889167 with position 18516 was 2 seconds
# getting url with title/tt0887258...
# url loaded
# Getting attributes for tt0887258
# Getting cast for tt0887258
# time to obtain tt0887258 with position 18517 was 3 seconds
# getting url with title/tt0898920...
# url loaded
# Getting attributes for tt0898920
# Getting cast for tt0898920
# time to obtain tt0898920 with position 18518 was 2 seconds
# getting url with title/tt0902996...
# url loaded
# Getting attributes for tt0902996
# Getting cast for tt0902996
# time to obtain tt0902996 with position 18519 was 4 seconds
# getting url with title/tt0902988...
# url loaded
# Getting attributes for tt0902988
# Getting cast for tt0902988
# time to obtain tt0902988 with position 18520 was 2 seconds
# getting url with title/tt0902992...
# url loaded
# Getting attributes for tt0902992
# Getting cast for tt0902992
# time to obtain tt0902992 with position 18521 was 2 seconds
# getting url with title/tt0907665...
# url loaded
# Getting attributes for tt0907665
# Getting cast for tt0907665
# time to obtain tt0907665 with position 18522 was 4 seconds
# getting url with title/tt0920471...
# url loaded
# Getting attributes for tt0920471
# Getting cast for tt0920471
# time to obtain tt0920471 with position 18523 was 2 seconds
# getting url with title/tt0923990...
# url loaded
# Getting attributes for tt0923990
# Getting cast for tt0923990
# time to obtain tt0923990 with position 18524 was 3 seconds
# getting url with title/tt0926166...
# url loaded
# Getting attributes for tt0926166
# Getting cast for tt0926166
# time to obtain tt0926166 with position 18525 was 1 seconds
# getting url with title/tt0927641...
# url loaded
# Getting attributes for tt0927641
# Getting cast for tt0927641
# time to obtain tt0927641 with position 18526 was 1 seconds
# getting url with title/tt0933031...
# url loaded
# Getting attributes for tt0933031
# Getting cast for tt0933031
# time to obtain tt0933031 with position 18527 was 2 seconds
# getting url with title/tt0939653...
# url loaded
# Getting attributes for tt0939653
# Getting cast for tt0939653
# time to obtain tt0939653 with position 18528 was 2 seconds
# getting url with title/tt0945401...
# url loaded
# Getting attributes for tt0945401
# Getting cast for tt0945401
# time to obtain tt0945401 with position 18529 was 2 seconds
# getting url with title/tt0951276...
# url loaded
# Getting attributes for tt0951276
# Getting cast for tt0951276
# time to obtain tt0951276 with position 18530 was 2 seconds
# getting url with title/tt0952675...
# url loaded
# Getting attributes for tt0952675
# Getting cast for tt0952675
# time to obtain tt0952675 with position 18531 was 2 seconds
# getting url with title/tt0958891...
# url loaded
# Getting attributes for tt0958891
# Getting cast for tt0958891
# time to obtain tt0958891 with position 18532 was 3 seconds
# getting url with title/tt0960726...
# url loaded
# Getting attributes for tt0960726
# Getting cast for tt0960726
# time to obtain tt0960726 with position 18533 was 4 seconds
# getting url with title/tt0984974...
# url loaded
# Getting attributes for tt0984974
# Getting cast for tt0984974
# time to obtain tt0984974 with position 18534 was 2 seconds
# getting url with title/tt0995853...
# url loaded
# Getting attributes for tt0995853
# Getting cast for tt0995853
# time to obtain tt0995853 with position 18535 was 1 seconds
# getting url with title/tt0994883...
# url loaded
# Getting attributes for tt0994883
# Getting cast for tt0994883
# time to obtain tt0994883 with position 18536 was 1 seconds
# getting url with title/tt0999919...
# url loaded
# Getting attributes for tt0999919
# Getting cast for tt0999919
# time to obtain tt0999919 with position 18537 was 2 seconds
# getting url with title/tt1010053...
# url loaded
# Getting attributes for tt1010053
# Getting cast for tt1010053
# time to obtain tt1010053 with position 18538 was 3 seconds
# getting url with title/tt1010434...
# url loaded
# Getting attributes for tt1010434
# Getting cast for tt1010434
# time to obtain tt1010434 with position 18539 was 10 seconds
# getting url with title/tt10145090...
# url loaded
# Getting attributes for tt10145090
# Getting cast for tt10145090
# time to obtain tt10145090 with position 18540 was 2 seconds
# getting url with title/tt10145284...
# url loaded
# Getting attributes for tt10145284
# Getting cast for tt10145284
# time to obtain tt10145284 with position 18541 was 1 seconds
# getting url with title/tt1016009...
# url loaded
# Getting attributes for tt1016009
# Getting cast for tt1016009
# time to obtain tt1016009 with position 18542 was 2 seconds
# getting url with title/tt1016287...
# url loaded
# Getting attributes for tt1016287
# Getting cast for tt1016287
# time to obtain tt1016287 with position 18543 was 2 seconds
# getting url with title/tt1018868...
# url loaded
# Getting attributes for tt1018868
# Getting cast for tt1018868
# time to obtain tt1018868 with position 18544 was 2 seconds
# getting url with title/tt10225440...
# url loaded
# Getting attributes for tt10225440
# Getting cast for tt10225440
# time to obtain tt10225440 with position 18545 was 1 seconds
# getting url with title/tt10241298...
# url loaded
# Getting attributes for tt10241298
# Getting cast for tt10241298
# time to obtain tt10241298 with position 18546 was 1 seconds
# getting url with title/tt10244032...
# url loaded
# Getting attributes for tt10244032
# Getting cast for tt10244032
# time to obtain tt10244032 with position 18547 was 1 seconds
# getting url with title/tt1024718...
# url loaded
# Getting attributes for tt1024718
# Getting cast for tt1024718
# time to obtain tt1024718 with position 18548 was 1 seconds
# getting url with title/tt1034437...
# url loaded
# Getting attributes for tt1034437
# Getting cast for tt1034437
# time to obtain tt1034437 with position 18549 was 1 seconds
# getting url with title/tt10360918...
# url loaded
# Getting attributes for tt10360918
# Getting cast for tt10360918
# time to obtain tt10360918 with position 18550 was 3 seconds
# getting url with title/tt10497582...
# url loaded
# Getting attributes for tt10497582
# Getting cast for tt10497582
# time to obtain tt10497582 with position 18551 was 1 seconds
# getting url with title/tt10559248...
# url loaded
# Getting attributes for tt10559248
# Getting cast for tt10559248
# time to obtain tt10559248 with position 18552 was 3 seconds
# getting url with title/tt10613526...
# url loaded
# Getting attributes for tt10613526
# Getting cast for tt10613526
# time to obtain tt10613526 with position 18553 was 1 seconds
# getting url with title/tt10771476...
# url loaded
# Getting attributes for tt10771476
# Getting cast for tt10771476
# time to obtain tt10771476 with position 18554 was 1 seconds
# getting url with title/tt1078573...
# url loaded
# Getting attributes for tt1078573
# Getting cast for tt1078573
# time to obtain tt1078573 with position 18555 was 2 seconds
# getting url with title/tt1085881...
# url loaded
# Getting attributes for tt1085881
# Getting cast for tt1085881
# time to obtain tt1085881 with position 18556 was 1 seconds
# getting url with title/tt1087901...
# url loaded
# Getting attributes for tt1087901
# Getting cast for tt1087901
# time to obtain tt1087901 with position 18557 was 2 seconds
# getting url with title/tt10913892...
# url loaded
# Getting attributes for tt10913892
# Getting cast for tt10913892
# time to obtain tt10913892 with position 18558 was 1 seconds
# getting url with title/tt10921456...
# url loaded
# Getting attributes for tt10921456
# Getting cast for tt10921456
# time to obtain tt10921456 with position 18559 was 2 seconds
# getting url with title/tt1095197...
# url loaded
# Getting attributes for tt1095197
# Getting cast for tt1095197
# time to obtain tt1095197 with position 18560 was 1 seconds
# getting url with title/tt10955528...
# url loaded
# Getting attributes for tt10955528
# Getting cast for tt10955528
# time to obtain tt10955528 with position 18561 was 1 seconds
# getting url with title/tt10962900...
# url loaded
# Getting attributes for tt10962900
# Getting cast for tt10962900
# time to obtain tt10962900 with position 18562 was 1 seconds
# getting url with title/tt1097008...
# url loaded
# Getting attributes for tt1097008
# Getting cast for tt1097008
# time to obtain tt1097008 with position 18563 was 1 seconds
# getting url with title/tt1100126...
# url loaded
# Getting attributes for tt1100126
# Getting cast for tt1100126
# time to obtain tt1100126 with position 18564 was 1 seconds
# getting url with title/tt11008216...
# url loaded
# Getting attributes for tt11008216
# Getting cast for tt11008216
# time to obtain tt11008216 with position 18565 was 1 seconds
# getting url with title/tt1104000...
# url loaded
# Getting attributes for tt1104000
# Getting cast for tt1104000
# time to obtain tt1104000 with position 18566 was 2 seconds
# getting url with title/tt1111373...
# url loaded
# Getting attributes for tt1111373
# Getting cast for tt1111373
# time to obtain tt1111373 with position 18567 was 1 seconds
# getting url with title/tt1112124...
# url loaded
# Getting attributes for tt1112124
# Getting cast for tt1112124
# time to obtain tt1112124 with position 18568 was 2 seconds
# getting url with title/tt1111834...
# url loaded
# Getting attributes for tt1111834
# Getting cast for tt1111834
# time to obtain tt1111834 with position 18569 was 2 seconds
# getting url with title/tt11202182...
# url loaded
# Getting attributes for tt11202182
# Getting cast for tt11202182
# time to obtain tt11202182 with position 18570 was 1 seconds
# getting url with title/tt11219390...
# url loaded
# Getting attributes for tt11219390
# Getting cast for tt11219390
# time to obtain tt11219390 with position 18571 was 2 seconds
# getting url with title/tt1126501...
# url loaded
# Getting attributes for tt1126501
# Getting cast for tt1126501
# time to obtain tt1126501 with position 18572 was 1 seconds
# getting url with title/tt1127184...
# url loaded
# Getting attributes for tt1127184
# Getting cast for tt1127184
# time to obtain tt1127184 with position 18573 was 4 seconds
# getting url with title/tt11269416...
# url loaded
# Getting attributes for tt11269416
# Getting cast for tt11269416
# time to obtain tt11269416 with position 18574 was 1 seconds
# getting url with title/tt11279298...
# url loaded
# Getting attributes for tt11279298
# Getting cast for tt11279298
# time to obtain tt11279298 with position 18575 was 2 seconds
# getting url with title/tt11345304...
# url loaded
# Getting attributes for tt11345304
# Getting cast for tt11345304
# time to obtain tt11345304 with position 18576 was 1 seconds
# getting url with title/tt11350406...
# url loaded
# Getting attributes for tt11350406
# Getting cast for tt11350406
# time to obtain tt11350406 with position 18577 was 2 seconds
# getting url with title/tt1135513...
# url loaded
# Getting attributes for tt1135513
# Getting cast for tt1135513
# time to obtain tt1135513 with position 18578 was 1 seconds
# getting url with title/tt11357148...
# url loaded
# Getting attributes for tt11357148
# Getting cast for tt11357148
# time to obtain tt11357148 with position 18579 was 3 seconds
# getting url with title/tt1139105...
# url loaded
# Getting attributes for tt1139105
# Getting cast for tt1139105
# time to obtain tt1139105 with position 18580 was 1 seconds
# getting url with title/tt1144504...
# url loaded
# Getting attributes for tt1144504
# Getting cast for tt1144504
# time to obtain tt1144504 with position 18581 was 3 seconds
# getting url with title/tt11460098...
# url loaded
# Getting attributes for tt11460098
# Getting cast for tt11460098
# time to obtain tt11460098 with position 18582 was 3 seconds
# getting url with title/tt11460132...
# url loaded
# Getting attributes for tt11460132
# Getting cast for tt11460132
# time to obtain tt11460132 with position 18583 was 4 seconds
# getting url with title/tt1159683...
# url loaded
# Getting attributes for tt1159683
# Getting cast for tt1159683
# time to obtain tt1159683 with position 18584 was 2 seconds
# getting url with title/tt1159638...
# url loaded
# Getting attributes for tt1159638
# Getting cast for tt1159638
# time to obtain tt1159638 with position 18585 was 2 seconds
# getting url with title/tt11640062...
# url loaded
# Getting attributes for tt11640062
# Getting cast for tt11640062
# time to obtain tt11640062 with position 18586 was 3 seconds
# getting url with title/tt1166099...
# url loaded
# Getting attributes for tt1166099
# Getting cast for tt1166099
# time to obtain tt1166099 with position 18587 was 3 seconds
# getting url with title/tt11729598...
# url loaded
# Getting attributes for tt11729598
# Getting cast for tt11729598
# time to obtain tt11729598 with position 18588 was 1 seconds
# getting url with title/tt1173495...
# url loaded
# Getting attributes for tt1173495
# Getting cast for tt1173495
# time to obtain tt1173495 with position 18589 was 3 seconds
# getting url with title/tt1173942...
# url loaded
# Getting attributes for tt1173942
# Getting cast for tt1173942
# time to obtain tt1173942 with position 18590 was 2 seconds
# getting url with title/tt11749424...
# url loaded
# Getting attributes for tt11749424
# Getting cast for tt11749424
# time to obtain tt11749424 with position 18591 was 1 seconds
# getting url with title/tt11795138...
# url loaded
# Getting attributes for tt11795138
# Getting cast for tt11795138
# time to obtain tt11795138 with position 18592 was 3 seconds
# getting url with title/tt1183161...
# url loaded
# Getting attributes for tt1183161
# Getting cast for tt1183161
# time to obtain tt1183161 with position 18593 was 4 seconds
# getting url with title/tt11848424...
# url loaded
# Getting attributes for tt11848424
# Getting cast for tt11848424
# time to obtain tt11848424 with position 18594 was 2 seconds
# getting url with title/tt11868106...
# url loaded
# Getting attributes for tt11868106
# Getting cast for tt11868106
# time to obtain tt11868106 with position 18595 was 2 seconds
# getting url with title/tt1193539...
# url loaded
# Getting attributes for tt1193539
# Getting cast for tt1193539
# time to obtain tt1193539 with position 18596 was 3 seconds
# getting url with title/tt1198212...
# url loaded
# Getting attributes for tt1198212
# Getting cast for tt1198212
# time to obtain tt1198212 with position 18597 was 3 seconds
# getting url with title/tt1205584...
# url loaded
# Getting attributes for tt1205584
# Getting cast for tt1205584
# time to obtain tt1205584 with position 18598 was 11 seconds
# getting url with title/tt12251068...
# url loaded
# Getting attributes for tt12251068
# Getting cast for tt12251068
# time to obtain tt12251068 with position 18599 was 7 seconds
# getting url with title/tt1233496...
# url loaded
# Getting attributes for tt1233496
# Getting cast for tt1233496
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt1233496 with position 18600 was 21 seconds
# getting url with title/tt1252288...
# url loaded
# Getting attributes for tt1252288
# Getting cast for tt1252288
# time to obtain tt1252288 with position 18601 was 2 seconds
# getting url with title/tt1252547...
# url loaded
# Getting attributes for tt1252547
# Getting cast for tt1252547
# time to obtain tt1252547 with position 18602 was 1 seconds
# getting url with title/tt12526344...
# url loaded
# Getting attributes for tt12526344
# Getting cast for tt12526344
# time to obtain tt12526344 with position 18603 was 2 seconds
# getting url with title/tt1254770...
# url loaded
# Getting attributes for tt1254770
# Getting cast for tt1254770
# time to obtain tt1254770 with position 18604 was 2 seconds
# getting url with title/tt12623298...
# url loaded
# Getting attributes for tt12623298
# Getting cast for tt12623298
# time to obtain tt12623298 with position 18605 was 1 seconds
# getting url with title/tt12633476...
# url loaded
# Getting attributes for tt12633476
# Getting cast for tt12633476
# time to obtain tt12633476 with position 18606 was 1 seconds
# getting url with title/tt1263691...
# url loaded
# Getting attributes for tt1263691
# Getting cast for tt1263691
# time to obtain tt1263691 with position 18607 was 2 seconds
# getting url with title/tt12674290...
# url loaded
# Getting attributes for tt12674290
# Getting cast for tt12674290
# time to obtain tt12674290 with position 18608 was 1 seconds
# getting url with title/tt12694772...
# url loaded
# Getting attributes for tt12694772
# Getting cast for tt12694772
# time to obtain tt12694772 with position 18609 was 2 seconds
# getting url with title/tt12711246...
# url loaded
# Getting attributes for tt12711246
# Getting cast for tt12711246
# time to obtain tt12711246 with position 18610 was 1 seconds
# getting url with title/tt1278436...
# url loaded
# Getting attributes for tt1278436
# Getting cast for tt1278436
# time to obtain tt1278436 with position 18611 was 1 seconds
# getting url with title/tt1279171...
# url loaded
# Getting attributes for tt1279171
# Getting cast for tt1279171
# time to obtain tt1279171 with position 18612 was 2 seconds
# getting url with title/tt1298761...
# url loaded
# Getting attributes for tt1298761
# error obtaining name for id tt1298761
# Getting cast for tt1298761
# time to obtain tt1298761 with position 18613 was 60 seconds
# getting url with title/tt13033918...
# url loaded
# Getting attributes for tt13033918
# Getting cast for tt13033918
# time to obtain tt13033918 with position 18614 was 1 seconds
# getting url with title/tt13038406...
# url loaded
# Getting attributes for tt13038406
# Getting cast for tt13038406
# time to obtain tt13038406 with position 18615 was 1 seconds
# getting url with title/tt13038438...
# url loaded
# Getting attributes for tt13038438
# Getting cast for tt13038438
# time to obtain tt13038438 with position 18616 was 1 seconds
# getting url with title/tt13039190...
# url loaded
# Getting attributes for tt13039190
# Getting cast for tt13039190
# time to obtain tt13039190 with position 18617 was 1 seconds
# getting url with title/tt13038756...
# url loaded
# Getting attributes for tt13038756
# Getting cast for tt13038756
# time to obtain tt13038756 with position 18618 was 1 seconds
# getting url with title/tt13045490...
# url loaded
# Getting attributes for tt13045490
# Getting cast for tt13045490
# time to obtain tt13045490 with position 18619 was 1 seconds
# getting url with title/tt1309468...
# url loaded
# Getting attributes for tt1309468
# Getting cast for tt1309468
# time to obtain tt1309468 with position 18620 was 2 seconds
# getting url with title/tt1313082...
# url loaded
# Getting attributes for tt1313082
# Getting cast for tt1313082
# time to obtain tt1313082 with position 18621 was 1 seconds
# getting url with title/tt13273230...
# url loaded
# Getting attributes for tt13273230
# Getting cast for tt13273230
# time to obtain tt13273230 with position 18622 was 1 seconds
# getting url with title/tt1355186...
# url loaded
# Getting attributes for tt1355186
# Getting cast for tt1355186
# time to obtain tt1355186 with position 18623 was 1 seconds
# getting url with title/tt1356530...
# url loaded
# Getting attributes for tt1356530
# Getting cast for tt1356530
# time to obtain tt1356530 with position 18624 was 1 seconds
# getting url with title/tt1356539...
# url loaded
# Getting attributes for tt1356539
# Getting cast for tt1356539
# time to obtain tt1356539 with position 18625 was 1 seconds
# getting url with title/tt13577592...
# url loaded
# Getting attributes for tt13577592
# Getting cast for tt13577592
# time to obtain tt13577592 with position 18626 was 2 seconds
# getting url with title/tt1359570...
# url loaded
# Getting attributes for tt1359570
# Getting cast for tt1359570
# time to obtain tt1359570 with position 18627 was 1 seconds
# getting url with title/tt1362109...
# url loaded
# Getting attributes for tt1362109
# Getting cast for tt1362109
# time to obtain tt1362109 with position 18628 was 1 seconds
# getting url with title/tt1365013...
# url loaded
# Getting attributes for tt1365013
# Getting cast for tt1365013
# time to obtain tt1365013 with position 18629 was 1 seconds
# getting url with title/tt1366254...
# url loaded
# Getting attributes for tt1366254
# Getting cast for tt1366254
# time to obtain tt1366254 with position 18630 was 2 seconds
# getting url with title/tt1366427...
# url loaded
# Getting attributes for tt1366427
# Getting cast for tt1366427
# time to obtain tt1366427 with position 18631 was 2 seconds
# getting url with title/tt1366649...
# url loaded
# Getting attributes for tt1366649
# Getting cast for tt1366649
# time to obtain tt1366649 with position 18632 was 2 seconds
# getting url with title/tt1366877...
# url loaded
# Getting attributes for tt1366877
# Getting cast for tt1366877
# time to obtain tt1366877 with position 18633 was 1 seconds
# getting url with title/tt1370145...
# url loaded
# Getting attributes for tt1370145
# Getting cast for tt1370145
# time to obtain tt1370145 with position 18634 was 1 seconds
# getting url with title/tt1377207...
# url loaded
# Getting attributes for tt1377207
# Getting cast for tt1377207
# time to obtain tt1377207 with position 18635 was 1 seconds
# getting url with title/tt13767794...
# url loaded
# Getting attributes for tt13767794
# Getting cast for tt13767794
# time to obtain tt13767794 with position 18636 was 1 seconds
# getting url with title/tt1377480...
# url loaded
# Getting attributes for tt1377480
# Getting cast for tt1377480
# time to obtain tt1377480 with position 18637 was 1 seconds
# getting url with title/tt1378365...
# url loaded
# Getting attributes for tt1378365
# Getting cast for tt1378365
# time to obtain tt1378365 with position 18638 was 2 seconds
# getting url with title/tt13814910...
# url loaded
# Getting attributes for tt13814910
# Getting cast for tt13814910
# time to obtain tt13814910 with position 18639 was 2 seconds
# getting url with title/tt13816194...
# url loaded
# Getting attributes for tt13816194
# Getting cast for tt13816194
# time to obtain tt13816194 with position 18640 was 1 seconds
# getting url with title/tt1389117...
# url loaded
# Getting attributes for tt1389117
# Getting cast for tt1389117
# time to obtain tt1389117 with position 18641 was 2 seconds
# getting url with title/tt1391864...
# url loaded
# Getting attributes for tt1391864
# Getting cast for tt1391864
# time to obtain tt1391864 with position 18642 was 1 seconds
# getting url with title/tt14064788...
# url loaded
# Getting attributes for tt14064788
# Getting cast for tt14064788
# time to obtain tt14064788 with position 18643 was 1 seconds
# getting url with title/tt1413550...
# url loaded
# Getting attributes for tt1413550
# Getting cast for tt1413550
# time to obtain tt1413550 with position 18644 was 2 seconds
# getting url with title/tt14137410...
# url loaded
# Getting attributes for tt14137410
# Getting cast for tt14137410
# time to obtain tt14137410 with position 18645 was 2 seconds
# getting url with title/tt1414098...
# url loaded
# Getting attributes for tt1414098
# Getting cast for tt1414098
# time to obtain tt1414098 with position 18646 was 2 seconds
# getting url with title/tt1414158...
# url loaded
# Getting attributes for tt1414158
# Getting cast for tt1414158
# time to obtain tt1414158 with position 18647 was 1 seconds
# getting url with title/tt1414862...
# url loaded
# Getting attributes for tt1414862
# Getting cast for tt1414862
# time to obtain tt1414862 with position 18648 was 2 seconds
# getting url with title/tt1418919...
# url loaded
# Getting attributes for tt1418919
# Getting cast for tt1418919
# time to obtain tt1418919 with position 18649 was 2 seconds
# getting url with title/tt1423424...
# url loaded
# Getting attributes for tt1423424
# Getting cast for tt1423424
# time to obtain tt1423424 with position 18650 was 2 seconds
# getting url with title/tt1423404...
# url loaded
# Getting attributes for tt1423404
# Getting cast for tt1423404
# time to obtain tt1423404 with position 18651 was 2 seconds
# getting url with title/tt1424391...
# url loaded
# Getting attributes for tt1424391
# Getting cast for tt1424391
# time to obtain tt1424391 with position 18652 was 3 seconds
# getting url with title/tt1424355...
# url loaded
# Getting attributes for tt1424355
# error obtaining name for id tt1424355
# Getting cast for tt1424355
# time to obtain tt1424355 with position 18653 was 60 seconds
# getting url with title/tt1424692...
# url loaded
# Getting attributes for tt1424692
# Getting cast for tt1424692
# time to obtain tt1424692 with position 18654 was 1 seconds
# getting url with title/tt1424522...
# url loaded
# Getting attributes for tt1424522
# Getting cast for tt1424522
# time to obtain tt1424522 with position 18655 was 1 seconds
# getting url with title/tt1424534...
# url loaded
# Getting attributes for tt1424534
# Getting cast for tt1424534
# time to obtain tt1424534 with position 18656 was 2 seconds
# getting url with title/tt1429067...
# url loaded
# Getting attributes for tt1429067
# Getting cast for tt1429067
# time to obtain tt1429067 with position 18657 was 2 seconds
# getting url with title/tt1429020...
# url loaded
# Getting attributes for tt1429020
# Getting cast for tt1429020
# time to obtain tt1429020 with position 18658 was 1 seconds
# getting url with title/tt1429071...
# url loaded
# Getting attributes for tt1429071
# Getting cast for tt1429071
# time to obtain tt1429071 with position 18659 was 1 seconds
# getting url with title/tt1429042...
# url loaded
# Getting attributes for tt1429042
# Getting cast for tt1429042
# time to obtain tt1429042 with position 18660 was 2 seconds
# getting url with title/tt1429140...
# url loaded
# Getting attributes for tt1429140
# Getting cast for tt1429140
# time to obtain tt1429140 with position 18661 was 1 seconds
# getting url with title/tt1429142...
# url loaded
# Getting attributes for tt1429142
# Getting cast for tt1429142
# time to obtain tt1429142 with position 18662 was 2 seconds
# getting url with title/tt1429118...
# url loaded
# Getting attributes for tt1429118
# Getting cast for tt1429118
# time to obtain tt1429118 with position 18663 was 2 seconds
# getting url with title/tt1429082...
# url loaded
# Getting attributes for tt1429082
# Getting cast for tt1429082
# time to obtain tt1429082 with position 18664 was 1 seconds
# getting url with title/tt14316664...
# url loaded
# Getting attributes for tt14316664
# Getting cast for tt14316664
# time to obtain tt14316664 with position 18665 was 1 seconds
# getting url with title/tt14316574...
# url loaded
# Getting attributes for tt14316574
# Getting cast for tt14316574
# time to obtain tt14316574 with position 18666 was 1 seconds
# getting url with title/tt1432041...
# url loaded
# Getting attributes for tt1432041
# Getting cast for tt1432041
# time to obtain tt1432041 with position 18667 was 1 seconds
# getting url with title/tt1432027...
# url loaded
# Getting attributes for tt1432027
# Getting cast for tt1432027
# time to obtain tt1432027 with position 18668 was 1 seconds
# getting url with title/tt1432224...
# url loaded
# Getting attributes for tt1432224
# Getting cast for tt1432224
# time to obtain tt1432224 with position 18669 was 2 seconds
# getting url with title/tt1432236...
# url loaded
# Getting attributes for tt1432236
# Getting cast for tt1432236
# time to obtain tt1432236 with position 18670 was 3 seconds
# getting url with title/tt1433014...
# url loaded
# Getting attributes for tt1433014
# Getting cast for tt1433014
# time to obtain tt1433014 with position 18671 was 2 seconds
# getting url with title/tt1433143...
# url loaded
# Getting attributes for tt1433143
# Getting cast for tt1433143
# time to obtain tt1433143 with position 18672 was 1 seconds
# getting url with title/tt1433187...
# url loaded
# Getting attributes for tt1433187
# Getting cast for tt1433187
# time to obtain tt1433187 with position 18673 was 1 seconds
# getting url with title/tt1436307...
# url loaded
# Getting attributes for tt1436307
# Getting cast for tt1436307
# time to obtain tt1436307 with position 18674 was 2 seconds
# getting url with title/tt1437281...
# url loaded
# Getting attributes for tt1437281
# Getting cast for tt1437281
# time to obtain tt1437281 with position 18675 was 1 seconds
# getting url with title/tt1437391...
# url loaded
# Getting attributes for tt1437391
# Getting cast for tt1437391
# time to obtain tt1437391 with position 18676 was 1 seconds
# getting url with title/tt1437293...
# url loaded
# Getting attributes for tt1437293
# Getting cast for tt1437293
# time to obtain tt1437293 with position 18677 was 1 seconds
# getting url with title/tt1437430...
# url loaded
# Getting attributes for tt1437430
# Getting cast for tt1437430
# time to obtain tt1437430 with position 18678 was 1 seconds
# getting url with title/tt1437424...
# url loaded
# Getting attributes for tt1437424
# Getting cast for tt1437424
# time to obtain tt1437424 with position 18679 was 1 seconds
# getting url with title/tt1437423...
# url loaded
# Getting attributes for tt1437423
# Getting cast for tt1437423
# time to obtain tt1437423 with position 18680 was 1 seconds
# getting url with title/tt1437433...
# url loaded
# Getting attributes for tt1437433
# Getting cast for tt1437433
# time to obtain tt1437433 with position 18681 was 2 seconds
# getting url with title/tt1438209...
# url loaded
# Getting attributes for tt1438209
# Getting cast for tt1438209
# time to obtain tt1438209 with position 18682 was 1 seconds
# getting url with title/tt1438217...
# url loaded
# Getting attributes for tt1438217
# Getting cast for tt1438217
# time to obtain tt1438217 with position 18683 was 2 seconds
# getting url with title/tt1439251...
# url loaded
# Getting attributes for tt1439251
# Getting cast for tt1439251
# time to obtain tt1439251 with position 18684 was 2 seconds
# getting url with title/tt1439481...
# url loaded
# Getting attributes for tt1439481
# Getting cast for tt1439481
# time to obtain tt1439481 with position 18685 was 1 seconds
# getting url with title/tt1440328...
# url loaded
# Getting attributes for tt1440328
# Getting cast for tt1440328
# time to obtain tt1440328 with position 18686 was 1 seconds
# getting url with title/tt1442290...
# url loaded
# Getting attributes for tt1442290
# Getting cast for tt1442290
# time to obtain tt1442290 with position 18687 was 2 seconds
# getting url with title/tt1442298...
# url loaded
# Getting attributes for tt1442298
# Getting cast for tt1442298
# time to obtain tt1442298 with position 18688 was 1 seconds
# getting url with title/tt1442292...
# url loaded
# Getting attributes for tt1442292
# Getting cast for tt1442292
# time to obtain tt1442292 with position 18689 was 1 seconds
# getting url with title/tt1442579...
# url loaded
# Getting attributes for tt1442579
# Getting cast for tt1442579
# time to obtain tt1442579 with position 18690 was 2 seconds
# getting url with title/tt1443463...
# url loaded
# Getting attributes for tt1443463
# Getting cast for tt1443463
# time to obtain tt1443463 with position 18691 was 2 seconds
# getting url with title/tt1445155...
# url loaded
# Getting attributes for tt1445155
# Getting cast for tt1445155
# time to obtain tt1445155 with position 18692 was 3 seconds
# getting url with title/tt1445123...
# url loaded
# Getting attributes for tt1445123
# error obtaining name for id tt1445123
# Getting cast for tt1445123
# time to obtain tt1445123 with position 18693 was 60 seconds
# getting url with title/tt14455000...
# url loaded
# Getting attributes for tt14455000
# Getting cast for tt14455000
# time to obtain tt14455000 with position 18694 was 1 seconds
# getting url with title/tt1446174...
# url loaded
# Getting attributes for tt1446174
# Getting cast for tt1446174
# time to obtain tt1446174 with position 18695 was 1 seconds
# getting url with title/tt1447200...
# url loaded
# Getting attributes for tt1447200
# Getting cast for tt1447200
# time to obtain tt1447200 with position 18696 was 2 seconds
# getting url with title/tt1447196...
# url loaded
# Getting attributes for tt1447196
# Getting cast for tt1447196
# time to obtain tt1447196 with position 18697 was 1 seconds
# getting url with title/tt1447975...
# url loaded
# Getting attributes for tt1447975
# Getting cast for tt1447975
# time to obtain tt1447975 with position 18698 was 1 seconds
# getting url with title/tt1450729...
# url loaded
# Getting attributes for tt1450729
# Getting cast for tt1450729
# time to obtain tt1450729 with position 18699 was 2 seconds
# getting url with title/tt1450686...
# url loaded
# Getting attributes for tt1450686
# Getting cast for tt1450686
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt1450686 with position 18700 was 18 seconds
# getting url with title/tt14513288...
# url loaded
# Getting attributes for tt14513288
# Getting cast for tt14513288
# time to obtain tt14513288 with position 18701 was 1 seconds
# getting url with title/tt14520490...
# url loaded
# Getting attributes for tt14520490
# Getting cast for tt14520490
# time to obtain tt14520490 with position 18702 was 2 seconds
# getting url with title/tt1454928...
# url loaded
# Getting attributes for tt1454928
# Getting cast for tt1454928
# time to obtain tt1454928 with position 18703 was 2 seconds
# getting url with title/tt1455030...
# url loaded
# Getting attributes for tt1455030
# Getting cast for tt1455030
# time to obtain tt1455030 with position 18704 was 1 seconds
# getting url with title/tt1455118...
# url loaded
# Getting attributes for tt1455118
# Getting cast for tt1455118
# time to obtain tt1455118 with position 18705 was 1 seconds
# getting url with title/tt1454975...
# url loaded
# Getting attributes for tt1454975
# Getting cast for tt1454975
# time to obtain tt1454975 with position 18706 was 1 seconds
# getting url with title/tt1454955...
# url loaded
# Getting attributes for tt1454955
# Getting cast for tt1454955
# time to obtain tt1454955 with position 18707 was 1 seconds
# getting url with title/tt1455036...
# url loaded
# Getting attributes for tt1455036
# Getting cast for tt1455036
# time to obtain tt1455036 with position 18708 was 3 seconds
# getting url with title/tt1455179...
# url loaded
# Getting attributes for tt1455179
# Getting cast for tt1455179
# time to obtain tt1455179 with position 18709 was 1 seconds
# getting url with title/tt1455660...
# url loaded
# Getting attributes for tt1455660
# Getting cast for tt1455660
# time to obtain tt1455660 with position 18710 was 1 seconds
# getting url with title/tt1456117...
# url loaded
# Getting attributes for tt1456117
# Getting cast for tt1456117
# time to obtain tt1456117 with position 18711 was 1 seconds
# getting url with title/tt1458995...
# url loaded
# Getting attributes for tt1458995
# Getting cast for tt1458995
# time to obtain tt1458995 with position 18712 was 1 seconds
# getting url with title/tt1462679...
# url loaded
# Getting attributes for tt1462679
# Getting cast for tt1462679
# time to obtain tt1462679 with position 18713 was 1 seconds
# getting url with title/tt1463128...
# url loaded
# Getting attributes for tt1463128
# Getting cast for tt1463128
# time to obtain tt1463128 with position 18714 was 1 seconds
# getting url with title/tt14641866...
# url loaded
# Getting attributes for tt14641866
# Getting cast for tt14641866
# time to obtain tt14641866 with position 18715 was 1 seconds
# getting url with title/tt1466558...
# url loaded
# Getting attributes for tt1466558
# Getting cast for tt1466558
# time to obtain tt1466558 with position 18716 was 1 seconds
# getting url with title/tt1467389...
# url loaded
# Getting attributes for tt1467389
# Getting cast for tt1467389
# time to obtain tt1467389 with position 18717 was 1 seconds
# getting url with title/tt14690612...
# url loaded
# Getting attributes for tt14690612
# Getting cast for tt14690612
# time to obtain tt14690612 with position 18718 was 1 seconds
# getting url with title/tt1474362...
# url loaded
# Getting attributes for tt1474362
# Getting cast for tt1474362
# time to obtain tt1474362 with position 18719 was 1 seconds
# getting url with title/tt1474494...
# url loaded
# Getting attributes for tt1474494
# Getting cast for tt1474494
# time to obtain tt1474494 with position 18720 was 2 seconds
# getting url with title/tt1474341...
# url loaded
# Getting attributes for tt1474341
# Getting cast for tt1474341
# time to obtain tt1474341 with position 18721 was 2 seconds
# getting url with title/tt1475298...
# url loaded
# Getting attributes for tt1475298
# Getting cast for tt1475298
# time to obtain tt1475298 with position 18722 was 1 seconds
# getting url with title/tt1478345...
# url loaded
# Getting attributes for tt1478345
# Getting cast for tt1478345
# time to obtain tt1478345 with position 18723 was 3 seconds
# getting url with title/tt1480297...
# url loaded
# Getting attributes for tt1480297
# Getting cast for tt1480297
# time to obtain tt1480297 with position 18724 was 2 seconds
# getting url with title/tt1484109...
# url loaded
# Getting attributes for tt1484109
# Getting cast for tt1484109
# time to obtain tt1484109 with position 18725 was 2 seconds
# getting url with title/tt1485086...
# url loaded
# Getting attributes for tt1485086
# Getting cast for tt1485086
# time to obtain tt1485086 with position 18726 was 2 seconds
# getting url with title/tt1485161...
# url loaded
# Getting attributes for tt1485161
# Getting cast for tt1485161
# time to obtain tt1485161 with position 18727 was 1 seconds
# getting url with title/tt1486744...
# url loaded
# Getting attributes for tt1486744
# Getting cast for tt1486744
# time to obtain tt1486744 with position 18728 was 1 seconds
# getting url with title/tt1486722...
# url loaded
# Getting attributes for tt1486722
# Getting cast for tt1486722
# time to obtain tt1486722 with position 18729 was 1 seconds
# getting url with title/tt1493857...
# url loaded
# Getting attributes for tt1493857
# Getting cast for tt1493857
# time to obtain tt1493857 with position 18730 was 2 seconds
# getting url with title/tt14966420...
# url loaded
# Getting attributes for tt14966420
# Getting cast for tt14966420
# time to obtain tt14966420 with position 18731 was 2 seconds
# getting url with title/tt15000098...
# url loaded
# Getting attributes for tt15000098
# Getting cast for tt15000098
# time to obtain tt15000098 with position 18732 was 1 seconds
# getting url with title/tt1500141...
# url loaded
# Getting attributes for tt1500141
# Getting cast for tt1500141
# time to obtain tt1500141 with position 18733 was 2 seconds
# getting url with title/tt1501354...
# url loaded
# Getting attributes for tt1501354
# Getting cast for tt1501354
# time to obtain tt1501354 with position 18734 was 2 seconds
# getting url with title/tt15043062...
# url loaded
# Getting attributes for tt15043062
# Getting cast for tt15043062
# time to obtain tt15043062 with position 18735 was 1 seconds
# getting url with title/tt15043474...
# url loaded
# Getting attributes for tt15043474
# Getting cast for tt15043474
# time to obtain tt15043474 with position 18736 was 1 seconds
# getting url with title/tt15043034...
# url loaded
# Getting attributes for tt15043034
# Getting cast for tt15043034
# time to obtain tt15043034 with position 18737 was 1 seconds
# getting url with title/tt15046844...
# url loaded
# Getting attributes for tt15046844
# Getting cast for tt15046844
# time to obtain tt15046844 with position 18738 was 1 seconds
# getting url with title/tt1505437...
# url loaded
# Getting attributes for tt1505437
# Getting cast for tt1505437
# time to obtain tt1505437 with position 18739 was 1 seconds
# getting url with title/tt1505378...
# url loaded
# Getting attributes for tt1505378
# Getting cast for tt1505378
# time to obtain tt1505378 with position 18740 was 2 seconds
# getting url with title/tt1506320...
# url loaded
# Getting attributes for tt1506320
# Getting cast for tt1506320
# time to obtain tt1506320 with position 18741 was 2 seconds
# getting url with title/tt15071490...
# url loaded
# Getting attributes for tt15071490
# Getting cast for tt15071490
# time to obtain tt15071490 with position 18742 was 2 seconds
# getting url with title/tt15086466...
# url loaded
# Getting attributes for tt15086466
# Getting cast for tt15086466
# time to obtain tt15086466 with position 18743 was 1 seconds
# getting url with title/tt1512213...
# url loaded
# Getting attributes for tt1512213
# Getting cast for tt1512213
# time to obtain tt1512213 with position 18744 was 1 seconds
# getting url with title/tt1513785...
# url loaded
# Getting attributes for tt1513785
# Getting cast for tt1513785
# time to obtain tt1513785 with position 18745 was 1 seconds
# getting url with title/tt1515861...
# url loaded
# Getting attributes for tt1515861
# Getting cast for tt1515861
# time to obtain tt1515861 with position 18746 was 1 seconds
# getting url with title/tt1517656...
# url loaded
# Getting attributes for tt1517656
# Getting cast for tt1517656
# time to obtain tt1517656 with position 18747 was 2 seconds
# getting url with title/tt1525897...
# url loaded
# Getting attributes for tt1525897
# Getting cast for tt1525897
# time to obtain tt1525897 with position 18748 was 2 seconds
# getting url with title/tt15263256...
# url loaded
# Getting attributes for tt15263256
# Getting cast for tt15263256
# time to obtain tt15263256 with position 18749 was 2 seconds
# getting url with title/tt1528281...
# url loaded
# Getting attributes for tt1528281
# Getting cast for tt1528281
# time to obtain tt1528281 with position 18750 was 2 seconds
# getting url with title/tt1532883...
# url loaded
# Getting attributes for tt1532883
# Getting cast for tt1532883
# time to obtain tt1532883 with position 18751 was 1 seconds
# getting url with title/tt1533026...
# url loaded
# Getting attributes for tt1533026
# Getting cast for tt1533026
# time to obtain tt1533026 with position 18752 was 2 seconds
# getting url with title/tt1533059...
# url loaded
# Getting attributes for tt1533059
# Getting cast for tt1533059
# time to obtain tt1533059 with position 18753 was 1 seconds
# getting url with title/tt1533975...
# url loaded
# Getting attributes for tt1533975
# Getting cast for tt1533975
# time to obtain tt1533975 with position 18754 was 2 seconds
# getting url with title/tt1533756...
# url loaded
# Getting attributes for tt1533756
# Getting cast for tt1533756
# time to obtain tt1533756 with position 18755 was 3 seconds
# getting url with title/tt1535022...
# url loaded
# Getting attributes for tt1535022
# Getting cast for tt1535022
# time to obtain tt1535022 with position 18756 was 3 seconds
# getting url with title/tt1534839...
# url loaded
# Getting attributes for tt1534839
# Getting cast for tt1534839
# time to obtain tt1534839 with position 18757 was 1 seconds
# getting url with title/tt1536102...
# url loaded
# Getting attributes for tt1536102
# Getting cast for tt1536102
# time to obtain tt1536102 with position 18758 was 2 seconds
# getting url with title/tt1535998...
# url loaded
# Getting attributes for tt1535998
# Getting cast for tt1535998
# time to obtain tt1535998 with position 18759 was 2 seconds
# getting url with title/tt1536060...
# url loaded
# Getting attributes for tt1536060
# Getting cast for tt1536060
# time to obtain tt1536060 with position 18760 was 2 seconds
# getting url with title/tt1536459...
# url loaded
# Getting attributes for tt1536459
# Getting cast for tt1536459
# time to obtain tt1536459 with position 18761 was 1 seconds
# getting url with title/tt1536467...
# url loaded
# Getting attributes for tt1536467
# Getting cast for tt1536467
# time to obtain tt1536467 with position 18762 was 4 seconds
# getting url with title/tt1537308...
# url loaded
# Getting attributes for tt1537308
# Getting cast for tt1537308
# time to obtain tt1537308 with position 18763 was 3 seconds
# getting url with title/tt1540037...
# url loaded
# Getting attributes for tt1540037
# Getting cast for tt1540037
# time to obtain tt1540037 with position 18764 was 2 seconds
# getting url with title/tt1540809...
# url loaded
# Getting attributes for tt1540809
# Getting cast for tt1540809
# time to obtain tt1540809 with position 18765 was 3 seconds
# getting url with title/tt1540993...
# url loaded
# Getting attributes for tt1540993
# Getting cast for tt1540993
# time to obtain tt1540993 with position 18766 was 1 seconds
# getting url with title/tt1541631...
# url loaded
# Getting attributes for tt1541631
# Getting cast for tt1541631
# time to obtain tt1541631 with position 18767 was 2 seconds
# getting url with title/tt1541877...
# url loaded
# Getting attributes for tt1541877
# Getting cast for tt1541877
# time to obtain tt1541877 with position 18768 was 1 seconds
# getting url with title/tt1543264...
# url loaded
# Getting attributes for tt1543264
# Getting cast for tt1543264
# time to obtain tt1543264 with position 18769 was 2 seconds
# getting url with title/tt1543638...
# url loaded
# Getting attributes for tt1543638
# Getting cast for tt1543638
# time to obtain tt1543638 with position 18770 was 2 seconds
# getting url with title/tt1548587...
# url loaded
# Getting attributes for tt1548587
# Getting cast for tt1548587
# time to obtain tt1548587 with position 18771 was 2 seconds
# getting url with title/tt1549104...
# url loaded
# Getting attributes for tt1549104
# Getting cast for tt1549104
# time to obtain tt1549104 with position 18772 was 2 seconds
# getting url with title/tt1549899...
# url loaded
# Getting attributes for tt1549899
# Getting cast for tt1549899
# time to obtain tt1549899 with position 18773 was 3 seconds
# getting url with title/tt1549903...
# url loaded
# Getting attributes for tt1549903
# Getting cast for tt1549903
# time to obtain tt1549903 with position 18774 was 4 seconds
# getting url with title/tt1549938...
# url loaded
# Getting attributes for tt1549938
# Getting cast for tt1549938
# time to obtain tt1549938 with position 18775 was 2 seconds
# getting url with title/tt1550494...
# url loaded
# Getting attributes for tt1550494
# Getting cast for tt1550494
# time to obtain tt1550494 with position 18776 was 2 seconds
# getting url with title/tt1553024...
# url loaded
# Getting attributes for tt1553024
# Getting cast for tt1553024
# time to obtain tt1553024 with position 18777 was 5 seconds
# getting url with title/tt1553237...
# url loaded
# Getting attributes for tt1553237
# Getting cast for tt1553237
# time to obtain tt1553237 with position 18778 was 1 seconds
# getting url with title/tt1553183...
# url loaded
# Getting attributes for tt1553183
# Getting cast for tt1553183
# time to obtain tt1553183 with position 18779 was 2 seconds
# getting url with title/tt1553672...
# url loaded
# Getting attributes for tt1553672
# Getting cast for tt1553672
# time to obtain tt1553672 with position 18780 was 3 seconds
# getting url with title/tt1553669...
# url loaded
# Getting attributes for tt1553669
# Getting cast for tt1553669
# time to obtain tt1553669 with position 18781 was 3 seconds
# getting url with title/tt1553682...
# url loaded
# Getting attributes for tt1553682
# Getting cast for tt1553682
# time to obtain tt1553682 with position 18782 was 2 seconds
# getting url with title/tt1553907...
# url loaded
# Getting attributes for tt1553907
# Getting cast for tt1553907
# time to obtain tt1553907 with position 18783 was 2 seconds
# getting url with title/tt1554487...
# url loaded
# Getting attributes for tt1554487
# Getting cast for tt1554487
# time to obtain tt1554487 with position 18784 was 1 seconds
# getting url with title/tt1556594...
# ...
# time to obtain tt0805588 with position 21403 was 3 seconds
# getting url with title/tt0802964...
# url loaded
# Getting attributes for tt0802964
# Getting cast for tt0802964
# time to obtain tt0802964 with position 21404 was 3 seconds
# getting url with title/tt0805573...
# url loaded
# Getting attributes for tt0805573
# Getting cast for tt0805573
# time to obtain tt0805573 with position 21405 was 1 seconds
# getting url with title/tt0805334...
# url loaded
# Getting attributes for tt0805334
# Getting cast for tt0805334
# time to obtain tt0805334 with position 21406 was 2 seconds
# getting url with title/tt0805499...
# url loaded
# Getting attributes for tt0805499
# Getting cast for tt0805499
# time to obtain tt0805499 with position 21407 was 2 seconds
# getting url with title/tt0802997...
# url loaded
# Getting attributes for tt0802997
# Getting cast for tt0802997
# time to obtain tt0802997 with position 21408 was 3 seconds
# getting url with title/tt0802979...
# url loaded
# Getting attributes for tt0802979
# Getting cast for tt0802979
# time to obtain tt0802979 with position 21409 was 2 seconds
# getting url with title/tt0806148...
# url loaded
# Getting attributes for tt0806148
# Getting cast for tt0806148
# time to obtain tt0806148 with position 21410 was 2 seconds
# getting url with title/tt0806170...
# url loaded
# Getting attributes for tt0806170
# Getting cast for tt0806170
# time to obtain tt0806170 with position 21411 was 4 seconds
# getting url with title/tt0806126...
# url loaded
# Getting attributes for tt0806126
# Getting cast for tt0806126
# time to obtain tt0806126 with position 21412 was 3 seconds
# getting url with title/tt0806251...
# url loaded
# Getting attributes for tt0806251
# Getting cast for tt0806251
# time to obtain tt0806251 with position 21413 was 2 seconds
# getting url with title/tt0805518...
# url loaded
# Getting attributes for tt0805518
# Getting cast for tt0805518
# time to obtain tt0805518 with position 21414 was 3 seconds
# getting url with title/tt0805479...
# url loaded
# Getting attributes for tt0805479
# Getting cast for tt0805479
# time to obtain tt0805479 with position 21415 was 2 seconds
# getting url with title/tt0805699...
# url loaded
# Getting attributes for tt0805699
# Getting cast for tt0805699
# time to obtain tt0805699 with position 21416 was 2 seconds
# getting url with title/tt0805322...
# url loaded
# Getting attributes for tt0805322
# Getting cast for tt0805322
# time to obtain tt0805322 with position 21417 was 3 seconds
# getting url with title/tt0805493...
# url loaded
# Getting attributes for tt0805493
# Getting cast for tt0805493
# time to obtain tt0805493 with position 21418 was 3 seconds
# getting url with title/tt0806948...
# url loaded
# Getting attributes for tt0806948
# Getting cast for tt0806948
# time to obtain tt0806948 with position 21419 was 2 seconds
# getting url with title/tt0808305...
# url loaded
# Getting attributes for tt0808305
# Getting cast for tt0808305
# time to obtain tt0808305 with position 21420 was 2 seconds
# getting url with title/tt0807940...
# url loaded
# Getting attributes for tt0807940
# Getting cast for tt0807940
# time to obtain tt0807940 with position 21421 was 3 seconds
# getting url with title/tt0808188...
# url loaded
# Getting attributes for tt0808188
# Getting cast for tt0808188
# time to obtain tt0808188 with position 21422 was 3 seconds
# getting url with title/tt0808469...
# url loaded
# Getting attributes for tt0808469
# Getting cast for tt0808469
# time to obtain tt0808469 with position 21423 was 2 seconds
# getting url with title/tt0808443...
# url loaded
# Getting attributes for tt0808443
# Getting cast for tt0808443
# time to obtain tt0808443 with position 21424 was 2 seconds
# getting url with title/tt0808271...
# url loaded
# Getting attributes for tt0808271
# Getting cast for tt0808271
# time to obtain tt0808271 with position 21425 was 2 seconds
# getting url with title/tt0807722...
# url loaded
# Getting attributes for tt0807722
# Getting cast for tt0807722
# time to obtain tt0807722 with position 21426 was 3 seconds
# getting url with title/tt0808304...
# url loaded
# Getting attributes for tt0808304
# Getting cast for tt0808304
# time to obtain tt0808304 with position 21427 was 2 seconds
# getting url with title/tt0808395...
# url loaded
# Getting attributes for tt0808395
# Getting cast for tt0808395
# time to obtain tt0808395 with position 21428 was 3 seconds
# getting url with title/tt0807848...
# url loaded
# Getting attributes for tt0807848
# Getting cast for tt0807848
# time to obtain tt0807848 with position 21429 was 3 seconds
# getting url with title/tt0808401...
# url loaded
# Getting attributes for tt0808401
# Getting cast for tt0808401
# time to obtain tt0808401 with position 21430 was 3 seconds
# getting url with title/tt0807856...
# url loaded
# Getting attributes for tt0807856
# Getting cast for tt0807856
# time to obtain tt0807856 with position 21431 was 2 seconds
# getting url with title/tt0808912...
# url loaded
# Getting attributes for tt0808912
# Getting cast for tt0808912
# time to obtain tt0808912 with position 21432 was 3 seconds
# getting url with title/tt0810820...
# url loaded
# Getting attributes for tt0810820
# Getting cast for tt0810820
# time to obtain tt0810820 with position 21433 was 3 seconds
# getting url with title/tt0808464...
# url loaded
# Getting attributes for tt0808464
# Getting cast for tt0808464
# time to obtain tt0808464 with position 21434 was 3 seconds
# getting url with title/tt0808275...
# url loaded
# Getting attributes for tt0808275
# Getting cast for tt0808275
# time to obtain tt0808275 with position 21435 was 2 seconds
# getting url with title/tt0808191...
# url loaded
# Getting attributes for tt0808191
# Getting cast for tt0808191
# time to obtain tt0808191 with position 21436 was 3 seconds
# getting url with title/tt0808890...
# url loaded
# Getting attributes for tt0808890
# Getting cast for tt0808890
# time to obtain tt0808890 with position 21437 was 3 seconds
# getting url with title/tt0808501...
# url loaded
# Getting attributes for tt0808501
# Getting cast for tt0808501
# time to obtain tt0808501 with position 21438 was 1 seconds
# getting url with title/tt0810427...
# url loaded
# Getting attributes for tt0810427
# Getting cast for tt0810427
# time to obtain tt0810427 with position 21439 was 2 seconds
# getting url with title/tt0808876...
# url loaded
# Getting attributes for tt0808876
# Getting cast for tt0808876
# time to obtain tt0808876 with position 21440 was 2 seconds
# getting url with title/tt0810835...
# url loaded
# Getting attributes for tt0810835
# Getting cast for tt0810835
# time to obtain tt0810835 with position 21441 was 3 seconds
# getting url with title/tt0808366...
# url loaded
# Getting attributes for tt0808366
# Getting cast for tt0808366
# time to obtain tt0808366 with position 21442 was 2 seconds
# getting url with title/tt0810848...
# url loaded
# Getting attributes for tt0810848
# Getting cast for tt0810848
# time to obtain tt0810848 with position 21443 was 4 seconds
# getting url with title/tt0810006...
# url loaded
# Getting attributes for tt0810006
# Getting cast for tt0810006
# time to obtain tt0810006 with position 21444 was 3 seconds
# getting url with title/tt0810040...
# url loaded
# Getting attributes for tt0810040
# Getting cast for tt0810040
# time to obtain tt0810040 with position 21445 was 4 seconds
# getting url with title/tt0810379...
# url loaded
# Getting attributes for tt0810379
# Getting cast for tt0810379
# time to obtain tt0810379 with position 21446 was 3 seconds
# getting url with title/tt0810079...
# url loaded
# Getting attributes for tt0810079
# Getting cast for tt0810079
# time to obtain tt0810079 with position 21447 was 4 seconds
# getting url with title/tt0809934...
# url loaded
# Getting attributes for tt0809934
# Getting cast for tt0809934
# time to obtain tt0809934 with position 21448 was 5 seconds
# getting url with title/tt0810933...
# url loaded
# Getting attributes for tt0810933
# Getting cast for tt0810933
# time to obtain tt0810933 with position 21449 was 3 seconds
# getting url with title/tt0810899...
# url loaded
# Getting attributes for tt0810899
# Getting cast for tt0810899
# time to obtain tt0810899 with position 21450 was 3 seconds
# getting url with title/tt0811100...
# url loaded
# Getting attributes for tt0811100
# Getting cast for tt0811100
# time to obtain tt0811100 with position 21451 was 2 seconds
# getting url with title/tt0811603...
# url loaded
# Getting attributes for tt0811603
# Getting cast for tt0811603
# time to obtain tt0811603 with position 21452 was 3 seconds
# getting url with title/tt0810858...
# url loaded
# Getting attributes for tt0810858
# Getting cast for tt0810858
# time to obtain tt0810858 with position 21453 was 4 seconds
# getting url with title/tt0810447...
# url loaded
# Getting attributes for tt0810447
# Getting cast for tt0810447
# time to obtain tt0810447 with position 21454 was 3 seconds
# getting url with title/tt0811070...
# url loaded
# Getting attributes for tt0811070
# Getting cast for tt0811070
# time to obtain tt0811070 with position 21455 was 2 seconds
# getting url with title/tt0810830...
# url loaded
# Getting attributes for tt0810830
# Getting cast for tt0810830
# time to obtain tt0810830 with position 21456 was 2 seconds
# getting url with title/tt0810418...
# url loaded
# Getting attributes for tt0810418
# Getting cast for tt0810418
# time to obtain tt0810418 with position 21457 was 3 seconds
# getting url with title/tt0810950...
# url loaded
# Getting attributes for tt0810950
# Getting cast for tt0810950
# time to obtain tt0810950 with position 21458 was 4 seconds
# getting url with title/tt0810881...
# url loaded
# Getting attributes for tt0810881
# Getting cast for tt0810881
# time to obtain tt0810881 with position 21459 was 2 seconds
# getting url with title/tt0810987...
# url loaded
# Getting attributes for tt0810987
# Getting cast for tt0810987
# time to obtain tt0810987 with position 21460 was 3 seconds
# getting url with title/tt0812387...
# url loaded
# Getting attributes for tt0812387
# Getting cast for tt0812387
# time to obtain tt0812387 with position 21461 was 5 seconds
# getting url with title/tt0811148...
# url loaded
# Getting attributes for tt0811148
# Getting cast for tt0811148
# time to obtain tt0811148 with position 21462 was 4 seconds
# getting url with title/tt0814167...
# url loaded
# Getting attributes for tt0814167
# Getting cast for tt0814167
# time to obtain tt0814167 with position 21463 was 2 seconds
# getting url with title/tt0814307...
# url loaded
# Getting attributes for tt0814307
# Getting cast for tt0814307
# time to obtain tt0814307 with position 21464 was 4 seconds
# getting url with title/tt0814405...
# url loaded
# Getting attributes for tt0814405
# Getting cast for tt0814405
# time to obtain tt0814405 with position 21465 was 5 seconds
# getting url with title/tt0814323...
# url loaded
# Getting attributes for tt0814323
# Getting cast for tt0814323
# time to obtain tt0814323 with position 21466 was 5 seconds
# getting url with title/tt0814301...
# url loaded
# Getting attributes for tt0814301
# Getting cast for tt0814301
# time to obtain tt0814301 with position 21467 was 5 seconds
# getting url with title/tt0814021...
# url loaded
# Getting attributes for tt0814021
# Getting cast for tt0814021
# time to obtain tt0814021 with position 21468 was 4 seconds
# getting url with title/tt0814300...
# url loaded
# Getting attributes for tt0814300
# Getting cast for tt0814300
# time to obtain tt0814300 with position 21469 was 2 seconds
# getting url with title/tt0813416...
# url loaded
# Getting attributes for tt0813416
# Getting cast for tt0813416
# time to obtain tt0813416 with position 21470 was 4 seconds
# getting url with title/tt0813409...
# url loaded
# Getting attributes for tt0813409
# Getting cast for tt0813409
# time to obtain tt0813409 with position 21471 was 5 seconds
# getting url with title/tt0814251...
# url loaded
# Getting attributes for tt0814251
# Getting cast for tt0814251
# time to obtain tt0814251 with position 21472 was 4 seconds
# getting url with title/tt0814066...
# url loaded
# Getting attributes for tt0814066
# Getting cast for tt0814066
# time to obtain tt0814066 with position 21473 was 2 seconds
# getting url with title/tt0814268...
# url loaded
# Getting attributes for tt0814268
# Getting cast for tt0814268
# time to obtain tt0814268 with position 21474 was 3 seconds
# getting url with title/tt0814347...
# url loaded
# Getting attributes for tt0814347
# Getting cast for tt0814347
# time to obtain tt0814347 with position 21475 was 4 seconds
# getting url with title/tt0814141...
# url loaded
# Getting attributes for tt0814141
# Getting cast for tt0814141
# time to obtain tt0814141 with position 21476 was 4 seconds
# getting url with title/tt0814049...
# url loaded
# Getting attributes for tt0814049
# Getting cast for tt0814049
# time to obtain tt0814049 with position 21477 was 2 seconds
# getting url with title/tt0815089...
# url loaded
# Getting attributes for tt0815089
# Getting cast for tt0815089
# time to obtain tt0815089 with position 21478 was 3 seconds
# getting url with title/tt0814110...
# url loaded
# Getting attributes for tt0814110
# Getting cast for tt0814110
# time to obtain tt0814110 with position 21479 was 2 seconds
# getting url with title/tt0814177...
# url loaded
# Getting attributes for tt0814177
# Getting cast for tt0814177
# time to obtain tt0814177 with position 21480 was 6 seconds
# getting url with title/tt0814270...
# url loaded
# Getting attributes for tt0814270
# Getting cast for tt0814270
# time to obtain tt0814270 with position 21481 was 2 seconds
# getting url with title/tt0814043...
# url loaded
# Getting attributes for tt0814043
# Getting cast for tt0814043
# time to obtain tt0814043 with position 21482 was 2 seconds
# getting url with title/tt0814358...
# url loaded
# Getting attributes for tt0814358
# Getting cast for tt0814358
# time to obtain tt0814358 with position 21483 was 4 seconds
# getting url with title/tt0815195...
# url loaded
# Getting attributes for tt0815195
# Getting cast for tt0815195
# time to obtain tt0815195 with position 21484 was 6 seconds
# getting url with title/tt0815164...
# url loaded
# Getting attributes for tt0815164
# Getting cast for tt0815164
# time to obtain tt0815164 with position 21485 was 5 seconds
# getting url with title/tt0815675...
# url loaded
# Getting attributes for tt0815675
# Getting cast for tt0815675
# time to obtain tt0815675 with position 21486 was 5 seconds
# getting url with title/tt0816263...
# url loaded
# Getting attributes for tt0816263
# Getting cast for tt0816263
# time to obtain tt0816263 with position 21487 was 5 seconds
# getting url with title/tt0816508...
# url loaded
# Getting attributes for tt0816508
# Getting cast for tt0816508
# time to obtain tt0816508 with position 21488 was 5 seconds
# getting url with title/tt0816083...
# url loaded
# Getting attributes for tt0816083
# Getting cast for tt0816083
# time to obtain tt0816083 with position 21489 was 5 seconds
# getting url with title/tt0816469...
# url loaded
# Getting attributes for tt0816469
# Getting cast for tt0816469
# time to obtain tt0816469 with position 21490 was 3 seconds
# getting url with title/tt0816477...
# url loaded
# Getting attributes for tt0816477
# Getting cast for tt0816477
# time to obtain tt0816477 with position 21491 was 3 seconds
# getting url with title/tt0816444...
# url loaded
# Getting attributes for tt0816444
# Getting cast for tt0816444
# time to obtain tt0816444 with position 21492 was 5 seconds
# getting url with title/tt0814179...
# url loaded
# Getting attributes for tt0814179
# Getting cast for tt0814179
# time to obtain tt0814179 with position 21493 was 5 seconds
# getting url with title/tt0816087...
# url loaded
# Getting attributes for tt0816087
# Getting cast for tt0816087
# time to obtain tt0816087 with position 21494 was 6 seconds
# getting url with title/tt0815231...
# url loaded
# Getting attributes for tt0815231
# Getting cast for tt0815231
# time to obtain tt0815231 with position 21495 was 2 seconds
# getting url with title/tt0816535...
# url loaded
# Getting attributes for tt0816535
# Getting cast for tt0816535
# time to obtain tt0816535 with position 21496 was 5 seconds
# getting url with title/tt0816578...
# url loaded
# Getting attributes for tt0816578
# Getting cast for tt0816578
# time to obtain tt0816578 with position 21497 was 5 seconds
# getting url with title/tt0816194...
# url loaded
# Getting attributes for tt0816194
# Getting cast for tt0816194
# time to obtain tt0816194 with position 21498 was 5 seconds
# getting url with title/tt0815691...
# url loaded
# Getting attributes for tt0815691
# Getting cast for tt0815691
# time to obtain tt0815691 with position 21499 was 5 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    3.974
# dtype: float64
