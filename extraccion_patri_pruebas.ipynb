# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 4
initial_counter = 0
incremental = 500

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    # driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers":
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("../INFO_PELIS/cortos_2021.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt10011052...
# url loaded
# Getting attributes for tt10011052
# Getting cast for tt10011052
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt10011052 with position 0 was 9 seconds
# getting url with title/tt10033714...
# url loaded
# Getting attributes for tt10033714
# Getting cast for tt10033714
# time to obtain tt10033714 with position 1 was 2 seconds
# getting url with title/tt10040326...
# url loaded
# Getting attributes for tt10040326
# Getting cast for tt10040326
# time to obtain tt10040326 with position 2 was 3 seconds
# getting url with title/tt10048746...
# url loaded
# Getting attributes for tt10048746
# Getting cast for tt10048746
# time to obtain tt10048746 with position 3 was 2 seconds
# getting url with title/tt10049134...
# url loaded
# Getting attributes for tt10049134
# Getting cast for tt10049134
# time to obtain tt10049134 with position 4 was 3 seconds
# getting url with title/tt10049710...
# url loaded
# Getting attributes for tt10049710
# Getting cast for tt10049710
# time to obtain tt10049710 with position 5 was 2 seconds
# getting url with title/tt10074108...
# url loaded
# Getting attributes for tt10074108
# Getting cast for tt10074108
# time to obtain tt10074108 with position 6 was 2 seconds
# getting url with title/tt10116030...
# url loaded
# Getting attributes for tt10116030
# Getting cast for tt10116030
# time to obtain tt10116030 with position 7 was 3 seconds
# getting url with title/tt10116000...
# url loaded
# Getting attributes for tt10116000
# Getting cast for tt10116000
# time to obtain tt10116000 with position 8 was 4 seconds
# getting url with title/tt10126104...
# url loaded
# Getting attributes for tt10126104
# Getting cast for tt10126104
# time to obtain tt10126104 with position 9 was 2 seconds
# getting url with title/tt10121942...
# url loaded
# Getting attributes for tt10121942
# Getting cast for tt10121942
# time to obtain tt10121942 with position 10 was 4 seconds
# getting url with title/tt10130050...
# url loaded
# Getting attributes for tt10130050
# Getting cast for tt10130050
# time to obtain tt10130050 with position 11 was 3 seconds
# getting url with title/tt10136966...
# url loaded
# Getting attributes for tt10136966
# Getting cast for tt10136966
# time to obtain tt10136966 with position 12 was 3 seconds
# getting url with title/tt10137298...
# url loaded
# Getting attributes for tt10137298
# Getting cast for tt10137298
# time to obtain tt10137298 with position 13 was 3 seconds
# getting url with title/tt10160440...
# url loaded
# Getting attributes for tt10160440
# Getting cast for tt10160440
# time to obtain tt10160440 with position 14 was 2 seconds
# getting url with title/tt10160712...
# url loaded
# Getting attributes for tt10160712
# Getting cast for tt10160712
# time to obtain tt10160712 with position 15 was 2 seconds
# getting url with title/tt10160948...
# url loaded
# Getting attributes for tt10160948
# Getting cast for tt10160948
# time to obtain tt10160948 with position 16 was 2 seconds
# getting url with title/tt10162788...
# url loaded
# Getting attributes for tt10162788
# Getting cast for tt10162788
# time to obtain tt10162788 with position 17 was 3 seconds
# getting url with title/tt10165720...
# url loaded
# Getting attributes for tt10165720
# error obtaining name for id tt10165720
# Getting cast for tt10165720
# time to obtain tt10165720 with position 18 was 1 seconds
# getting url with title/tt10173624...
# url loaded
# Getting attributes for tt10173624
# Getting cast for tt10173624
# time to obtain tt10173624 with position 19 was 3 seconds
# getting url with title/tt10178240...
# url loaded
# Getting attributes for tt10178240
# Getting cast for tt10178240
# time to obtain tt10178240 with position 20 was 4 seconds
# getting url with title/tt10202368...
# url loaded
# Getting attributes for tt10202368
# Getting cast for tt10202368
# time to obtain tt10202368 with position 21 was 2 seconds
# getting url with title/tt10209778...
# url loaded
# Getting attributes for tt10209778
# Getting cast for tt10209778
# time to obtain tt10209778 with position 22 was 2 seconds
# getting url with title/tt10211236...
# url loaded
# Getting attributes for tt10211236
# Getting cast for tt10211236
# time to obtain tt10211236 with position 23 was 5 seconds
# getting url with title/tt10214926...
# url loaded
# Getting attributes for tt10214926
# Getting cast for tt10214926
# time to obtain tt10214926 with position 24 was 4 seconds
# getting url with title/tt10217312...
# url loaded
# Getting attributes for tt10217312
# Getting cast for tt10217312
# time to obtain tt10217312 with position 25 was 2 seconds
# getting url with title/tt10223204...
# url loaded
# Getting attributes for tt10223204
# Getting cast for tt10223204
# time to obtain tt10223204 with position 26 was 8 seconds
# getting url with title/tt10232622...
# url loaded
# Getting attributes for tt10232622
# Getting cast for tt10232622
# time to obtain tt10232622 with position 27 was 2 seconds
# getting url with title/tt10255620...
# url loaded
# Getting attributes for tt10255620
# Getting cast for tt10255620
# time to obtain tt10255620 with position 28 was 5 seconds
# getting url with title/tt10264392...
# url loaded
# Getting attributes for tt10264392
# Getting cast for tt10264392
# time to obtain tt10264392 with position 29 was 3 seconds
# getting url with title/tt10265126...
# url loaded
# Getting attributes for tt10265126
# Getting cast for tt10265126
# time to obtain tt10265126 with position 30 was 2 seconds
# getting url with title/tt10263160...
# url loaded
# Getting attributes for tt10263160
# Getting cast for tt10263160
# time to obtain tt10263160 with position 31 was 2 seconds
# getting url with title/tt10262172...
# url loaded
# Getting attributes for tt10262172
# Getting cast for tt10262172
# time to obtain tt10262172 with position 32 was 2 seconds
# getting url with title/tt10268132...
# url loaded
# Getting attributes for tt10268132
# Getting cast for tt10268132
# time to obtain tt10268132 with position 33 was 4 seconds
# getting url with title/tt10288032...
# url loaded
# Getting attributes for tt10288032
# Getting cast for tt10288032
# time to obtain tt10288032 with position 34 was 5 seconds
# getting url with title/tt10293032...
# url loaded
# Getting attributes for tt10293032
# Getting cast for tt10293032
# time to obtain tt10293032 with position 35 was 6 seconds
# getting url with title/tt10308068...
# url loaded
# Getting attributes for tt10308068
# Getting cast for tt10308068
# time to obtain tt10308068 with position 36 was 3 seconds
# getting url with title/tt10323164...
# url loaded
# Getting attributes for tt10323164
# Getting cast for tt10323164
# time to obtain tt10323164 with position 37 was 2 seconds
# getting url with title/tt10324186...
# url loaded
# Getting attributes for tt10324186
# Getting cast for tt10324186
# time to obtain tt10324186 with position 38 was 3 seconds
# getting url with title/tt10332270...
# url loaded
# Getting attributes for tt10332270
# Getting cast for tt10332270
# time to obtain tt10332270 with position 39 was 3 seconds
# getting url with title/tt10342478...
# url loaded
# Getting attributes for tt10342478
# Getting cast for tt10342478
# time to obtain tt10342478 with position 40 was 3 seconds
# getting url with title/tt10348936...
# url loaded
# Getting attributes for tt10348936
# Getting cast for tt10348936
# time to obtain tt10348936 with position 41 was 3 seconds
# getting url with title/tt10348902...
# url loaded
# Getting attributes for tt10348902
# Getting cast for tt10348902
# time to obtain tt10348902 with position 42 was 6 seconds
# getting url with title/tt10350572...
# url loaded
# Getting attributes for tt10350572
# Getting cast for tt10350572
# time to obtain tt10350572 with position 43 was 7 seconds
# getting url with title/tt10350920...
# url loaded
# Getting attributes for tt10350920
# Getting cast for tt10350920
# time to obtain tt10350920 with position 44 was 3 seconds
# getting url with title/tt10353864...
# url loaded
# Getting attributes for tt10353864
# Getting cast for tt10353864
# time to obtain tt10353864 with position 45 was 4 seconds
# getting url with title/tt10358578...
# url loaded
# Getting attributes for tt10358578
# Getting cast for tt10358578
# time to obtain tt10358578 with position 46 was 5 seconds
# getting url with title/tt10365704...
# url loaded
# Getting attributes for tt10365704
# Getting cast for tt10365704
# time to obtain tt10365704 with position 47 was 5 seconds
# getting url with title/tt10363182...
# url loaded
# Getting attributes for tt10363182
# Getting cast for tt10363182
# time to obtain tt10363182 with position 48 was 3 seconds
# getting url with title/tt10365862...
# url loaded
# Getting attributes for tt10365862
# Getting cast for tt10365862
# time to obtain tt10365862 with position 49 was 3 seconds
# getting url with title/tt10369560...
# url loaded
# Getting attributes for tt10369560
# Getting cast for tt10369560
# time to obtain tt10369560 with position 50 was 5 seconds
# getting url with title/tt10373668...
# url loaded
# Getting attributes for tt10373668
# Getting cast for tt10373668
# time to obtain tt10373668 with position 51 was 3 seconds
# getting url with title/tt10373608...
# url loaded
# Getting attributes for tt10373608
# Getting cast for tt10373608
# time to obtain tt10373608 with position 52 was 2 seconds
# getting url with title/tt10376530...
# url loaded
# Getting attributes for tt10376530
# Getting cast for tt10376530
# time to obtain tt10376530 with position 53 was 3 seconds
# getting url with title/tt10378806...
# url loaded
# Getting attributes for tt10378806
# Getting cast for tt10378806
# time to obtain tt10378806 with position 54 was 5 seconds
# getting url with title/tt10381288...
# url loaded
# Getting attributes for tt10381288
# Getting cast for tt10381288
# time to obtain tt10381288 with position 55 was 3 seconds
# getting url with title/tt10383780...
# url loaded
# Getting attributes for tt10383780
# Getting cast for tt10383780
# time to obtain tt10383780 with position 56 was 4 seconds
# getting url with title/tt10388514...
# url loaded
# Getting attributes for tt10388514
# Getting cast for tt10388514
# time to obtain tt10388514 with position 57 was 4 seconds
# getting url with title/tt10397810...
# url loaded
# Getting attributes for tt10397810
# Getting cast for tt10397810
# time to obtain tt10397810 with position 58 was 6 seconds
# getting url with title/tt10399532...
# url loaded
# Getting attributes for tt10399532
# Getting cast for tt10399532
# time to obtain tt10399532 with position 59 was 6 seconds
# getting url with title/tt10426186...
# url loaded
# Getting attributes for tt10426186
# Getting cast for tt10426186
# time to obtain tt10426186 with position 60 was 5 seconds
# getting url with title/tt10431668...
# url loaded
# Getting attributes for tt10431668
# Getting cast for tt10431668
# time to obtain tt10431668 with position 61 was 6 seconds
# getting url with title/tt10433734...
# url loaded
# Getting attributes for tt10433734
# Getting cast for tt10433734
# time to obtain tt10433734 with position 62 was 5 seconds
# getting url with title/tt10449406...
# url loaded
# Getting attributes for tt10449406
# Getting cast for tt10449406
# time to obtain tt10449406 with position 63 was 5 seconds
# getting url with title/tt10451004...
# url loaded
# Getting attributes for tt10451004
# Getting cast for tt10451004
# time to obtain tt10451004 with position 64 was 6 seconds
# getting url with title/tt10461698...
# url loaded
# Getting attributes for tt10461698
# Getting cast for tt10461698
# time to obtain tt10461698 with position 65 was 6 seconds
# getting url with title/tt10464802...
# url loaded
# Getting attributes for tt10464802
# Getting cast for tt10464802
# time to obtain tt10464802 with position 66 was 6 seconds
# getting url with title/tt10474800...
# url loaded
# Getting attributes for tt10474800
# Getting cast for tt10474800
# time to obtain tt10474800 with position 67 was 7 seconds
# getting url with title/tt10479784...
# url loaded
# Getting attributes for tt10479784
# Getting cast for tt10479784
# time to obtain tt10479784 with position 68 was 8 seconds
# getting url with title/tt10482866...
# url loaded
# Getting attributes for tt10482866
# Getting cast for tt10482866
# time to obtain tt10482866 with position 69 was 2 seconds
# getting url with title/tt10483856...
# url loaded
# Getting attributes for tt10483856
# Getting cast for tt10483856
# time to obtain tt10483856 with position 70 was 7 seconds
# getting url with title/tt10487984...
# url loaded
# Getting attributes for tt10487984
# Getting cast for tt10487984
# time to obtain tt10487984 with position 71 was 7 seconds
# getting url with title/tt10498052...
# url loaded
# Getting attributes for tt10498052
# Getting cast for tt10498052
# time to obtain tt10498052 with position 72 was 6 seconds
# getting url with title/tt10509924...
# url loaded
# Getting attributes for tt10509924
# Getting cast for tt10509924
# time to obtain tt10509924 with position 73 was 3 seconds
# getting url with title/tt10517736...
# url loaded
# Getting attributes for tt10517736
# Getting cast for tt10517736
# time to obtain tt10517736 with position 74 was 7 seconds
# getting url with title/tt10518812...
# url loaded
# Getting attributes for tt10518812
# Getting cast for tt10518812
# time to obtain tt10518812 with position 75 was 7 seconds
# getting url with title/tt10522608...
# url loaded
# Getting attributes for tt10522608
# Getting cast for tt10522608
# time to obtain tt10522608 with position 76 was 6 seconds
# getting url with title/tt10533540...
# url loaded
# Getting attributes for tt10533540
# Getting cast for tt10533540
# time to obtain tt10533540 with position 77 was 5 seconds
# getting url with title/tt10544106...
# url loaded
# Getting attributes for tt10544106
# Getting cast for tt10544106
# time to obtain tt10544106 with position 78 was 3 seconds
# getting url with title/tt10544116...
# url loaded
# Getting attributes for tt10544116
# Getting cast for tt10544116
# time to obtain tt10544116 with position 79 was 10 seconds
# getting url with title/tt10545658...
# url loaded
# Getting attributes for tt10545658
# Getting cast for tt10545658
# time to obtain tt10545658 with position 80 was 7 seconds
# getting url with title/tt10546172...
# url loaded
# Getting attributes for tt10546172
# Getting cast for tt10546172
# time to obtain tt10546172 with position 81 was 11 seconds
# getting url with title/tt10551584...
# url loaded
# Getting attributes for tt10551584
# Getting cast for tt10551584
# time to obtain tt10551584 with position 82 was 14 seconds
# getting url with title/tt10553408...
# url loaded
# Getting attributes for tt10553408
# Getting cast for tt10553408
# time to obtain tt10553408 with position 83 was 8 seconds
# getting url with title/tt10553930...
# url loaded
# Getting attributes for tt10553930
# Getting cast for tt10553930
# time to obtain tt10553930 with position 84 was 3 seconds
# getting url with title/tt10560282...
# url loaded
# Getting attributes for tt10560282
# Getting cast for tt10560282
# time to obtain tt10560282 with position 85 was 7 seconds
# getting url with title/tt10573952...
# url loaded
# Getting attributes for tt10573952
# Getting cast for tt10573952
# time to obtain tt10573952 with position 86 was 6 seconds
# getting url with title/tt10592782...
# url loaded
# Getting attributes for tt10592782
# Getting cast for tt10592782
# time to obtain tt10592782 with position 87 was 11 seconds
# getting url with title/tt10607058...
# url loaded
# Getting attributes for tt10607058
# Getting cast for tt10607058
# time to obtain tt10607058 with position 88 was 4 seconds
# getting url with title/tt10622284...
# url loaded
# Getting attributes for tt10622284
# Getting cast for tt10622284
# time to obtain tt10622284 with position 89 was 9 seconds
# getting url with title/tt10634918...
# url loaded
# Getting attributes for tt10634918
# Getting cast for tt10634918
# time to obtain tt10634918 with position 90 was 3 seconds
# getting url with title/tt10645274...
# url loaded
# Getting attributes for tt10645274
# Getting cast for tt10645274
# time to obtain tt10645274 with position 91 was 10 seconds
# getting url with title/tt10648352...
# url loaded
# Getting attributes for tt10648352
# Getting cast for tt10648352
# time to obtain tt10648352 with position 92 was 9 seconds
# getting url with title/tt10655036...
# url loaded
# Getting attributes for tt10655036
# Getting cast for tt10655036
# time to obtain tt10655036 with position 93 was 14 seconds
# getting url with title/tt10665422...
# url loaded
# Getting attributes for tt10665422
# Getting cast for tt10665422
# time to obtain tt10665422 with position 94 was 16 seconds
# getting url with title/tt10681682...
# url loaded
# Getting attributes for tt10681682
# Getting cast for tt10681682
# time to obtain tt10681682 with position 95 was 9 seconds
# getting url with title/tt10685024...
# url loaded
# Getting attributes for tt10685024
# Getting cast for tt10685024
# time to obtain tt10685024 with position 96 was 10 seconds
# getting url with title/tt10691448...
# url loaded
# Getting attributes for tt10691448
# Getting cast for tt10691448
# time to obtain tt10691448 with position 97 was 10 seconds
# getting url with title/tt10699260...
# url loaded
# Getting attributes for tt10699260
# Getting cast for tt10699260
# time to obtain tt10699260 with position 98 was 10 seconds
# getting url with title/tt10697676...
# url loaded
# Getting attributes for tt10697676
# Getting cast for tt10697676
# time to obtain tt10697676 with position 99 was 6 seconds
# getting url with title/tt10709592...
# url loaded
# Getting attributes for tt10709592
# Getting cast for tt10709592
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt10709592 with position 100 was 20 seconds
# getting url with title/tt10716904...
# url loaded
# Getting attributes for tt10716904
# Getting cast for tt10716904
# time to obtain tt10716904 with position 101 was 2 seconds
# getting url with title/tt10738602...
# url loaded
# Getting attributes for tt10738602
# Getting cast for tt10738602
# time to obtain tt10738602 with position 102 was 2 seconds
# getting url with title/tt10736286...
# url loaded
# Getting attributes for tt10736286
# Getting cast for tt10736286
# time to obtain tt10736286 with position 103 was 1 seconds
# getting url with title/tt10736172...
# url loaded
# Getting attributes for tt10736172
# Getting cast for tt10736172
# time to obtain tt10736172 with position 104 was 3 seconds
# getting url with title/tt10746680...
# url loaded
# Getting attributes for tt10746680
# Getting cast for tt10746680
# time to obtain tt10746680 with position 105 was 3 seconds
# getting url with title/tt10768602...
# url loaded
# Getting attributes for tt10768602
# Getting cast for tt10768602
# time to obtain tt10768602 with position 106 was 2 seconds
# getting url with title/tt10782720...
# url loaded
# Getting attributes for tt10782720
# Getting cast for tt10782720
# time to obtain tt10782720 with position 107 was 2 seconds
# getting url with title/tt10786894...
# url loaded
# Getting attributes for tt10786894
# Getting cast for tt10786894
# time to obtain tt10786894 with position 108 was 2 seconds
# getting url with title/tt10790184...
# url loaded
# Getting attributes for tt10790184
# Getting cast for tt10790184
# time to obtain tt10790184 with position 109 was 1 seconds
# getting url with title/tt10805740...
# url loaded
# Getting attributes for tt10805740
# Getting cast for tt10805740
# time to obtain tt10805740 with position 110 was 2 seconds
# getting url with title/tt10814820...
# url loaded
# Getting attributes for tt10814820
# Getting cast for tt10814820
# time to obtain tt10814820 with position 111 was 2 seconds
# getting url with title/tt10815898...
# url loaded
# Getting attributes for tt10815898
# Getting cast for tt10815898
# time to obtain tt10815898 with position 112 was 2 seconds
# getting url with title/tt10833172...
# url loaded
# Getting attributes for tt10833172
# Getting cast for tt10833172
# time to obtain tt10833172 with position 113 was 2 seconds
# getting url with title/tt10834016...
# url loaded
# Getting attributes for tt10834016
# Getting cast for tt10834016
# time to obtain tt10834016 with position 114 was 2 seconds
# getting url with title/tt10837310...
# url loaded
# Getting attributes for tt10837310
# Getting cast for tt10837310
# time to obtain tt10837310 with position 115 was 3 seconds
# getting url with title/tt10838698...
# url loaded
# Getting attributes for tt10838698
# Getting cast for tt10838698
# time to obtain tt10838698 with position 116 was 3 seconds
# getting url with title/tt10843204...
# url loaded
# Getting attributes for tt10843204
# Getting cast for tt10843204
# time to obtain tt10843204 with position 117 was 2 seconds
# getting url with title/tt10849714...
# url loaded
# Getting attributes for tt10849714
# error obtaining name for id tt10849714
# Getting cast for tt10849714
# time to obtain tt10849714 with position 118 was 60 seconds
# getting url with title/tt10855054...
# url loaded
# Getting attributes for tt10855054
# Getting cast for tt10855054
# time to obtain tt10855054 with position 119 was 2 seconds
# getting url with title/tt10863602...
# url loaded
# Getting attributes for tt10863602
# Getting cast for tt10863602
# time to obtain tt10863602 with position 120 was 2 seconds
# getting url with title/tt10868062...
# url loaded
# Getting attributes for tt10868062
# Getting cast for tt10868062
# time to obtain tt10868062 with position 121 was 2 seconds
# getting url with title/tt10874280...
# url loaded
# Getting attributes for tt10874280
# Getting cast for tt10874280
# time to obtain tt10874280 with position 122 was 2 seconds
# getting url with title/tt10883230...
# url loaded
# Getting attributes for tt10883230
# Getting cast for tt10883230
# time to obtain tt10883230 with position 123 was 2 seconds
# getting url with title/tt10889752...
# url loaded
# Getting attributes for tt10889752
# Getting cast for tt10889752
# time to obtain tt10889752 with position 124 was 2 seconds
# getting url with title/tt10907898...
# url loaded
# Getting attributes for tt10907898
# Getting cast for tt10907898
# time to obtain tt10907898 with position 125 was 2 seconds
# getting url with title/tt10907150...
# url loaded
# Getting attributes for tt10907150
# Getting cast for tt10907150
# time to obtain tt10907150 with position 126 was 2 seconds
# getting url with title/tt10905828...
# url loaded
# Getting attributes for tt10905828
# Getting cast for tt10905828
# time to obtain tt10905828 with position 127 was 1 seconds
# getting url with title/tt10911990...
# url loaded
# Getting attributes for tt10911990
# Getting cast for tt10911990
# time to obtain tt10911990 with position 128 was 3 seconds
# getting url with title/tt10913636...
# url loaded
# Getting attributes for tt10913636
# Getting cast for tt10913636
# time to obtain tt10913636 with position 129 was 2 seconds
# getting url with title/tt10920502...
# url loaded
# Getting attributes for tt10920502
# Getting cast for tt10920502
# time to obtain tt10920502 with position 130 was 2 seconds
# getting url with title/tt10923116...
# url loaded
# Getting attributes for tt10923116
# Getting cast for tt10923116
# time to obtain tt10923116 with position 131 was 2 seconds
# getting url with title/tt10941044...
# url loaded
# Getting attributes for tt10941044
# Getting cast for tt10941044
# time to obtain tt10941044 with position 132 was 2 seconds
# getting url with title/tt10947128...
# url loaded
# Getting attributes for tt10947128
# Getting cast for tt10947128
# time to obtain tt10947128 with position 133 was 2 seconds
# getting url with title/tt10949052...
# url loaded
# Getting attributes for tt10949052
# Getting cast for tt10949052
# time to obtain tt10949052 with position 134 was 2 seconds
# getting url with title/tt10949768...
# url loaded
# Getting attributes for tt10949768
# Getting cast for tt10949768
# time to obtain tt10949768 with position 135 was 4 seconds
# getting url with title/tt10952024...
# url loaded
# Getting attributes for tt10952024
# Getting cast for tt10952024
# time to obtain tt10952024 with position 136 was 4 seconds
# getting url with title/tt10953880...
# url loaded
# Getting attributes for tt10953880
# Getting cast for tt10953880
# time to obtain tt10953880 with position 137 was 3 seconds
# getting url with title/tt10954458...
# url loaded
# Getting attributes for tt10954458
# Getting cast for tt10954458
# time to obtain tt10954458 with position 138 was 2 seconds
# getting url with title/tt10959348...
# url loaded
# Getting attributes for tt10959348
# Getting cast for tt10959348
# time to obtain tt10959348 with position 139 was 2 seconds
# getting url with title/tt10961188...
# url loaded
# Getting attributes for tt10961188
# Getting cast for tt10961188
# time to obtain tt10961188 with position 140 was 2 seconds
# getting url with title/tt10959336...
# url loaded
# Getting attributes for tt10959336
# Getting cast for tt10959336
# time to obtain tt10959336 with position 141 was 2 seconds
# getting url with title/tt10969224...
# url loaded
# Getting attributes for tt10969224
# Getting cast for tt10969224
# time to obtain tt10969224 with position 142 was 2 seconds
# getting url with title/tt10980954...
# url loaded
# Getting attributes for tt10980954
# Getting cast for tt10980954
# time to obtain tt10980954 with position 143 was 2 seconds
# getting url with title/tt10994156...
# url loaded
# Getting attributes for tt10994156
# Getting cast for tt10994156
# time to obtain tt10994156 with position 144 was 3 seconds
# getting url with title/tt11000672...
# url loaded
# Getting attributes for tt11000672
# Getting cast for tt11000672
# time to obtain tt11000672 with position 145 was 3 seconds
# getting url with title/tt11004574...
# url loaded
# Getting attributes for tt11004574
# Getting cast for tt11004574
# time to obtain tt11004574 with position 146 was 2 seconds
# getting url with title/tt11011272...
# url loaded
# Getting attributes for tt11011272
# Getting cast for tt11011272
# time to obtain tt11011272 with position 147 was 2 seconds
# getting url with title/tt11021772...
# url loaded
# Getting attributes for tt11021772
# Getting cast for tt11021772
# time to obtain tt11021772 with position 148 was 2 seconds
# getting url with title/tt11042878...
# url loaded
# Getting attributes for tt11042878
# Getting cast for tt11042878
# time to obtain tt11042878 with position 149 was 3 seconds
# getting url with title/tt11043522...
# url loaded
# Getting attributes for tt11043522
# Getting cast for tt11043522
# time to obtain tt11043522 with position 150 was 2 seconds
# getting url with title/tt11044090...
# url loaded
# Getting attributes for tt11044090
# Getting cast for tt11044090
# time to obtain tt11044090 with position 151 was 3 seconds
# getting url with title/tt11046630...
# url loaded
# Getting attributes for tt11046630
# Getting cast for tt11046630
# time to obtain tt11046630 with position 152 was 2 seconds
# getting url with title/tt11050440...
# url loaded
# Getting attributes for tt11050440
# Getting cast for tt11050440
# time to obtain tt11050440 with position 153 was 3 seconds
# getting url with title/tt11055560...
# url loaded
# Getting attributes for tt11055560
# error obtaining name for id tt11055560
# Getting cast for tt11055560
# time to obtain tt11055560 with position 154 was 2 seconds
# getting url with title/tt11061916...
# url loaded
# Getting attributes for tt11061916
# Getting cast for tt11061916
# time to obtain tt11061916 with position 155 was 2 seconds
# getting url with title/tt11065194...
# url loaded
# Getting attributes for tt11065194
# Getting cast for tt11065194
# time to obtain tt11065194 with position 156 was 2 seconds
# getting url with title/tt11070724...
# url loaded
# Getting attributes for tt11070724
# Getting cast for tt11070724
# time to obtain tt11070724 with position 157 was 2 seconds
# getting url with title/tt11081318...
# url loaded
# Getting attributes for tt11081318
# Getting cast for tt11081318
# time to obtain tt11081318 with position 158 was 2 seconds
# getting url with title/tt11083280...
# url loaded
# Getting attributes for tt11083280
# Getting cast for tt11083280
# time to obtain tt11083280 with position 159 was 2 seconds
# getting url with title/tt11086286...
# url loaded
# Getting attributes for tt11086286
# Getting cast for tt11086286
# time to obtain tt11086286 with position 160 was 3 seconds
# getting url with title/tt11086104...
# url loaded
# Getting attributes for tt11086104
# Getting cast for tt11086104
# time to obtain tt11086104 with position 161 was 2 seconds
# getting url with title/tt11092496...
# url loaded
# Getting attributes for tt11092496
# Getting cast for tt11092496
# time to obtain tt11092496 with position 162 was 2 seconds
# getting url with title/tt11095494...
# url loaded
# Getting attributes for tt11095494
# Getting cast for tt11095494
# time to obtain tt11095494 with position 163 was 2 seconds
# getting url with title/tt11101812...
# url loaded
# Getting attributes for tt11101812
# Getting cast for tt11101812
# time to obtain tt11101812 with position 164 was 2 seconds
# getting url with title/tt11112028...
# url loaded
# Getting attributes for tt11112028
# Getting cast for tt11112028
# time to obtain tt11112028 with position 165 was 2 seconds
# getting url with title/tt11114792...
# url loaded
# Getting attributes for tt11114792
# Getting cast for tt11114792
# time to obtain tt11114792 with position 166 was 3 seconds
# getting url with title/tt11121578...
# url loaded
# Getting attributes for tt11121578
# Getting cast for tt11121578
# time to obtain tt11121578 with position 167 was 2 seconds
# getting url with title/tt11126992...
# url loaded
# Getting attributes for tt11126992
# Getting cast for tt11126992
# time to obtain tt11126992 with position 168 was 3 seconds
# getting url with title/tt11131160...
# url loaded
# Getting attributes for tt11131160
# Getting cast for tt11131160
# time to obtain tt11131160 with position 169 was 3 seconds
# getting url with title/tt11137438...
# url loaded
# Getting attributes for tt11137438
# Getting cast for tt11137438
# time to obtain tt11137438 with position 170 was 3 seconds
# getting url with title/tt11136418...
# url loaded
# Getting attributes for tt11136418
# Getting cast for tt11136418
# time to obtain tt11136418 with position 171 was 3 seconds
# getting url with title/tt11138236...
# url loaded
# Getting attributes for tt11138236
# Getting cast for tt11138236
# time to obtain tt11138236 with position 172 was 2 seconds
# getting url with title/tt11151074...
# url loaded
# Getting attributes for tt11151074
# Getting cast for tt11151074
# time to obtain tt11151074 with position 173 was 2 seconds
# getting url with title/tt11155802...
# url loaded
# Getting attributes for tt11155802
# Getting cast for tt11155802
# time to obtain tt11155802 with position 174 was 3 seconds
# getting url with title/tt11154218...
# url loaded
# Getting attributes for tt11154218
# Getting cast for tt11154218
# time to obtain tt11154218 with position 175 was 2 seconds
# getting url with title/tt11162220...
# url loaded
# Getting attributes for tt11162220
# Getting cast for tt11162220
# time to obtain tt11162220 with position 176 was 3 seconds
# getting url with title/tt11163066...
# url loaded
# Getting attributes for tt11163066
# Getting cast for tt11163066
# time to obtain tt11163066 with position 177 was 3 seconds
# getting url with title/tt11162224...
# url loaded
# Getting attributes for tt11162224
# Getting cast for tt11162224
# time to obtain tt11162224 with position 178 was 3 seconds
# getting url with title/tt11166472...
# url loaded
# Getting attributes for tt11166472
# Getting cast for tt11166472
# time to obtain tt11166472 with position 179 was 3 seconds
# getting url with title/tt11172672...
# url loaded
# Getting attributes for tt11172672
# Getting cast for tt11172672
# time to obtain tt11172672 with position 180 was 3 seconds
# getting url with title/tt11183332...
# url loaded
# Getting attributes for tt11183332
# Getting cast for tt11183332
# time to obtain tt11183332 with position 181 was 4 seconds
# getting url with title/tt11192394...
# url loaded
# Getting attributes for tt11192394
# error obtaining name for id tt11192394
# Getting cast for tt11192394
# time to obtain tt11192394 with position 182 was 1 seconds
# getting url with title/tt11192736...
# url loaded
# Getting attributes for tt11192736
# Getting cast for tt11192736
# time to obtain tt11192736 with position 183 was 2 seconds
# getting url with title/tt11194056...
# url loaded
# Getting attributes for tt11194056
# Getting cast for tt11194056
# time to obtain tt11194056 with position 184 was 3 seconds
# getting url with title/tt11198136...
# url loaded
# Getting attributes for tt11198136
# Getting cast for tt11198136
# time to obtain tt11198136 with position 185 was 3 seconds
# getting url with title/tt11203132...
# url loaded
# Getting attributes for tt11203132
# Getting cast for tt11203132
# time to obtain tt11203132 with position 186 was 2 seconds
# getting url with title/tt11212278...
# url loaded
# Getting attributes for tt11212278
# Getting cast for tt11212278
# time to obtain tt11212278 with position 187 was 3 seconds
# getting url with title/tt11213404...
# url loaded
# Getting attributes for tt11213404
# Getting cast for tt11213404
# time to obtain tt11213404 with position 188 was 3 seconds
# getting url with title/tt11226358...
# url loaded
# Getting attributes for tt11226358
# Getting cast for tt11226358
# time to obtain tt11226358 with position 189 was 3 seconds
# getting url with title/tt11230174...
# url loaded
# Getting attributes for tt11230174
# Getting cast for tt11230174
# time to obtain tt11230174 with position 190 was 2 seconds
# getting url with title/tt11235876...
# url loaded
# Getting attributes for tt11235876
# Getting cast for tt11235876
# time to obtain tt11235876 with position 191 was 3 seconds
# getting url with title/tt11239486...
# url loaded
# Getting attributes for tt11239486
# Getting cast for tt11239486
# time to obtain tt11239486 with position 192 was 3 seconds
# getting url with title/tt11236294...
# url loaded
# Getting attributes for tt11236294
# Getting cast for tt11236294
# time to obtain tt11236294 with position 193 was 3 seconds
# getting url with title/tt11238748...
# url loaded
# Getting attributes for tt11238748
# Getting cast for tt11238748
# time to obtain tt11238748 with position 194 was 3 seconds
# getting url with title/tt11240806...
# url loaded
# Getting attributes for tt11240806
# Getting cast for tt11240806
# time to obtain tt11240806 with position 195 was 4 seconds
# getting url with title/tt11241198...
# url loaded
# Getting attributes for tt11241198
# Getting cast for tt11241198
# time to obtain tt11241198 with position 196 was 2 seconds
# getting url with title/tt11241724...
# url loaded
# Getting attributes for tt11241724
# Getting cast for tt11241724
# time to obtain tt11241724 with position 197 was 3 seconds
# getting url with title/tt11242792...
# url loaded
# Getting attributes for tt11242792
# Getting cast for tt11242792
# time to obtain tt11242792 with position 198 was 2 seconds
# getting url with title/tt11246630...
# url loaded
# Getting attributes for tt11246630
# Getting cast for tt11246630
# time to obtain tt11246630 with position 199 was 3 seconds
# getting url with title/tt11246768...
# url loaded
# Getting attributes for tt11246768
# Getting cast for tt11246768
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt11246768 with position 200 was 12 seconds
# getting url with title/tt11247700...
# url loaded
# Getting attributes for tt11247700
# Getting cast for tt11247700
# time to obtain tt11247700 with position 201 was 2 seconds
# getting url with title/tt11252308...
# url loaded
# Getting attributes for tt11252308
# Getting cast for tt11252308
# time to obtain tt11252308 with position 202 was 2 seconds
# getting url with title/tt11251756...
# url loaded
# Getting attributes for tt11251756
# Getting cast for tt11251756
# time to obtain tt11251756 with position 203 was 3 seconds
# getting url with title/tt11256508...
# url loaded
# Getting attributes for tt11256508
# Getting cast for tt11256508
# time to obtain tt11256508 with position 204 was 2 seconds
# getting url with title/tt11259728...
# url loaded
# Getting attributes for tt11259728
# Getting cast for tt11259728
# time to obtain tt11259728 with position 205 was 2 seconds
# getting url with title/tt11274622...
# url loaded
# Getting attributes for tt11274622
# Getting cast for tt11274622
# time to obtain tt11274622 with position 206 was 2 seconds
# getting url with title/tt11281294...
# url loaded
# Getting attributes for tt11281294
# Getting cast for tt11281294
# time to obtain tt11281294 with position 207 was 2 seconds
# getting url with title/tt11282090...
# url loaded
# Getting attributes for tt11282090
# Getting cast for tt11282090
# time to obtain tt11282090 with position 208 was 3 seconds
# getting url with title/tt11290778...
# url loaded
# Getting attributes for tt11290778
# Getting cast for tt11290778
# time to obtain tt11290778 with position 209 was 2 seconds
# getting url with title/tt11291254...
# url loaded
# Getting attributes for tt11291254
# Getting cast for tt11291254
# time to obtain tt11291254 with position 210 was 3 seconds
# getting url with title/tt11296542...
# url loaded
# Getting attributes for tt11296542
# error obtaining name for id tt11296542
# Getting cast for tt11296542
# time to obtain tt11296542 with position 211 was 1 seconds
# getting url with title/tt11304644...
# url loaded
# Getting attributes for tt11304644
# Getting cast for tt11304644
# time to obtain tt11304644 with position 212 was 2 seconds
# getting url with title/tt11306178...
# url loaded
# Getting attributes for tt11306178
# Getting cast for tt11306178
# time to obtain tt11306178 with position 213 was 2 seconds
# getting url with title/tt11305914...
# url loaded
# Getting attributes for tt11305914
# Getting cast for tt11305914
# time to obtain tt11305914 with position 214 was 2 seconds
# getting url with title/tt11306262...
# url loaded
# Getting attributes for tt11306262
# Getting cast for tt11306262
# time to obtain tt11306262 with position 215 was 3 seconds
# getting url with title/tt11307554...
# url loaded
# Getting attributes for tt11307554
# Getting cast for tt11307554
# time to obtain tt11307554 with position 216 was 2 seconds
# getting url with title/tt11306946...
# url loaded
# Getting attributes for tt11306946
# Getting cast for tt11306946
# time to obtain tt11306946 with position 217 was 2 seconds
# getting url with title/tt11306882...
# url loaded
# Getting attributes for tt11306882
# Getting cast for tt11306882
# time to obtain tt11306882 with position 218 was 2 seconds
# getting url with title/tt11311288...
# url loaded
# Getting attributes for tt11311288
# Getting cast for tt11311288
# time to obtain tt11311288 with position 219 was 2 seconds
# getting url with title/tt11313094...
# url loaded
# Getting attributes for tt11313094
# Getting cast for tt11313094
# time to obtain tt11313094 with position 220 was 2 seconds
# getting url with title/tt11317388...
# url loaded
# Getting attributes for tt11317388
# Getting cast for tt11317388
# time to obtain tt11317388 with position 221 was 2 seconds
# getting url with title/tt11321956...
# url loaded
# Getting attributes for tt11321956
# Getting cast for tt11321956
# time to obtain tt11321956 with position 222 was 2 seconds
# getting url with title/tt11323362...
# url loaded
# Getting attributes for tt11323362
# Getting cast for tt11323362
# time to obtain tt11323362 with position 223 was 2 seconds
# getting url with title/tt11322816...
# url loaded
# Getting attributes for tt11322816
# Getting cast for tt11322816
# time to obtain tt11322816 with position 224 was 2 seconds
# getting url with title/tt11333008...
# url loaded
# Getting attributes for tt11333008
# Getting cast for tt11333008
# time to obtain tt11333008 with position 225 was 2 seconds
# getting url with title/tt11336098...
# url loaded
# Getting attributes for tt11336098
# Getting cast for tt11336098
# time to obtain tt11336098 with position 226 was 2 seconds
# getting url with title/tt11337834...
# url loaded
# Getting attributes for tt11337834
# Getting cast for tt11337834
# time to obtain tt11337834 with position 227 was 3 seconds
# getting url with title/tt11344036...
# url loaded
# Getting attributes for tt11344036
# Getting cast for tt11344036
# time to obtain tt11344036 with position 228 was 2 seconds
# getting url with title/tt11343208...
# url loaded
# Getting attributes for tt11343208
# Getting cast for tt11343208
# time to obtain tt11343208 with position 229 was 2 seconds
# getting url with title/tt11348438...
# url loaded
# Getting attributes for tt11348438
# Getting cast for tt11348438
# time to obtain tt11348438 with position 230 was 2 seconds
# getting url with title/tt11352002...
# url loaded
# Getting attributes for tt11352002
# Getting cast for tt11352002
# time to obtain tt11352002 with position 231 was 2 seconds
# getting url with title/tt11355510...
# url loaded
# Getting attributes for tt11355510
# Getting cast for tt11355510
# time to obtain tt11355510 with position 232 was 2 seconds
# getting url with title/tt11359160...
# url loaded
# Getting attributes for tt11359160
# Getting cast for tt11359160
# time to obtain tt11359160 with position 233 was 2 seconds
# getting url with title/tt11363862...
# url loaded
# Getting attributes for tt11363862
# Getting cast for tt11363862
# time to obtain tt11363862 with position 234 was 3 seconds
# getting url with title/tt11378940...
# url loaded
# Getting attributes for tt11378940
# Getting cast for tt11378940
# time to obtain tt11378940 with position 235 was 2 seconds
# getting url with title/tt11378890...
# url loaded
# Getting attributes for tt11378890
# Getting cast for tt11378890
# time to obtain tt11378890 with position 236 was 3 seconds
# getting url with title/tt11378726...
# url loaded
# Getting attributes for tt11378726
# Getting cast for tt11378726
# time to obtain tt11378726 with position 237 was 2 seconds
# getting url with title/tt11384312...
# url loaded
# Getting attributes for tt11384312
# Getting cast for tt11384312
# time to obtain tt11384312 with position 238 was 3 seconds
# getting url with title/tt11383808...
# url loaded
# Getting attributes for tt11383808
# Getting cast for tt11383808
# time to obtain tt11383808 with position 239 was 2 seconds
# getting url with title/tt11399696...
# url loaded
# Getting attributes for tt11399696
# Getting cast for tt11399696
# time to obtain tt11399696 with position 240 was 2 seconds
# getting url with title/tt11401130...
# url loaded
# Getting attributes for tt11401130
# Getting cast for tt11401130
# time to obtain tt11401130 with position 241 was 2 seconds
# getting url with title/tt11410008...
# url loaded
# Getting attributes for tt11410008
# Getting cast for tt11410008
# time to obtain tt11410008 with position 242 was 3 seconds
# getting url with title/tt11409458...
# url loaded
# Getting attributes for tt11409458
# Getting cast for tt11409458
# time to obtain tt11409458 with position 243 was 2 seconds
# getting url with title/tt11417880...
# url loaded
# Getting attributes for tt11417880
# Getting cast for tt11417880
# time to obtain tt11417880 with position 244 was 2 seconds
# getting url with title/tt11429548...
# url loaded
# Getting attributes for tt11429548
# error obtaining name for id tt11429548
# Getting cast for tt11429548
# time to obtain tt11429548 with position 245 was 60 seconds
# getting url with title/tt11427786...
# url loaded
# Getting attributes for tt11427786
# Getting cast for tt11427786
# time to obtain tt11427786 with position 246 was 2 seconds
# getting url with title/tt11435582...
# url loaded
# Getting attributes for tt11435582
# Getting cast for tt11435582
# time to obtain tt11435582 with position 247 was 3 seconds
# getting url with title/tt11437092...
# url loaded
# Getting attributes for tt11437092
# Getting cast for tt11437092
# time to obtain tt11437092 with position 248 was 2 seconds
# getting url with title/tt11440924...
# url loaded
# Getting attributes for tt11440924
# Getting cast for tt11440924
# time to obtain tt11440924 with position 249 was 2 seconds
# getting url with title/tt11442176...
# url loaded
# Getting attributes for tt11442176
# Getting cast for tt11442176
# time to obtain tt11442176 with position 250 was 2 seconds
# getting url with title/tt11448530...
# url loaded
# Getting attributes for tt11448530
# Getting cast for tt11448530
# time to obtain tt11448530 with position 251 was 2 seconds
# getting url with title/tt11459374...
# url loaded
# Getting attributes for tt11459374
# Getting cast for tt11459374
# time to obtain tt11459374 with position 252 was 3 seconds
# getting url with title/tt11453170...
# url loaded
# Getting attributes for tt11453170
# Getting cast for tt11453170
# time to obtain tt11453170 with position 253 was 2 seconds
# getting url with title/tt11462182...
# url loaded
# Getting attributes for tt11462182
# Getting cast for tt11462182
# time to obtain tt11462182 with position 254 was 2 seconds
# getting url with title/tt11464562...
# url loaded
# Getting attributes for tt11464562
# error obtaining name for id tt11464562
# Getting cast for tt11464562
# time to obtain tt11464562 with position 255 was 60 seconds
# getting url with title/tt11464632...
# url loaded
# Getting attributes for tt11464632
# Getting cast for tt11464632
# time to obtain tt11464632 with position 256 was 2 seconds
# getting url with title/tt11472772...
# url loaded
# Getting attributes for tt11472772
# Getting cast for tt11472772
# time to obtain tt11472772 with position 257 was 2 seconds
# getting url with title/tt11471250...
# url loaded
# Getting attributes for tt11471250
# Getting cast for tt11471250
# time to obtain tt11471250 with position 258 was 2 seconds
# getting url with title/tt11474166...
# url loaded
# Getting attributes for tt11474166
# Getting cast for tt11474166
# time to obtain tt11474166 with position 259 was 2 seconds
# getting url with title/tt11471296...
# url loaded
# Getting attributes for tt11471296
# Getting cast for tt11471296
# time to obtain tt11471296 with position 260 was 2 seconds
# getting url with title/tt11471894...
# url loaded
# Getting attributes for tt11471894
# Getting cast for tt11471894
# time to obtain tt11471894 with position 261 was 2 seconds
# getting url with title/tt11473942...
# url loaded
# Getting attributes for tt11473942
# Getting cast for tt11473942
# time to obtain tt11473942 with position 262 was 2 seconds
# getting url with title/tt11505844...
# url loaded
# Getting attributes for tt11505844
# Getting cast for tt11505844
# time to obtain tt11505844 with position 263 was 3 seconds
# getting url with title/tt11512026...
# url loaded
# Getting attributes for tt11512026
# Getting cast for tt11512026
# time to obtain tt11512026 with position 264 was 2 seconds
# getting url with title/tt11524124...
# url loaded
# Getting attributes for tt11524124
# Getting cast for tt11524124
# time to obtain tt11524124 with position 265 was 2 seconds
# getting url with title/tt11527600...
# url loaded
# Getting attributes for tt11527600
# Getting cast for tt11527600
# time to obtain tt11527600 with position 266 was 2 seconds
# getting url with title/tt11526646...
# url loaded
# Getting attributes for tt11526646
# Getting cast for tt11526646
# time to obtain tt11526646 with position 267 was 2 seconds
# getting url with title/tt11529588...
# url loaded
# Getting attributes for tt11529588
# Getting cast for tt11529588
# time to obtain tt11529588 with position 268 was 2 seconds
# getting url with title/tt11536594...
# url loaded
# Getting attributes for tt11536594
# Getting cast for tt11536594
# time to obtain tt11536594 with position 269 was 2 seconds
# getting url with title/tt11552480...
# url loaded
# Getting attributes for tt11552480
# Getting cast for tt11552480
# time to obtain tt11552480 with position 270 was 2 seconds
# getting url with title/tt11554930...
# url loaded
# Getting attributes for tt11554930
# Getting cast for tt11554930
# time to obtain tt11554930 with position 271 was 1 seconds
# getting url with title/tt11558632...
# url loaded
# Getting attributes for tt11558632
# Getting cast for tt11558632
# time to obtain tt11558632 with position 272 was 2 seconds
# getting url with title/tt11563664...
# url loaded
# Getting attributes for tt11563664
# Getting cast for tt11563664
# time to obtain tt11563664 with position 273 was 2 seconds
# getting url with title/tt11570344...
# url loaded
# Getting attributes for tt11570344
# Getting cast for tt11570344
# time to obtain tt11570344 with position 274 was 2 seconds
# getting url with title/tt11570620...
# url loaded
# Getting attributes for tt11570620
# Getting cast for tt11570620
# time to obtain tt11570620 with position 275 was 3 seconds
# getting url with title/tt11575400...
# url loaded
# Getting attributes for tt11575400
# Getting cast for tt11575400
# time to obtain tt11575400 with position 276 was 3 seconds
# getting url with title/tt11578718...
# url loaded
# Getting attributes for tt11578718
# Getting cast for tt11578718
# time to obtain tt11578718 with position 277 was 2 seconds
# getting url with title/tt11581378...
# url loaded
# Getting attributes for tt11581378
# Getting cast for tt11581378
# time to obtain tt11581378 with position 278 was 2 seconds
# getting url with title/tt11590164...
# url loaded
# Getting attributes for tt11590164
# Getting cast for tt11590164
# time to obtain tt11590164 with position 279 was 2 seconds
# getting url with title/tt11591420...
# url loaded
# Getting attributes for tt11591420
# Getting cast for tt11591420
# time to obtain tt11591420 with position 280 was 2 seconds
# getting url with title/tt11604286...
# url loaded
# Getting attributes for tt11604286
# Getting cast for tt11604286
# time to obtain tt11604286 with position 281 was 2 seconds
# getting url with title/tt11608184...
# url loaded
# Getting attributes for tt11608184
# Getting cast for tt11608184
# time to obtain tt11608184 with position 282 was 2 seconds
# ...
# Getting cast for tt11922936
# time to obtain tt11922936 with position 405 was 3 seconds
# getting url with title/tt11928650...
# url loaded
# Getting attributes for tt11928650
# Getting cast for tt11928650
# time to obtain tt11928650 with position 406 was 2 seconds
# getting url with title/tt11928476...
# url loaded
# Getting attributes for tt11928476
# Getting cast for tt11928476
# time to obtain tt11928476 with position 407 was 2 seconds
# getting url with title/tt11930436...
# url loaded
# Getting attributes for tt11930436
# error obtaining name for id tt11930436
# Getting cast for tt11930436
# time to obtain tt11930436 with position 408 was 1 seconds
# getting url with title/tt11929754...
# url loaded
# Getting attributes for tt11929754
# Getting cast for tt11929754
# time to obtain tt11929754 with position 409 was 3 seconds
# getting url with title/tt11933162...
# url loaded
# Getting attributes for tt11933162
# Getting cast for tt11933162
# time to obtain tt11933162 with position 410 was 2 seconds
# getting url with title/tt11935556...
# url loaded
# Getting attributes for tt11935556
# Getting cast for tt11935556
# time to obtain tt11935556 with position 411 was 3 seconds
# getting url with title/tt11935384...
# url loaded
# Getting attributes for tt11935384
# Getting cast for tt11935384
# time to obtain tt11935384 with position 412 was 3 seconds
# getting url with title/tt11940194...
# url loaded
# Getting attributes for tt11940194
# Getting cast for tt11940194
# time to obtain tt11940194 with position 413 was 2 seconds
# getting url with title/tt11937652...
# url loaded
# Getting attributes for tt11937652
# Getting cast for tt11937652
# time to obtain tt11937652 with position 414 was 3 seconds
# getting url with title/tt11941410...
# url loaded
# Getting attributes for tt11941410
# Getting cast for tt11941410
# time to obtain tt11941410 with position 415 was 3 seconds
# getting url with title/tt11941200...
# url loaded
# Getting attributes for tt11941200
# Getting cast for tt11941200
# time to obtain tt11941200 with position 416 was 4 seconds
# getting url with title/tt11940700...
# url loaded
# Getting attributes for tt11940700
# Getting cast for tt11940700
# time to obtain tt11940700 with position 417 was 3 seconds
# getting url with title/tt11942174...
# url loaded
# Getting attributes for tt11942174
# Getting cast for tt11942174
# time to obtain tt11942174 with position 418 was 4 seconds
# getting url with title/tt11946352...
# url loaded
# Getting attributes for tt11946352
# Getting cast for tt11946352
# time to obtain tt11946352 with position 419 was 4 seconds
# getting url with title/tt11945370...
# url loaded
# Getting attributes for tt11945370
# Getting cast for tt11945370
# time to obtain tt11945370 with position 420 was 2 seconds
# getting url with title/tt11944396...
# url loaded
# Getting attributes for tt11944396
# Getting cast for tt11944396
# time to obtain tt11944396 with position 421 was 2 seconds
# getting url with title/tt11947680...
# url loaded
# Getting attributes for tt11947680
# Getting cast for tt11947680
# time to obtain tt11947680 with position 422 was 3 seconds
# getting url with title/tt11947010...
# url loaded
# Getting attributes for tt11947010
# error obtaining name for id tt11947010
# Getting cast for tt11947010
# time to obtain tt11947010 with position 423 was 1 seconds
# getting url with title/tt11951220...
# url loaded
# Getting attributes for tt11951220
# Getting cast for tt11951220
# time to obtain tt11951220 with position 424 was 2 seconds
# getting url with title/tt11956646...
# url loaded
# Getting attributes for tt11956646
# Getting cast for tt11956646
# time to obtain tt11956646 with position 425 was 4 seconds
# getting url with title/tt11960222...
# url loaded
# Getting attributes for tt11960222
# Getting cast for tt11960222
# time to obtain tt11960222 with position 426 was 2 seconds
# getting url with title/tt11961888...
# url loaded
# Getting attributes for tt11961888
# Getting cast for tt11961888
# time to obtain tt11961888 with position 427 was 3 seconds
# getting url with title/tt11968654...
# url loaded
# Getting attributes for tt11968654
# Getting cast for tt11968654
# time to obtain tt11968654 with position 428 was 2 seconds
# getting url with title/tt11980598...
# url loaded
# Getting attributes for tt11980598
# Getting cast for tt11980598
# time to obtain tt11980598 with position 429 was 3 seconds
# getting url with title/tt11980226...
# url loaded
# Getting attributes for tt11980226
# Getting cast for tt11980226
# time to obtain tt11980226 with position 430 was 4 seconds
# getting url with title/tt11985218...
# url loaded
# Getting attributes for tt11985218
# Getting cast for tt11985218
# time to obtain tt11985218 with position 431 was 5 seconds
# getting url with title/tt11988300...
# url loaded
# Getting attributes for tt11988300
# Getting cast for tt11988300
# time to obtain tt11988300 with position 432 was 4 seconds
# getting url with title/tt11993782...
# url loaded
# Getting attributes for tt11993782
# Getting cast for tt11993782
# time to obtain tt11993782 with position 433 was 2 seconds
# getting url with title/tt11997504...
# url loaded
# Getting attributes for tt11997504
# Getting cast for tt11997504
# time to obtain tt11997504 with position 434 was 3 seconds
# getting url with title/tt12016516...
# url loaded
# Getting attributes for tt12016516
# Getting cast for tt12016516
# time to obtain tt12016516 with position 435 was 7 seconds
# getting url with title/tt12014120...
# url loaded
# Getting attributes for tt12014120
# Getting cast for tt12014120
# time to obtain tt12014120 with position 436 was 5 seconds
# getting url with title/tt12016198...
# url loaded
# Getting attributes for tt12016198
# Getting cast for tt12016198
# time to obtain tt12016198 with position 437 was 4 seconds
# getting url with title/tt12013428...
# url loaded
# Getting attributes for tt12013428
# Getting cast for tt12013428
# time to obtain tt12013428 with position 438 was 4 seconds
# getting url with title/tt12019312...
# url loaded
# Getting attributes for tt12019312
# Getting cast for tt12019312
# time to obtain tt12019312 with position 439 was 2 seconds
# getting url with title/tt12021170...
# url loaded
# Getting attributes for tt12021170
# Getting cast for tt12021170
# time to obtain tt12021170 with position 440 was 3 seconds
# getting url with title/tt12025422...
# url loaded
# Getting attributes for tt12025422
# Getting cast for tt12025422
# time to obtain tt12025422 with position 441 was 2 seconds
# getting url with title/tt12025470...
# url loaded
# Getting attributes for tt12025470
# Getting cast for tt12025470
# time to obtain tt12025470 with position 442 was 3 seconds
# getting url with title/tt12030648...
# url loaded
# Getting attributes for tt12030648
# Getting cast for tt12030648
# time to obtain tt12030648 with position 443 was 4 seconds
# getting url with title/tt12034870...
# url loaded
# Getting attributes for tt12034870
# Getting cast for tt12034870
# time to obtain tt12034870 with position 444 was 3 seconds
# getting url with title/tt12042814...
# url loaded
# Getting attributes for tt12042814
# Getting cast for tt12042814
# time to obtain tt12042814 with position 445 was 6 seconds
# getting url with title/tt12044326...
# url loaded
# Getting attributes for tt12044326
# Getting cast for tt12044326
# time to obtain tt12044326 with position 446 was 8 seconds
# getting url with title/tt12048070...
# url loaded
# Getting attributes for tt12048070
# Getting cast for tt12048070
# time to obtain tt12048070 with position 447 was 9 seconds
# getting url with title/tt12048090...
# url loaded
# Getting attributes for tt12048090
# Getting cast for tt12048090
# time to obtain tt12048090 with position 448 was 6 seconds
# getting url with title/tt12047654...
# url loaded
# Getting attributes for tt12047654
# Getting cast for tt12047654
# time to obtain tt12047654 with position 449 was 7 seconds
# getting url with title/tt12051110...
# url loaded
# Getting attributes for tt12051110
# Getting cast for tt12051110
# time to obtain tt12051110 with position 450 was 5 seconds
# getting url with title/tt12052990...
# url loaded
# Getting attributes for tt12052990
# Getting cast for tt12052990
# time to obtain tt12052990 with position 451 was 2 seconds
# getting url with title/tt12053328...
# url loaded
# Getting attributes for tt12053328
# Getting cast for tt12053328
# time to obtain tt12053328 with position 452 was 4 seconds
# getting url with title/tt12055404...
# url loaded
# Getting attributes for tt12055404
# Getting cast for tt12055404
# time to obtain tt12055404 with position 453 was 5 seconds
# getting url with title/tt12060046...
# url loaded
# Getting attributes for tt12060046
# Getting cast for tt12060046
# time to obtain tt12060046 with position 454 was 6 seconds
# getting url with title/tt12060664...
# url loaded
# Getting attributes for tt12060664
# Getting cast for tt12060664
# time to obtain tt12060664 with position 455 was 3 seconds
# getting url with title/tt12063594...
# url loaded
# Getting attributes for tt12063594
# Getting cast for tt12063594
# time to obtain tt12063594 with position 456 was 6 seconds
# getting url with title/tt12076718...
# url loaded
# Getting attributes for tt12076718
# Getting cast for tt12076718
# time to obtain tt12076718 with position 457 was 3 seconds
# getting url with title/tt12078610...
# url loaded
# Getting attributes for tt12078610
# Getting cast for tt12078610
# time to obtain tt12078610 with position 458 was 8 seconds
# getting url with title/tt12078050...
# url loaded
# Getting attributes for tt12078050
# Getting cast for tt12078050
# time to obtain tt12078050 with position 459 was 3 seconds
# getting url with title/tt12082856...
# url loaded
# Getting attributes for tt12082856
# Getting cast for tt12082856
# time to obtain tt12082856 with position 460 was 5 seconds
# getting url with title/tt12089260...
# url loaded
# Getting attributes for tt12089260
# Getting cast for tt12089260
# time to obtain tt12089260 with position 461 was 4 seconds
# getting url with title/tt12099304...
# url loaded
# Getting attributes for tt12099304
# Getting cast for tt12099304
# time to obtain tt12099304 with position 462 was 5 seconds
# getting url with title/tt12098966...
# url loaded
# Getting attributes for tt12098966
# Getting cast for tt12098966
# time to obtain tt12098966 with position 463 was 3 seconds
# getting url with title/tt12101076...
# url loaded
# Getting attributes for tt12101076
# Getting cast for tt12101076
# time to obtain tt12101076 with position 464 was 3 seconds
# getting url with title/tt12106238...
# url loaded
# Getting attributes for tt12106238
# Getting cast for tt12106238
# time to obtain tt12106238 with position 465 was 2 seconds
# getting url with title/tt12121228...
# url loaded
# Getting attributes for tt12121228
# Getting cast for tt12121228
# time to obtain tt12121228 with position 466 was 3 seconds
# getting url with title/tt12144864...
# url loaded
# Getting attributes for tt12144864
# Getting cast for tt12144864
# time to obtain tt12144864 with position 467 was 6 seconds
# getting url with title/tt12153372...
# url loaded
# Getting attributes for tt12153372
# Getting cast for tt12153372
# time to obtain tt12153372 with position 468 was 6 seconds
# getting url with title/tt12154432...
# url loaded
# Getting attributes for tt12154432
# Getting cast for tt12154432
# time to obtain tt12154432 with position 469 was 5 seconds
# getting url with title/tt12157862...
# url loaded
# Getting attributes for tt12157862
# Getting cast for tt12157862
# time to obtain tt12157862 with position 470 was 2 seconds
# getting url with title/tt12160464...
# url loaded
# Getting attributes for tt12160464
# Getting cast for tt12160464
# time to obtain tt12160464 with position 471 was 4 seconds
# getting url with title/tt12163974...
# url loaded
# Getting attributes for tt12163974
# Getting cast for tt12163974
# time to obtain tt12163974 with position 472 was 3 seconds
# getting url with title/tt12177084...
# url loaded
# Getting attributes for tt12177084
# Getting cast for tt12177084
# time to obtain tt12177084 with position 473 was 3 seconds
# getting url with title/tt12179884...
# url loaded
# Getting attributes for tt12179884
# Getting cast for tt12179884
# time to obtain tt12179884 with position 474 was 2 seconds
# getting url with title/tt12179564...
# url loaded
# Getting attributes for tt12179564
# Getting cast for tt12179564
# time to obtain tt12179564 with position 475 was 2 seconds
# getting url with title/tt12180042...
# url loaded
# Getting attributes for tt12180042
# Getting cast for tt12180042
# time to obtain tt12180042 with position 476 was 9 seconds
# getting url with title/tt12182196...
# url loaded
# Getting attributes for tt12182196
# Getting cast for tt12182196
# time to obtain tt12182196 with position 477 was 6 seconds
# getting url with title/tt12185928...
# url loaded
# Getting attributes for tt12185928
# Getting cast for tt12185928
# time to obtain tt12185928 with position 478 was 3 seconds
# getting url with title/tt12187494...
# url loaded
# Getting attributes for tt12187494
# error obtaining name for id tt12187494
# Getting cast for tt12187494
# time to obtain tt12187494 with position 479 was 60 seconds
# getting url with title/tt12188828...
# url loaded
# Getting attributes for tt12188828
# Getting cast for tt12188828
# time to obtain tt12188828 with position 480 was 2 seconds
# getting url with title/tt12193606...
# url loaded
# Getting attributes for tt12193606
# Getting cast for tt12193606
# time to obtain tt12193606 with position 481 was 2 seconds
# getting url with title/tt12199654...
# url loaded
# Getting attributes for tt12199654
# Getting cast for tt12199654
# time to obtain tt12199654 with position 482 was 2 seconds
# getting url with title/tt12198570...
# url loaded
# Getting attributes for tt12198570
# Getting cast for tt12198570
# time to obtain tt12198570 with position 483 was 2 seconds
# getting url with title/tt12202180...
# url loaded
# Getting attributes for tt12202180
# Getting cast for tt12202180
# time to obtain tt12202180 with position 484 was 2 seconds
# getting url with title/tt12211134...
# url loaded
# Getting attributes for tt12211134
# Getting cast for tt12211134
# time to obtain tt12211134 with position 485 was 2 seconds
# getting url with title/tt12211884...
# url loaded
# Getting attributes for tt12211884
# Getting cast for tt12211884
# time to obtain tt12211884 with position 486 was 3 seconds
# getting url with title/tt12219854...
# url loaded
# Getting attributes for tt12219854
# Getting cast for tt12219854
# time to obtain tt12219854 with position 487 was 2 seconds
# getting url with title/tt12223390...
# url loaded
# Getting attributes for tt12223390
# Getting cast for tt12223390
# time to obtain tt12223390 with position 488 was 2 seconds
# getting url with title/tt12221788...
# url loaded
# Getting attributes for tt12221788
# Getting cast for tt12221788
# time to obtain tt12221788 with position 489 was 2 seconds
# getting url with title/tt12221818...
# url loaded
# Getting attributes for tt12221818
# Getting cast for tt12221818
# time to obtain tt12221818 with position 490 was 2 seconds
# getting url with title/tt12225586...
# url loaded
# Getting attributes for tt12225586
# Getting cast for tt12225586
# time to obtain tt12225586 with position 491 was 2 seconds
# getting url with title/tt12225450...
# url loaded
# Getting attributes for tt12225450
# Getting cast for tt12225450
# time to obtain tt12225450 with position 492 was 2 seconds
# getting url with title/tt12227072...
# url loaded
# Getting attributes for tt12227072
# Getting cast for tt12227072
# time to obtain tt12227072 with position 493 was 2 seconds
# getting url with title/tt12230052...
# url loaded
# Getting attributes for tt12230052
# Getting cast for tt12230052
# time to obtain tt12230052 with position 494 was 2 seconds
# getting url with title/tt12233006...
# url loaded
# Getting attributes for tt12233006
# Getting cast for tt12233006
# time to obtain tt12233006 with position 495 was 2 seconds
# getting url with title/tt12237226...
# url loaded
# Getting attributes for tt12237226
# Getting cast for tt12237226
# time to obtain tt12237226 with position 496 was 2 seconds
# getting url with title/tt12239480...
# url loaded
# Getting attributes for tt12239480
# Getting cast for tt12239480
# time to obtain tt12239480 with position 497 was 2 seconds
# getting url with title/tt12240110...
# url loaded
# Getting attributes for tt12240110
# Getting cast for tt12240110
# time to obtain tt12240110 with position 498 was 3 seconds
# getting url with title/tt12250392...
# url loaded
# Getting attributes for tt12250392
# Getting cast for tt12250392
# time to obtain tt12250392 with position 499 was 2 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    3.974
# dtype: float64
