# %%
import pandas as pd
# Out:
# C:\Users\femes\AppData\Local\Temp\ipykernel_13816\217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_1 = pd.read_csv("incremental/fedra_actors_2014_ACCION_9014_10000.csv", index_col = 0)
df_2 = pd.read_csv("incremental/fedra_actors_2014_COMEDY_6019_6500.csv", index_col = 0)
df_3 = pd.read_csv("incremental/fedra_actors_2014_COMEDY_6500_6900.csv", index_col = 0)
df_4 = pd.read_csv("incremental/fedra_actors_2014_DRAMA_1_1000.csv", index_col = 0)
df_5 = pd.read_csv("incremental/fedra_actors_2015_ACCION_19309_20300.csv", index_col = 0)
df_6 = pd.read_csv("incremental/fedra_actors_2015_COMEDY_16379_17300.csv", index_col = 0)
df_7 = pd.read_csv("incremental/fedra_actors_2015_DRAMA_10188_11100.csv", index_col = 0)
df_8 = pd.read_csv("incremental/fedra_actors_2016_ACCION_29904_30900.csv", index_col = 0)
df_9 = pd.read_csv("incremental/fedra_actors_2016_COMEDY_26858_27700.csv", index_col = 0)
df_10 = pd.read_csv("incremental/fedra_actors_2016_DRAMA_20506_22500.csv", index_col = 0)
df_11 = pd.read_csv("incremental/fedra_actors_2017_ACCION_ 40757_41700.csv", index_col = 0)
df_12 = pd.read_csv("incremental/fedra_actors_2017_COMEDY_37686_38600.csv", index_col = 0)
df_13 = pd.read_csv("incremental/fedra_actors_2017_DRAMA_31252_32600.csv", index_col = 0)
df_14 = pd.read_csv("incremental/fedra_actors_2018_ACCION_51868_52800.csv", index_col = 0)
df_15 = pd.read_csv("incremental/fedra_actors_2018_COMEDY_48725_49100.csv", index_col = 0)
df_16 = pd.read_csv("incremental/fedra_actors_2018_COMEDY_49100_49700.csv", index_col = 0)
df_17 = pd.read_csv("incremental/fedra_actors_2018_DRAMA_42169_42600.csv", index_col = 0)
df_18 = pd.read_csv("incremental/fedra_actors_2018_DRAMA_42601_43600.csv", index_col = 0)
df_19 = pd.read_csv("incremental/fedra_actors_2019_ACCION_62488_63400.csv", index_col = 0)
df_20 = pd.read_csv("incremental/fedra_actors_2019_COMEDY_59584_61200.csv", index_col = 0)
df_21 = pd.read_csv("incremental/fedra_actors_2019_DRAMA_53217_53500.csv", index_col = 0)
df_22 = pd.read_csv("incremental/fedra_actors_2019_DRAMA_53500_54200.csv", index_col = 0)
df_23 = pd.read_csv("incremental/fedra_actors_2020_ACCION_71203_72200.csv", index_col = 0)
df_24 = pd.read_csv("incremental/fedra_actors_2020_COMEDY_68933_69900.csv", index_col = 0)
df_25 = pd.read_csv("incremental/fedra_actors_2020_DRAMA_63834_64200.csv", index_col = 0)
df_26 = pd.read_csv("incremental/fedra_actors_2020_DRAMA_64200_64800.csv", index_col = 0)

# %%
df_actores = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24,df_25,df_26], axis=0)

# %%
len(df_actores)
# Out:
# 172637

# %%
df_actores.tail()
# Out:
#                     name                                               link
# 4488  Merlisa Determined  ('Merlisa Determined', 'https://www.imdb.com/n...
# 4489          Uche Jombo  ('Uche Jombo', 'https://www.imdb.com/name/nm22...
# 4490         DJ Kelblizz  ('DJ Kelblizz', 'https://www.imdb.com/name/nm1...
# 4491         John Maciag  ('John Maciag', 'https://www.imdb.com/name/nm6...
# 4492     Magdalen Vaughn  ('Magdalen Vaughn', 'https://www.imdb.com/name...

# %%
df_actores.reset_index()
# Out:
#         index                name  \
# 0           0         Sam Spruell
# 1           1           Sean Bean
# 2           2        James D'Arcy
# 3           3       Charles Dance
# 4           4        Rupert Grint
# ...       ...                 ...
# 172632   4488  Merlisa Determined
# 172633   4489          Uche Jombo
# 172634   4490         DJ Kelblizz
# 172635   4491         John Maciag
# 172636   4492     Magdalen Vaughn
#
#                                                      link
# 0       ('Sam Spruell', 'https://www.imdb.com/name/nm0...
# 1       ('Sean Bean', 'https://www.imdb.com/name/nm000...
# 2       ("James D'Arcy", 'https://www.imdb.com/name/nm...
# 3       ('Charles Dance', 'https://www.imdb.com/name/n...
# 4       ('Rupert Grint', 'https://www.imdb.com/name/nm...
# ...                                                   ...
# 172632  ('Merlisa Determined', 'https://www.imdb.com/n...
# 172633  ('Uche Jombo', 'https://www.imdb.com/name/nm22...
# ...

# %%
df_actores.to_csv("extraccion_total_actores_2014_2020.csv")

# %% [markdown]
#     UNION DE EXTRACCION PELICULAS

# %%
df_1 = pd.read_csv("incremental/fedra_films_2014_ACCION_9014_10000.csv", index_col = 0)
df_2 = pd.read_csv("incremental/fedra_films_2014_COMEDY_6019_6500.csv", index_col = 0)
df_3 = pd.read_csv("incremental/fedra_films_2014_COMEDY_6500_6900.csv", index_col = 0)
df_4 = pd.read_csv("incremental/fedra_films_2014_DRAMA_1_1000.csv", index_col = 0)
df_5 = pd.read_csv("incremental/fedra_films_2015_ACCION_19309_20300.csv", index_col = 0)
df_6 = pd.read_csv("incremental/fedra_films_2015_COMEDY_16379_17300.csv", index_col = 0)
df_7 = pd.read_csv("incremental/fedra_films_2015_DRAMA_10188_11100.csv", index_col = 0)
df_8 = pd.read_csv("incremental/fedra_films_2016_ACCION_29904_30900.csv", index_col = 0)
df_9 = pd.read_csv("incremental/fedra_films_2016_COMEDY_26858_27700.csv", index_col = 0)
df_10 = pd.read_csv("incremental/fedra_films_2016_DRAMA_20506_22500.csv", index_col = 0)
df_11 = pd.read_csv("incremental/fedra_films_2017_ACCION_40757_41700.csv", index_col = 0)
df_12 = pd.read_csv("incremental/fedra_films_2017_COMEDY_37686_38600.csv", index_col = 0)
df_13 = pd.read_csv("incremental/fedra_films_2017_DRAMA_31252_32600.csv", index_col = 0)
df_14 = pd.read_csv("incremental/fedra_films_2018_ACCION_51868_52800.csv", index_col = 0)
df_15 = pd.read_csv("incremental/fedra_films_2018_COMEDY_48725_49100.csv", index_col = 0)
df_16 = pd.read_csv("incremental/fedra_films_2018_COMEDY_49100_49700.csv", index_col = 0)
df_17 = pd.read_csv("incremental/fedra_films_2018_DRAMA_42169_42600.csv", index_col = 0)
df_18 = pd.read_csv("incremental/fedra_films_2018_DRAMA42601_43600.csv", index_col = 0)
df_19 = pd.read_csv("incremental/fedra_films_2019_ACCION_62488_63400.csv", index_col = 0)
df_20 = pd.read_csv("incremental/fedra_films_2019_COMEDY_59584_61200.csv", index_col = 0)
df_21 = pd.read_csv("incremental/fedra_films_2019_DRAMA_53217_53500.csv", index_col = 0)
df_22 = pd.read_csv("incremental/fedra_films_2019_DRAMA_53500_54200.csv", index_col = 0)
df_23 = pd.read_csv("incremental/fedra_films_2020_ACCION71203_72200.csv", index_col = 0)
df_24 = pd.read_csv("incremental/fedra_films_2020_COMEDY_68933_69900.csv", index_col = 0)
df_25 = pd.read_csv("incremental/fedra_films_2020_DRAMA_63834_64200.csv", index_col = 0)
df_26 = pd.read_csv("incremental/fedra_films_2020_DRAMA_64200_64800.csv", index_col = 0)

# %%
df_films = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24,df_25,df_26], axis=0)

# %%
len(df_films)
# Out:
# 22531

# %%
df_films.keys()
for k,v in df_films.items():
    
    print(k,len(df_films[k]))
# Out:
# Puntuacion_IMDB 22531
# Dirección 22531
# Guionistas 22531
# Argumento 22531
# Duración 22531
# Nombre de la película 22531

# %%
df_films.tail()
# Out:
#     Puntuacion_IMDB               Dirección  \
# 596             7.6  ['Srinivas Thimmaiah']
# 597             6.0     ['Gokul Hariharan']
# 598              --          ['Emem Isong']
# 599              --             DESCONOCIDO
# 600             8.6             DESCONOCIDO
#
#                                      Guionistas  \
# 596                                 DESCONOCIDO
# 597        ['Santhosh Raja', 'Venkitesh Venki']
# 598  ['Anthony Kehinde Joseph', 'Rita Onwurah']
# 599                                 DESCONOCIDO
# 600                                 DESCONOCIDO
#
#                                              Argumento Duración  \
# 596  Shankar, an auto driver, finds a dog in his ri...   2h 19m
# 597  Stories of two strangers, Kuttiyappan and Giri...       --
# 598  Rachel Hudson was living the life. With a lovi...   1h 25m
# 599                                                NaN   1h 59m
# 600  Synopsis of PACHAI VILAKKU (Green Signal) The ...   2h 38m
#
# ...

# %%
df_films
# Out:
#     Puntuacion_IMDB               Dirección  \
# 0               6.4       ['Vincent Regan']
# 1               6.5         ['Scott Frank']
# 2               3.4         ['Prabhu Deva']
# 3               7.2       ['Antoine Fuqua']
# 4               6.5             DESCONOCIDO
# ..              ...                     ...
# 596             7.6  ['Srinivas Thimmaiah']
# 597             6.0     ['Gokul Hariharan']
# 598              --          ['Emem Isong']
# 599              --             DESCONOCIDO
# 600             8.6             DESCONOCIDO
#
#                                             Guionistas  \
# 0             ['Vincent Regan', 'William Shakespeare']
# 1                    ['Lawrence Block', 'Scott Frank']
# 2                                          DESCONOCIDO
# 3    ['Richard Wenk', 'Michael Sloan', 'Richard Lin...
# 4                                          DESCONOCIDO
# ..                                                 ...
# ...

# %%
df_films.reset_index()
# Out:
#        index Puntuacion_IMDB               Dirección  \
# 0          0             6.4       ['Vincent Regan']
# 1          1             6.5         ['Scott Frank']
# 2          2             3.4         ['Prabhu Deva']
# 3          3             7.2       ['Antoine Fuqua']
# 4          4             6.5             DESCONOCIDO
# ...      ...             ...                     ...
# 22526    596             7.6  ['Srinivas Thimmaiah']
# 22527    597             6.0     ['Gokul Hariharan']
# 22528    598              --          ['Emem Isong']
# 22529    599              --             DESCONOCIDO
# 22530    600             8.6             DESCONOCIDO
#
#                                               Guionistas  \
# 0               ['Vincent Regan', 'William Shakespeare']
# 1                      ['Lawrence Block', 'Scott Frank']
# 2                                            DESCONOCIDO
# 3      ['Richard Wenk', 'Michael Sloan', 'Richard Lin...
# ...

# %%
df_films.to_csv("extraccion_total_pelis_2014_2020.csv")

# %%
df_pelis_2014_2020 = pd.DataFrame(df_films)

# %%
## Convertir en DF Pelis y Actores
df_pelis_2014_2020 = pd.DataFrame(df_films)


df_actores_2014_2020 = pd.Series(df_actores,name="url")
df_actores_2014_2020.index.name="nombre_actor"
df_actores_2014_2020.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13816\2108700444.py in ?()
#       1 ## Convertir en DF Pelis y Actores
#       2
#       3
#       4
# ----> 5 df_actores_2014_2020 = pd.Series(df_actores,name="url")
#       6 df_actores_2014_2020.index.name="nombre_actor"
#       7 df_actores_2014_2020.reset_index()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     532                 data = data.reindex(index, copy=copy)
#     533                 copy = False
#     534                 data = data._mgr
#     535         elif is_dict_like(data):
# --> 536             data, index = self._init_dict(data, index, dtype)
#     537             dtype = None
#     538             copy = False
# ...
