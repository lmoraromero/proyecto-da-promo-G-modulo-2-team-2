# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION
 # 
#cortos del  año 2021: 25024 45354 
# la 23 tirar desde 37001

execution_number = 22
initial_counter = 36501
incremental = 500

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    # driver.maximize_window()
    if accept_cookies:
        sleep(2)
        # Aceptar las cookies PAG IMDB
        driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
        print("cookies accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
        
            try:
                nombre = elemento.find_element("css selector", "span").text
                    
                if nombre == "Dirección":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                    except:
                        directors = "DESCONOCIDO"
                    

                elif nombre == "Guión":
                    
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                    except:
                        scripters = "DESCONOCIDO"
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("INFO_PELIS/cortos_2022.csv")
lista_ID = union_peliculas["ID"].to_list()

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies accepted
# getting url with title/tt22012682...
# url loaded
# Getting attributes for tt22012682
# Getting cast for tt22012682
# time to obtain tt22012682 with position 36501 was 2 seconds
# getting url with title/tt22014894...
# url loaded
# Getting attributes for tt22014894
# Getting cast for tt22014894
# time to obtain tt22014894 with position 36502 was 2 seconds
# getting url with title/tt22015076...
# url loaded
# Getting attributes for tt22015076
# Getting cast for tt22015076
# time to obtain tt22015076 with position 36503 was 2 seconds
# getting url with title/tt22015100...
# url loaded
# Getting attributes for tt22015100
# Getting cast for tt22015100
# time to obtain tt22015100 with position 36504 was 1 seconds
# getting url with title/tt22015046...
# url loaded
# Getting attributes for tt22015046
# Getting cast for tt22015046
# time to obtain tt22015046 with position 36505 was 2 seconds
# getting url with title/tt22015124...
# url loaded
# Getting attributes for tt22015124
# Getting cast for tt22015124
# time to obtain tt22015124 with position 36506 was 2 seconds
# getting url with title/tt22015090...
# url loaded
# Getting attributes for tt22015090
# Getting cast for tt22015090
# time to obtain tt22015090 with position 36507 was 1 seconds
# getting url with title/tt22022288...
# url loaded
# Getting attributes for tt22022288
# Getting cast for tt22022288
# time to obtain tt22022288 with position 36508 was 2 seconds
# getting url with title/tt22019254...
# url loaded
# Getting attributes for tt22019254
# Getting cast for tt22019254
# time to obtain tt22019254 with position 36509 was 2 seconds
# getting url with title/tt22016564...
# url loaded
# Getting attributes for tt22016564
# Getting cast for tt22016564
# time to obtain tt22016564 with position 36510 was 3 seconds
# getting url with title/tt22023274...
# url loaded
# Getting attributes for tt22023274
# Getting cast for tt22023274
# time to obtain tt22023274 with position 36511 was 2 seconds
# getting url with title/tt22024276...
# url loaded
# Getting attributes for tt22024276
# Getting cast for tt22024276
# time to obtain tt22024276 with position 36512 was 2 seconds
# getting url with title/tt22026754...
# url loaded
# Getting attributes for tt22026754
# Getting cast for tt22026754
# time to obtain tt22026754 with position 36513 was 2 seconds
# getting url with title/tt22026920...
# url loaded
# Getting attributes for tt22026920
# Getting cast for tt22026920
# time to obtain tt22026920 with position 36514 was 2 seconds
# getting url with title/tt22022946...
# url loaded
# Getting attributes for tt22022946
# Getting cast for tt22022946
# time to obtain tt22022946 with position 36515 was 2 seconds
# getting url with title/tt22093172...
# url loaded
# Getting attributes for tt22093172
# Getting cast for tt22093172
# time to obtain tt22093172 with position 36516 was 2 seconds
# getting url with title/tt22165176...
# url loaded
# Getting attributes for tt22165176
# Getting cast for tt22165176
# time to obtain tt22165176 with position 36517 was 2 seconds
# getting url with title/tt22168328...
# url loaded
# Getting attributes for tt22168328
# Getting cast for tt22168328
# time to obtain tt22168328 with position 36518 was 2 seconds
# getting url with title/tt22168990...
# url loaded
# Getting attributes for tt22168990
# Getting cast for tt22168990
# time to obtain tt22168990 with position 36519 was 4 seconds
# getting url with title/tt22166294...
# url loaded
# Getting attributes for tt22166294
# Getting cast for tt22166294
# time to obtain tt22166294 with position 36520 was 2 seconds
# getting url with title/tt22171866...
# url loaded
# Getting attributes for tt22171866
# Getting cast for tt22171866
# time to obtain tt22171866 with position 36521 was 3 seconds
# getting url with title/tt22177916...
# url loaded
# Getting attributes for tt22177916
# Getting cast for tt22177916
# time to obtain tt22177916 with position 36522 was 2 seconds
# getting url with title/tt22179778...
# url loaded
# Getting attributes for tt22179778
# Getting cast for tt22179778
# time to obtain tt22179778 with position 36523 was 3 seconds
# getting url with title/tt22182322...
# url loaded
# Getting attributes for tt22182322
# Getting cast for tt22182322
# time to obtain tt22182322 with position 36524 was 4 seconds
# getting url with title/tt22183126...
# url loaded
# Getting attributes for tt22183126
# Getting cast for tt22183126
# time to obtain tt22183126 with position 36525 was 2 seconds
# getting url with title/tt22185046...
# url loaded
# Getting attributes for tt22185046
# Getting cast for tt22185046
# time to obtain tt22185046 with position 36526 was 2 seconds
# getting url with title/tt22186854...
# url loaded
# Getting attributes for tt22186854
# Getting cast for tt22186854
# time to obtain tt22186854 with position 36527 was 3 seconds
# getting url with title/tt22190988...
# url loaded
# Getting attributes for tt22190988
# Getting cast for tt22190988
# time to obtain tt22190988 with position 36528 was 2 seconds
# getting url with title/tt22196368...
# url loaded
# Getting attributes for tt22196368
# Getting cast for tt22196368
# time to obtain tt22196368 with position 36529 was 3 seconds
# getting url with title/tt22196226...
# url loaded
# Getting attributes for tt22196226
# Getting cast for tt22196226
# time to obtain tt22196226 with position 36530 was 8 seconds
# getting url with title/tt22208402...
# url loaded
# Getting attributes for tt22208402
# Getting cast for tt22208402
# time to obtain tt22208402 with position 36531 was 4 seconds
# getting url with title/tt22208396...
# url loaded
# Getting attributes for tt22208396
# Getting cast for tt22208396
# time to obtain tt22208396 with position 36532 was 2 seconds
# getting url with title/tt22236082...
# url loaded
# Getting attributes for tt22236082
# Getting cast for tt22236082
# time to obtain tt22236082 with position 36533 was 4 seconds
# getting url with title/tt22246356...
# url loaded
# Getting attributes for tt22246356
# Getting cast for tt22246356
# time to obtain tt22246356 with position 36534 was 2 seconds
# getting url with title/tt22246748...
# url loaded
# Getting attributes for tt22246748
# Getting cast for tt22246748
# time to obtain tt22246748 with position 36535 was 2 seconds
# getting url with title/tt22208448...
# url loaded
# Getting attributes for tt22208448
# Getting cast for tt22208448
# time to obtain tt22208448 with position 36536 was 3 seconds
# getting url with title/tt22248178...
# url loaded
# Getting attributes for tt22248178
# Getting cast for tt22248178
# time to obtain tt22248178 with position 36537 was 2 seconds
# getting url with title/tt22262646...
# url loaded
# Getting attributes for tt22262646
# Getting cast for tt22262646
# time to obtain tt22262646 with position 36538 was 3 seconds
# getting url with title/tt22262046...
# url loaded
# Getting attributes for tt22262046
# Getting cast for tt22262046
# time to obtain tt22262046 with position 36539 was 4 seconds
# getting url with title/tt22261650...
# url loaded
# Getting attributes for tt22261650
# Getting cast for tt22261650
# time to obtain tt22261650 with position 36540 was 2 seconds
# getting url with title/tt22263268...
# url loaded
# Getting attributes for tt22263268
# Getting cast for tt22263268
# time to obtain tt22263268 with position 36541 was 2 seconds
# getting url with title/tt22264800...
# url loaded
# Getting attributes for tt22264800
# Getting cast for tt22264800
# time to obtain tt22264800 with position 36542 was 2 seconds
# getting url with title/tt22266218...
# url loaded
# Getting attributes for tt22266218
# Getting cast for tt22266218
# time to obtain tt22266218 with position 36543 was 3 seconds
# getting url with title/tt22267704...
# url loaded
# Getting attributes for tt22267704
# Getting cast for tt22267704
# time to obtain tt22267704 with position 36544 was 3 seconds
# getting url with title/tt22295782...
# url loaded
# Getting attributes for tt22295782
# Getting cast for tt22295782
# time to obtain tt22295782 with position 36545 was 5 seconds
# getting url with title/tt22296052...
# url loaded
# Getting attributes for tt22296052
# Getting cast for tt22296052
# time to obtain tt22296052 with position 36546 was 8 seconds
# getting url with title/tt22298234...
# url loaded
# Getting attributes for tt22298234
# Getting cast for tt22298234
# time to obtain tt22298234 with position 36547 was 4 seconds
# getting url with title/tt22298182...
# url loaded
# Getting attributes for tt22298182
# Getting cast for tt22298182
# time to obtain tt22298182 with position 36548 was 5 seconds
# getting url with title/tt22302554...
# url loaded
# Getting attributes for tt22302554
# Getting cast for tt22302554
# time to obtain tt22302554 with position 36549 was 6 seconds
# getting url with title/tt22325798...
# url loaded
# Getting attributes for tt22325798
# Getting cast for tt22325798
# time to obtain tt22325798 with position 36550 was 4 seconds
# getting url with title/tt22331792...
# url loaded
# Getting attributes for tt22331792
# Getting cast for tt22331792
# time to obtain tt22331792 with position 36551 was 3 seconds
# getting url with title/tt22332268...
# url loaded
# Getting attributes for tt22332268
# Getting cast for tt22332268
# time to obtain tt22332268 with position 36552 was 9 seconds
# getting url with title/tt22332570...
# url loaded
# Getting attributes for tt22332570
# Getting cast for tt22332570
# time to obtain tt22332570 with position 36553 was 3 seconds
# getting url with title/tt22334122...
# url loaded
# Getting attributes for tt22334122
# Getting cast for tt22334122
# time to obtain tt22334122 with position 36554 was 7 seconds
# getting url with title/tt22334922...
# url loaded
# Getting attributes for tt22334922
# Getting cast for tt22334922
# time to obtain tt22334922 with position 36555 was 5 seconds
# getting url with title/tt22325876...
# url loaded
# Getting attributes for tt22325876
# Getting cast for tt22325876
# time to obtain tt22325876 with position 36556 was 8 seconds
# getting url with title/tt22376782...
# url loaded
# Getting attributes for tt22376782
# Getting cast for tt22376782
# time to obtain tt22376782 with position 36557 was 4 seconds
# getting url with title/tt22376438...
# url loaded
# Getting attributes for tt22376438
# Getting cast for tt22376438
# time to obtain tt22376438 with position 36558 was 8 seconds
# getting url with title/tt22376048...
# url loaded
# Getting attributes for tt22376048
# Getting cast for tt22376048
# time to obtain tt22376048 with position 36559 was 3 seconds
# getting url with title/tt22394058...
# url loaded
# Getting attributes for tt22394058
# Getting cast for tt22394058
# time to obtain tt22394058 with position 36560 was 5 seconds
# getting url with title/tt22398706...
# url loaded
# Getting attributes for tt22398706
# Getting cast for tt22398706
# time to obtain tt22398706 with position 36561 was 4 seconds
# getting url with title/tt22399558...
# url loaded
# Getting attributes for tt22399558
# Getting cast for tt22399558
# time to obtain tt22399558 with position 36562 was 3 seconds
# getting url with title/tt22410128...
# url loaded
# Getting attributes for tt22410128
# Getting cast for tt22410128
# time to obtain tt22410128 with position 36563 was 6 seconds
# getting url with title/tt22410984...
# url loaded
# Getting attributes for tt22410984
# Getting cast for tt22410984
# time to obtain tt22410984 with position 36564 was 7 seconds
# getting url with title/tt22411120...
# url loaded
# Getting attributes for tt22411120
# Getting cast for tt22411120
# time to obtain tt22411120 with position 36565 was 4 seconds
# getting url with title/tt22435968...
# url loaded
# Getting attributes for tt22435968
# Getting cast for tt22435968
# time to obtain tt22435968 with position 36566 was 3 seconds
# getting url with title/tt22436800...
# url loaded
# Getting attributes for tt22436800
# Getting cast for tt22436800
# time to obtain tt22436800 with position 36567 was 3 seconds
# getting url with title/tt22443806...
# url loaded
# Getting attributes for tt22443806
# Getting cast for tt22443806
# time to obtain tt22443806 with position 36568 was 18 seconds
# getting url with title/tt22444198...
# url loaded
# Getting attributes for tt22444198
# Getting cast for tt22444198
# time to obtain tt22444198 with position 36569 was 3 seconds
# getting url with title/tt22443068...
# url loaded
# Getting attributes for tt22443068
# Getting cast for tt22443068
# time to obtain tt22443068 with position 36570 was 5 seconds
# getting url with title/tt22460856...
# url loaded
# Getting attributes for tt22460856
# Getting cast for tt22460856
# time to obtain tt22460856 with position 36571 was 9 seconds
# getting url with title/tt22463700...
# url loaded
# Getting attributes for tt22463700
# Getting cast for tt22463700
# time to obtain tt22463700 with position 36572 was 3 seconds
# getting url with title/tt22466494...
# url loaded
# Getting attributes for tt22466494
# Getting cast for tt22466494
# time to obtain tt22466494 with position 36573 was 8 seconds
# getting url with title/tt22468186...
# url loaded
# Getting attributes for tt22468186
# Getting cast for tt22468186
# time to obtain tt22468186 with position 36574 was 5 seconds
# getting url with title/tt22468802...
# url loaded
# Getting attributes for tt22468802
# Getting cast for tt22468802
# time to obtain tt22468802 with position 36575 was 3 seconds
# getting url with title/tt22469094...
# url loaded
# Getting attributes for tt22469094
# Getting cast for tt22469094
# time to obtain tt22469094 with position 36576 was 3 seconds
# getting url with title/tt22469152...
# url loaded
# Getting attributes for tt22469152
# Getting cast for tt22469152
# time to obtain tt22469152 with position 36577 was 3 seconds
# getting url with title/tt22469216...
# url loaded
# Getting attributes for tt22469216
# Getting cast for tt22469216
# time to obtain tt22469216 with position 36578 was 7 seconds
# getting url with title/tt22469534...
# url loaded
# Getting attributes for tt22469534
# Getting cast for tt22469534
# time to obtain tt22469534 with position 36579 was 3 seconds
# getting url with title/tt22469396...
# url loaded
# Getting attributes for tt22469396
# Getting cast for tt22469396
# time to obtain tt22469396 with position 36580 was 3 seconds
# getting url with title/tt22477380...
# url loaded
# Getting attributes for tt22477380
# Getting cast for tt22477380
# time to obtain tt22477380 with position 36581 was 3 seconds
# getting url with title/tt22486998...
# url loaded
# Getting attributes for tt22486998
# Getting cast for tt22486998
# time to obtain tt22486998 with position 36582 was 7 seconds
# getting url with title/tt22487212...
# url loaded
# Getting attributes for tt22487212
# Getting cast for tt22487212
# time to obtain tt22487212 with position 36583 was 11 seconds
# getting url with title/tt22487190...
# url loaded
# Getting attributes for tt22487190
# Getting cast for tt22487190
# time to obtain tt22487190 with position 36584 was 2 seconds
# getting url with title/tt22487314...
# url loaded
# Getting attributes for tt22487314
# Getting cast for tt22487314
# time to obtain tt22487314 with position 36585 was 11 seconds
# getting url with title/tt22488338...
# url loaded
# Getting attributes for tt22488338
# Getting cast for tt22488338
# time to obtain tt22488338 with position 36586 was 3 seconds
# getting url with title/tt22487534...
# url loaded
# Getting attributes for tt22487534
# Getting cast for tt22487534
# time to obtain tt22487534 with position 36587 was 3 seconds
# getting url with title/tt22490652...
# url loaded
# Getting attributes for tt22490652
# Getting cast for tt22490652
# time to obtain tt22490652 with position 36588 was 9 seconds
# getting url with title/tt22492162...
# url loaded
# Getting attributes for tt22492162
# Getting cast for tt22492162
# time to obtain tt22492162 with position 36589 was 3 seconds
# getting url with title/tt22495610...
# url loaded
# Getting attributes for tt22495610
# Getting cast for tt22495610
# time to obtain tt22495610 with position 36590 was 7 seconds
# getting url with title/tt22494142...
# url loaded
# Getting attributes for tt22494142
# Getting cast for tt22494142
# time to obtain tt22494142 with position 36591 was 6 seconds
# getting url with title/tt22498450...
# url loaded
# Getting attributes for tt22498450
# Getting cast for tt22498450
# time to obtain tt22498450 with position 36592 was 3 seconds
# getting url with title/tt22498978...
# url loaded
# Getting attributes for tt22498978
# Getting cast for tt22498978
# time to obtain tt22498978 with position 36593 was 4 seconds
# getting url with title/tt22500522...
# url loaded
# Getting attributes for tt22500522
# Getting cast for tt22500522
# time to obtain tt22500522 with position 36594 was 8 seconds
# getting url with title/tt22500650...
# url loaded
# Getting attributes for tt22500650
# Getting cast for tt22500650
# time to obtain tt22500650 with position 36595 was 13 seconds
# getting url with title/tt22503520...
# url loaded
# Getting attributes for tt22503520
# Getting cast for tt22503520
# time to obtain tt22503520 with position 36596 was 4 seconds
# getting url with title/tt22504084...
# url loaded
# Getting attributes for tt22504084
# Getting cast for tt22504084
# time to obtain tt22504084 with position 36597 was 8 seconds
# getting url with title/tt22504910...
# url loaded
# Getting attributes for tt22504910
# Getting cast for tt22504910
# time to obtain tt22504910 with position 36598 was 8 seconds
# getting url with title/tt22498650...
# url loaded
# Getting attributes for tt22498650
# Getting cast for tt22498650
# time to obtain tt22498650 with position 36599 was 8 seconds
# getting url with title/tt22507402...
# url loaded
# Getting attributes for tt22507402
# Getting cast for tt22507402
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt22507402 with position 36600 was 23 seconds
# getting url with title/tt22523744...
# url loaded
# Getting attributes for tt22523744
# Getting cast for tt22523744
# time to obtain tt22523744 with position 36601 was 2 seconds
# getting url with title/tt22524204...
# url loaded
# Getting attributes for tt22524204
# Getting cast for tt22524204
# time to obtain tt22524204 with position 36602 was 2 seconds
# getting url with title/tt22541742...
# url loaded
# Getting attributes for tt22541742
# Getting cast for tt22541742
# time to obtain tt22541742 with position 36603 was 2 seconds
# getting url with title/tt22542012...
# url loaded
# Getting attributes for tt22542012
# Getting cast for tt22542012
# time to obtain tt22542012 with position 36604 was 2 seconds
# getting url with title/tt22530082...
# url loaded
# Getting attributes for tt22530082
# Getting cast for tt22530082
# time to obtain tt22530082 with position 36605 was 2 seconds
# getting url with title/tt22529366...
# url loaded
# Getting attributes for tt22529366
# Getting cast for tt22529366
# time to obtain tt22529366 with position 36606 was 2 seconds
# getting url with title/tt22543282...
# url loaded
# Getting attributes for tt22543282
# Getting cast for tt22543282
# time to obtain tt22543282 with position 36607 was 2 seconds
# getting url with title/tt22641088...
# url loaded
# Getting attributes for tt22641088
# Getting cast for tt22641088
# time to obtain tt22641088 with position 36608 was 2 seconds
# getting url with title/tt22641044...
# url loaded
# Getting attributes for tt22641044
# Getting cast for tt22641044
# time to obtain tt22641044 with position 36609 was 2 seconds
# getting url with title/tt22694558...
# url loaded
# Getting attributes for tt22694558
# Getting cast for tt22694558
# time to obtain tt22694558 with position 36610 was 2 seconds
# getting url with title/tt22694744...
# url loaded
# Getting attributes for tt22694744
# Getting cast for tt22694744
# time to obtain tt22694744 with position 36611 was 2 seconds
# getting url with title/tt22740876...
# url loaded
# Getting attributes for tt22740876
# Getting cast for tt22740876
# time to obtain tt22740876 with position 36612 was 2 seconds
# getting url with title/tt22741016...
# url loaded
# Getting attributes for tt22741016
# Getting cast for tt22741016
# time to obtain tt22741016 with position 36613 was 2 seconds
# getting url with title/tt22746428...
# url loaded
# Getting attributes for tt22746428
# Getting cast for tt22746428
# time to obtain tt22746428 with position 36614 was 2 seconds
# getting url with title/tt22746426...
# url loaded
# Getting attributes for tt22746426
# Getting cast for tt22746426
# time to obtain tt22746426 with position 36615 was 2 seconds
# getting url with title/tt22751672...
# url loaded
# Getting attributes for tt22751672
# Getting cast for tt22751672
# time to obtain tt22751672 with position 36616 was 2 seconds
# getting url with title/tt22756834...
# url loaded
# Getting attributes for tt22756834
# Getting cast for tt22756834
# time to obtain tt22756834 with position 36617 was 2 seconds
# getting url with title/tt22769230...
# url loaded
# Getting attributes for tt22769230
# Getting cast for tt22769230
# time to obtain tt22769230 with position 36618 was 2 seconds
# getting url with title/tt22774732...
# url loaded
# Getting attributes for tt22774732
# Getting cast for tt22774732
# time to obtain tt22774732 with position 36619 was 2 seconds
# getting url with title/tt22780520...
# url loaded
# Getting attributes for tt22780520
# Getting cast for tt22780520
# time to obtain tt22780520 with position 36620 was 2 seconds
# getting url with title/tt22771586...
# url loaded
# Getting attributes for tt22771586
# Getting cast for tt22771586
# time to obtain tt22771586 with position 36621 was 2 seconds
# getting url with title/tt22782084...
# url loaded
# Getting attributes for tt22782084
# Getting cast for tt22782084
# time to obtain tt22782084 with position 36622 was 2 seconds
# getting url with title/tt22803996...
# url loaded
# Getting attributes for tt22803996
# Getting cast for tt22803996
# time to obtain tt22803996 with position 36623 was 2 seconds
# getting url with title/tt22805480...
# url loaded
# Getting attributes for tt22805480
# Getting cast for tt22805480
# time to obtain tt22805480 with position 36624 was 2 seconds
# getting url with title/tt22814992...
# url loaded
# Getting attributes for tt22814992
# Getting cast for tt22814992
# time to obtain tt22814992 with position 36625 was 3 seconds
# getting url with title/tt22803446...
# url loaded
# Getting attributes for tt22803446
# Getting cast for tt22803446
# time to obtain tt22803446 with position 36626 was 2 seconds
# getting url with title/tt22805048...
# url loaded
# Getting attributes for tt22805048
# Getting cast for tt22805048
# time to obtain tt22805048 with position 36627 was 2 seconds
# getting url with title/tt22803982...
# url loaded
# Getting attributes for tt22803982
# Getting cast for tt22803982
# time to obtain tt22803982 with position 36628 was 3 seconds
# getting url with title/tt22803910...
# url loaded
# Getting attributes for tt22803910
# Getting cast for tt22803910
# time to obtain tt22803910 with position 36629 was 2 seconds
# getting url with title/tt22816840...
# url loaded
# Getting attributes for tt22816840
# Getting cast for tt22816840
# time to obtain tt22816840 with position 36630 was 2 seconds
# getting url with title/tt22819910...
# url loaded
# Getting attributes for tt22819910
# Getting cast for tt22819910
# time to obtain tt22819910 with position 36631 was 2 seconds
# getting url with title/tt22853650...
# url loaded
# Getting attributes for tt22853650
# Getting cast for tt22853650
# time to obtain tt22853650 with position 36632 was 3 seconds
# getting url with title/tt22851528...
# url loaded
# Getting attributes for tt22851528
# Getting cast for tt22851528
# time to obtain tt22851528 with position 36633 was 2 seconds
# getting url with title/tt22854268...
# url loaded
# Getting attributes for tt22854268
# Getting cast for tt22854268
# time to obtain tt22854268 with position 36634 was 2 seconds
# getting url with title/tt22856586...
# url loaded
# Getting attributes for tt22856586
# Getting cast for tt22856586
# time to obtain tt22856586 with position 36635 was 3 seconds
# getting url with title/tt22863128...
# url loaded
# Getting attributes for tt22863128
# Getting cast for tt22863128
# time to obtain tt22863128 with position 36636 was 3 seconds
# getting url with title/tt22864784...
# url loaded
# Getting attributes for tt22864784
# Getting cast for tt22864784
# time to obtain tt22864784 with position 36637 was 2 seconds
# getting url with title/tt22865398...
# url loaded
# Getting attributes for tt22865398
# Getting cast for tt22865398
# time to obtain tt22865398 with position 36638 was 2 seconds
# getting url with title/tt22867212...
# url loaded
# Getting attributes for tt22867212
# Getting cast for tt22867212
# time to obtain tt22867212 with position 36639 was 2 seconds
# getting url with title/tt22867322...
# url loaded
# Getting attributes for tt22867322
# Getting cast for tt22867322
# time to obtain tt22867322 with position 36640 was 2 seconds
# getting url with title/tt22869562...
# url loaded
# Getting attributes for tt22869562
# Getting cast for tt22869562
# time to obtain tt22869562 with position 36641 was 4 seconds
# getting url with title/tt22870962...
# url loaded
# Getting attributes for tt22870962
# Getting cast for tt22870962
# time to obtain tt22870962 with position 36642 was 4 seconds
# getting url with title/tt22871676...
# url loaded
# Getting attributes for tt22871676
# Getting cast for tt22871676
# time to obtain tt22871676 with position 36643 was 2 seconds
# getting url with title/tt22881894...
# url loaded
# Getting attributes for tt22881894
# Getting cast for tt22881894
# time to obtain tt22881894 with position 36644 was 3 seconds
# getting url with title/tt22881938...
# url loaded
# Getting attributes for tt22881938
# Getting cast for tt22881938
# time to obtain tt22881938 with position 36645 was 2 seconds
# getting url with title/tt22872860...
# url loaded
# Getting attributes for tt22872860
# Getting cast for tt22872860
# time to obtain tt22872860 with position 36646 was 2 seconds
# getting url with title/tt22891694...
# url loaded
# Getting attributes for tt22891694
# Getting cast for tt22891694
# time to obtain tt22891694 with position 36647 was 4 seconds
# getting url with title/tt22896754...
# url loaded
# Getting attributes for tt22896754
# Getting cast for tt22896754
# time to obtain tt22896754 with position 36648 was 7 seconds
# getting url with title/tt22898742...
# url loaded
# Getting attributes for tt22898742
# Getting cast for tt22898742
# time to obtain tt22898742 with position 36649 was 6 seconds
# getting url with title/tt22900140...
# url loaded
# Getting attributes for tt22900140
# Getting cast for tt22900140
# time to obtain tt22900140 with position 36650 was 6 seconds
# getting url with title/tt22950172...
# url loaded
# Getting attributes for tt22950172
# error obtaining name for id tt22950172
# Getting cast for tt22950172
# time to obtain tt22950172 with position 36651 was 60 seconds
# getting url with title/tt22986328...
# url loaded
# Getting attributes for tt22986328
# Getting cast for tt22986328
# time to obtain tt22986328 with position 36652 was 2 seconds
# getting url with title/tt22987298...
# url loaded
# Getting attributes for tt22987298
# Getting cast for tt22987298
# time to obtain tt22987298 with position 36653 was 2 seconds
# getting url with title/tt22987746...
# url loaded
# Getting attributes for tt22987746
# Getting cast for tt22987746
# time to obtain tt22987746 with position 36654 was 2 seconds
# getting url with title/tt22987882...
# url loaded
# Getting attributes for tt22987882
# Getting cast for tt22987882
# time to obtain tt22987882 with position 36655 was 2 seconds
# getting url with title/tt23017418...
# url loaded
# Getting attributes for tt23017418
# Getting cast for tt23017418
# time to obtain tt23017418 with position 36656 was 2 seconds
# getting url with title/tt22988384...
# url loaded
# Getting attributes for tt22988384
# Getting cast for tt22988384
# time to obtain tt22988384 with position 36657 was 2 seconds
# getting url with title/tt23028820...
# url loaded
# Getting attributes for tt23028820
# Getting cast for tt23028820
# time to obtain tt23028820 with position 36658 was 2 seconds
# getting url with title/tt23024370...
# url loaded
# Getting attributes for tt23024370
# Getting cast for tt23024370
# time to obtain tt23024370 with position 36659 was 2 seconds
# getting url with title/tt23027696...
# url loaded
# Getting attributes for tt23027696
# Getting cast for tt23027696
# time to obtain tt23027696 with position 36660 was 2 seconds
# getting url with title/tt23031216...
# url loaded
# Getting attributes for tt23031216
# Getting cast for tt23031216
# time to obtain tt23031216 with position 36661 was 2 seconds
# getting url with title/tt23036992...
# url loaded
# Getting attributes for tt23036992
# Getting cast for tt23036992
# time to obtain tt23036992 with position 36662 was 2 seconds
# getting url with title/tt23037840...
# url loaded
# Getting attributes for tt23037840
# Getting cast for tt23037840
# time to obtain tt23037840 with position 36663 was 2 seconds
# getting url with title/tt23034520...
# url loaded
# Getting attributes for tt23034520
# Getting cast for tt23034520
# time to obtain tt23034520 with position 36664 was 2 seconds
# getting url with title/tt23036476...
# url loaded
# Getting attributes for tt23036476
# Getting cast for tt23036476
# time to obtain tt23036476 with position 36665 was 2 seconds
# getting url with title/tt23036628...
# url loaded
# Getting attributes for tt23036628
# Getting cast for tt23036628
# time to obtain tt23036628 with position 36666 was 2 seconds
# getting url with title/tt23050334...
# url loaded
# Getting attributes for tt23050334
# Getting cast for tt23050334
# time to obtain tt23050334 with position 36667 was 2 seconds
# getting url with title/tt23056748...
# url loaded
# Getting attributes for tt23056748
# Getting cast for tt23056748
# time to obtain tt23056748 with position 36668 was 3 seconds
# getting url with title/tt23057154...
# url loaded
# Getting attributes for tt23057154
# Getting cast for tt23057154
# time to obtain tt23057154 with position 36669 was 2 seconds
# getting url with title/tt23051794...
# url loaded
# Getting attributes for tt23051794
# Getting cast for tt23051794
# time to obtain tt23051794 with position 36670 was 2 seconds
# getting url with title/tt23055248...
# url loaded
# Getting attributes for tt23055248
# Getting cast for tt23055248
# time to obtain tt23055248 with position 36671 was 2 seconds
# getting url with title/tt23058556...
# url loaded
# Getting attributes for tt23058556
# Getting cast for tt23058556
# time to obtain tt23058556 with position 36672 was 3 seconds
# getting url with title/tt23060090...
# url loaded
# Getting attributes for tt23060090
# Getting cast for tt23060090
# time to obtain tt23060090 with position 36673 was 2 seconds
# getting url with title/tt23060814...
# url loaded
# Getting attributes for tt23060814
# Getting cast for tt23060814
# time to obtain tt23060814 with position 36674 was 3 seconds
# getting url with title/tt23074332...
# url loaded
# Getting attributes for tt23074332
# Getting cast for tt23074332
# time to obtain tt23074332 with position 36675 was 2 seconds
# getting url with title/tt23111452...
# url loaded
# Getting attributes for tt23111452
# Getting cast for tt23111452
# time to obtain tt23111452 with position 36676 was 2 seconds
# getting url with title/tt23117934...
# url loaded
# Getting attributes for tt23117934
# Getting cast for tt23117934
# time to obtain tt23117934 with position 36677 was 2 seconds
# getting url with title/tt23131638...
# url loaded
# Getting attributes for tt23131638
# Getting cast for tt23131638
# time to obtain tt23131638 with position 36678 was 2 seconds
# getting url with title/tt23135266...
# url loaded
# Getting attributes for tt23135266
# Getting cast for tt23135266
# time to obtain tt23135266 with position 36679 was 3 seconds
# getting url with title/tt23135400...
# url loaded
# Getting attributes for tt23135400
# Getting cast for tt23135400
# time to obtain tt23135400 with position 36680 was 2 seconds
# getting url with title/tt23137120...
# url loaded
# Getting attributes for tt23137120
# Getting cast for tt23137120
# time to obtain tt23137120 with position 36681 was 3 seconds
# getting url with title/tt23138442...
# url loaded
# Getting attributes for tt23138442
# Getting cast for tt23138442
# time to obtain tt23138442 with position 36682 was 2 seconds
# getting url with title/tt23145960...
# url loaded
# Getting attributes for tt23145960
# Getting cast for tt23145960
# time to obtain tt23145960 with position 36683 was 3 seconds
# getting url with title/tt23148780...
# url loaded
# Getting attributes for tt23148780
# Getting cast for tt23148780
# time to obtain tt23148780 with position 36684 was 2 seconds
# getting url with title/tt23160398...
# url loaded
# Getting attributes for tt23160398
# Getting cast for tt23160398
# time to obtain tt23160398 with position 36685 was 3 seconds
# getting url with title/tt23180740...
# url loaded
# Getting attributes for tt23180740
# Getting cast for tt23180740
# time to obtain tt23180740 with position 36686 was 5 seconds
# getting url with title/tt23181622...
# url loaded
# Getting attributes for tt23181622
# Getting cast for tt23181622
# time to obtain tt23181622 with position 36687 was 4 seconds
# getting url with title/tt23182040...
# url loaded
# Getting attributes for tt23182040
# Getting cast for tt23182040
# time to obtain tt23182040 with position 36688 was 3 seconds
# getting url with title/tt23182758...
# url loaded
# Getting attributes for tt23182758
# Getting cast for tt23182758
# time to obtain tt23182758 with position 36689 was 2 seconds
# getting url with title/tt23208098...
# url loaded
# Getting attributes for tt23208098
# Getting cast for tt23208098
# time to obtain tt23208098 with position 36690 was 2 seconds
# getting url with title/tt23218060...
# url loaded
# Getting attributes for tt23218060
# Getting cast for tt23218060
# time to obtain tt23218060 with position 36691 was 2 seconds
# getting url with title/tt23221666...
# url loaded
# Getting attributes for tt23221666
# Getting cast for tt23221666
# time to obtain tt23221666 with position 36692 was 2 seconds
# getting url with title/tt23228472...
# url loaded
# Getting attributes for tt23228472
# Getting cast for tt23228472
# time to obtain tt23228472 with position 36693 was 3 seconds
# getting url with title/tt23312008...
# url loaded
# Getting attributes for tt23312008
# Getting cast for tt23312008
# time to obtain tt23312008 with position 36694 was 2 seconds
# getting url with title/tt23320424...
# url loaded
# Getting attributes for tt23320424
# Getting cast for tt23320424
# time to obtain tt23320424 with position 36695 was 2 seconds
# getting url with title/tt23325768...
# url loaded
# Getting attributes for tt23325768
# Getting cast for tt23325768
# time to obtain tt23325768 with position 36696 was 2 seconds
# getting url with title/tt23326072...
# url loaded
# Getting attributes for tt23326072
# Getting cast for tt23326072
# time to obtain tt23326072 with position 36697 was 2 seconds
# getting url with title/tt23326232...
# url loaded
# Getting attributes for tt23326232
# Getting cast for tt23326232
# time to obtain tt23326232 with position 36698 was 4 seconds
# getting url with title/tt23326528...
# url loaded
# Getting attributes for tt23326528
# Getting cast for tt23326528
# time to obtain tt23326528 with position 36699 was 2 seconds
# getting url with title/tt23328892...
# url loaded
# Getting attributes for tt23328892
# Getting cast for tt23328892
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt23328892 with position 36700 was 11 seconds
# getting url with title/tt23330292...
# url loaded
# Getting attributes for tt23330292
# Getting cast for tt23330292
# time to obtain tt23330292 with position 36701 was 2 seconds
# getting url with title/tt23332286...
# url loaded
# Getting attributes for tt23332286
# Getting cast for tt23332286
# time to obtain tt23332286 with position 36702 was 2 seconds
# getting url with title/tt23350924...
# url loaded
# Getting attributes for tt23350924
# Getting cast for tt23350924
# time to obtain tt23350924 with position 36703 was 2 seconds
# getting url with title/tt23369442...
# url loaded
# Getting attributes for tt23369442
# Getting cast for tt23369442
# time to obtain tt23369442 with position 36704 was 2 seconds
# getting url with title/tt23378624...
# url loaded
# Getting attributes for tt23378624
# Getting cast for tt23378624
# time to obtain tt23378624 with position 36705 was 2 seconds
# getting url with title/tt23395410...
# url loaded
# Getting attributes for tt23395410
# Getting cast for tt23395410
# time to obtain tt23395410 with position 36706 was 2 seconds
# getting url with title/tt23403580...
# url loaded
# Getting attributes for tt23403580
# Getting cast for tt23403580
# time to obtain tt23403580 with position 36707 was 2 seconds
# getting url with title/tt23410130...
# url loaded
# Getting attributes for tt23410130
# Getting cast for tt23410130
# time to obtain tt23410130 with position 36708 was 2 seconds
# getting url with title/tt23455946...
# url loaded
# Getting attributes for tt23455946
# Getting cast for tt23455946
# time to obtain tt23455946 with position 36709 was 2 seconds
# getting url with title/tt23457250...
# url loaded
# Getting attributes for tt23457250
# Getting cast for tt23457250
# time to obtain tt23457250 with position 36710 was 2 seconds
# getting url with title/tt23457344...
# url loaded
# Getting attributes for tt23457344
# Getting cast for tt23457344
# time to obtain tt23457344 with position 36711 was 2 seconds
# getting url with title/tt23460376...
# url loaded
# Getting attributes for tt23460376
# Getting cast for tt23460376
# time to obtain tt23460376 with position 36712 was 2 seconds
# getting url with title/tt23464058...
# url loaded
# Getting attributes for tt23464058
# Getting cast for tt23464058
# time to obtain tt23464058 with position 36713 was 2 seconds
# getting url with title/tt23464734...
# url loaded
# Getting attributes for tt23464734
# Getting cast for tt23464734
# time to obtain tt23464734 with position 36714 was 2 seconds
# getting url with title/tt23469418...
# url loaded
# Getting attributes for tt23469418
# Getting cast for tt23469418
# time to obtain tt23469418 with position 36715 was 3 seconds
# getting url with title/tt23472490...
# url loaded
# Getting attributes for tt23472490
# Getting cast for tt23472490
# time to obtain tt23472490 with position 36716 was 2 seconds
# getting url with title/tt23473966...
# url loaded
# Getting attributes for tt23473966
# Getting cast for tt23473966
# time to obtain tt23473966 with position 36717 was 2 seconds
# getting url with title/tt23477090...
# url loaded
# Getting attributes for tt23477090
# Getting cast for tt23477090
# time to obtain tt23477090 with position 36718 was 2 seconds
# getting url with title/tt23489062...
# url loaded
# Getting attributes for tt23489062
# Getting cast for tt23489062
# time to obtain tt23489062 with position 36719 was 2 seconds
# getting url with title/tt23542388...
# url loaded
# Getting attributes for tt23542388
# Getting cast for tt23542388
# time to obtain tt23542388 with position 36720 was 2 seconds
# getting url with title/tt23544948...
# url loaded
# Getting attributes for tt23544948
# Getting cast for tt23544948
# time to obtain tt23544948 with position 36721 was 5 seconds
# getting url with title/tt23545794...
# url loaded
# Getting attributes for tt23545794
# Getting cast for tt23545794
# time to obtain tt23545794 with position 36722 was 2 seconds
# getting url with title/tt23555140...
# url loaded
# Getting attributes for tt23555140
# Getting cast for tt23555140
# time to obtain tt23555140 with position 36723 was 2 seconds
# getting url with title/tt23555900...
# url loaded
# Getting attributes for tt23555900
# Getting cast for tt23555900
# time to obtain tt23555900 with position 36724 was 2 seconds
# getting url with title/tt23556630...
# url loaded
# Getting attributes for tt23556630
# Getting cast for tt23556630
# time to obtain tt23556630 with position 36725 was 2 seconds
# getting url with title/tt23556680...
# url loaded
# Getting attributes for tt23556680
# Getting cast for tt23556680
# time to obtain tt23556680 with position 36726 was 2 seconds
# getting url with title/tt23558416...
# url loaded
# Getting attributes for tt23558416
# Getting cast for tt23558416
# time to obtain tt23558416 with position 36727 was 2 seconds
# getting url with title/tt23558840...
# url loaded
# Getting attributes for tt23558840
# Getting cast for tt23558840
# time to obtain tt23558840 with position 36728 was 4 seconds
# getting url with title/tt23573258...
# url loaded
# Getting attributes for tt23573258
# Getting cast for tt23573258
# time to obtain tt23573258 with position 36729 was 2 seconds
# getting url with title/tt23575252...
# url loaded
# Getting attributes for tt23575252
# Getting cast for tt23575252
# time to obtain tt23575252 with position 36730 was 3 seconds
# getting url with title/tt23576402...
# url loaded
# Getting attributes for tt23576402
# Getting cast for tt23576402
# time to obtain tt23576402 with position 36731 was 2 seconds
# getting url with title/tt23587912...
# url loaded
# Getting attributes for tt23587912
# Getting cast for tt23587912
# time to obtain tt23587912 with position 36732 was 2 seconds
# getting url with title/tt23623410...
# url loaded
# Getting attributes for tt23623410
# Getting cast for tt23623410
# time to obtain tt23623410 with position 36733 was 2 seconds
# getting url with title/tt23625000...
# url loaded
# Getting attributes for tt23625000
# Getting cast for tt23625000
# time to obtain tt23625000 with position 36734 was 3 seconds
# getting url with title/tt23629990...
# url loaded
# Getting attributes for tt23629990
# Getting cast for tt23629990
# time to obtain tt23629990 with position 36735 was 3 seconds
# getting url with title/tt23633490...
# url loaded
# Getting attributes for tt23633490
# Getting cast for tt23633490
# time to obtain tt23633490 with position 36736 was 2 seconds
# getting url with title/tt23635678...
# url loaded
# Getting attributes for tt23635678
# Getting cast for tt23635678
# time to obtain tt23635678 with position 36737 was 3 seconds
# getting url with title/tt23636112...
# url loaded
# Getting attributes for tt23636112
# Getting cast for tt23636112
# time to obtain tt23636112 with position 36738 was 3 seconds
# getting url with title/tt23640356...
# url loaded
# Getting attributes for tt23640356
# Getting cast for tt23640356
# time to obtain tt23640356 with position 36739 was 3 seconds
# getting url with title/tt23642944...
# url loaded
# Getting attributes for tt23642944
# Getting cast for tt23642944
# time to obtain tt23642944 with position 36740 was 5 seconds
# getting url with title/tt23645290...
# url loaded
# Getting attributes for tt23645290
# Getting cast for tt23645290
# time to obtain tt23645290 with position 36741 was 3 seconds
# getting url with title/tt23646026...
# url loaded
# Getting attributes for tt23646026
# Getting cast for tt23646026
# time to obtain tt23646026 with position 36742 was 7 seconds
# getting url with title/tt23648234...
# url loaded
# Getting attributes for tt23648234
# Getting cast for tt23648234
# time to obtain tt23648234 with position 36743 was 6 seconds
# getting url with title/tt23648504...
# url loaded
# Getting attributes for tt23648504
# Getting cast for tt23648504
# time to obtain tt23648504 with position 36744 was 5 seconds
# getting url with title/tt23648516...
# url loaded
# Getting attributes for tt23648516
# Getting cast for tt23648516
# time to obtain tt23648516 with position 36745 was 3 seconds
# getting url with title/tt23650776...
# url loaded
# Getting attributes for tt23650776
# Getting cast for tt23650776
# time to obtain tt23650776 with position 36746 was 3 seconds
# getting url with title/tt23664088...
# url loaded
# Getting attributes for tt23664088
# Getting cast for tt23664088
# time to obtain tt23664088 with position 36747 was 3 seconds
# getting url with title/tt23664150...
# url loaded
# Getting attributes for tt23664150
# Getting cast for tt23664150
# time to obtain tt23664150 with position 36748 was 7 seconds
# getting url with title/tt23665270...
# url loaded
# Getting attributes for tt23665270
# Getting cast for tt23665270
# time to obtain tt23665270 with position 36749 was 3 seconds
# getting url with title/tt23666702...
# url loaded
# Getting attributes for tt23666702
# Getting cast for tt23666702
# time to obtain tt23666702 with position 36750 was 4 seconds
# getting url with title/tt23694806...
# url loaded
# Getting attributes for tt23694806
# Getting cast for tt23694806
# time to obtain tt23694806 with position 36751 was 5 seconds
# getting url with title/tt23699456...
# url loaded
# Getting attributes for tt23699456
# Getting cast for tt23699456
# time to obtain tt23699456 with position 36752 was 3 seconds
# getting url with title/tt23709266...
# url loaded
# Getting attributes for tt23709266
# Getting cast for tt23709266
# time to obtain tt23709266 with position 36753 was 5 seconds
# getting url with title/tt23709626...
# url loaded
# Getting attributes for tt23709626
# Getting cast for tt23709626
# time to obtain tt23709626 with position 36754 was 3 seconds
# getting url with title/tt23726606...
# url loaded
# Getting attributes for tt23726606
# Getting cast for tt23726606
# time to obtain tt23726606 with position 36755 was 2 seconds
# getting url with title/tt23728208...
# url loaded
# Getting attributes for tt23728208
# Getting cast for tt23728208
# time to obtain tt23728208 with position 36756 was 9 seconds
# getting url with title/tt23729350...
# url loaded
# Getting attributes for tt23729350
# Getting cast for tt23729350
# time to obtain tt23729350 with position 36757 was 6 seconds
# getting url with title/tt23732868...
# url loaded
# Getting attributes for tt23732868
# Getting cast for tt23732868
# time to obtain tt23732868 with position 36758 was 4 seconds
# getting url with title/tt23733034...
# url loaded
# Getting attributes for tt23733034
# Getting cast for tt23733034
# time to obtain tt23733034 with position 36759 was 5 seconds
# getting url with title/tt23733174...
# url loaded
# Getting attributes for tt23733174
# Getting cast for tt23733174
# time to obtain tt23733174 with position 36760 was 6 seconds
# getting url with title/tt23736678...
# url loaded
# Getting attributes for tt23736678
# Getting cast for tt23736678
# time to obtain tt23736678 with position 36761 was 12 seconds
# getting url with title/tt23744214...
# url loaded
# Getting attributes for tt23744214
# Getting cast for tt23744214
# time to obtain tt23744214 with position 36762 was 3 seconds
# getting url with title/tt23746902...
# url loaded
# Getting attributes for tt23746902
# Getting cast for tt23746902
# time to obtain tt23746902 with position 36763 was 6 seconds
# getting url with title/tt23750632...
# url loaded
# Getting attributes for tt23750632
# Getting cast for tt23750632
# time to obtain tt23750632 with position 36764 was 4 seconds
# getting url with title/tt23751708...
# url loaded
# Getting attributes for tt23751708
# Getting cast for tt23751708
# time to obtain tt23751708 with position 36765 was 4 seconds
# getting url with title/tt23751816...
# url loaded
# Getting attributes for tt23751816
# Getting cast for tt23751816
# time to obtain tt23751816 with position 36766 was 3 seconds
# getting url with title/tt23769150...
# url loaded
# Getting attributes for tt23769150
# Getting cast for tt23769150
# time to obtain tt23769150 with position 36767 was 7 seconds
# getting url with title/tt23769312...
# url loaded
# Getting attributes for tt23769312
# Getting cast for tt23769312
# time to obtain tt23769312 with position 36768 was 12 seconds
# getting url with title/tt23769350...
# url loaded
# Getting attributes for tt23769350
# Getting cast for tt23769350
# time to obtain tt23769350 with position 36769 was 12 seconds
# getting url with title/tt23770832...
# url loaded
# Getting attributes for tt23770832
# Getting cast for tt23770832
# time to obtain tt23770832 with position 36770 was 4 seconds
# getting url with title/tt23777140...
# url loaded
# Getting attributes for tt23777140
# Getting cast for tt23777140
# time to obtain tt23777140 with position 36771 was 11 seconds
# getting url with title/tt23778110...
# url loaded
# Getting attributes for tt23778110
# Getting cast for tt23778110
# time to obtain tt23778110 with position 36772 was 8 seconds
# getting url with title/tt23779946...
# url loaded
# Getting attributes for tt23779946
# Getting cast for tt23779946
# time to obtain tt23779946 with position 36773 was 3 seconds
# getting url with title/tt23781210...
# url loaded
# Getting attributes for tt23781210
# Getting cast for tt23781210
# time to obtain tt23781210 with position 36774 was 8 seconds
# getting url with title/tt23782234...
# url loaded
# Getting attributes for tt23782234
# Getting cast for tt23782234
# time to obtain tt23782234 with position 36775 was 4 seconds
# getting url with title/tt23785222...
# url loaded
# Getting attributes for tt23785222
# Getting cast for tt23785222
# time to obtain tt23785222 with position 36776 was 7 seconds
# getting url with title/tt23785780...
# url loaded
# Getting attributes for tt23785780
# Getting cast for tt23785780
# time to obtain tt23785780 with position 36777 was 17 seconds
# getting url with title/tt23801280...
# url loaded
# Getting attributes for tt23801280
# Getting cast for tt23801280
# time to obtain tt23801280 with position 36778 was 4 seconds
# getting url with title/tt23801398...
# url loaded
# Getting attributes for tt23801398
# Getting cast for tt23801398
# time to obtain tt23801398 with position 36779 was 6 seconds
# getting url with title/tt23802262...
# url loaded
# Getting attributes for tt23802262
# Getting cast for tt23802262
# time to obtain tt23802262 with position 36780 was 11 seconds
# getting url with title/tt23829858...
# url loaded
# Getting attributes for tt23829858
# Getting cast for tt23829858
# ...
# Getting cast for tt24577334
# time to obtain tt24577334 with position 36907 was 3 seconds
# getting url with title/tt24579348...
# url loaded
# Getting attributes for tt24579348
# Getting cast for tt24579348
# time to obtain tt24579348 with position 36908 was 2 seconds
# getting url with title/tt24578800...
# url loaded
# Getting attributes for tt24578800
# Getting cast for tt24578800
# time to obtain tt24578800 with position 36909 was 2 seconds
# getting url with title/tt24633884...
# url loaded
# Getting attributes for tt24633884
# Getting cast for tt24633884
# time to obtain tt24633884 with position 36910 was 4 seconds
# getting url with title/tt24637724...
# url loaded
# Getting attributes for tt24637724
# Getting cast for tt24637724
# time to obtain tt24637724 with position 36911 was 2 seconds
# getting url with title/tt24638600...
# url loaded
# Getting attributes for tt24638600
# Getting cast for tt24638600
# time to obtain tt24638600 with position 36912 was 3 seconds
# getting url with title/tt24638672...
# url loaded
# Getting attributes for tt24638672
# Getting cast for tt24638672
# time to obtain tt24638672 with position 36913 was 2 seconds
# getting url with title/tt24638698...
# url loaded
# Getting attributes for tt24638698
# Getting cast for tt24638698
# time to obtain tt24638698 with position 36914 was 2 seconds
# getting url with title/tt24639104...
# url loaded
# Getting attributes for tt24639104
# Getting cast for tt24639104
# time to obtain tt24639104 with position 36915 was 2 seconds
# getting url with title/tt24639384...
# url loaded
# Getting attributes for tt24639384
# Getting cast for tt24639384
# time to obtain tt24639384 with position 36916 was 2 seconds
# getting url with title/tt24653494...
# url loaded
# Getting attributes for tt24653494
# Getting cast for tt24653494
# time to obtain tt24653494 with position 36917 was 2 seconds
# getting url with title/tt24654528...
# url loaded
# Getting attributes for tt24654528
# Getting cast for tt24654528
# time to obtain tt24654528 with position 36918 was 2 seconds
# getting url with title/tt24657180...
# url loaded
# Getting attributes for tt24657180
# Getting cast for tt24657180
# time to obtain tt24657180 with position 36919 was 3 seconds
# getting url with title/tt24666808...
# url loaded
# Getting attributes for tt24666808
# Getting cast for tt24666808
# time to obtain tt24666808 with position 36920 was 2 seconds
# getting url with title/tt24700918...
# url loaded
# Getting attributes for tt24700918
# Getting cast for tt24700918
# time to obtain tt24700918 with position 36921 was 1 seconds
# getting url with title/tt24722306...
# url loaded
# Getting attributes for tt24722306
# Getting cast for tt24722306
# time to obtain tt24722306 with position 36922 was 2 seconds
# getting url with title/tt24765698...
# url loaded
# Getting attributes for tt24765698
# Getting cast for tt24765698
# time to obtain tt24765698 with position 36923 was 2 seconds
# getting url with title/tt24785784...
# url loaded
# Getting attributes for tt24785784
# Getting cast for tt24785784
# time to obtain tt24785784 with position 36924 was 2 seconds
# getting url with title/tt24764644...
# url loaded
# Getting attributes for tt24764644
# Getting cast for tt24764644
# time to obtain tt24764644 with position 36925 was 2 seconds
# getting url with title/tt24787636...
# url loaded
# Getting attributes for tt24787636
# Getting cast for tt24787636
# time to obtain tt24787636 with position 36926 was 2 seconds
# getting url with title/tt24806946...
# url loaded
# Getting attributes for tt24806946
# Getting cast for tt24806946
# time to obtain tt24806946 with position 36927 was 2 seconds
# getting url with title/tt24851470...
# url loaded
# Getting attributes for tt24851470
# Getting cast for tt24851470
# time to obtain tt24851470 with position 36928 was 2 seconds
# getting url with title/tt24852006...
# url loaded
# Getting attributes for tt24852006
# Getting cast for tt24852006
# time to obtain tt24852006 with position 36929 was 2 seconds
# getting url with title/tt24852058...
# url loaded
# Getting attributes for tt24852058
# Getting cast for tt24852058
# time to obtain tt24852058 with position 36930 was 3 seconds
# getting url with title/tt24852096...
# url loaded
# Getting attributes for tt24852096
# Getting cast for tt24852096
# time to obtain tt24852096 with position 36931 was 2 seconds
# getting url with title/tt24821822...
# url loaded
# Getting attributes for tt24821822
# Getting cast for tt24821822
# time to obtain tt24821822 with position 36932 was 4 seconds
# getting url with title/tt24854590...
# url loaded
# Getting attributes for tt24854590
# Getting cast for tt24854590
# time to obtain tt24854590 with position 36933 was 5 seconds
# getting url with title/tt24854744...
# url loaded
# Getting attributes for tt24854744
# Getting cast for tt24854744
# time to obtain tt24854744 with position 36934 was 2 seconds
# getting url with title/tt24862210...
# url loaded
# Getting attributes for tt24862210
# Getting cast for tt24862210
# time to obtain tt24862210 with position 36935 was 3 seconds
# getting url with title/tt24948660...
# url loaded
# Getting attributes for tt24948660
# Getting cast for tt24948660
# time to obtain tt24948660 with position 36936 was 4 seconds
# getting url with title/tt24997838...
# url loaded
# Getting attributes for tt24997838
# Getting cast for tt24997838
# time to obtain tt24997838 with position 36937 was 2 seconds
# getting url with title/tt25134508...
# url loaded
# Getting attributes for tt25134508
# Getting cast for tt25134508
# time to obtain tt25134508 with position 36938 was 2 seconds
# getting url with title/tt25144956...
# url loaded
# Getting attributes for tt25144956
# Getting cast for tt25144956
# time to obtain tt25144956 with position 36939 was 4 seconds
# getting url with title/tt25144964...
# url loaded
# Getting attributes for tt25144964
# Getting cast for tt25144964
# time to obtain tt25144964 with position 36940 was 2 seconds
# getting url with title/tt25145330...
# url loaded
# Getting attributes for tt25145330
# Getting cast for tt25145330
# time to obtain tt25145330 with position 36941 was 3 seconds
# getting url with title/tt25146030...
# url loaded
# Getting attributes for tt25146030
# Getting cast for tt25146030
# time to obtain tt25146030 with position 36942 was 4 seconds
# getting url with title/tt25146946...
# url loaded
# Getting attributes for tt25146946
# Getting cast for tt25146946
# time to obtain tt25146946 with position 36943 was 2 seconds
# getting url with title/tt25148364...
# url loaded
# Getting attributes for tt25148364
# Getting cast for tt25148364
# time to obtain tt25148364 with position 36944 was 6 seconds
# getting url with title/tt25179644...
# url loaded
# Getting attributes for tt25179644
# Getting cast for tt25179644
# time to obtain tt25179644 with position 36945 was 3 seconds
# getting url with title/tt25195760...
# url loaded
# Getting attributes for tt25195760
# Getting cast for tt25195760
# time to obtain tt25195760 with position 36946 was 3 seconds
# getting url with title/tt25245026...
# url loaded
# Getting attributes for tt25245026
# Getting cast for tt25245026
# time to obtain tt25245026 with position 36947 was 4 seconds
# getting url with title/tt25273426...
# url loaded
# Getting attributes for tt25273426
# Getting cast for tt25273426
# time to obtain tt25273426 with position 36948 was 3 seconds
# getting url with title/tt25347988...
# url loaded
# Getting attributes for tt25347988
# Getting cast for tt25347988
# time to obtain tt25347988 with position 36949 was 5 seconds
# getting url with title/tt25352248...
# url loaded
# Getting attributes for tt25352248
# Getting cast for tt25352248
# time to obtain tt25352248 with position 36950 was 4 seconds
# getting url with title/tt25381040...
# url loaded
# Getting attributes for tt25381040
# Getting cast for tt25381040
# time to obtain tt25381040 with position 36951 was 6 seconds
# getting url with title/tt25381178...
# url loaded
# Getting attributes for tt25381178
# Getting cast for tt25381178
# time to obtain tt25381178 with position 36952 was 4 seconds
# getting url with title/tt25381690...
# url loaded
# Getting attributes for tt25381690
# Getting cast for tt25381690
# time to obtain tt25381690 with position 36953 was 3 seconds
# getting url with title/tt25380602...
# url loaded
# Getting attributes for tt25380602
# Getting cast for tt25380602
# time to obtain tt25380602 with position 36954 was 5 seconds
# getting url with title/tt25386248...
# url loaded
# Getting attributes for tt25386248
# Getting cast for tt25386248
# time to obtain tt25386248 with position 36955 was 4 seconds
# getting url with title/tt25386272...
# url loaded
# Getting attributes for tt25386272
# Getting cast for tt25386272
# time to obtain tt25386272 with position 36956 was 3 seconds
# getting url with title/tt25390994...
# url loaded
# Getting attributes for tt25390994
# Getting cast for tt25390994
# time to obtain tt25390994 with position 36957 was 3 seconds
# getting url with title/tt25393024...
# url loaded
# Getting attributes for tt25393024
# Getting cast for tt25393024
# time to obtain tt25393024 with position 36958 was 9 seconds
# getting url with title/tt25393404...
# url loaded
# Getting attributes for tt25393404
# Getting cast for tt25393404
# time to obtain tt25393404 with position 36959 was 3 seconds
# getting url with title/tt25397200...
# url loaded
# Getting attributes for tt25397200
# Getting cast for tt25397200
# time to obtain tt25397200 with position 36960 was 6 seconds
# getting url with title/tt25406990...
# url loaded
# Getting attributes for tt25406990
# Getting cast for tt25406990
# time to obtain tt25406990 with position 36961 was 8 seconds
# getting url with title/tt25438996...
# url loaded
# Getting attributes for tt25438996
# Getting cast for tt25438996
# time to obtain tt25438996 with position 36962 was 3 seconds
# getting url with title/tt25446428...
# url loaded
# Getting attributes for tt25446428
# Getting cast for tt25446428
# time to obtain tt25446428 with position 36963 was 5 seconds
# getting url with title/tt25434606...
# url loaded
# Getting attributes for tt25434606
# Getting cast for tt25434606
# time to obtain tt25434606 with position 36964 was 8 seconds
# getting url with title/tt25503904...
# url loaded
# Getting attributes for tt25503904
# Getting cast for tt25503904
# time to obtain tt25503904 with position 36965 was 7 seconds
# getting url with title/tt25504016...
# url loaded
# Getting attributes for tt25504016
# Getting cast for tt25504016
# time to obtain tt25504016 with position 36966 was 7 seconds
# getting url with title/tt25505076...
# url loaded
# Getting attributes for tt25505076
# Getting cast for tt25505076
# time to obtain tt25505076 with position 36967 was 3 seconds
# getting url with title/tt25505182...
# url loaded
# Getting attributes for tt25505182
# Getting cast for tt25505182
# time to obtain tt25505182 with position 36968 was 7 seconds
# getting url with title/tt25505322...
# url loaded
# Getting attributes for tt25505322
# Getting cast for tt25505322
# time to obtain tt25505322 with position 36969 was 4 seconds
# getting url with title/tt25602856...
# url loaded
# Getting attributes for tt25602856
# Getting cast for tt25602856
# time to obtain tt25602856 with position 36970 was 6 seconds
# getting url with title/tt25607174...
# url loaded
# Getting attributes for tt25607174
# Getting cast for tt25607174
# time to obtain tt25607174 with position 36971 was 3 seconds
# getting url with title/tt25636218...
# url loaded
# Getting attributes for tt25636218
# Getting cast for tt25636218
# time to obtain tt25636218 with position 36972 was 4 seconds
# getting url with title/tt25640412...
# url loaded
# Getting attributes for tt25640412
# Getting cast for tt25640412
# time to obtain tt25640412 with position 36973 was 3 seconds
# getting url with title/tt25708850...
# url loaded
# Getting attributes for tt25708850
# Getting cast for tt25708850
# time to obtain tt25708850 with position 36974 was 3 seconds
# getting url with title/tt25684922...
# url loaded
# Getting attributes for tt25684922
# Getting cast for tt25684922
# time to obtain tt25684922 with position 36975 was 4 seconds
# getting url with title/tt25630924...
# url loaded
# Getting attributes for tt25630924
# Getting cast for tt25630924
# time to obtain tt25630924 with position 36976 was 5 seconds
# getting url with title/tt25727952...
# url loaded
# Getting attributes for tt25727952
# Getting cast for tt25727952
# time to obtain tt25727952 with position 36977 was 3 seconds
# getting url with title/tt25728408...
# url loaded
# Getting attributes for tt25728408
# Getting cast for tt25728408
# time to obtain tt25728408 with position 36978 was 3 seconds
# getting url with title/tt25729360...
# url loaded
# Getting attributes for tt25729360
# Getting cast for tt25729360
# time to obtain tt25729360 with position 36979 was 3 seconds
# getting url with title/tt25730308...
# url loaded
# Getting attributes for tt25730308
# Getting cast for tt25730308
# time to obtain tt25730308 with position 36980 was 8 seconds
# getting url with title/tt25745910...
# url loaded
# Getting attributes for tt25745910
# Getting cast for tt25745910
# time to obtain tt25745910 with position 36981 was 3 seconds
# getting url with title/tt25756420...
# url loaded
# Getting attributes for tt25756420
# Getting cast for tt25756420
# time to obtain tt25756420 with position 36982 was 7 seconds
# getting url with title/tt25756562...
# url loaded
# Getting attributes for tt25756562
# Getting cast for tt25756562
# time to obtain tt25756562 with position 36983 was 8 seconds
# getting url with title/tt25769530...
# url loaded
# Getting attributes for tt25769530
# Getting cast for tt25769530
# time to obtain tt25769530 with position 36984 was 3 seconds
# getting url with title/tt25729902...
# url loaded
# Getting attributes for tt25729902
# Getting cast for tt25729902
# time to obtain tt25729902 with position 36985 was 3 seconds
# getting url with title/tt25755812...
# url loaded
# Getting attributes for tt25755812
# Getting cast for tt25755812
# time to obtain tt25755812 with position 36986 was 3 seconds
# getting url with title/tt25786650...
# url loaded
# Getting attributes for tt25786650
# Getting cast for tt25786650
# time to obtain tt25786650 with position 36987 was 3 seconds
# getting url with title/tt25809068...
# url loaded
# Getting attributes for tt25809068
# Getting cast for tt25809068
# time to obtain tt25809068 with position 36988 was 12 seconds
# getting url with title/tt25810564...
# url loaded
# Getting attributes for tt25810564
# Getting cast for tt25810564
# time to obtain tt25810564 with position 36989 was 5 seconds
# getting url with title/tt25811440...
# url loaded
# Getting attributes for tt25811440
# Getting cast for tt25811440
# time to obtain tt25811440 with position 36990 was 12 seconds
# getting url with title/tt25812222...
# url loaded
# Getting attributes for tt25812222
# Getting cast for tt25812222
# time to obtain tt25812222 with position 36991 was 3 seconds
# getting url with title/tt25812812...
# url loaded
# Getting attributes for tt25812812
# Getting cast for tt25812812
# time to obtain tt25812812 with position 36992 was 8 seconds
# getting url with title/tt25812836...
# url loaded
# Getting attributes for tt25812836
# Getting cast for tt25812836
# time to obtain tt25812836 with position 36993 was 5 seconds
# getting url with title/tt25812876...
# url loaded
# Getting attributes for tt25812876
# Getting cast for tt25812876
# time to obtain tt25812876 with position 36994 was 3 seconds
# getting url with title/tt25813618...
# url loaded
# Getting attributes for tt25813618
# Getting cast for tt25813618
# time to obtain tt25813618 with position 36995 was 3 seconds
# getting url with title/tt25814728...
# url loaded
# Getting attributes for tt25814728
# Getting cast for tt25814728
# time to obtain tt25814728 with position 36996 was 12 seconds
# getting url with title/tt25815088...
# url loaded
# Getting attributes for tt25815088
# Getting cast for tt25815088
# time to obtain tt25815088 with position 36997 was 4 seconds
# getting url with title/tt25815250...
# url loaded
# Getting attributes for tt25815250
# Getting cast for tt25815250
# time to obtain tt25815250 with position 36998 was 4 seconds
# getting url with title/tt25815788...
# url loaded
# Getting attributes for tt25815788
# Getting cast for tt25815788
# time to obtain tt25815788 with position 36999 was 9 seconds
# getting url with title/tt25829728...
# url loaded
# Getting attributes for tt25829728
# Getting cast for tt25829728
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt25829728 with position 37000 was 12 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    4.334
# dtype: float64
