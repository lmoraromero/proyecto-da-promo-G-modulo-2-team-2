# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas para manipulación y análisis de datos en Python.
# Importar librerías para web scraping y manipulación de datos

from bs4 import BeautifulSoup
import requests
# Importar librerías para automatización de navegadores web con Selenium

from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
# ChromeDriverManager gestiona la instalación del controlador de Chrome

from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.
# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import random
from datetime import datetime
# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

import warnings
warnings.filterwarnings("ignore")

import os
import json

# %%
# CONFIGURACION

execution_number = 32
initial_counter = 12191
incremental = 1000

# %%
def get_url(driver, path, accept_cookies = False): 

    url = f"https://www.imdb.com/{path}"

    print(f"getting url with {path}...")
    driver.get(url)
    print("url loaded")
    # driver.maximize_window()
    if accept_cookies:
        sleep(1)
        # Aceptar las cookies PAG IMDB
        try:
            driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-dkrFOg.sc-iBYQkv.dcvrLS.ddtuHe.dRCGjd").click()
            print("cookies accepted")
        except:
            print("cookies haven't been accepted")

    return driver

# %%
def getting_name_score(driver, id):
    
    error = None

    #nombre:
    try:
        name = driver.find_element("css selector", 'span[data-testid="hero__primary-text"]').text
    except:
        name = f"Error nombre para la pelicula con id: {id}"
        error = id
                
    #puntuacion:
        
    try: 
        score = driver.find_element("css selector",'div[data-testid="hero-rating-bar__aggregate-rating__score"] > span:first-child').text
                
    except:  
        score = "--"

    return name, score, error

# %%
def getting_directors_scripters(driver):
        directors = "DESCONOCIDO"
        scripters = "DESCONOCIDO"

        for elemento in driver.find_elements("css selector",'li[data-testid="title-pc-principal-credit"]'):
       

            
            
            try:
                nombre = elemento.find_element("css selector", "span").text

                if nombre == "Director":
                

                    # Seleccionar director
                    try:          
                        directors = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]

                    except:
                        directors = "DESCONOCIDO"
             
                    

                elif nombre == "Writers" or nombre == "Writer":
              
                    
                    # Seleccionar Guionista
                    try:          
                        scripters = [e.text for e in elemento.find_elements("css selector",'div > ul > li > a') if e.text != ""]
                   
                    except:
                        scripters = "DESCONOCIDO"
                     
            except:
                continue


        return directors, scripters

# %%
def getting_plot(driver):

    try:      
        return driver.find_element("css selector", 'span[data-testid="plot-xl"]').text
                    
    except:
            
        return "DESCONOCIDO"

# %%
def getting_time(driver):
            
    # Seleccionar DURACION        
    try:   
        
        busqueda_duracion = driver.find_element("css selector",'div.sc-491663c0-3.bdjVSf > div:first-child > ul > li:last-child').text
            
        if "min" in busqueda_duracion or "h" in busqueda_duracion:
            return busqueda_duracion
                
        else:
            return "--"
        
    except:
        
        return "--"

# %%
def getting_cast(driver, dict_actores):
    try:
        for elemento in driver.find_elements("css selector",'section[data-testid="title-cast"]'):
            actor =[e for e in  elemento.find_elements("css selector", "div > div > div > div > a") if e.text != "" and e.text != "\n"]  
            
            for element in actor[0:10]:
            
                nombre = element.text
                    
                if nombre not in dict_actores.keys():
                    
                    dict_actores[nombre]  = element.get_attribute("href")

                    driver.find_element("css selector",'section[data-testid="title-cast"]')
            
    except:
        dict_actores[nombre]  = "desconocido"
    return dict_actores

# %%
INCREMENTAL_PATH = "incremental"
TOTAL_PATH = "total"

options = webdriver.FirefoxOptions()
options.page_load_strategy = "eager"
driver = webdriver.Firefox(options)

driver = get_url(driver, "", True)

films_dict = {"Puntuacion_IMDB":[], "Dirección": [],"Guionistas":[], "Argumento":[], "Duración":[], "Nombre de la película": []}
actors_dict = {}
# diccionario_actores = {"Actor":[], "Fehca_nacimiento":[], "Conocido_por:":[], "Que_hace":[], "Premios":[]}
df_films = pd.DataFrame(films_dict)

errors = 0

times_dict = { "id": [], "time_sec": []}

counter = initial_counter
last_checkpoint = None
ids_with_error = []

union_peliculas = pd.read_csv("../INFO_PELIS/cortos_2023.csv")
lista_ID = union_peliculas["ID"].to_list()

#with open ("peliculas_que_faltan.json", "r") as fichero:
    #lista_ID = json.loads(fichero.read())

for id in lista_ID[counter:counter+incremental]:
    start_time = datetime.now()
    error = True
    while error: 
        try:
            driver = get_url(driver, f"title/{id}")

            error = False
        except:
            print(f"Error getting {id}")
            if errors > 10:
                print(f"Fatal error")
                break
            errors += 1
            sleep(random.randint(2,20))

    errors = 0
    # sleep(1)
    print(f"Getting attributes for {id}")
    name, score, error_id = getting_name_score(driver, id)
    if error_id:
        print(f"error obtaining name for id {id}")
        ids_with_error.append(error_id)
    films_dict["Nombre de la película"].append(name)
    films_dict["Puntuacion_IMDB"].append(score)
    directors, scripters = getting_directors_scripters(driver)
    films_dict["Dirección"].append(directors)
    films_dict["Guionistas"].append(scripters)
    films_dict["Argumento"].append(getting_plot(driver))
    films_dict["Duración"].append(getting_time(driver))
    print(f"Getting cast for {id}")
    actors_dict = getting_cast(driver, actors_dict)

    if counter % 100 == 0:
        print("Saving checkpoint...")
        df_films = pd.DataFrame(films_dict)
        df_films.to_csv(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{counter}.csv")
        df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
        df_actors.to_csv(f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{counter}.csv")
        if last_checkpoint:
            os.remove(f"{INCREMENTAL_PATH}/patri_films_{initial_counter}_{last_checkpoint}.csv")
            os.remove((f"{INCREMENTAL_PATH}/patri_actors_{initial_counter}_{last_checkpoint}.csv"))
        last_checkpoint = counter
        driver.close()
        driver = webdriver.Firefox(options)
        driver = get_url(driver, "", True)
    
    counter += 1
    end_time = datetime.now()
    times_dict["id"].append(id)
    times_dict["time_sec"].append((end_time-start_time).seconds)
    print(f"time to obtain {id} with position {counter-1} was {(end_time-start_time).seconds} seconds")
    # break

df_times = pd.DataFrame(times_dict)
df_times.to_csv(f"{TOTAL_PATH}/{execution_number}_times_extraction.csv")
df_films = pd.DataFrame(films_dict)
df_films.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_films_total.csv")
df_actors = pd.DataFrame({"name": actors_dict.keys(), "link": actors_dict.items()})
df_actors.to_csv(f"{TOTAL_PATH}/{execution_number}_patri_actors_total.csv")
with open(f"{TOTAL_PATH}/{execution_number}_ids_with_errors.txt", "w") as file:
    json.dump(ids_with_error, file)
driver.close()
# Out:
# getting url with ...
# url loaded
# cookies haven't been accepted
# getting url with title/tt15077488...
# url loaded
# Getting attributes for tt15077488
# Getting cast for tt15077488
# time to obtain tt15077488 with position 12191 was 3 seconds
# getting url with title/tt18271544...
# url loaded
# Getting attributes for tt18271544
# Getting cast for tt18271544
# time to obtain tt18271544 with position 12192 was 1 seconds
# getting url with title/tt18285490...
# url loaded
# Getting attributes for tt18285490
# Getting cast for tt18285490
# time to obtain tt18285490 with position 12193 was 1 seconds
# getting url with title/tt18797620...
# url loaded
# Getting attributes for tt18797620
# Getting cast for tt18797620
# time to obtain tt18797620 with position 12194 was 2 seconds
# getting url with title/tt19539550...
# url loaded
# Getting attributes for tt19539550
# Getting cast for tt19539550
# time to obtain tt19539550 with position 12195 was 2 seconds
# getting url with title/tt19759382...
# url loaded
# Getting attributes for tt19759382
# Getting cast for tt19759382
# time to obtain tt19759382 with position 12196 was 3 seconds
# getting url with title/tt19816152...
# url loaded
# Getting attributes for tt19816152
# Getting cast for tt19816152
# time to obtain tt19816152 with position 12197 was 2 seconds
# getting url with title/tt20852264...
# url loaded
# Getting attributes for tt20852264
# Getting cast for tt20852264
# time to obtain tt20852264 with position 12198 was 2 seconds
# getting url with title/tt21941516...
# url loaded
# Getting attributes for tt21941516
# Getting cast for tt21941516
# time to obtain tt21941516 with position 12199 was 2 seconds
# getting url with title/tt22796716...
# url loaded
# Getting attributes for tt22796716
# Getting cast for tt22796716
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt22796716 with position 12200 was 8 seconds
# getting url with title/tt23131232...
# url loaded
# Getting attributes for tt23131232
# Getting cast for tt23131232
# time to obtain tt23131232 with position 12201 was 3 seconds
# getting url with title/tt24072316...
# url loaded
# Getting attributes for tt24072316
# Getting cast for tt24072316
# time to obtain tt24072316 with position 12202 was 2 seconds
# getting url with title/tt22083024...
# url loaded
# Getting attributes for tt22083024
# error obtaining name for id tt22083024
# Getting cast for tt22083024
# time to obtain tt22083024 with position 12203 was 1 seconds
# getting url with title/tt25000442...
# url loaded
# Getting attributes for tt25000442
# Getting cast for tt25000442
# time to obtain tt25000442 with position 12204 was 1 seconds
# getting url with title/tt25154062...
# url loaded
# Getting attributes for tt25154062
# Getting cast for tt25154062
# time to obtain tt25154062 with position 12205 was 2 seconds
# getting url with title/tt25165514...
# url loaded
# Getting attributes for tt25165514
# Getting cast for tt25165514
# time to obtain tt25165514 with position 12206 was 2 seconds
# getting url with title/tt25406638...
# url loaded
# Getting attributes for tt25406638
# Getting cast for tt25406638
# time to obtain tt25406638 with position 12207 was 3 seconds
# getting url with title/tt25434578...
# url loaded
# Getting attributes for tt25434578
# Getting cast for tt25434578
# time to obtain tt25434578 with position 12208 was 2 seconds
# getting url with title/tt25574520...
# url loaded
# Getting attributes for tt25574520
# Getting cast for tt25574520
# time to obtain tt25574520 with position 12209 was 2 seconds
# getting url with title/tt25602778...
# url loaded
# Getting attributes for tt25602778
# Getting cast for tt25602778
# time to obtain tt25602778 with position 12210 was 2 seconds
# getting url with title/tt25964474...
# url loaded
# Getting attributes for tt25964474
# Getting cast for tt25964474
# time to obtain tt25964474 with position 12211 was 2 seconds
# getting url with title/tt26082058...
# url loaded
# Getting attributes for tt26082058
# Getting cast for tt26082058
# time to obtain tt26082058 with position 12212 was 2 seconds
# getting url with title/tt26229120...
# url loaded
# Getting attributes for tt26229120
# Getting cast for tt26229120
# time to obtain tt26229120 with position 12213 was 4 seconds
# getting url with title/tt26230284...
# url loaded
# Getting attributes for tt26230284
# Getting cast for tt26230284
# time to obtain tt26230284 with position 12214 was 3 seconds
# getting url with title/tt26242114...
# url loaded
# Getting attributes for tt26242114
# Getting cast for tt26242114
# time to obtain tt26242114 with position 12215 was 2 seconds
# getting url with title/tt26248680...
# url loaded
# Getting attributes for tt26248680
# Getting cast for tt26248680
# time to obtain tt26248680 with position 12216 was 2 seconds
# getting url with title/tt26250152...
# url loaded
# Getting attributes for tt26250152
# Getting cast for tt26250152
# time to obtain tt26250152 with position 12217 was 2 seconds
# getting url with title/tt26254894...
# url loaded
# Getting attributes for tt26254894
# Getting cast for tt26254894
# time to obtain tt26254894 with position 12218 was 3 seconds
# getting url with title/tt26257372...
# url loaded
# Getting attributes for tt26257372
# Getting cast for tt26257372
# time to obtain tt26257372 with position 12219 was 2 seconds
# getting url with title/tt26341389...
# url loaded
# Getting attributes for tt26341389
# Getting cast for tt26341389
# time to obtain tt26341389 with position 12220 was 2 seconds
# getting url with title/tt26345868...
# url loaded
# Getting attributes for tt26345868
# Getting cast for tt26345868
# time to obtain tt26345868 with position 12221 was 2 seconds
# getting url with title/tt26350757...
# url loaded
# Getting attributes for tt26350757
# Getting cast for tt26350757
# time to obtain tt26350757 with position 12222 was 2 seconds
# getting url with title/tt26353328...
# url loaded
# Getting attributes for tt26353328
# Getting cast for tt26353328
# time to obtain tt26353328 with position 12223 was 2 seconds
# getting url with title/tt26424088...
# url loaded
# Getting attributes for tt26424088
# Getting cast for tt26424088
# time to obtain tt26424088 with position 12224 was 1 seconds
# getting url with title/tt26432356...
# url loaded
# Getting attributes for tt26432356
# error obtaining name for id tt26432356
# Getting cast for tt26432356
# time to obtain tt26432356 with position 12225 was 1 seconds
# getting url with title/tt26439701...
# url loaded
# Getting attributes for tt26439701
# Getting cast for tt26439701
# time to obtain tt26439701 with position 12226 was 3 seconds
# getting url with title/tt26441879...
# url loaded
# Getting attributes for tt26441879
# Getting cast for tt26441879
# time to obtain tt26441879 with position 12227 was 3 seconds
# getting url with title/tt26448876...
# url loaded
# Getting attributes for tt26448876
# Getting cast for tt26448876
# time to obtain tt26448876 with position 12228 was 2 seconds
# getting url with title/tt26453383...
# url loaded
# Getting attributes for tt26453383
# Getting cast for tt26453383
# time to obtain tt26453383 with position 12229 was 2 seconds
# getting url with title/tt26457659...
# url loaded
# Getting attributes for tt26457659
# Getting cast for tt26457659
# time to obtain tt26457659 with position 12230 was 2 seconds
# getting url with title/tt26459167...
# url loaded
# Getting attributes for tt26459167
# Getting cast for tt26459167
# time to obtain tt26459167 with position 12231 was 2 seconds
# getting url with title/tt26537239...
# url loaded
# Getting attributes for tt26537239
# Getting cast for tt26537239
# time to obtain tt26537239 with position 12232 was 2 seconds
# getting url with title/tt26537440...
# url loaded
# Getting attributes for tt26537440
# Getting cast for tt26537440
# time to obtain tt26537440 with position 12233 was 2 seconds
# getting url with title/tt26548980...
# url loaded
# Getting attributes for tt26548980
# Getting cast for tt26548980
# time to obtain tt26548980 with position 12234 was 3 seconds
# getting url with title/tt26591235...
# url loaded
# Getting attributes for tt26591235
# Getting cast for tt26591235
# time to obtain tt26591235 with position 12235 was 2 seconds
# getting url with title/tt26593606...
# url loaded
# Getting attributes for tt26593606
# Getting cast for tt26593606
# time to obtain tt26593606 with position 12236 was 2 seconds
# getting url with title/tt26654413...
# url loaded
# Getting attributes for tt26654413
# Getting cast for tt26654413
# time to obtain tt26654413 with position 12237 was 2 seconds
# getting url with title/tt26655820...
# url loaded
# Getting attributes for tt26655820
# Getting cast for tt26655820
# time to obtain tt26655820 with position 12238 was 2 seconds
# getting url with title/tt26658921...
# url loaded
# Getting attributes for tt26658921
# Getting cast for tt26658921
# time to obtain tt26658921 with position 12239 was 3 seconds
# getting url with title/tt26685380...
# url loaded
# Getting attributes for tt26685380
# Getting cast for tt26685380
# time to obtain tt26685380 with position 12240 was 2 seconds
# getting url with title/tt26697266...
# url loaded
# Getting attributes for tt26697266
# Getting cast for tt26697266
# time to obtain tt26697266 with position 12241 was 2 seconds
# getting url with title/tt26731051...
# url loaded
# Getting attributes for tt26731051
# Getting cast for tt26731051
# time to obtain tt26731051 with position 12242 was 2 seconds
# getting url with title/tt26732370...
# url loaded
# Getting attributes for tt26732370
# Getting cast for tt26732370
# time to obtain tt26732370 with position 12243 was 3 seconds
# getting url with title/tt26732808...
# url loaded
# Getting attributes for tt26732808
# Getting cast for tt26732808
# time to obtain tt26732808 with position 12244 was 2 seconds
# getting url with title/tt26736605...
# url loaded
# Getting attributes for tt26736605
# Getting cast for tt26736605
# time to obtain tt26736605 with position 12245 was 2 seconds
# getting url with title/tt26736939...
# url loaded
# Getting attributes for tt26736939
# Getting cast for tt26736939
# time to obtain tt26736939 with position 12246 was 2 seconds
# getting url with title/tt26742543...
# url loaded
# Getting attributes for tt26742543
# Getting cast for tt26742543
# time to obtain tt26742543 with position 12247 was 3 seconds
# getting url with title/tt26742609...
# url loaded
# Getting attributes for tt26742609
# Getting cast for tt26742609
# time to obtain tt26742609 with position 12248 was 2 seconds
# getting url with title/tt26738839...
# url loaded
# Getting attributes for tt26738839
# Getting cast for tt26738839
# time to obtain tt26738839 with position 12249 was 2 seconds
# getting url with title/tt26749149...
# url loaded
# Getting attributes for tt26749149
# Getting cast for tt26749149
# time to obtain tt26749149 with position 12250 was 3 seconds
# getting url with title/tt26750382...
# url loaded
# Getting attributes for tt26750382
# Getting cast for tt26750382
# time to obtain tt26750382 with position 12251 was 2 seconds
# getting url with title/tt26756173...
# url loaded
# Getting attributes for tt26756173
# Getting cast for tt26756173
# time to obtain tt26756173 with position 12252 was 2 seconds
# getting url with title/tt26767867...
# url loaded
# Getting attributes for tt26767867
# Getting cast for tt26767867
# time to obtain tt26767867 with position 12253 was 2 seconds
# getting url with title/tt26771286...
# url loaded
# Getting attributes for tt26771286
# Getting cast for tt26771286
# time to obtain tt26771286 with position 12254 was 2 seconds
# getting url with title/tt26770704...
# url loaded
# Getting attributes for tt26770704
# Getting cast for tt26770704
# time to obtain tt26770704 with position 12255 was 2 seconds
# getting url with title/tt26772542...
# url loaded
# Getting attributes for tt26772542
# Getting cast for tt26772542
# time to obtain tt26772542 with position 12256 was 1 seconds
# getting url with title/tt26775841...
# url loaded
# Getting attributes for tt26775841
# Getting cast for tt26775841
# time to obtain tt26775841 with position 12257 was 4 seconds
# getting url with title/tt26786496...
# url loaded
# Getting attributes for tt26786496
# Getting cast for tt26786496
# time to obtain tt26786496 with position 12258 was 2 seconds
# getting url with title/tt26787235...
# url loaded
# Getting attributes for tt26787235
# Getting cast for tt26787235
# time to obtain tt26787235 with position 12259 was 2 seconds
# getting url with title/tt26796297...
# url loaded
# Getting attributes for tt26796297
# Getting cast for tt26796297
# time to obtain tt26796297 with position 12260 was 2 seconds
# getting url with title/tt26834853...
# url loaded
# Getting attributes for tt26834853
# Getting cast for tt26834853
# time to obtain tt26834853 with position 12261 was 3 seconds
# getting url with title/tt26895227...
# url loaded
# Getting attributes for tt26895227
# Getting cast for tt26895227
# time to obtain tt26895227 with position 12262 was 2 seconds
# getting url with title/tt26908381...
# url loaded
# Getting attributes for tt26908381
# Getting cast for tt26908381
# time to obtain tt26908381 with position 12263 was 4 seconds
# getting url with title/tt26910925...
# url loaded
# Getting attributes for tt26910925
# Getting cast for tt26910925
# time to obtain tt26910925 with position 12264 was 5 seconds
# getting url with title/tt26915305...
# url loaded
# Getting attributes for tt26915305
# Getting cast for tt26915305
# time to obtain tt26915305 with position 12265 was 2 seconds
# getting url with title/tt26920738...
# url loaded
# Getting attributes for tt26920738
# Getting cast for tt26920738
# time to obtain tt26920738 with position 12266 was 2 seconds
# getting url with title/tt26934979...
# url loaded
# Getting attributes for tt26934979
# Getting cast for tt26934979
# time to obtain tt26934979 with position 12267 was 2 seconds
# getting url with title/tt26935760...
# url loaded
# Getting attributes for tt26935760
# Getting cast for tt26935760
# time to obtain tt26935760 with position 12268 was 2 seconds
# getting url with title/tt26936402...
# url loaded
# Getting attributes for tt26936402
# Getting cast for tt26936402
# time to obtain tt26936402 with position 12269 was 2 seconds
# getting url with title/tt26935718...
# url loaded
# Getting attributes for tt26935718
# Getting cast for tt26935718
# time to obtain tt26935718 with position 12270 was 5 seconds
# getting url with title/tt26966203...
# url loaded
# Getting attributes for tt26966203
# Getting cast for tt26966203
# time to obtain tt26966203 with position 12271 was 2 seconds
# getting url with title/tt27031881...
# url loaded
# Getting attributes for tt27031881
# Getting cast for tt27031881
# time to obtain tt27031881 with position 12272 was 2 seconds
# getting url with title/tt27036709...
# url loaded
# Getting attributes for tt27036709
# Getting cast for tt27036709
# time to obtain tt27036709 with position 12273 was 2 seconds
# getting url with title/tt27044108...
# url loaded
# Getting attributes for tt27044108
# Getting cast for tt27044108
# time to obtain tt27044108 with position 12274 was 2 seconds
# getting url with title/tt27047009...
# url loaded
# Getting attributes for tt27047009
# Getting cast for tt27047009
# time to obtain tt27047009 with position 12275 was 3 seconds
# getting url with title/tt27047276...
# url loaded
# Getting attributes for tt27047276
# Getting cast for tt27047276
# time to obtain tt27047276 with position 12276 was 3 seconds
# getting url with title/tt27053946...
# url loaded
# Getting attributes for tt27053946
# Getting cast for tt27053946
# time to obtain tt27053946 with position 12277 was 2 seconds
# getting url with title/tt27078782...
# url loaded
# Getting attributes for tt27078782
# Getting cast for tt27078782
# time to obtain tt27078782 with position 12278 was 2 seconds
# getting url with title/tt27109880...
# url loaded
# Getting attributes for tt27109880
# Getting cast for tt27109880
# time to obtain tt27109880 with position 12279 was 1 seconds
# getting url with title/tt27116294...
# url loaded
# Getting attributes for tt27116294
# error obtaining name for id tt27116294
# Getting cast for tt27116294
# time to obtain tt27116294 with position 12280 was 1 seconds
# getting url with title/tt27116627...
# url loaded
# Getting attributes for tt27116627
# Getting cast for tt27116627
# time to obtain tt27116627 with position 12281 was 3 seconds
# getting url with title/tt27116814...
# url loaded
# Getting attributes for tt27116814
# error obtaining name for id tt27116814
# Getting cast for tt27116814
# time to obtain tt27116814 with position 12282 was 60 seconds
# getting url with title/tt27122280...
# url loaded
# Getting attributes for tt27122280
# Getting cast for tt27122280
# time to obtain tt27122280 with position 12283 was 2 seconds
# getting url with title/tt27122552...
# url loaded
# Getting attributes for tt27122552
# Getting cast for tt27122552
# time to obtain tt27122552 with position 12284 was 2 seconds
# getting url with title/tt27122725...
# url loaded
# Getting attributes for tt27122725
# Getting cast for tt27122725
# time to obtain tt27122725 with position 12285 was 2 seconds
# getting url with title/tt27123692...
# url loaded
# Getting attributes for tt27123692
# Getting cast for tt27123692
# time to obtain tt27123692 with position 12286 was 2 seconds
# getting url with title/tt27128847...
# url loaded
# Getting attributes for tt27128847
# Getting cast for tt27128847
# time to obtain tt27128847 with position 12287 was 2 seconds
# getting url with title/tt27136829...
# url loaded
# Getting attributes for tt27136829
# Getting cast for tt27136829
# time to obtain tt27136829 with position 12288 was 2 seconds
# getting url with title/tt27148244...
# url loaded
# Getting attributes for tt27148244
# Getting cast for tt27148244
# time to obtain tt27148244 with position 12289 was 3 seconds
# getting url with title/tt27156204...
# url loaded
# Getting attributes for tt27156204
# Getting cast for tt27156204
# time to obtain tt27156204 with position 12290 was 4 seconds
# getting url with title/tt27160100...
# url loaded
# Getting attributes for tt27160100
# Getting cast for tt27160100
# time to obtain tt27160100 with position 12291 was 3 seconds
# getting url with title/tt27170866...
# url loaded
# Getting attributes for tt27170866
# Getting cast for tt27170866
# time to obtain tt27170866 with position 12292 was 3 seconds
# getting url with title/tt27172292...
# url loaded
# Getting attributes for tt27172292
# Getting cast for tt27172292
# time to obtain tt27172292 with position 12293 was 7 seconds
# getting url with title/tt27189518...
# url loaded
# Getting attributes for tt27189518
# Getting cast for tt27189518
# time to obtain tt27189518 with position 12294 was 2 seconds
# getting url with title/tt27192010...
# url loaded
# Getting attributes for tt27192010
# Getting cast for tt27192010
# time to obtain tt27192010 with position 12295 was 2 seconds
# getting url with title/tt27194105...
# url loaded
# Getting attributes for tt27194105
# Getting cast for tt27194105
# time to obtain tt27194105 with position 12296 was 2 seconds
# getting url with title/tt27211241...
# url loaded
# Getting attributes for tt27211241
# Getting cast for tt27211241
# time to obtain tt27211241 with position 12297 was 2 seconds
# getting url with title/tt27217796...
# url loaded
# Getting attributes for tt27217796
# Getting cast for tt27217796
# time to obtain tt27217796 with position 12298 was 2 seconds
# getting url with title/tt27232815...
# url loaded
# Getting attributes for tt27232815
# Getting cast for tt27232815
# time to obtain tt27232815 with position 12299 was 2 seconds
# getting url with title/tt27235175...
# url loaded
# Getting attributes for tt27235175
# Getting cast for tt27235175
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies accepted
# time to obtain tt27235175 with position 12300 was 10 seconds
# getting url with title/tt27241498...
# url loaded
# Getting attributes for tt27241498
# Getting cast for tt27241498
# time to obtain tt27241498 with position 12301 was 2 seconds
# getting url with title/tt27244876...
# url loaded
# Getting attributes for tt27244876
# Getting cast for tt27244876
# time to obtain tt27244876 with position 12302 was 2 seconds
# getting url with title/tt27260680...
# url loaded
# Getting attributes for tt27260680
# Getting cast for tt27260680
# time to obtain tt27260680 with position 12303 was 2 seconds
# getting url with title/tt27262301...
# url loaded
# Getting attributes for tt27262301
# Getting cast for tt27262301
# time to obtain tt27262301 with position 12304 was 1 seconds
# getting url with title/tt27302448...
# url loaded
# Getting attributes for tt27302448
# Getting cast for tt27302448
# time to obtain tt27302448 with position 12305 was 2 seconds
# getting url with title/tt27304463...
# url loaded
# Getting attributes for tt27304463
# Getting cast for tt27304463
# time to obtain tt27304463 with position 12306 was 2 seconds
# getting url with title/tt27300797...
# url loaded
# Getting attributes for tt27300797
# Getting cast for tt27300797
# time to obtain tt27300797 with position 12307 was 2 seconds
# getting url with title/tt27324690...
# url loaded
# Getting attributes for tt27324690
# Getting cast for tt27324690
# time to obtain tt27324690 with position 12308 was 2 seconds
# getting url with title/tt27368273...
# url loaded
# Getting attributes for tt27368273
# Getting cast for tt27368273
# time to obtain tt27368273 with position 12309 was 2 seconds
# getting url with title/tt27371611...
# url loaded
# Getting attributes for tt27371611
# Getting cast for tt27371611
# time to obtain tt27371611 with position 12310 was 2 seconds
# getting url with title/tt27372081...
# url loaded
# Getting attributes for tt27372081
# Getting cast for tt27372081
# time to obtain tt27372081 with position 12311 was 2 seconds
# getting url with title/tt27417218...
# url loaded
# Getting attributes for tt27417218
# Getting cast for tt27417218
# time to obtain tt27417218 with position 12312 was 2 seconds
# getting url with title/tt27420123...
# url loaded
# Getting attributes for tt27420123
# Getting cast for tt27420123
# time to obtain tt27420123 with position 12313 was 2 seconds
# getting url with title/tt27426087...
# url loaded
# Getting attributes for tt27426087
# Getting cast for tt27426087
# time to obtain tt27426087 with position 12314 was 2 seconds
# getting url with title/tt27426688...
# url loaded
# Getting attributes for tt27426688
# Getting cast for tt27426688
# time to obtain tt27426688 with position 12315 was 4 seconds
# getting url with title/tt27468137...
# url loaded
# Getting attributes for tt27468137
# Getting cast for tt27468137
# time to obtain tt27468137 with position 12316 was 2 seconds
# getting url with title/tt27470716...
# url loaded
# Getting attributes for tt27470716
# Getting cast for tt27470716
# time to obtain tt27470716 with position 12317 was 2 seconds
# getting url with title/tt27481564...
# url loaded
# Getting attributes for tt27481564
# Getting cast for tt27481564
# time to obtain tt27481564 with position 12318 was 3 seconds
# getting url with title/tt27496889...
# url loaded
# Getting attributes for tt27496889
# Getting cast for tt27496889
# time to obtain tt27496889 with position 12319 was 2 seconds
# getting url with title/tt27499414...
# url loaded
# Getting attributes for tt27499414
# Getting cast for tt27499414
# time to obtain tt27499414 with position 12320 was 3 seconds
# getting url with title/tt27505086...
# url loaded
# Getting attributes for tt27505086
# Getting cast for tt27505086
# time to obtain tt27505086 with position 12321 was 1 seconds
# getting url with title/tt27505327...
# url loaded
# Getting attributes for tt27505327
# Getting cast for tt27505327
# time to obtain tt27505327 with position 12322 was 1 seconds
# getting url with title/tt27517411...
# url loaded
# Getting attributes for tt27517411
# Getting cast for tt27517411
# time to obtain tt27517411 with position 12323 was 2 seconds
# getting url with title/tt27518266...
# url loaded
# Getting attributes for tt27518266
# Getting cast for tt27518266
# time to obtain tt27518266 with position 12324 was 2 seconds
# getting url with title/tt27518509...
# url loaded
# Getting attributes for tt27518509
# Getting cast for tt27518509
# time to obtain tt27518509 with position 12325 was 2 seconds
# getting url with title/tt27519385...
# url loaded
# Getting attributes for tt27519385
# Getting cast for tt27519385
# time to obtain tt27519385 with position 12326 was 3 seconds
# getting url with title/tt27524400...
# url loaded
# Getting attributes for tt27524400
# Getting cast for tt27524400
# time to obtain tt27524400 with position 12327 was 3 seconds
# getting url with title/tt27526865...
# url loaded
# Getting attributes for tt27526865
# Getting cast for tt27526865
# time to obtain tt27526865 with position 12328 was 2 seconds
# getting url with title/tt27529397...
# url loaded
# Getting attributes for tt27529397
# Getting cast for tt27529397
# time to obtain tt27529397 with position 12329 was 2 seconds
# getting url with title/tt27540002...
# url loaded
# Getting attributes for tt27540002
# Getting cast for tt27540002
# time to obtain tt27540002 with position 12330 was 2 seconds
# getting url with title/tt27542429...
# url loaded
# Getting attributes for tt27542429
# Getting cast for tt27542429
# time to obtain tt27542429 with position 12331 was 2 seconds
# getting url with title/tt27559902...
# url loaded
# Getting attributes for tt27559902
# Getting cast for tt27559902
# time to obtain tt27559902 with position 12332 was 2 seconds
# getting url with title/tt27563069...
# url loaded
# Getting attributes for tt27563069
# Getting cast for tt27563069
# time to obtain tt27563069 with position 12333 was 2 seconds
# getting url with title/tt27565550...
# url loaded
# Getting attributes for tt27565550
# Getting cast for tt27565550
# time to obtain tt27565550 with position 12334 was 3 seconds
# getting url with title/tt27566064...
# url loaded
# Getting attributes for tt27566064
# Getting cast for tt27566064
# time to obtain tt27566064 with position 12335 was 2 seconds
# getting url with title/tt27571890...
# url loaded
# Getting attributes for tt27571890
# Getting cast for tt27571890
# time to obtain tt27571890 with position 12336 was 2 seconds
# getting url with title/tt27578438...
# url loaded
# Getting attributes for tt27578438
# Getting cast for tt27578438
# time to obtain tt27578438 with position 12337 was 2 seconds
# getting url with title/tt27579578...
# url loaded
# Getting attributes for tt27579578
# Getting cast for tt27579578
# time to obtain tt27579578 with position 12338 was 4 seconds
# getting url with title/tt27590074...
# url loaded
# Getting attributes for tt27590074
# Getting cast for tt27590074
# time to obtain tt27590074 with position 12339 was 3 seconds
# getting url with title/tt27590598...
# url loaded
# Getting attributes for tt27590598
# Getting cast for tt27590598
# time to obtain tt27590598 with position 12340 was 2 seconds
# getting url with title/tt27598132...
# url loaded
# Getting attributes for tt27598132
# error obtaining name for id tt27598132
# Getting cast for tt27598132
# time to obtain tt27598132 with position 12341 was 60 seconds
# getting url with title/tt27610777...
# url loaded
# Getting attributes for tt27610777
# Getting cast for tt27610777
# time to obtain tt27610777 with position 12342 was 2 seconds
# getting url with title/tt27619894...
# url loaded
# Getting attributes for tt27619894
# Getting cast for tt27619894
# time to obtain tt27619894 with position 12343 was 2 seconds
# getting url with title/tt27625771...
# url loaded
# Getting attributes for tt27625771
# Getting cast for tt27625771
# time to obtain tt27625771 with position 12344 was 2 seconds
# getting url with title/tt27626402...
# url loaded
# Getting attributes for tt27626402
# Getting cast for tt27626402
# time to obtain tt27626402 with position 12345 was 2 seconds
# getting url with title/tt27628950...
# url loaded
# Getting attributes for tt27628950
# Getting cast for tt27628950
# time to obtain tt27628950 with position 12346 was 2 seconds
# getting url with title/tt27629200...
# url loaded
# Getting attributes for tt27629200
# Getting cast for tt27629200
# time to obtain tt27629200 with position 12347 was 3 seconds
# getting url with title/tt27631045...
# url loaded
# Getting attributes for tt27631045
# Getting cast for tt27631045
# time to obtain tt27631045 with position 12348 was 2 seconds
# getting url with title/tt27627655...
# url loaded
# Getting attributes for tt27627655
# Getting cast for tt27627655
# time to obtain tt27627655 with position 12349 was 2 seconds
# getting url with title/tt27620906...
# url loaded
# Getting attributes for tt27620906
# Getting cast for tt27620906
# time to obtain tt27620906 with position 12350 was 2 seconds
# getting url with title/tt27645064...
# url loaded
# Getting attributes for tt27645064
# Getting cast for tt27645064
# time to obtain tt27645064 with position 12351 was 2 seconds
# getting url with title/tt27646872...
# url loaded
# Getting attributes for tt27646872
# Getting cast for tt27646872
# time to obtain tt27646872 with position 12352 was 2 seconds
# getting url with title/tt27648491...
# url loaded
# Getting attributes for tt27648491
# Getting cast for tt27648491
# time to obtain tt27648491 with position 12353 was 2 seconds
# getting url with title/tt27650080...
# url loaded
# Getting attributes for tt27650080
# Getting cast for tt27650080
# time to obtain tt27650080 with position 12354 was 2 seconds
# getting url with title/tt27656458...
# url loaded
# Getting attributes for tt27656458
# Getting cast for tt27656458
# time to obtain tt27656458 with position 12355 was 2 seconds
# getting url with title/tt27658542...
# url loaded
# Getting attributes for tt27658542
# error obtaining name for id tt27658542
# Getting cast for tt27658542
# time to obtain tt27658542 with position 12356 was 2 seconds
# getting url with title/tt27661240...
# url loaded
# Getting attributes for tt27661240
# Getting cast for tt27661240
# time to obtain tt27661240 with position 12357 was 2 seconds
# getting url with title/tt27663080...
# url loaded
# Getting attributes for tt27663080
# Getting cast for tt27663080
# time to obtain tt27663080 with position 12358 was 2 seconds
# getting url with title/tt27663660...
# url loaded
# Getting attributes for tt27663660
# Getting cast for tt27663660
# time to obtain tt27663660 with position 12359 was 2 seconds
# getting url with title/tt27665775...
# url loaded
# Getting attributes for tt27665775
# Getting cast for tt27665775
# time to obtain tt27665775 with position 12360 was 3 seconds
# getting url with title/tt27663967...
# url loaded
# Getting attributes for tt27663967
# Getting cast for tt27663967
# time to obtain tt27663967 with position 12361 was 2 seconds
# getting url with title/tt27670710...
# url loaded
# Getting attributes for tt27670710
# Getting cast for tt27670710
# time to obtain tt27670710 with position 12362 was 2 seconds
# getting url with title/tt27674933...
# url loaded
# Getting attributes for tt27674933
# Getting cast for tt27674933
# time to obtain tt27674933 with position 12363 was 2 seconds
# getting url with title/tt27676293...
# url loaded
# Getting attributes for tt27676293
# Getting cast for tt27676293
# time to obtain tt27676293 with position 12364 was 2 seconds
# getting url with title/tt27676542...
# url loaded
# Getting attributes for tt27676542
# Getting cast for tt27676542
# time to obtain tt27676542 with position 12365 was 1 seconds
# getting url with title/tt27678569...
# url loaded
# Getting attributes for tt27678569
# Getting cast for tt27678569
# time to obtain tt27678569 with position 12366 was 2 seconds
# getting url with title/tt27701474...
# url loaded
# Getting attributes for tt27701474
# Getting cast for tt27701474
# time to obtain tt27701474 with position 12367 was 2 seconds
# getting url with title/tt27711132...
# url loaded
# Getting attributes for tt27711132
# Getting cast for tt27711132
# time to obtain tt27711132 with position 12368 was 2 seconds
# getting url with title/tt27718190...
# url loaded
# Getting attributes for tt27718190
# Getting cast for tt27718190
# time to obtain tt27718190 with position 12369 was 2 seconds
# getting url with title/tt27713940...
# url loaded
# Getting attributes for tt27713940
# Getting cast for tt27713940
# time to obtain tt27713940 with position 12370 was 2 seconds
# getting url with title/tt27728208...
# url loaded
# Getting attributes for tt27728208
# Getting cast for tt27728208
# time to obtain tt27728208 with position 12371 was 2 seconds
# getting url with title/tt27730211...
# url loaded
# Getting attributes for tt27730211
# Getting cast for tt27730211
# time to obtain tt27730211 with position 12372 was 2 seconds
# getting url with title/tt27730369...
# url loaded
# Getting attributes for tt27730369
# Getting cast for tt27730369
# time to obtain tt27730369 with position 12373 was 3 seconds
# getting url with title/tt27453213...
# url loaded
# Getting attributes for tt27453213
# Getting cast for tt27453213
# time to obtain tt27453213 with position 12374 was 2 seconds
# getting url with title/tt27735981...
# url loaded
# Getting attributes for tt27735981
# Getting cast for tt27735981
# time to obtain tt27735981 with position 12375 was 2 seconds
# getting url with title/tt27739054...
# url loaded
# Getting attributes for tt27739054
# Getting cast for tt27739054
# time to obtain tt27739054 with position 12376 was 2 seconds
# getting url with title/tt27743600...
# url loaded
# Getting attributes for tt27743600
# Getting cast for tt27743600
# time to obtain tt27743600 with position 12377 was 2 seconds
# getting url with title/tt27763579...
# url loaded
# Getting attributes for tt27763579
# Getting cast for tt27763579
# time to obtain tt27763579 with position 12378 was 1 seconds
# getting url with title/tt27785058...
# url loaded
# Getting attributes for tt27785058
# Getting cast for tt27785058
# time to obtain tt27785058 with position 12379 was 2 seconds
# getting url with title/tt27791390...
# url loaded
# Getting attributes for tt27791390
# Getting cast for tt27791390
# time to obtain tt27791390 with position 12380 was 2 seconds
# getting url with title/tt27793859...
# url loaded
# Getting attributes for tt27793859
# Getting cast for tt27793859
# time to obtain tt27793859 with position 12381 was 2 seconds
# getting url with title/tt27798935...
# url loaded
# Getting attributes for tt27798935
# Getting cast for tt27798935
# time to obtain tt27798935 with position 12382 was 2 seconds
# getting url with title/tt27806076...
# url loaded
# Getting attributes for tt27806076
# Getting cast for tt27806076
# time to obtain tt27806076 with position 12383 was 2 seconds
# getting url with title/tt27807171...
# url loaded
# Getting attributes for tt27807171
# Getting cast for tt27807171
# time to obtain tt27807171 with position 12384 was 2 seconds
# getting url with title/tt27815805...
# url loaded
# Getting attributes for tt27815805
# error obtaining name for id tt27815805
# Getting cast for tt27815805
# time to obtain tt27815805 with position 12385 was 1 seconds
# getting url with title/tt27816946...
# url loaded
# Getting attributes for tt27816946
# error obtaining name for id tt27816946
# Getting cast for tt27816946
# time to obtain tt27816946 with position 12386 was 1 seconds
# getting url with title/tt27817437...
# url loaded
# Getting attributes for tt27817437
# Getting cast for tt27817437
# time to obtain tt27817437 with position 12387 was 2 seconds
# getting url with title/tt27826529...
# url loaded
# Getting attributes for tt27826529
# Getting cast for tt27826529
# time to obtain tt27826529 with position 12388 was 2 seconds
# getting url with title/tt27828068...
# url loaded
# Getting attributes for tt27828068
# Getting cast for tt27828068
# time to obtain tt27828068 with position 12389 was 2 seconds
# getting url with title/tt27828277...
# url loaded
# Getting attributes for tt27828277
# Getting cast for tt27828277
# time to obtain tt27828277 with position 12390 was 2 seconds
# getting url with title/tt27831242...
# url loaded
# Getting attributes for tt27831242
# Getting cast for tt27831242
# time to obtain tt27831242 with position 12391 was 2 seconds
# getting url with title/tt27831290...
# url loaded
# Getting attributes for tt27831290
# Getting cast for tt27831290
# time to obtain tt27831290 with position 12392 was 2 seconds
# getting url with title/tt27831845...
# url loaded
# Getting attributes for tt27831845
# Getting cast for tt27831845
# time to obtain tt27831845 with position 12393 was 2 seconds
# getting url with title/tt27835975...
# url loaded
# Getting attributes for tt27835975
# Getting cast for tt27835975
# time to obtain tt27835975 with position 12394 was 2 seconds
# getting url with title/tt27838476...
# url loaded
# Getting attributes for tt27838476
# Getting cast for tt27838476
# time to obtain tt27838476 with position 12395 was 2 seconds
# getting url with title/tt27843084...
# url loaded
# Getting attributes for tt27843084
# Getting cast for tt27843084
# time to obtain tt27843084 with position 12396 was 2 seconds
# getting url with title/tt27847637...
# url loaded
# Getting attributes for tt27847637
# Getting cast for tt27847637
# time to obtain tt27847637 with position 12397 was 2 seconds
# getting url with title/tt27850592...
# url loaded
# Getting attributes for tt27850592
# Getting cast for tt27850592
# time to obtain tt27850592 with position 12398 was 3 seconds
# getting url with title/tt27856267...
# url loaded
# Getting attributes for tt27856267
# Getting cast for tt27856267
# time to obtain tt27856267 with position 12399 was 2 seconds
# getting url with title/tt27854635...
# url loaded
# Getting attributes for tt27854635
# Getting cast for tt27854635
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies haven't been accepted
# time to obtain tt27854635 with position 12400 was 9 seconds
# getting url with title/tt27859198...
# url loaded
# Getting attributes for tt27859198
# Getting cast for tt27859198
# time to obtain tt27859198 with position 12401 was 2 seconds
# getting url with title/tt27862344...
# url loaded
# Getting attributes for tt27862344
# Getting cast for tt27862344
# time to obtain tt27862344 with position 12402 was 1 seconds
# getting url with title/tt27862537...
# url loaded
# Getting attributes for tt27862537
# Getting cast for tt27862537
# time to obtain tt27862537 with position 12403 was 2 seconds
# getting url with title/tt27864600...
# url loaded
# Getting attributes for tt27864600
# Getting cast for tt27864600
# time to obtain tt27864600 with position 12404 was 2 seconds
# getting url with title/tt27866599...
# url loaded
# Getting attributes for tt27866599
# Getting cast for tt27866599
# time to obtain tt27866599 with position 12405 was 2 seconds
# getting url with title/tt27866960...
# url loaded
# Getting attributes for tt27866960
# Getting cast for tt27866960
# time to obtain tt27866960 with position 12406 was 2 seconds
# getting url with title/tt27868484...
# url loaded
# Getting attributes for tt27868484
# Getting cast for tt27868484
# time to obtain tt27868484 with position 12407 was 2 seconds
# getting url with title/tt27873747...
# url loaded
# Getting attributes for tt27873747
# Getting cast for tt27873747
# time to obtain tt27873747 with position 12408 was 2 seconds
# getting url with title/tt27873769...
# url loaded
# Getting attributes for tt27873769
# Getting cast for tt27873769
# time to obtain tt27873769 with position 12409 was 1 seconds
# getting url with title/tt27873886...
# url loaded
# Getting attributes for tt27873886
# error obtaining name for id tt27873886
# Getting cast for tt27873886
# time to obtain tt27873886 with position 12410 was 1 seconds
# getting url with title/tt27877106...
# url loaded
# Getting attributes for tt27877106
# Getting cast for tt27877106
# time to obtain tt27877106 with position 12411 was 2 seconds
# getting url with title/tt27878418...
# url loaded
# Getting attributes for tt27878418
# Getting cast for tt27878418
# time to obtain tt27878418 with position 12412 was 2 seconds
# getting url with title/tt27880988...
# url loaded
# Getting attributes for tt27880988
# Getting cast for tt27880988
# time to obtain tt27880988 with position 12413 was 2 seconds
# getting url with title/tt27895641...
# url loaded
# Getting attributes for tt27895641
# Getting cast for tt27895641
# time to obtain tt27895641 with position 12414 was 1 seconds
# getting url with title/tt27898356...
# url loaded
# Getting attributes for tt27898356
# Getting cast for tt27898356
# time to obtain tt27898356 with position 12415 was 2 seconds
# getting url with title/tt27898409...
# url loaded
# Getting attributes for tt27898409
# Getting cast for tt27898409
# time to obtain tt27898409 with position 12416 was 2 seconds
# getting url with title/tt27899474...
# url loaded
# Getting attributes for tt27899474
# Getting cast for tt27899474
# time to obtain tt27899474 with position 12417 was 2 seconds
# getting url with title/tt27901927...
# url loaded
# Getting attributes for tt27901927
# Getting cast for tt27901927
# time to obtain tt27901927 with position 12418 was 3 seconds
# getting url with title/tt27916906...
# url loaded
# Getting attributes for tt27916906
# Getting cast for tt27916906
# time to obtain tt27916906 with position 12419 was 1 seconds
# getting url with title/tt27918534...
# url loaded
# Getting attributes for tt27918534
# Getting cast for tt27918534
# time to obtain tt27918534 with position 12420 was 1 seconds
# getting url with title/tt27921987...
# url loaded
# Getting attributes for tt27921987
# Getting cast for tt27921987
# time to obtain tt27921987 with position 12421 was 1 seconds
# getting url with title/tt27923640...
# url loaded
# Getting attributes for tt27923640
# Getting cast for tt27923640
# time to obtain tt27923640 with position 12422 was 1 seconds
# getting url with title/tt27926233...
# url loaded
# Getting attributes for tt27926233
# Getting cast for tt27926233
# time to obtain tt27926233 with position 12423 was 2 seconds
# getting url with title/tt27802593...
# url loaded
# Getting attributes for tt27802593
# Getting cast for tt27802593
# time to obtain tt27802593 with position 12424 was 2 seconds
# getting url with title/tt27925892...
# url loaded
# Getting attributes for tt27925892
# Getting cast for tt27925892
# time to obtain tt27925892 with position 12425 was 1 seconds
# getting url with title/tt27934961...
# url loaded
# Getting attributes for tt27934961
# Getting cast for tt27934961
# time to obtain tt27934961 with position 12426 was 2 seconds
# getting url with title/tt27952675...
# url loaded
# Getting attributes for tt27952675
# Getting cast for tt27952675
# time to obtain tt27952675 with position 12427 was 3 seconds
# getting url with title/tt27950704...
# url loaded
# Getting attributes for tt27950704
# Getting cast for tt27950704
# time to obtain tt27950704 with position 12428 was 1 seconds
# getting url with title/tt27967980...
# url loaded
# Getting attributes for tt27967980
# Getting cast for tt27967980
# time to obtain tt27967980 with position 12429 was 2 seconds
# getting url with title/tt27975901...
# url loaded
# Getting attributes for tt27975901
# Getting cast for tt27975901
# time to obtain tt27975901 with position 12430 was 3 seconds
# getting url with title/tt27975978...
# url loaded
# Getting attributes for tt27975978
# Getting cast for tt27975978
# time to obtain tt27975978 with position 12431 was 3 seconds
# getting url with title/tt27991460...
# url loaded
# Getting attributes for tt27991460
# Getting cast for tt27991460
# time to obtain tt27991460 with position 12432 was 2 seconds
# getting url with title/tt27994769...
# url loaded
# Getting attributes for tt27994769
# Getting cast for tt27994769
# time to obtain tt27994769 with position 12433 was 2 seconds
# getting url with title/tt27999454...
# url loaded
# Getting attributes for tt27999454
# Getting cast for tt27999454
# time to obtain tt27999454 with position 12434 was 2 seconds
# getting url with title/tt28015206...
# url loaded
# Getting attributes for tt28015206
# error obtaining name for id tt28015206
# Getting cast for tt28015206
# time to obtain tt28015206 with position 12435 was 0 seconds
# getting url with title/tt28020031...
# url loaded
# Getting attributes for tt28020031
# Getting cast for tt28020031
# time to obtain tt28020031 with position 12436 was 3 seconds
# getting url with title/tt28029676...
# url loaded
# Getting attributes for tt28029676
# Getting cast for tt28029676
# time to obtain tt28029676 with position 12437 was 2 seconds
# getting url with title/tt28035198...
# url loaded
# Getting attributes for tt28035198
# Getting cast for tt28035198
# time to obtain tt28035198 with position 12438 was 2 seconds
# getting url with title/tt28035661...
# url loaded
# Getting attributes for tt28035661
# Getting cast for tt28035661
# time to obtain tt28035661 with position 12439 was 2 seconds
# getting url with title/tt27851955...
# url loaded
# Getting attributes for tt27851955
# Getting cast for tt27851955
# time to obtain tt27851955 with position 12440 was 1 seconds
# getting url with title/tt28067644...
# url loaded
# Getting attributes for tt28067644
# Getting cast for tt28067644
# time to obtain tt28067644 with position 12441 was 1 seconds
# getting url with title/tt28078358...
# url loaded
# Getting attributes for tt28078358
# Getting cast for tt28078358
# time to obtain tt28078358 with position 12442 was 2 seconds
# getting url with title/tt28079183...
# url loaded
# Getting attributes for tt28079183
# Getting cast for tt28079183
# time to obtain tt28079183 with position 12443 was 2 seconds
# getting url with title/tt28087833...
# url loaded
# Getting attributes for tt28087833
# Getting cast for tt28087833
# time to obtain tt28087833 with position 12444 was 2 seconds
# getting url with title/tt28087831...
# url loaded
# Getting attributes for tt28087831
# Getting cast for tt28087831
# time to obtain tt28087831 with position 12445 was 2 seconds
# getting url with title/tt28090763...
# url loaded
# Getting attributes for tt28090763
# Getting cast for tt28090763
# time to obtain tt28090763 with position 12446 was 3 seconds
# getting url with title/tt28092565...
# url loaded
# Getting attributes for tt28092565
# Getting cast for tt28092565
# time to obtain tt28092565 with position 12447 was 1 seconds
# getting url with title/tt28099601...
# url loaded
# Getting attributes for tt28099601
# Getting cast for tt28099601
# time to obtain tt28099601 with position 12448 was 2 seconds
# getting url with title/tt28109737...
# url loaded
# Getting attributes for tt28109737
# Getting cast for tt28109737
# time to obtain tt28109737 with position 12449 was 2 seconds
# getting url with title/tt28110028...
# url loaded
# Getting attributes for tt28110028
# Getting cast for tt28110028
# time to obtain tt28110028 with position 12450 was 1 seconds
# getting url with title/tt28114020...
# url loaded
# Getting attributes for tt28114020
# error obtaining name for id tt28114020
# Getting cast for tt28114020
# time to obtain tt28114020 with position 12451 was 60 seconds
# getting url with title/tt28118712...
# url loaded
# Getting attributes for tt28118712
# Getting cast for tt28118712
# time to obtain tt28118712 with position 12452 was 2 seconds
# getting url with title/tt28120698...
# url loaded
# Getting attributes for tt28120698
# Getting cast for tt28120698
# time to obtain tt28120698 with position 12453 was 1 seconds
# getting url with title/tt28138455...
# url loaded
# Getting attributes for tt28138455
# Getting cast for tt28138455
# time to obtain tt28138455 with position 12454 was 2 seconds
# getting url with title/tt28139443...
# url loaded
# Getting attributes for tt28139443
# Getting cast for tt28139443
# time to obtain tt28139443 with position 12455 was 2 seconds
# getting url with title/tt28142807...
# url loaded
# Getting attributes for tt28142807
# Getting cast for tt28142807
# time to obtain tt28142807 with position 12456 was 2 seconds
# getting url with title/tt28150325...
# url loaded
# Getting attributes for tt28150325
# Getting cast for tt28150325
# time to obtain tt28150325 with position 12457 was 2 seconds
# getting url with title/tt28143746...
# url loaded
# Getting attributes for tt28143746
# Getting cast for tt28143746
# time to obtain tt28143746 with position 12458 was 1 seconds
# getting url with title/tt28152810...
# url loaded
# Getting attributes for tt28152810
# Getting cast for tt28152810
# time to obtain tt28152810 with position 12459 was 3 seconds
# getting url with title/tt28153250...
# url loaded
# Getting attributes for tt28153250
# Getting cast for tt28153250
# time to obtain tt28153250 with position 12460 was 2 seconds
# getting url with title/tt28194505...
# url loaded
# Getting attributes for tt28194505
# Getting cast for tt28194505
# time to obtain tt28194505 with position 12461 was 2 seconds
# getting url with title/tt28197732...
# url loaded
# Getting attributes for tt28197732
# Getting cast for tt28197732
# time to obtain tt28197732 with position 12462 was 1 seconds
# getting url with title/tt28219436...
# url loaded
# Getting attributes for tt28219436
# Getting cast for tt28219436
# time to obtain tt28219436 with position 12463 was 2 seconds
# getting url with title/tt28222047...
# url loaded
# Getting attributes for tt28222047
# Getting cast for tt28222047
# time to obtain tt28222047 with position 12464 was 2 seconds
# getting url with title/tt28224628...
# url loaded
# Getting attributes for tt28224628
# Getting cast for tt28224628
# time to obtain tt28224628 with position 12465 was 3 seconds
# getting url with title/tt28226976...
# url loaded
# Getting attributes for tt28226976
# Getting cast for tt28226976
# time to obtain tt28226976 with position 12466 was 4 seconds
# getting url with title/tt28229702...
# url loaded
# Getting attributes for tt28229702
# Getting cast for tt28229702
# time to obtain tt28229702 with position 12467 was 2 seconds
# getting url with title/tt28232856...
# url loaded
# Getting attributes for tt28232856
# Getting cast for tt28232856
# time to obtain tt28232856 with position 12468 was 1 seconds
# ...
# time to obtain tt30428940 with position 12786 was 3 seconds
# getting url with title/tt30443268...
# url loaded
# Getting attributes for tt30443268
# Getting cast for tt30443268
# time to obtain tt30443268 with position 12787 was 2 seconds
# getting url with title/tt30459235...
# url loaded
# Getting attributes for tt30459235
# Getting cast for tt30459235
# time to obtain tt30459235 with position 12788 was 2 seconds
# getting url with title/tt30469388...
# url loaded
# Getting attributes for tt30469388
# Getting cast for tt30469388
# time to obtain tt30469388 with position 12789 was 3 seconds
# getting url with title/tt30469689...
# url loaded
# Getting attributes for tt30469689
# Getting cast for tt30469689
# time to obtain tt30469689 with position 12790 was 2 seconds
# getting url with title/tt30469696...
# url loaded
# Getting attributes for tt30469696
# Getting cast for tt30469696
# time to obtain tt30469696 with position 12791 was 2 seconds
# getting url with title/tt30488494...
# url loaded
# Getting attributes for tt30488494
# Getting cast for tt30488494
# time to obtain tt30488494 with position 12792 was 2 seconds
# getting url with title/tt30490218...
# url loaded
# Getting attributes for tt30490218
# Getting cast for tt30490218
# time to obtain tt30490218 with position 12793 was 2 seconds
# getting url with title/tt30497350...
# url loaded
# Getting attributes for tt30497350
# Getting cast for tt30497350
# time to obtain tt30497350 with position 12794 was 1 seconds
# getting url with title/tt30516194...
# url loaded
# Getting attributes for tt30516194
# Getting cast for tt30516194
# time to obtain tt30516194 with position 12795 was 2 seconds
# getting url with title/tt30523597...
# url loaded
# Getting attributes for tt30523597
# Getting cast for tt30523597
# time to obtain tt30523597 with position 12796 was 2 seconds
# getting url with title/tt30524050...
# url loaded
# Getting attributes for tt30524050
# Getting cast for tt30524050
# time to obtain tt30524050 with position 12797 was 2 seconds
# getting url with title/tt30524279...
# url loaded
# Getting attributes for tt30524279
# Getting cast for tt30524279
# time to obtain tt30524279 with position 12798 was 2 seconds
# getting url with title/tt30526806...
# url loaded
# Getting attributes for tt30526806
# Getting cast for tt30526806
# time to obtain tt30526806 with position 12799 was 2 seconds
# getting url with title/tt30583629...
# url loaded
# Getting attributes for tt30583629
# Getting cast for tt30583629
# Saving checkpoint...
# getting url with ...
# url loaded
# cookies haven't been accepted
# time to obtain tt30583629 with position 12800 was 9 seconds
# getting url with title/tt30597217...
# url loaded
# Getting attributes for tt30597217
# Getting cast for tt30597217
# time to obtain tt30597217 with position 12801 was 2 seconds
# getting url with title/tt30604841...
# url loaded
# Getting attributes for tt30604841
# error obtaining name for id tt30604841
# Getting cast for tt30604841
# time to obtain tt30604841 with position 12802 was 60 seconds
# getting url with title/tt30608433...
# url loaded
# Getting attributes for tt30608433
# Getting cast for tt30608433
# time to obtain tt30608433 with position 12803 was 2 seconds
# getting url with title/tt30608808...
# url loaded
# Getting attributes for tt30608808
# Getting cast for tt30608808
# time to obtain tt30608808 with position 12804 was 3 seconds
# getting url with title/tt30624503...
# url loaded
# Getting attributes for tt30624503
# Getting cast for tt30624503
# time to obtain tt30624503 with position 12805 was 1 seconds
# getting url with title/tt30625305...
# url loaded
# Getting attributes for tt30625305
# Getting cast for tt30625305
# time to obtain tt30625305 with position 12806 was 1 seconds
# getting url with title/tt30629499...
# url loaded
# Getting attributes for tt30629499
# Getting cast for tt30629499
# time to obtain tt30629499 with position 12807 was 1 seconds
# getting url with title/tt30630147...
# url loaded
# Getting attributes for tt30630147
# Getting cast for tt30630147
# time to obtain tt30630147 with position 12808 was 1 seconds
# getting url with title/tt30690747...
# url loaded
# Getting attributes for tt30690747
# Getting cast for tt30690747
# time to obtain tt30690747 with position 12809 was 2 seconds
# getting url with title/tt30691458...
# url loaded
# Getting attributes for tt30691458
# Getting cast for tt30691458
# time to obtain tt30691458 with position 12810 was 1 seconds
# getting url with title/tt30692032...
# url loaded
# Getting attributes for tt30692032
# Getting cast for tt30692032
# time to obtain tt30692032 with position 12811 was 2 seconds
# getting url with title/tt30699053...
# url loaded
# Getting attributes for tt30699053
# Getting cast for tt30699053
# time to obtain tt30699053 with position 12812 was 2 seconds
# getting url with title/tt30702159...
# url loaded
# Getting attributes for tt30702159
# Getting cast for tt30702159
# time to obtain tt30702159 with position 12813 was 2 seconds
# getting url with title/tt30744056...
# url loaded
# Getting attributes for tt30744056
# Getting cast for tt30744056
# time to obtain tt30744056 with position 12814 was 2 seconds
# getting url with title/tt30744101...
# url loaded
# Getting attributes for tt30744101
# Getting cast for tt30744101
# time to obtain tt30744101 with position 12815 was 2 seconds
# getting url with title/tt30744411...
# url loaded
# Getting attributes for tt30744411
# Getting cast for tt30744411
# time to obtain tt30744411 with position 12816 was 2 seconds
# getting url with title/tt30749685...
# url loaded
# Getting attributes for tt30749685
# Getting cast for tt30749685
# time to obtain tt30749685 with position 12817 was 1 seconds
# getting url with title/tt30761265...
# url loaded
# Getting attributes for tt30761265
# Getting cast for tt30761265
# time to obtain tt30761265 with position 12818 was 2 seconds
# getting url with title/tt30761531...
# url loaded
# Getting attributes for tt30761531
# Getting cast for tt30761531
# time to obtain tt30761531 with position 12819 was 2 seconds
# getting url with title/tt30761597...
# url loaded
# Getting attributes for tt30761597
# Getting cast for tt30761597
# time to obtain tt30761597 with position 12820 was 2 seconds
# getting url with title/tt30780721...
# url loaded
# Getting attributes for tt30780721
# Getting cast for tt30780721
# time to obtain tt30780721 with position 12821 was 2 seconds
# getting url with title/tt30797675...
# url loaded
# Getting attributes for tt30797675
# Getting cast for tt30797675
# time to obtain tt30797675 with position 12822 was 3 seconds
# getting url with title/tt30808071...
# url loaded
# Getting attributes for tt30808071
# Getting cast for tt30808071
# time to obtain tt30808071 with position 12823 was 2 seconds
# getting url with title/tt30809258...
# url loaded
# Getting attributes for tt30809258
# Getting cast for tt30809258
# time to obtain tt30809258 with position 12824 was 2 seconds
# getting url with title/tt30810228...
# url loaded
# Getting attributes for tt30810228
# Getting cast for tt30810228
# time to obtain tt30810228 with position 12825 was 2 seconds
# getting url with title/tt30816552...
# url loaded
# Getting attributes for tt30816552
# Getting cast for tt30816552
# time to obtain tt30816552 with position 12826 was 1 seconds
# getting url with title/tt30827520...
# url loaded
# Getting attributes for tt30827520
# Getting cast for tt30827520
# time to obtain tt30827520 with position 12827 was 2 seconds
# getting url with title/tt30834578...
# url loaded
# Getting attributes for tt30834578
# Getting cast for tt30834578
# time to obtain tt30834578 with position 12828 was 2 seconds
# getting url with title/tt30836235...
# url loaded
# Getting attributes for tt30836235
# Getting cast for tt30836235
# time to obtain tt30836235 with position 12829 was 1 seconds
# getting url with title/tt30841246...
# url loaded
# Getting attributes for tt30841246
# Getting cast for tt30841246
# time to obtain tt30841246 with position 12830 was 1 seconds
# getting url with title/tt30842316...
# url loaded
# Getting attributes for tt30842316
# Getting cast for tt30842316
# time to obtain tt30842316 with position 12831 was 2 seconds
# getting url with title/tt30875657...
# url loaded
# Getting attributes for tt30875657
# Getting cast for tt30875657
# time to obtain tt30875657 with position 12832 was 2 seconds
# getting url with title/tt30888408...
# url loaded
# Getting attributes for tt30888408
# Getting cast for tt30888408
# time to obtain tt30888408 with position 12833 was 2 seconds
# getting url with title/tt30928303...
# url loaded
# Getting attributes for tt30928303
# Getting cast for tt30928303
# time to obtain tt30928303 with position 12834 was 2 seconds
# getting url with title/tt30948763...
# url loaded
# Getting attributes for tt30948763
# Getting cast for tt30948763
# time to obtain tt30948763 with position 12835 was 1 seconds
# getting url with title/tt30949094...
# url loaded
# Getting attributes for tt30949094
# Getting cast for tt30949094
# time to obtain tt30949094 with position 12836 was 1 seconds
# getting url with title/tt30949710...
# url loaded
# Getting attributes for tt30949710
# Getting cast for tt30949710
# time to obtain tt30949710 with position 12837 was 2 seconds
# getting url with title/tt30955832...
# url loaded
# Getting attributes for tt30955832
# Getting cast for tt30955832
# time to obtain tt30955832 with position 12838 was 2 seconds
# getting url with title/tt30961534...
# url loaded
# Getting attributes for tt30961534
# Getting cast for tt30961534
# time to obtain tt30961534 with position 12839 was 1 seconds
# getting url with title/tt30982707...
# url loaded
# Getting attributes for tt30982707
# Getting cast for tt30982707
# time to obtain tt30982707 with position 12840 was 3 seconds
# getting url with title/tt30983481...
# url loaded
# Getting attributes for tt30983481
# Getting cast for tt30983481
# time to obtain tt30983481 with position 12841 was 2 seconds
# getting url with title/tt30984517...
# url loaded
# Getting attributes for tt30984517
# Getting cast for tt30984517
# time to obtain tt30984517 with position 12842 was 1 seconds
# getting url with title/tt30985103...
# url loaded
# Getting attributes for tt30985103
# Getting cast for tt30985103
# time to obtain tt30985103 with position 12843 was 1 seconds
# getting url with title/tt30991967...
# url loaded
# Getting attributes for tt30991967
# Getting cast for tt30991967
# time to obtain tt30991967 with position 12844 was 2 seconds
# getting url with title/tt31022531...
# url loaded
# Getting attributes for tt31022531
# Getting cast for tt31022531
# time to obtain tt31022531 with position 12845 was 2 seconds
# getting url with title/tt31023322...
# url loaded
# Getting attributes for tt31023322
# Getting cast for tt31023322
# time to obtain tt31023322 with position 12846 was 2 seconds
# getting url with title/tt31027589...
# url loaded
# Getting attributes for tt31027589
# Getting cast for tt31027589
# time to obtain tt31027589 with position 12847 was 2 seconds
# getting url with title/tt31067036...
# url loaded
# Getting attributes for tt31067036
# Getting cast for tt31067036
# time to obtain tt31067036 with position 12848 was 2 seconds
# getting url with title/tt31067842...
# url loaded
# Getting attributes for tt31067842
# Getting cast for tt31067842
# time to obtain tt31067842 with position 12849 was 2 seconds
# getting url with title/tt31067884...
# url loaded
# Getting attributes for tt31067884
# Getting cast for tt31067884
# time to obtain tt31067884 with position 12850 was 1 seconds
# getting url with title/tt31067905...
# url loaded
# Getting attributes for tt31067905
# Getting cast for tt31067905
# time to obtain tt31067905 with position 12851 was 1 seconds
# getting url with title/tt31068209...
# url loaded
# Getting attributes for tt31068209
# Getting cast for tt31068209
# time to obtain tt31068209 with position 12852 was 1 seconds
# getting url with title/tt31068292...
# url loaded
# Getting attributes for tt31068292
# Getting cast for tt31068292
# time to obtain tt31068292 with position 12853 was 1 seconds
# getting url with title/tt31068286...
# url loaded
# Getting attributes for tt31068286
# Getting cast for tt31068286
# time to obtain tt31068286 with position 12854 was 1 seconds
# getting url with title/tt31068309...
# url loaded
# Getting attributes for tt31068309
# Getting cast for tt31068309
# time to obtain tt31068309 with position 12855 was 2 seconds
# getting url with title/tt31069249...
# url loaded
# Getting attributes for tt31069249
# Getting cast for tt31069249
# time to obtain tt31069249 with position 12856 was 2 seconds
# getting url with title/tt31070697...
# url loaded
# Getting attributes for tt31070697
# Getting cast for tt31070697
# time to obtain tt31070697 with position 12857 was 2 seconds
# getting url with title/tt31083868...
# url loaded
# Getting attributes for tt31083868
# Getting cast for tt31083868
# time to obtain tt31083868 with position 12858 was 2 seconds
# getting url with title/tt31091459...
# url loaded
# Getting attributes for tt31091459
# Getting cast for tt31091459
# time to obtain tt31091459 with position 12859 was 2 seconds
# getting url with title/tt31079329...
# url loaded
# Getting attributes for tt31079329
# Getting cast for tt31079329
# time to obtain tt31079329 with position 12860 was 2 seconds
# getting url with title/tt31101377...
# url loaded
# Getting attributes for tt31101377
# Getting cast for tt31101377
# time to obtain tt31101377 with position 12861 was 2 seconds
# getting url with title/tt31116913...
# url loaded
# Getting attributes for tt31116913
# Getting cast for tt31116913
# time to obtain tt31116913 with position 12862 was 2 seconds
# getting url with title/tt31118373...
# url loaded
# Getting attributes for tt31118373
# Getting cast for tt31118373
# time to obtain tt31118373 with position 12863 was 3 seconds
# getting url with title/tt31157534...
# url loaded
# Getting attributes for tt31157534
# Getting cast for tt31157534
# time to obtain tt31157534 with position 12864 was 2 seconds
# getting url with title/tt31160006...
# url loaded
# Getting attributes for tt31160006
# Getting cast for tt31160006
# time to obtain tt31160006 with position 12865 was 2 seconds
# getting url with title/tt31170667...
# url loaded
# Getting attributes for tt31170667
# Getting cast for tt31170667
# time to obtain tt31170667 with position 12866 was 2 seconds
# getting url with title/tt31172377...
# url loaded
# Getting attributes for tt31172377
# Getting cast for tt31172377
# time to obtain tt31172377 with position 12867 was 3 seconds
# getting url with title/tt31190095...
# url loaded
# Getting attributes for tt31190095
# Getting cast for tt31190095
# time to obtain tt31190095 with position 12868 was 2 seconds
# getting url with title/tt31250440...
# url loaded
# Getting attributes for tt31250440
# Getting cast for tt31250440
# time to obtain tt31250440 with position 12869 was 2 seconds
# getting url with title/tt31250513...
# url loaded
# Getting attributes for tt31250513
# Getting cast for tt31250513
# time to obtain tt31250513 with position 12870 was 1 seconds
# getting url with title/tt31259174...
# url loaded
# Getting attributes for tt31259174
# Getting cast for tt31259174
# time to obtain tt31259174 with position 12871 was 2 seconds
# getting url with title/tt31261535...
# url loaded
# Getting attributes for tt31261535
# Getting cast for tt31261535
# time to obtain tt31261535 with position 12872 was 2 seconds
# getting url with title/tt31313976...
# url loaded
# Getting attributes for tt31313976
# Getting cast for tt31313976
# time to obtain tt31313976 with position 12873 was 2 seconds
# getting url with title/tt31315400...
# url loaded
# Getting attributes for tt31315400
# Getting cast for tt31315400
# time to obtain tt31315400 with position 12874 was 2 seconds
# getting url with title/tt31315919...
# url loaded
# Getting attributes for tt31315919
# Getting cast for tt31315919
# time to obtain tt31315919 with position 12875 was 2 seconds
# getting url with title/tt31316890...
# url loaded
# Getting attributes for tt31316890
# Getting cast for tt31316890
# time to obtain tt31316890 with position 12876 was 2 seconds
# getting url with title/tt31391456...
# url loaded
# Getting attributes for tt31391456
# Getting cast for tt31391456
# time to obtain tt31391456 with position 12877 was 2 seconds
# getting url with title/tt31414648...
# url loaded
# Getting attributes for tt31414648
# Getting cast for tt31414648
# time to obtain tt31414648 with position 12878 was 1 seconds
# getting url with title/tt31434416...
# url loaded
# Getting attributes for tt31434416
# Getting cast for tt31434416
# time to obtain tt31434416 with position 12879 was 1 seconds

# %%
df_times[["time_sec"]].mean()
# Out:
# time_sec    2.703919
# dtype: float64
